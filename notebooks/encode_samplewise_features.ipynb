# %% [markdown]
# # encode_samplewise_features.py

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import numpy as np
import pandas as pd
import torch
from IPython.display import display
from transformers import (
    AutoModel,
    AutoTokenizer,
    GPT2LMHeadModel,
    GPT2TokenizerFast,
    RobertaForMaskedLM,
    RobertaTokenizer,
)

from nlp_adversarial_attacks.feature_extraction import FeatureExtractor
from nlp_adversarial_attacks.models import load_target_model
from nlp_adversarial_attacks.utils.hashing import get_pk_tuple, hash_pk_tuple
from nlp_adversarial_attacks.utils.pandas_ops import no_duplicate_index

assert (
    torch.cuda.is_available()
), "encoding features is quite expensive, defenitely use gpus"
CUDA_DEVICE = torch.device("cuda")

# %%
tp_model = "sentence-transformers/bert-base-nli-mean-tokens"
lm_perplexity_model = "gpt2"
lm_proba_model = "roberta-base"
tm_model = "distilcamembert"
tm_model_name_or_path = "baptiste-pasquier/distilcamembert-allocine"

# %%
df = pd.read_csv("data_tcab/whole_catted_dataset.csv")
df = df.sample(3).reset_index(drop=True)
df
# Out:
#     scenario target_model_dataset     target_model attack_toolchain  \
# 0  sentiment             allocine  distilcamembert             none
# 1  sentiment             allocine  distilcamembert             none
# 2  sentiment             allocine  distilcamembert             none
#
#   attack_name                                      original_text  \
# 0       clean  On ne comprend que guère l'espace et le temps ...
# 1       clean  Rémi Bezançon signe là son premier long métrag...
# 2       clean  Très belle surprise que ce « Nid de guêpes » t...
#
#                                       perturbed_text  \
# 0  On ne comprend que guère l'espace et le temps ...
# 1  Rémi Bezançon signe là son premier long métrag...
# 2  Très belle surprise que ce « Nid de guêpes » t...
#
#                    original_output                 perturbed_output status  \
# 0  [9.99755109e-01 2.44891003e-04]  [9.99755109e-01 2.44891003e-04]  clean
# 1          [0.00321949 0.99678051]          [0.00321949 0.99678051]  clean
# 2  [6.35053838e-04 9.99364946e-01]  [6.35053838e-04 9.99364946e-01]  clean
#
#   target_model_train_dataset  test_index  ground_truth  num_queries  \
# 0                   allocine          12             0            0
# 1                   allocine       16412             1            0
# 2                   allocine       18820             1            0
#
#    frac_words_changed  attacked_all_instances  test_ndx  \
# 0                 0.0                    True        12
# 1                 0.0                    True     16412
# 2                 0.0                    True     18820
#
#    original_text_identifier   dataset
# 0                        12  allocine
# 1                     16412  allocine
# 2                     18820  allocine

# %% [markdown]
# ## encode_all_properties

# %%
def get_value_holder(df):
    """
    Given a df, return a dict keyed by index
    """
    out = {}
    for idx in df.index:
        out[idx] = {}
        out[idx]["num_successful_loop"] = 0
        out[idx]["deliverable"] = {}
        pk = get_pk_tuple(df, idx)
        out[idx]["primary_key"] = pk
        out[idx]["unique_id"] = hash_pk_tuple(pk)
    return out

# %%
assert no_duplicate_index(df)
holder = get_value_holder(df)
holder
# Out:
# {0: {'num_successful_loop': 0,
#   'deliverable': {},
#   'primary_key': ['clean',
#    'none',
#    12,
#    'sentiment',
#    'distilcamembert',
#    'allocine',
#    12],
#   'unique_id': '227889344748385074993418811187107806614'},
#  1: {'num_successful_loop': 0,
#   'deliverable': {},
#   'primary_key': ['clean',
#    'none',
#    16412,
#    'sentiment',
#    'distilcamembert',
#    'allocine',
#    16412],
#   'unique_id': '212504654302479398588504114440141141439'},
#  2: {'num_successful_loop': 0,
#   'deliverable': {},
#   'primary_key': ['clean',
#    'none',
#    18820,
#    'sentiment',
#    'distilcamembert',
#    'allocine',
#    18820],
#   'unique_id': '81427168969727594878692125641742529269'}}

# %% [markdown]
# ### encode_text_properties

# %%
bert_model_name = tp_model

print("preparing text properties encoding")
assert no_duplicate_index(df)

# define feature extractor
fe = FeatureExtractor(add_tags=["tp"])
display(fe.extractors)
display(fe.necessary_params)
# Out:
# preparing text properties encoding
# [<function nlp_adversarial_attacks.reactdetect.feature_extraction.extractors.text_properties.tp_avg_word_length(text_list, quantiles=None, regions=None, feature_list=None)>,
#  <function nlp_adversarial_attacks.reactdetect.feature_extraction.extractors.text_properties.tp_bert(text_list, lm_bert_model, lm_bert_tokenizer, device, max_length=128, batch_size=50, feature_list=None)>,
#  <function nlp_adversarial_attacks.reactdetect.feature_extraction.extractors.text_properties.tp_is_first_word_lowercase(text_list, feature_list=None)>,
#  <function nlp_adversarial_attacks.reactdetect.feature_extraction.extractors.text_properties.tp_num_alpha_chars(text_list, feature_list=None)>,
#  <function nlp_adversarial_attacks.reactdetect.feature_extraction.extractors.text_properties.tp_num_cased_letters(text_list, feature_list=None)>,
#  <function nlp_adversarial_attacks.reactdetect.feature_extraction.extractors.text_properties.tp_num_cased_word_switches(text_list, feature_list=None)>,
#  <function nlp_adversarial_attacks.reactdetect.feature_extraction.extractors.text_properties.tp_num_chars(text_list, feature_list=None)>,
#  <function nlp_adversarial_attacks.reactdetect.feature_extraction.extractors.text_properties.tp_num_digits(text_list, feature_list=None)>,
#  <function nlp_adversarial_attacks.reactdetect.feature_extraction.extractors.text_properties.tp_num_lowercase_after_punctuation(text_list, feature_list=None)>,
#  <function nlp_adversarial_attacks.reactdetect.feature_extraction.extractors.text_properties.tp_num_mixed_case_words(text_list, feature_list=None)>,
#  <function nlp_adversarial_attacks.reactdetect.feature_extraction.extractors.text_properties.tp_num_multi_spaces(text_list, feature_list=None)>,
#  <function nlp_adversarial_attacks.reactdetect.feature_extraction.extractors.text_properties.tp_num_non_ascii(text_list, feature_list=None)>,
#  <function nlp_adversarial_attacks.reactdetect.feature_extraction.extractors.text_properties.tp_num_punctuation(text_list, feature_list=None)>,
#  <function nlp_adversarial_attacks.reactdetect.feature_extraction.extractors.text_properties.tp_num_single_lowercase_letters(text_list, feature_list=None)>,
#  <function nlp_adversarial_attacks.reactdetect.feature_extraction.extractors.text_properties.tp_num_words(text_list, feature_list=None)>]
# ['lm_bert_tokenizer', 'device', 'lm_bert_model', 'text_list']

# %%
# then load the bert model (out-of-box)
print("--- loading lm")
print(f"AutoModel: {bert_model_name}")
lm_bert_model = AutoModel.from_pretrained(bert_model_name).to(CUDA_DEVICE)
lm_bert_tokenizer = AutoTokenizer.from_pretrained(bert_model_name)
print("--- lm loaded")
# Out:
# --- loading lm
# AutoModel: sentence-transformers/bert-base-nli-mean-tokens
# --- lm loaded

# %%
idx = 0
res = fe(
    return_dict=True,
    text_list=pd.Series([df.at[idx, "perturbed_text"]]),
    lm_bert_model=lm_bert_model,
    lm_bert_tokenizer=lm_bert_tokenizer,
    device=CUDA_DEVICE,
)
res
# Out:
# {'tp_avg_word_length': (['avg_word_length_mean_region0',
#    'avg_word_length_var_region0',
#    'avg_word_length_quant0_region0',
#    'avg_word_length_quant1_region0',
#    'avg_word_length_quant2_region0',
#    'avg_word_length_mean_region1',
#    'avg_word_length_var_region1',
#    'avg_word_length_quant0_region1',
#    'avg_word_length_quant1_region1',
#    'avg_word_length_quant2_region1',
#    'avg_word_length_mean_region2',
#    'avg_word_length_var_region2',
#    'avg_word_length_quant0_region2',
#    'avg_word_length_quant1_region2',
#    'avg_word_length_quant2_region2',
#    'avg_word_length_mean_region3',
#    'avg_word_length_var_region3',
#    'avg_word_length_quant0_region3',
#    'avg_word_length_quant1_region3',
#    'avg_word_length_quant2_region3'],
#   array([[ 3.8       ,  3.62666667,  2.        ,  3.        ,  5.        ,
#            5.09677419, 12.21644121,  3.        ,  3.        ,  6.        ,
#            5.86666667,  9.31555556,  3.        ,  5.        ,  9.        ,
#            4.91525424,  9.77247917,  3.        ,  4.        ,  6.5       ]])),
#  'tp_bert': (['lm_bert_0',
#    'lm_bert_1',
#    'lm_bert_2',
#    'lm_bert_3',
#    'lm_bert_4',
#    'lm_bert_5',
#    'lm_bert_6',
#    'lm_bert_7',
#    'lm_bert_8',
#    'lm_bert_9',
#    'lm_bert_10',
#    'lm_bert_11',
#    'lm_bert_12',
#    'lm_bert_13',
#    'lm_bert_14',
#    'lm_bert_15',
#    'lm_bert_16',
#    'lm_bert_17',
#    'lm_bert_18',
#    'lm_bert_19',
#    'lm_bert_20',
#    'lm_bert_21',
#    'lm_bert_22',
#    'lm_bert_23',
#    'lm_bert_24',
#    'lm_bert_25',
#    'lm_bert_26',
#    'lm_bert_27',
#    'lm_bert_28',
#    'lm_bert_29',
#    'lm_bert_30',
#    'lm_bert_31',
#    'lm_bert_32',
#    'lm_bert_33',
#    'lm_bert_34',
#    'lm_bert_35',
#    'lm_bert_36',
#    'lm_bert_37',
#    'lm_bert_38',
#    'lm_bert_39',
#    'lm_bert_40',
#    'lm_bert_41',
#    'lm_bert_42',
#    'lm_bert_43',
#    'lm_bert_44',
#    'lm_bert_45',
#    'lm_bert_46',
#    'lm_bert_47',
#    'lm_bert_48',
#    'lm_bert_49',
#    'lm_bert_50',
#    'lm_bert_51',
#    'lm_bert_52',
#    'lm_bert_53',
#    'lm_bert_54',
#    'lm_bert_55',
#    'lm_bert_56',
#    'lm_bert_57',
#    'lm_bert_58',
#    'lm_bert_59',
#    'lm_bert_60',
#    'lm_bert_61',
#    'lm_bert_62',
#    'lm_bert_63',
#    'lm_bert_64',
#    'lm_bert_65',
#    'lm_bert_66',
#    'lm_bert_67',
#    'lm_bert_68',
#    'lm_bert_69',
#    'lm_bert_70',
#    'lm_bert_71',
#    'lm_bert_72',
#    'lm_bert_73',
#    'lm_bert_74',
#    'lm_bert_75',
#    'lm_bert_76',
#    'lm_bert_77',
#    'lm_bert_78',
#    'lm_bert_79',
#    'lm_bert_80',
#    'lm_bert_81',
#    'lm_bert_82',
#    'lm_bert_83',
#    'lm_bert_84',
#    'lm_bert_85',
#    'lm_bert_86',
#    'lm_bert_87',
#    'lm_bert_88',
#    'lm_bert_89',
#    'lm_bert_90',
#    'lm_bert_91',
#    'lm_bert_92',
#    'lm_bert_93',
#    'lm_bert_94',
#    'lm_bert_95',
#    'lm_bert_96',
#    'lm_bert_97',
#    'lm_bert_98',
#    'lm_bert_99',
#    'lm_bert_100',
#    'lm_bert_101',
#    'lm_bert_102',
#    'lm_bert_103',
#    'lm_bert_104',
#    'lm_bert_105',
#    'lm_bert_106',
#    'lm_bert_107',
#    'lm_bert_108',
#    'lm_bert_109',
#    'lm_bert_110',
#    'lm_bert_111',
#    'lm_bert_112',
#    'lm_bert_113',
#    'lm_bert_114',
#    'lm_bert_115',
#    'lm_bert_116',
#    'lm_bert_117',
#    'lm_bert_118',
#    'lm_bert_119',
#    'lm_bert_120',
#    'lm_bert_121',
#    'lm_bert_122',
#    'lm_bert_123',
#    'lm_bert_124',
#    'lm_bert_125',
#    'lm_bert_126',
#    'lm_bert_127',
#    'lm_bert_128',
#    'lm_bert_129',
#    'lm_bert_130',
#    'lm_bert_131',
#    'lm_bert_132',
#    'lm_bert_133',
#    'lm_bert_134',
#    'lm_bert_135',
#    'lm_bert_136',
#    'lm_bert_137',
#    'lm_bert_138',
#    'lm_bert_139',
#    'lm_bert_140',
#    'lm_bert_141',
#    'lm_bert_142',
#    'lm_bert_143',
#    'lm_bert_144',
#    'lm_bert_145',
#    'lm_bert_146',
#    'lm_bert_147',
#    'lm_bert_148',
#    'lm_bert_149',
#    'lm_bert_150',
#    'lm_bert_151',
#    'lm_bert_152',
#    'lm_bert_153',
#    'lm_bert_154',
#    'lm_bert_155',
#    'lm_bert_156',
#    'lm_bert_157',
#    'lm_bert_158',
#    'lm_bert_159',
#    'lm_bert_160',
#    'lm_bert_161',
#    'lm_bert_162',
#    'lm_bert_163',
#    'lm_bert_164',
#    'lm_bert_165',
#    'lm_bert_166',
#    'lm_bert_167',
#    'lm_bert_168',
#    'lm_bert_169',
#    'lm_bert_170',
#    'lm_bert_171',
#    'lm_bert_172',
#    'lm_bert_173',
#    'lm_bert_174',
#    'lm_bert_175',
#    'lm_bert_176',
#    'lm_bert_177',
#    'lm_bert_178',
#    'lm_bert_179',
#    'lm_bert_180',
#    'lm_bert_181',
#    'lm_bert_182',
#    'lm_bert_183',
#    'lm_bert_184',
#    'lm_bert_185',
#    'lm_bert_186',
#    'lm_bert_187',
#    'lm_bert_188',
#    'lm_bert_189',
#    'lm_bert_190',
#    'lm_bert_191',
#    'lm_bert_192',
#    'lm_bert_193',
#    'lm_bert_194',
#    'lm_bert_195',
#    'lm_bert_196',
#    'lm_bert_197',
#    'lm_bert_198',
#    'lm_bert_199',
#    'lm_bert_200',
#    'lm_bert_201',
#    'lm_bert_202',
#    'lm_bert_203',
#    'lm_bert_204',
#    'lm_bert_205',
#    'lm_bert_206',
#    'lm_bert_207',
#    'lm_bert_208',
#    'lm_bert_209',
#    'lm_bert_210',
#    'lm_bert_211',
#    'lm_bert_212',
#    'lm_bert_213',
#    'lm_bert_214',
#    'lm_bert_215',
#    'lm_bert_216',
#    'lm_bert_217',
#    'lm_bert_218',
#    'lm_bert_219',
#    'lm_bert_220',
#    'lm_bert_221',
#    'lm_bert_222',
#    'lm_bert_223',
#    'lm_bert_224',
#    'lm_bert_225',
#    'lm_bert_226',
#    'lm_bert_227',
#    'lm_bert_228',
#    'lm_bert_229',
#    'lm_bert_230',
#    'lm_bert_231',
#    'lm_bert_232',
#    'lm_bert_233',
#    'lm_bert_234',
#    'lm_bert_235',
#    'lm_bert_236',
#    'lm_bert_237',
#    'lm_bert_238',
#    'lm_bert_239',
#    'lm_bert_240',
#    'lm_bert_241',
#    'lm_bert_242',
#    'lm_bert_243',
#    'lm_bert_244',
#    'lm_bert_245',
#    'lm_bert_246',
#    'lm_bert_247',
#    'lm_bert_248',
#    'lm_bert_249',
#    'lm_bert_250',
#    'lm_bert_251',
#    'lm_bert_252',
#    'lm_bert_253',
#    'lm_bert_254',
#    'lm_bert_255',
#    'lm_bert_256',
#    'lm_bert_257',
#    'lm_bert_258',
#    'lm_bert_259',
#    'lm_bert_260',
#    'lm_bert_261',
#    'lm_bert_262',
#    'lm_bert_263',
#    'lm_bert_264',
#    'lm_bert_265',
#    'lm_bert_266',
#    'lm_bert_267',
#    'lm_bert_268',
#    'lm_bert_269',
#    'lm_bert_270',
#    'lm_bert_271',
#    'lm_bert_272',
#    'lm_bert_273',
#    'lm_bert_274',
#    'lm_bert_275',
#    'lm_bert_276',
#    'lm_bert_277',
#    'lm_bert_278',
#    'lm_bert_279',
#    'lm_bert_280',
#    'lm_bert_281',
#    'lm_bert_282',
#    'lm_bert_283',
#    'lm_bert_284',
#    'lm_bert_285',
#    'lm_bert_286',
#    'lm_bert_287',
#    'lm_bert_288',
#    'lm_bert_289',
#    'lm_bert_290',
#    'lm_bert_291',
#    'lm_bert_292',
#    'lm_bert_293',
#    'lm_bert_294',
#    'lm_bert_295',
#    'lm_bert_296',
#    'lm_bert_297',
#    'lm_bert_298',
#    'lm_bert_299',
#    'lm_bert_300',
#    'lm_bert_301',
#    'lm_bert_302',
#    'lm_bert_303',
#    'lm_bert_304',
#    'lm_bert_305',
#    'lm_bert_306',
#    'lm_bert_307',
#    'lm_bert_308',
#    'lm_bert_309',
#    'lm_bert_310',
#    'lm_bert_311',
#    'lm_bert_312',
#    'lm_bert_313',
#    'lm_bert_314',
#    'lm_bert_315',
#    'lm_bert_316',
#    'lm_bert_317',
#    'lm_bert_318',
#    'lm_bert_319',
#    'lm_bert_320',
#    'lm_bert_321',
#    'lm_bert_322',
#    'lm_bert_323',
#    'lm_bert_324',
#    'lm_bert_325',
#    'lm_bert_326',
#    'lm_bert_327',
#    'lm_bert_328',
#    'lm_bert_329',
#    'lm_bert_330',
#    'lm_bert_331',
#    'lm_bert_332',
#    'lm_bert_333',
#    'lm_bert_334',
#    'lm_bert_335',
#    'lm_bert_336',
#    'lm_bert_337',
#    'lm_bert_338',
#    'lm_bert_339',
#    'lm_bert_340',
#    'lm_bert_341',
#    'lm_bert_342',
#    'lm_bert_343',
#    'lm_bert_344',
#    'lm_bert_345',
#    'lm_bert_346',
#    'lm_bert_347',
#    'lm_bert_348',
#    'lm_bert_349',
#    'lm_bert_350',
#    'lm_bert_351',
#    'lm_bert_352',
#    'lm_bert_353',
#    'lm_bert_354',
#    'lm_bert_355',
#    'lm_bert_356',
#    'lm_bert_357',
#    'lm_bert_358',
#    'lm_bert_359',
#    'lm_bert_360',
#    'lm_bert_361',
#    'lm_bert_362',
#    'lm_bert_363',
#    'lm_bert_364',
#    'lm_bert_365',
#    'lm_bert_366',
#    'lm_bert_367',
#    'lm_bert_368',
#    'lm_bert_369',
#    'lm_bert_370',
#    'lm_bert_371',
#    'lm_bert_372',
#    'lm_bert_373',
#    'lm_bert_374',
#    'lm_bert_375',
#    'lm_bert_376',
#    'lm_bert_377',
#    'lm_bert_378',
#    'lm_bert_379',
#    'lm_bert_380',
#    'lm_bert_381',
#    'lm_bert_382',
#    'lm_bert_383',
#    'lm_bert_384',
#    'lm_bert_385',
#    'lm_bert_386',
#    'lm_bert_387',
#    'lm_bert_388',
#    'lm_bert_389',
#    'lm_bert_390',
#    'lm_bert_391',
#    'lm_bert_392',
#    'lm_bert_393',
#    'lm_bert_394',
#    'lm_bert_395',
#    'lm_bert_396',
#    'lm_bert_397',
#    'lm_bert_398',
#    'lm_bert_399',
#    'lm_bert_400',
#    'lm_bert_401',
#    'lm_bert_402',
#    'lm_bert_403',
#    'lm_bert_404',
#    'lm_bert_405',
#    'lm_bert_406',
#    'lm_bert_407',
#    'lm_bert_408',
#    'lm_bert_409',
#    'lm_bert_410',
#    'lm_bert_411',
#    'lm_bert_412',
#    'lm_bert_413',
#    'lm_bert_414',
#    'lm_bert_415',
#    'lm_bert_416',
#    'lm_bert_417',
#    'lm_bert_418',
#    'lm_bert_419',
#    'lm_bert_420',
#    'lm_bert_421',
#    'lm_bert_422',
#    'lm_bert_423',
#    'lm_bert_424',
#    'lm_bert_425',
#    'lm_bert_426',
#    'lm_bert_427',
#    'lm_bert_428',
#    'lm_bert_429',
#    'lm_bert_430',
#    'lm_bert_431',
#    'lm_bert_432',
#    'lm_bert_433',
#    'lm_bert_434',
#    'lm_bert_435',
#    'lm_bert_436',
#    'lm_bert_437',
#    'lm_bert_438',
#    'lm_bert_439',
#    'lm_bert_440',
#    'lm_bert_441',
#    'lm_bert_442',
#    'lm_bert_443',
#    'lm_bert_444',
#    'lm_bert_445',
#    'lm_bert_446',
#    'lm_bert_447',
#    'lm_bert_448',
#    'lm_bert_449',
#    'lm_bert_450',
#    'lm_bert_451',
#    'lm_bert_452',
#    'lm_bert_453',
#    'lm_bert_454',
#    'lm_bert_455',
#    'lm_bert_456',
#    'lm_bert_457',
#    'lm_bert_458',
#    'lm_bert_459',
#    'lm_bert_460',
#    'lm_bert_461',
#    'lm_bert_462',
#    'lm_bert_463',
#    'lm_bert_464',
#    'lm_bert_465',
#    'lm_bert_466',
#    'lm_bert_467',
#    'lm_bert_468',
#    'lm_bert_469',
#    'lm_bert_470',
#    'lm_bert_471',
#    'lm_bert_472',
#    'lm_bert_473',
#    'lm_bert_474',
#    'lm_bert_475',
#    'lm_bert_476',
#    'lm_bert_477',
#    'lm_bert_478',
#    'lm_bert_479',
#    'lm_bert_480',
#    'lm_bert_481',
#    'lm_bert_482',
#    'lm_bert_483',
#    'lm_bert_484',
#    'lm_bert_485',
#    'lm_bert_486',
#    'lm_bert_487',
#    'lm_bert_488',
#    'lm_bert_489',
#    'lm_bert_490',
#    'lm_bert_491',
#    'lm_bert_492',
#    'lm_bert_493',
#    'lm_bert_494',
#    'lm_bert_495',
#    'lm_bert_496',
#    'lm_bert_497',
#    'lm_bert_498',
#    'lm_bert_499',
#    'lm_bert_500',
#    'lm_bert_501',
#    'lm_bert_502',
#    'lm_bert_503',
#    'lm_bert_504',
#    'lm_bert_505',
#    'lm_bert_506',
#    'lm_bert_507',
#    'lm_bert_508',
#    'lm_bert_509',
#    'lm_bert_510',
#    'lm_bert_511',
#    'lm_bert_512',
#    'lm_bert_513',
#    'lm_bert_514',
#    'lm_bert_515',
#    'lm_bert_516',
#    'lm_bert_517',
#    'lm_bert_518',
#    'lm_bert_519',
#    'lm_bert_520',
#    'lm_bert_521',
#    'lm_bert_522',
#    'lm_bert_523',
#    'lm_bert_524',
#    'lm_bert_525',
#    'lm_bert_526',
#    'lm_bert_527',
#    'lm_bert_528',
#    'lm_bert_529',
#    'lm_bert_530',
#    'lm_bert_531',
#    'lm_bert_532',
#    'lm_bert_533',
#    'lm_bert_534',
#    'lm_bert_535',
#    'lm_bert_536',
#    'lm_bert_537',
#    'lm_bert_538',
#    'lm_bert_539',
#    'lm_bert_540',
#    'lm_bert_541',
#    'lm_bert_542',
#    'lm_bert_543',
#    'lm_bert_544',
#    'lm_bert_545',
#    'lm_bert_546',
#    'lm_bert_547',
#    'lm_bert_548',
#    'lm_bert_549',
#    'lm_bert_550',
#    'lm_bert_551',
#    'lm_bert_552',
#    'lm_bert_553',
#    'lm_bert_554',
#    'lm_bert_555',
#    'lm_bert_556',
#    'lm_bert_557',
#    'lm_bert_558',
#    'lm_bert_559',
#    'lm_bert_560',
#    'lm_bert_561',
#    'lm_bert_562',
#    'lm_bert_563',
#    'lm_bert_564',
#    'lm_bert_565',
#    'lm_bert_566',
#    'lm_bert_567',
#    'lm_bert_568',
#    'lm_bert_569',
#    'lm_bert_570',
#    'lm_bert_571',
#    'lm_bert_572',
#    'lm_bert_573',
#    'lm_bert_574',
#    'lm_bert_575',
#    'lm_bert_576',
#    'lm_bert_577',
#    'lm_bert_578',
#    'lm_bert_579',
#    'lm_bert_580',
#    'lm_bert_581',
#    'lm_bert_582',
#    'lm_bert_583',
#    'lm_bert_584',
#    'lm_bert_585',
#    'lm_bert_586',
#    'lm_bert_587',
#    'lm_bert_588',
#    'lm_bert_589',
#    'lm_bert_590',
#    'lm_bert_591',
#    'lm_bert_592',
#    'lm_bert_593',
#    'lm_bert_594',
#    'lm_bert_595',
#    'lm_bert_596',
#    'lm_bert_597',
#    'lm_bert_598',
#    'lm_bert_599',
#    'lm_bert_600',
#    'lm_bert_601',
#    'lm_bert_602',
#    'lm_bert_603',
#    'lm_bert_604',
#    'lm_bert_605',
#    'lm_bert_606',
#    'lm_bert_607',
#    'lm_bert_608',
#    'lm_bert_609',
#    'lm_bert_610',
#    'lm_bert_611',
#    'lm_bert_612',
#    'lm_bert_613',
#    'lm_bert_614',
#    'lm_bert_615',
#    'lm_bert_616',
#    'lm_bert_617',
#    'lm_bert_618',
#    'lm_bert_619',
#    'lm_bert_620',
#    'lm_bert_621',
#    'lm_bert_622',
#    'lm_bert_623',
#    'lm_bert_624',
#    'lm_bert_625',
#    'lm_bert_626',
#    'lm_bert_627',
#    'lm_bert_628',
#    'lm_bert_629',
#    'lm_bert_630',
#    'lm_bert_631',
#    'lm_bert_632',
#    'lm_bert_633',
#    'lm_bert_634',
#    'lm_bert_635',
#    'lm_bert_636',
#    'lm_bert_637',
#    'lm_bert_638',
#    'lm_bert_639',
#    'lm_bert_640',
#    'lm_bert_641',
#    'lm_bert_642',
#    'lm_bert_643',
#    'lm_bert_644',
#    'lm_bert_645',
#    'lm_bert_646',
#    'lm_bert_647',
#    'lm_bert_648',
#    'lm_bert_649',
#    'lm_bert_650',
#    'lm_bert_651',
#    'lm_bert_652',
#    'lm_bert_653',
#    'lm_bert_654',
#    'lm_bert_655',
#    'lm_bert_656',
#    'lm_bert_657',
#    'lm_bert_658',
#    'lm_bert_659',
#    'lm_bert_660',
#    'lm_bert_661',
#    'lm_bert_662',
#    'lm_bert_663',
#    'lm_bert_664',
#    'lm_bert_665',
#    'lm_bert_666',
#    'lm_bert_667',
#    'lm_bert_668',
#    'lm_bert_669',
#    'lm_bert_670',
#    'lm_bert_671',
#    'lm_bert_672',
#    'lm_bert_673',
#    'lm_bert_674',
#    'lm_bert_675',
#    'lm_bert_676',
#    'lm_bert_677',
#    'lm_bert_678',
#    'lm_bert_679',
#    'lm_bert_680',
#    'lm_bert_681',
#    'lm_bert_682',
#    'lm_bert_683',
#    'lm_bert_684',
#    'lm_bert_685',
#    'lm_bert_686',
#    'lm_bert_687',
#    'lm_bert_688',
#    'lm_bert_689',
#    'lm_bert_690',
#    'lm_bert_691',
#    'lm_bert_692',
#    'lm_bert_693',
#    'lm_bert_694',
#    'lm_bert_695',
#    'lm_bert_696',
#    'lm_bert_697',
#    'lm_bert_698',
#    'lm_bert_699',
#    'lm_bert_700',
#    'lm_bert_701',
#    'lm_bert_702',
#    'lm_bert_703',
#    'lm_bert_704',
#    'lm_bert_705',
#    'lm_bert_706',
#    'lm_bert_707',
#    'lm_bert_708',
#    'lm_bert_709',
#    'lm_bert_710',
#    'lm_bert_711',
#    'lm_bert_712',
#    'lm_bert_713',
#    'lm_bert_714',
#    'lm_bert_715',
#    'lm_bert_716',
#    'lm_bert_717',
#    'lm_bert_718',
#    'lm_bert_719',
#    'lm_bert_720',
#    'lm_bert_721',
#    'lm_bert_722',
#    'lm_bert_723',
#    'lm_bert_724',
#    'lm_bert_725',
#    'lm_bert_726',
#    'lm_bert_727',
#    'lm_bert_728',
#    'lm_bert_729',
#    'lm_bert_730',
#    'lm_bert_731',
#    'lm_bert_732',
#    'lm_bert_733',
#    'lm_bert_734',
#    'lm_bert_735',
#    'lm_bert_736',
#    'lm_bert_737',
#    'lm_bert_738',
#    'lm_bert_739',
#    'lm_bert_740',
#    'lm_bert_741',
#    'lm_bert_742',
#    'lm_bert_743',
#    'lm_bert_744',
#    'lm_bert_745',
#    'lm_bert_746',
#    'lm_bert_747',
#    'lm_bert_748',
#    'lm_bert_749',
#    'lm_bert_750',
#    'lm_bert_751',
#    'lm_bert_752',
#    'lm_bert_753',
#    'lm_bert_754',
#    'lm_bert_755',
#    'lm_bert_756',
#    'lm_bert_757',
#    'lm_bert_758',
#    'lm_bert_759',
#    'lm_bert_760',
#    'lm_bert_761',
#    'lm_bert_762',
#    'lm_bert_763',
#    'lm_bert_764',
#    'lm_bert_765',
#    'lm_bert_766',
#    'lm_bert_767'],
#   array([[-3.06791455e-01,  7.90720284e-01,  1.01071060e+00,
#            5.87291420e-01,  1.06362152e+00, -4.48848873e-01,
#            5.25600374e-01, -5.65350801e-02,  4.46897000e-01,
#           -2.35652607e-02, -5.76172352e-01,  4.79454875e-01,
#            2.31330261e-01,  9.20407355e-01,  1.78519599e-02,
#            7.17854440e-01, -1.78758219e-01, -1.18905270e+00,
#            8.11006486e-01, -7.72459567e-01, -9.73944664e-01,
#            1.27628013e-01,  5.99420629e-02,  3.60700786e-01,
#            2.63481110e-01,  2.57346183e-01,  2.22084284e-01,
#           -2.09628820e-01, -7.65786886e-01,  7.63716459e-01,
#           -2.30415881e-01,  1.37783423e-01, -7.04915285e-01,
#           -3.30935776e-01, -4.54865471e-02,  1.24588072e+00,
#            2.92578131e-01,  4.52926397e-01,  1.76257327e-01,
#            5.22969663e-01,  4.35053885e-01, -4.82903093e-01,
#            3.44046146e-01, -3.72702092e-01, -1.51505613e+00,
#           -5.77499747e-01,  7.91962922e-01,  3.06930482e-01,
#           -3.29131722e-01, -8.07872593e-01,  3.85288805e-01,
#            1.33135095e-01,  8.26287448e-01, -3.73154283e-01,
#           -1.04705207e-01, -1.49255574e-01, -4.35248703e-01,
#           -1.25885105e+00, -2.43316159e-01, -4.09504443e-01,
#           -3.09789568e-01,  3.31857391e-02,  5.51156640e-01,
#            6.16751790e-01, -4.82828528e-01,  3.45630586e-01,
#           -1.09187074e-01, -5.05891323e-01, -1.96080491e-01,
#            3.84134978e-01,  1.83011107e-02, -1.39267370e-01,
#           -8.95659268e-01,  2.75614262e-01,  1.87426567e-01,
#           -4.58268255e-01,  5.46543896e-01,  4.52145040e-01,
#            5.15433133e-01,  1.04256833e+00,  8.53977203e-01,
#           -2.76632249e-01,  1.00111115e+00,  4.75837767e-01,
#           -2.17660517e-01,  9.88397896e-01,  6.97147310e-01,
#            4.13832814e-01, -1.63678086e+00,  4.55446333e-01,
#           -2.03880638e-01,  1.67758182e-01,  9.60410953e-01,
#           -6.70065582e-01,  6.11711703e-02,  3.34388047e-01,
#            5.19916356e-01, -2.70240694e-01,  1.65149271e-01,
#            3.43302161e-01, -4.43329334e-01,  8.99284333e-02,
#           -5.55423021e-01, -5.62369190e-02, -1.34623528e+00,
#            1.58797905e-01, -3.80897731e-01, -8.90024960e-01,
#           -1.29743016e+00,  7.93493032e-01,  4.49463099e-01,
#           -2.21166506e-01,  6.74027205e-01, -3.28941703e-01,
#           -8.68785679e-01, -7.54610240e-01, -1.01892447e+00,
#            4.44451779e-01,  1.49730733e-02,  7.09107578e-01,
#            3.73938203e-01, -1.53492481e-01, -3.72145936e-04,
#           -2.84348696e-01,  1.11263859e+00,  5.24970412e-01,
#            5.12091637e-01,  2.09114939e-01, -7.21482635e-01,
#           -1.18652759e-02,  9.47606742e-01,  2.21152112e-01,
#           -4.11640465e-01,  2.24162359e-02, -7.97826409e-01,
#            1.69568017e-01,  6.20343864e-01, -9.54407454e-01,
#            9.90942940e-02, -2.41979107e-01, -9.46222663e-01,
#           -9.33936983e-03, -8.14760804e-01, -8.53410780e-01,
#           -3.87429744e-01, -5.01279891e-01,  5.31497777e-01,
#            4.64596480e-01,  5.98995626e-01, -2.02151522e-01,
#           -8.52626622e-01, -1.13630101e-01, -1.90666273e-01,
#           -1.73191175e-01, -8.26048434e-01, -2.72972137e-01,
#           -3.88618827e-01,  6.67618752e-01,  1.40948119e-02,
#            2.32870262e-02, -3.09443593e-01,  8.12900722e-01,
#            5.90500310e-02,  4.38735485e-01,  9.06672955e-01,
#           -5.18939912e-01, -7.49265328e-02, -3.54569465e-01,
#            4.79410410e-01, -3.95794123e-01,  1.81829974e-01,
#            2.44564936e-01,  1.69695652e+00, -7.04746604e-01,
#            3.67403835e-01,  2.15165019e-01,  7.59932220e-01,
#            5.75229049e-01, -2.43383124e-01,  4.22513932e-01,
#           -1.01278102e+00, -1.84716016e-01, -4.08573329e-01,
#           -5.53302350e-04, -3.15368086e-01, -2.73028910e-01,
#           -5.84779792e-02, -5.15279830e-01,  4.25087035e-01,
#           -1.52189761e-01, -4.05119330e-01, -4.06238407e-01,
#           -3.86244468e-02, -1.77873921e+00, -7.55924582e-01,
#            3.54230642e-01, -3.10592741e-01,  9.53441441e-01,
#           -2.83377260e-01, -4.44132924e-01, -4.29953814e-01,
#           -6.52009174e-02,  8.60055864e-01,  6.57377988e-02,
#           -3.42270106e-01,  8.78622174e-01, -9.98431724e-03,
#            3.71420175e-01, -5.04666030e-01,  1.10745788e-01,
#           -9.94346440e-02, -3.18143547e-01,  9.52721894e-01,
#            1.54205918e-01, -2.11408734e-01, -6.21945739e-01,
#           -1.42916068e-02, -4.58509147e-01, -3.30784917e-01,
#            1.19916856e+00,  1.12148359e-01, -1.34032682e-01,
#           -6.21778369e-01,  5.57129204e-01, -4.80297714e-01,
#            8.70974064e-01,  1.74129635e-01, -6.86599612e-01,
#           -2.32424960e-01,  7.41237164e-01,  2.47408897e-01,
#           -9.83377397e-01, -7.49657214e-01,  2.13573743e-02,
#            1.59473345e-01,  1.07721436e+00, -8.08772862e-01,
#            1.51242957e-01,  7.62037814e-01, -7.65272379e-01,
#           -7.29725584e-02,  2.12993175e-01,  6.98223472e-01,
#            3.11347067e-01, -1.03752553e+00, -5.68268657e-01,
#            1.11859787e+00,  4.15921450e-01, -1.02467871e+00,
#            3.33314866e-01, -8.70646656e-01,  6.38014436e-01,
#            4.95443434e-01, -5.91035724e-01, -5.59948325e-01,
#           -2.57202119e-01, -1.68546125e-01, -8.32025856e-02,
#            5.55342197e-01, -1.33760691e+00,  2.75877982e-01,
#            1.70180127e-01, -6.72878399e-02,  6.88601851e-01,
#           -1.26079679e-01,  2.89990958e-02,  1.84446052e-01,
#            7.12658703e-01, -8.64200771e-01,  8.53388011e-01,
#           -4.13036764e-01,  1.63342446e-01,  1.16365470e-01,
#            7.50815630e-01, -2.51823545e-01,  3.07439148e-01,
#            8.50624621e-01,  9.21253562e-01, -5.13857491e-02,
#            1.04901440e-01,  1.33072034e-01,  1.68666542e-01,
#           -2.00024366e+00,  2.84224391e-01, -1.02437413e+00,
#           -1.42414376e-01,  4.09396857e-01, -9.75367188e-01,
#           -4.81801748e-01, -3.58727992e-01, -5.26389897e-01,
#            2.06486732e-01,  1.17763214e-01, -6.01541638e-01,
#            2.12294057e-01, -9.42534626e-01,  2.65777290e-01,
#            2.32372314e-01,  6.20982707e-01, -4.80670869e-01,
#            2.63064168e-02, -1.07865714e-01, -3.27595323e-01,
#            1.24343538e+00,  6.86926067e-01,  2.49749199e-01,
#            6.25169158e-01,  6.73692822e-02, -9.70969856e-01,
#           -7.62757123e-01, -5.02178609e-01,  3.30769211e-01,
#            5.98805487e-01,  5.13653994e-01, -1.72017768e-01,
#           -1.01294219e-01, -1.23374581e+00,  3.71836632e-01,
#            2.19780385e-01, -7.53367960e-01, -2.35691667e-01,
#           -2.28062496e-02,  3.88677329e-01, -1.09948061e-01,
#           -4.11442714e-03,  2.22513273e-01, -3.62821877e-01,
#            6.69128299e-01, -1.00942206e+00, -2.69521922e-01,
#            1.17940927e+00, -5.64723969e-01,  5.78737967e-02,
#            1.61069091e-02, -3.53888065e-01,  8.40712965e-01,
#           -9.67503905e-01, -7.90310740e-01,  4.34140861e-02,
#           -6.26063526e-01,  1.07771647e+00, -3.51534754e-01,
#            1.32337582e+00,  4.23492432e-01,  3.78891200e-01,
#           -3.99464071e-01, -1.34549569e-03,  1.36832327e-01,
#           -4.50561255e-01, -1.64242551e-01, -1.92553073e-03,
#            5.45657396e-01, -3.33593398e-01, -4.02732164e-01,
#           -1.44040734e-01, -3.43167841e-01,  3.26522857e-01,
#            3.83006111e-02, -4.50765222e-01,  6.37539744e-01,
#           -4.82535005e-01,  9.60570037e-01, -4.60028350e-01,
#            2.01182902e-01,  1.29168823e-01, -3.11849743e-01,
#           -8.33013654e-02,  2.54258841e-01,  9.98227715e-01,
#            1.18577152e-01, -3.23166102e-01,  1.70697019e-01,
#           -2.19307095e-01,  1.76910050e-02, -1.00263298e+00,
#           -8.22653845e-02, -1.58967584e-01, -2.87341982e-01,
#            1.42941386e-01, -4.53419209e-01, -9.24740583e-02,
#           -2.13460609e-01,  3.33147556e-01,  5.84006011e-01,
#           -3.93088877e-01,  1.32418592e-02, -5.60968697e-01,
#            6.23776674e-01,  4.73689407e-01,  1.30538374e-01,
#            1.03081965e+00, -1.58232190e-02, -5.54102838e-01,
#           -5.92852354e-01,  6.12593651e-01, -1.51225388e+00,
#            2.92814612e-01,  2.41543427e-02, -1.57012656e-01,
#            8.98764729e-01, -8.06116223e-01, -4.02499467e-01,
#            1.42051220e-01, -1.29720068e+00, -1.83261558e-01,
#           -3.80183041e-01,  7.04173267e-01, -7.46148005e-02,
#           -4.57018197e-01,  5.31708933e-02,  8.28322172e-01,
#           -8.80440474e-01, -1.00851143e-02, -1.62312537e-01,
#           -7.46745542e-02,  1.17096567e+00, -5.13197958e-01,
#           -7.98325300e-01,  1.77690849e-01,  8.63770425e-01,
#            4.02808249e-01,  6.57048881e-01,  1.20218325e+00,
#           -1.12828517e+00, -4.08902049e-01,  5.48372388e-01,
#           -1.02721548e+00, -3.65529984e-01,  4.77723062e-01,
#            8.95924091e-01, -4.67258692e-01, -1.42428335e-02,
#           -4.04610097e-01,  1.08800679e-01, -1.59040256e-03,
#           -4.71651942e-01, -5.63836694e-01,  2.94434726e-02,
#            3.40334117e-01, -8.30150604e-01,  5.33557415e-01,
#           -5.47975957e-01,  8.90911102e-01, -6.09899044e-01,
#            6.52574599e-02,  4.06156152e-01,  9.12940651e-02,
#            5.92633002e-02,  1.18001521e+00, -3.37112010e-01,
#            2.49289155e-01, -1.07122406e-01,  5.11975348e-01,
#            3.17643210e-02,  1.30529451e+00, -9.16261524e-02,
#           -1.11651361e+00,  2.26618797e-02, -4.20257270e-01,
#           -2.76568890e-01,  5.32784402e-01, -4.30339575e-01,
#           -2.97552019e-01, -3.46683890e-01,  2.42334366e-01,
#            1.24323778e-01, -4.24006097e-02, -1.56854317e-02,
#            4.63567704e-01, -3.68867487e-01, -3.09543647e-02,
#            5.69114208e-01, -8.68462995e-02,  5.71813822e-01,
#            4.77133185e-01, -6.11031413e-01, -7.85596669e-01,
#           -1.73461244e-01, -8.50549817e-01,  1.56734955e+00,
#            2.67526299e-01,  1.41502963e-02,  2.18882143e-01,
#           -2.70227134e-01, -5.36880672e-01, -4.66864049e-01,
#            2.45876595e-01,  6.99411333e-01,  6.30531132e-01,
#           -4.24757183e-01,  1.50282428e-01, -6.52231157e-01,
#           -1.56425402e-01, -1.48210895e+00, -3.32763731e-01,
#           -4.35894698e-01, -4.98928964e-01, -8.07679817e-02,
#            2.87618548e-01, -2.04779088e-01,  6.73976839e-01,
#           -2.61542827e-01,  1.24013111e-01, -2.31053486e-01,
#            3.53035212e-01,  7.42774010e-02, -5.87283134e-01,
#            2.08807692e-01,  5.04607141e-01,  1.63408428e-01,
#           -9.76588130e-02,  3.28572005e-01, -4.87333909e-02,
#            1.07608311e-01, -4.18212682e-01,  2.19750047e-01,
#            3.88913512e-01,  1.07692115e-01, -3.42920542e-01,
#           -9.23418164e-01, -5.30200183e-01,  4.39455003e-01,
#            5.97439706e-01, -4.56687242e-01,  1.25310466e-01,
#           -6.16519332e-01,  3.24024618e-01,  2.13124067e-01,
#            3.35559160e-01, -9.65574801e-01,  3.17151636e-01,
#           -3.16583104e-02, -8.64944875e-01,  5.70943594e-01,
#            7.72843957e-01,  5.55347621e-01, -1.33442879e-01,
#            6.52611732e-01, -4.56843823e-01, -3.26531291e-01,
#           -2.03925878e-01,  5.06118760e-02, -1.64380699e-01,
#           -2.12505221e-01, -6.20640695e-01, -2.24287868e-01,
#           -1.15459755e-01,  1.41625538e-01, -2.54294783e-01,
#            3.32350135e-01,  4.46535915e-01, -3.11147988e-01,
#           -4.41755503e-01,  4.02974784e-01, -1.63504481e-01,
#           -9.24124122e-01, -1.07439733e+00,  4.76309747e-01,
#           -1.02014577e+00,  5.39168537e-01, -8.57509971e-02,
#            1.54861212e-01, -3.62113804e-01, -5.17912507e-01,
#           -5.46781778e-01,  3.01706821e-01,  7.04729781e-02,
#            1.53358579e-01, -1.09541714e+00, -7.27984786e-01,
#           -1.79658890e-01, -7.99992800e-01,  4.63416219e-01,
#            5.46249390e-01, -6.37359262e-01,  3.28065574e-01,
#           -4.72172767e-01, -6.07093394e-01, -4.40831751e-01,
#           -3.34891900e-02, -8.85829031e-02,  3.32508475e-01,
#           -4.22552414e-02,  2.93706000e-01, -7.50848234e-01,
#           -3.61093014e-01,  7.68052042e-01, -8.06724131e-01,
#            2.69344598e-02,  2.01278687e-01, -1.29122496e-01,
#            6.33762717e-01,  6.22114062e-01, -4.25702393e-01,
#            3.05899799e-01,  6.49074912e-01, -9.84596089e-02,
#            8.92209828e-01,  5.20672761e-02, -1.04415966e-02,
#            9.95566785e-01,  2.65580148e-01, -8.82838905e-01,
#            8.66708398e-01, -1.08220242e-01,  1.89955965e-01,
#            3.60632032e-01, -4.97249752e-01,  2.79886752e-01,
#           -1.03522420e+00,  4.07866240e-01, -7.50830293e-01,
#            5.08186281e-01, -7.06177592e-01,  7.75964186e-02,
#           -5.89318991e-01, -6.45632371e-02,  2.89774239e-01,
#            6.59323275e-01,  5.82968116e-01, -3.88980716e-01,
#            1.22496951e+00, -1.06814578e-01,  5.43021560e-01,
#            3.16248566e-01, -8.97694886e-01, -2.27581829e-01,
#           -2.41349995e-01, -3.98471057e-01,  4.72639143e-01,
#            2.28941590e-01, -8.18288326e-01,  5.81978619e-01,
#            2.71663636e-01, -3.53890844e-02,  1.21000564e+00,
#            1.68932825e-01,  2.61702925e-01,  4.57956702e-01,
#            2.89439540e-02, -2.60499865e-01,  9.79223922e-02,
#            1.43752232e-01,  7.85526335e-02, -3.99261490e-02,
#           -9.06772792e-01,  6.18157804e-01, -2.00251982e-01,
#            5.89356422e-01,  5.87608159e-01,  3.77268285e-01,
#            1.68994591e-01, -3.71405303e-01, -4.02045958e-02,
#            4.24762905e-01,  3.04577082e-01, -5.66921830e-02,
#            4.09399837e-01,  2.22489119e-01,  4.03810263e-01,
#            6.01519525e-01,  3.44812632e-01,  6.72078907e-01,
#            2.59630919e-01,  5.18464088e-01, -2.74108618e-01,
#            5.94089329e-01,  7.42042243e-01, -5.37706614e-01,
#           -5.84210575e-01, -3.03833604e-01, -2.46802136e-01,
#           -1.33066207e-01, -1.32000744e+00, -7.95150027e-02,
#           -6.44290030e-01,  9.48264778e-01, -1.06791091e+00,
#           -1.13925517e-01, -2.90379792e-01,  5.86695194e-01,
#            3.24566722e-01,  8.19155335e-01, -2.30308712e-01,
#            1.39636159e-01,  6.23388104e-02, -4.43448722e-01,
#            3.55245888e-01, -3.32618840e-02,  1.61654934e-01,
#            9.66681600e-01,  8.43147755e-01, -5.21646976e-01,
#           -1.00311458e+00,  1.61303744e-01,  2.19040528e-01,
#           -2.88495600e-01, -1.82459742e-01, -4.21510130e-01,
#           -1.43014342e-01, -8.95083606e-01, -9.63797569e-02,
#           -5.95339835e-01, -7.57669389e-01, -6.53257310e-01,
#           -8.64275336e-01, -7.84834802e-01, -8.27223897e-01,
#           -1.93157852e-01,  3.23685795e-01, -9.71364081e-01,
#            1.04362798e+00,  1.52827144e+00,  2.16140188e-02,
#           -5.41697562e-01,  1.58858085e+00, -2.23761752e-01,
#           -4.05709982e-01, -5.45962036e-01, -7.20010459e-01,
#           -6.24805152e-01,  1.54209912e-01, -4.22193974e-01,
#           -1.13213050e+00,  2.98298784e-02,  4.31504637e-01,
#           -1.84784263e-01, -3.50311220e-01, -7.23951876e-01,
#           -1.91485718e-01, -3.85357112e-01, -3.29802692e-01,
#           -1.76975071e-01,  1.86300039e-01,  7.77978420e-01,
#           -9.78393555e-02,  1.36241496e-01, -9.11723599e-02,
#           -4.09430683e-01, -1.55130953e-01,  1.53950140e-01,
#            4.98014748e-01, -3.59617233e-01, -1.52942568e-01,
#            3.36126164e-02,  3.60759377e-01, -6.17787838e-01,
#            7.12753739e-03,  2.90360987e-01,  7.46499240e-01,
#            5.46273649e-01, -7.45855272e-01,  2.60639459e-01,
#           -3.60502042e-02, -3.39060009e-01,  8.21223795e-01,
#           -2.59774387e-01, -2.28920639e-01,  5.04778087e-01,
#           -9.23405051e-01, -5.10599375e-01, -1.02431905e+00,
#           -3.78629833e-01, -7.31019601e-02,  4.36980784e-01,
#           -4.68581051e-01,  6.30139410e-01,  6.75193369e-01]], dtype=float32)),
#  'tp_is_first_word_lowercase': (['is_first_word_lowercase'], array([[0.]])),
#  'tp_num_alpha_chars': (['num_alpha_chars'], array([[290.]])),
#  'tp_num_cased_letters': (['num_uppercase_letters',
#    'num_lowercase_letters',
#    'fraction_uppercase_letters',
#    'fraction_lowercase_letters'],
#   array([[7.00000000e+00, 2.83000000e+02, 2.41379310e-02, 9.75862069e-01]])),
#  'tp_num_cased_word_switches': (['num_cased_word_switches'], array([[0.]])),
#  'tp_num_chars': (['num_chars'], array([[359.]])),
#  'tp_num_digits': (['num_digits'], array([[0.]])),
#  'tp_num_lowercase_after_punctuation': (['num_lowercase_letters_after_punctuation'],
#   array([[0.]])),
#  'tp_num_mixed_case_words': (['num_mixed_case_words'], array([[1.]])),
#  'tp_num_multi_spaces': (['num_multi_spaces'], array([[0.]])),
#  'tp_num_non_ascii': (['num_non_ascii'], array([[9.]])),
#  'tp_num_punctuation': (['num_punctuation'], array([[11.]])),
#  'tp_num_single_lowercase_letters': (['num_single_lowercase_letters'],
#   array([[0.]])),
#  'tp_num_words': (['num_words'], array([[59.]]))}

# %%
for extractor_name in res.keys():
    _, values = res[extractor_name][0], res[extractor_name][1]
    holder[idx]["deliverable"][extractor_name] = values
holder[idx]["num_successful_loop"] += 1

del lm_bert_model
del lm_bert_tokenizer

# %% [markdown]
# ### encode_lm_perplexity

# %%
lm_causal_model_gpt_name = lm_perplexity_model

print("preparing lm perplexity encoding")
assert no_duplicate_index(df)

# define the feature extractor
fe = FeatureExtractor(add_specific=["lm_perplexity"])
display(fe.extractors)
display(fe.necessary_params)
# Out:
# preparing lm perplexity encoding
# [<function nlp_adversarial_attacks.reactdetect.feature_extraction.extractors.language_model_properties.lm_perplexity(text_list, lm_causal_model, lm_causal_tokenizer, device, logger=None, stride=1, regions=None, feature_list=None)>]
# ['device', 'lm_causal_tokenizer', 'lm_causal_model', 'text_list']

# %%
# then load the language models (out-of-box)
print("--- loading lm")
print(f"GPT2LMHeadModel: {lm_causal_model_gpt_name}")
lm_causal_model_gpt = GPT2LMHeadModel.from_pretrained(lm_causal_model_gpt_name).to(
    CUDA_DEVICE
)
lm_causal_tokenizer_gpt = GPT2TokenizerFast.from_pretrained(lm_causal_model_gpt_name)
print("--- lm loaded")
# Out:
# --- loading lm
# GPT2LMHeadModel: gpt2
# --- lm loaded

# %%
idx = 0
res = fe(
    return_dict=True,
    text_list=pd.Series([df.at[idx, "perturbed_text"]]),
    lm_causal_model=lm_causal_model_gpt,
    lm_causal_tokenizer=lm_causal_tokenizer_gpt,
    device=CUDA_DEVICE,
)
res
# Out:
# {'lm_perplexity': (['lm_perplexity_region0',
#    'lm_perplexity_region1',
#    'lm_perplexity_region2',
#    'lm_perplexity_region3'],
#   array([[172.46365356, 134.79693604, 382.29852295, 136.00213623]]))}

# %%
for extractor_name in res.keys():
    _, values = res[extractor_name][0], res[extractor_name][1]
    holder[idx]["deliverable"][extractor_name] = values
holder[idx]["num_successful_loop"] += 1

del lm_causal_model_gpt

# %% [markdown]
# ### encode_lm_proba

# %%
lm_masked_model_roberta_name = lm_proba_model

print("preparing lm proba encoding")
assert no_duplicate_index(df)

# define the feature extractor
fe = FeatureExtractor(add_specific=["lm_proba_and_rank"])
display(fe.extractors)
display(fe.necessary_params)
# Out:
# preparing lm proba encoding
# [<function nlp_adversarial_attacks.reactdetect.feature_extraction.extractors.language_model_properties.lm_proba_and_rank(text_list, lm_masked_model, lm_masked_tokenizer, device, logger=None, quantiles=None, regions=None, feature_list=None)>]
# ['device', 'lm_masked_model', 'lm_masked_tokenizer', 'text_list']

# %%
# load mlm
print("--- loading lm")
print(f"RobertaForMaskedLM: {lm_masked_model_roberta_name}")
lm_masked_model_roberta = RobertaForMaskedLM.from_pretrained(
    lm_masked_model_roberta_name, return_dict=True
).to(CUDA_DEVICE)
lm_masked_tokenizer_roberta = RobertaTokenizer.from_pretrained(
    lm_masked_model_roberta_name
)
print("--- lm loaded")
# Out:
# --- loading lm
# RobertaForMaskedLM: roberta-base
# --- lm loaded

# %%
idx = 0
res = fe(
    return_dict=True,
    text_list=pd.Series([df.at[idx, "perturbed_text"]]),
    lm_masked_model=lm_masked_model_roberta,
    lm_masked_tokenizer=lm_masked_tokenizer_roberta,
    device=CUDA_DEVICE,
)
res
# Out:
# {'lm_proba_and_rank': (['lm_proba_mean_region0',
#    'lm_proba_var_region0',
#    'lm_proba_quant0_region0',
#    'lm_proba_quant1_region0',
#    'lm_proba_quant2_region0',
#    'lm_rank_mean_region0',
#    'lm_rank_var_region0',
#    'lm_rank_quant0_region0',
#    'lm_rank_quant1_region0',
#    'lm_rank_quant2_region0',
#    'lm_proba_mean_region1',
#    'lm_proba_var_region1',
#    'lm_proba_quant0_region1',
#    'lm_proba_quant1_region1',
#    'lm_proba_quant2_region1',
#    'lm_rank_mean_region1',
#    'lm_rank_var_region1',
#    'lm_rank_quant0_region1',
#    'lm_rank_quant1_region1',
#    'lm_rank_quant2_region1',
#    'lm_proba_mean_region2',
#    'lm_proba_var_region2',
#    'lm_proba_quant0_region2',
#    'lm_proba_quant1_region2',
#    'lm_proba_quant2_region2',
#    'lm_rank_mean_region2',
#    'lm_rank_var_region2',
#    'lm_rank_quant0_region2',
#    'lm_rank_quant1_region2',
#    'lm_rank_quant2_region2',
#    'lm_proba_mean_region3',
#    'lm_proba_var_region3',
#    'lm_proba_quant0_region3',
#    'lm_proba_quant1_region3',
#    'lm_proba_quant2_region3',
#    'lm_rank_mean_region3',
#    'lm_rank_var_region3',
#    'lm_rank_quant0_region3',
#    'lm_rank_quant1_region3',
#    'lm_rank_quant2_region3'],
#   array([[9.49145544e-01, 4.02589161e-02, 9.97613370e-01, 9.99768317e-01,
#           9.99875247e-01, 1.45833333e+00, 4.83159722e+00, 1.00000000e+00,
#           1.00000000e+00, 1.00000000e+00, 9.39923239e-01, 4.01006424e-02,
#           9.87819850e-01, 9.99570608e-01, 9.99937564e-01, 9.93181818e+01,
#           5.24124611e+05, 1.00000000e+00, 1.00000000e+00, 1.00000000e+00,
#           9.44726660e-01, 3.32240929e-02, 9.74842250e-01, 9.98805165e-01,
#           9.99964654e-01, 3.38709677e+00, 1.70946930e+02, 1.00000000e+00,
#           1.00000000e+00, 1.00000000e+00, 9.42555498e-01, 3.92343831e-02,
#           9.92722332e-01, 9.98664975e-01, 9.99882579e-01, 1.81376068e+02,
#           2.25388374e+06, 1.00000000e+00, 1.00000000e+00, 1.00000000e+00]]))}

# %%
for extractor_name in res.keys():
    _, values = res[extractor_name][0], res[extractor_name][1]
    holder[idx]["deliverable"][extractor_name] = values
holder[idx]["num_successful_loop"] += 1

del lm_masked_model_roberta

# %% [markdown]
# ### encode_tm_properties

# %%
target_model_name = tm_model
pretrained_model_name_or_path = tm_model_name_or_path

print("preparing tm properties encoding")
assert no_duplicate_index(df)
assert "target_model_dataset" in df.columns
assert "target_model" in df.columns

assert df["target_model_dataset"].nunique() == 1
target_model_dataset = df["target_model_dataset"][0]

num_labels_lookup = {
    "fnc1": 4,
    "civil_comments": 2,
    "hatebase": 2,
    "wikipedia": 2,
    "sst": 2,
    "imdb": 2,
    "climate-change_waterloo": 3,
    "nuclear_energy": 3,
    "gab_dataset": 2,
    "reddit_dataset": 2,
    "wikipedia_personal": 2,
    "allocine": 2,
}
# lookup how many labels are there
num_labels = num_labels_lookup[target_model_dataset]
# Out:
# preparing tm properties encoding

# %%
print("--- loading target model")
print(
    f"{pretrained_model_name_or_path} ({target_model_name} trained on {target_model_dataset})"
)
target_model = load_target_model(
    model_name=target_model_name,
    pretrained_model_name_or_path=pretrained_model_name_or_path,
    num_labels=num_labels,
    max_seq_len=None,
    device=CUDA_DEVICE,
)
regions = [(0.0, 0.25), (0.25, 0.75), (0.75, 1.0), (0.0, 1.0)]
print("--- target model loaded")
# Out:
# --- loading target model
# baptiste-pasquier/distilcamembert-allocine (distilcamembert trained on allocine)
# --- target model loaded

# %%
# define the feature extractor
fe = FeatureExtractor(add_tags=["tm"])
display(fe.extractors)
display(fe.necessary_params)
# Out:
# [<function nlp_adversarial_attacks.reactdetect.feature_extraction.extractors.target_model_properties.tm_activation(text_list, target_model, device, logger=None, regions=None, quantiles=None, feature_list=None)>,
#  <function nlp_adversarial_attacks.reactdetect.feature_extraction.extractors.target_model_properties.tm_gradient(text_list, labels, target_model, device='cpu', logger=None, regions=None, quantiles=None, feature_list=None)>,
#  <function nlp_adversarial_attacks.reactdetect.feature_extraction.extractors.target_model_properties.tm_posterior(text_list, target_model, device, batch_size=32, logger=None, feature_list=None)>,
#  <function nlp_adversarial_attacks.reactdetect.feature_extraction.extractors.target_model_properties.tm_saliency(text_list, labels, target_model, device, saliency_type='simple_gradient', logger=None, regions=None, quantiles=None, feature_list=None)>]
# ['device', 'target_model', 'labels', 'text_list']

# %%
idx = 0
perturbed_text = df.at[idx, "perturbed_text"]
perturbed_output = np.argmax(df.at[idx, "perturbed_output"])
res = fe(
    return_dict=True,
    text_list=pd.Series([perturbed_text]),
    labels=pd.Series([perturbed_output]),
    target_model=target_model,
    device=CUDA_DEVICE,
    regions=regions,
)
res
# Out:
# c:\Users\Baptiste\AppData\Local\pypoetry\Cache\virtualenvs\nlp-adversarial-attacks-ghBt6cj_-py3.10\lib\site-packages\torch\nn\modules\module.py:1117: UserWarning: Using a non-full backward hook when the forward contains multiple autograd Nodes is deprecated and will be removed in future versions. This hook will be missing some grad_input. Please use register_full_backward_hook to get the documented behavior.
#   warnings.warn("Using a non-full backward hook when the forward contains multiple autograd Nodes "
# {'tm_activation': (['tm_activation_mean_layer0_region0',
#    'tm_activation_var_layer0_region0',
#    'tm_activation_quant0_layer0_region0',
#    'tm_activation_quant1_layer0_region0',
#    'tm_activation_quant2_layer0_region0',
#    'tm_activation_mean_layer1_region0',
#    'tm_activation_var_layer1_region0',
#    'tm_activation_quant0_layer1_region0',
#    'tm_activation_quant1_layer1_region0',
#    'tm_activation_quant2_layer1_region0',
#    'tm_activation_mean_layer2_region0',
#    'tm_activation_var_layer2_region0',
#    'tm_activation_quant0_layer2_region0',
#    'tm_activation_quant1_layer2_region0',
#    'tm_activation_quant2_layer2_region0',
#    'tm_activation_mean_layer3_region0',
#    'tm_activation_var_layer3_region0',
#    'tm_activation_quant0_layer3_region0',
#    'tm_activation_quant1_layer3_region0',
#    'tm_activation_quant2_layer3_region0',
#    'tm_activation_mean_layer4_region0',
#    'tm_activation_var_layer4_region0',
#    'tm_activation_quant0_layer4_region0',
#    'tm_activation_quant1_layer4_region0',
#    'tm_activation_quant2_layer4_region0',
#    'tm_activation_mean_layer5_region0',
#    'tm_activation_var_layer5_region0',
#    'tm_activation_quant0_layer5_region0',
#    'tm_activation_quant1_layer5_region0',
#    'tm_activation_quant2_layer5_region0',
#    'tm_activation_mean_layer6_region0',
#    'tm_activation_var_layer6_region0',
#    'tm_activation_quant0_layer6_region0',
#    'tm_activation_quant1_layer6_region0',
#    'tm_activation_quant2_layer6_region0',
#    'tm_activation_mean_layer7_region0',
#    'tm_activation_var_layer7_region0',
#    'tm_activation_quant0_layer7_region0',
#    'tm_activation_quant1_layer7_region0',
#    'tm_activation_quant2_layer7_region0',
#    'tm_activation_mean_layer8_region0',
#    'tm_activation_var_layer8_region0',
#    'tm_activation_quant0_layer8_region0',
#    'tm_activation_quant1_layer8_region0',
#    'tm_activation_quant2_layer8_region0',
#    'tm_activation_mean_layer9_region0',
#    'tm_activation_var_layer9_region0',
#    'tm_activation_quant0_layer9_region0',
#    'tm_activation_quant1_layer9_region0',
#    'tm_activation_quant2_layer9_region0',
#    'tm_activation_mean_layer10_region0',
#    'tm_activation_var_layer10_region0',
#    'tm_activation_quant0_layer10_region0',
#    'tm_activation_quant1_layer10_region0',
#    'tm_activation_quant2_layer10_region0',
#    'tm_activation_mean_layer11_region0',
#    'tm_activation_var_layer11_region0',
#    'tm_activation_quant0_layer11_region0',
#    'tm_activation_quant1_layer11_region0',
#    'tm_activation_quant2_layer11_region0',
#    'tm_activation_mean_layer12_region0',
#    'tm_activation_var_layer12_region0',
#    'tm_activation_quant0_layer12_region0',
#    'tm_activation_quant1_layer12_region0',
#    'tm_activation_quant2_layer12_region0',
#    'tm_activation_mean_layer13_region0',
#    'tm_activation_var_layer13_region0',
#    'tm_activation_quant0_layer13_region0',
#    'tm_activation_quant1_layer13_region0',
#    'tm_activation_quant2_layer13_region0',
#    'tm_activation_mean_layer14_region0',
#    'tm_activation_var_layer14_region0',
#    'tm_activation_quant0_layer14_region0',
#    'tm_activation_quant1_layer14_region0',
#    'tm_activation_quant2_layer14_region0',
#    'tm_activation_mean_layer15_region0',
#    'tm_activation_var_layer15_region0',
#    'tm_activation_quant0_layer15_region0',
#    'tm_activation_quant1_layer15_region0',
#    'tm_activation_quant2_layer15_region0',
#    'tm_activation_mean_layer16_region0',
#    'tm_activation_var_layer16_region0',
#    'tm_activation_quant0_layer16_region0',
#    'tm_activation_quant1_layer16_region0',
#    'tm_activation_quant2_layer16_region0',
#    'tm_activation_mean_layer17_region0',
#    'tm_activation_var_layer17_region0',
#    'tm_activation_quant0_layer17_region0',
#    'tm_activation_quant1_layer17_region0',
#    'tm_activation_quant2_layer17_region0',
#    'tm_activation_mean_layer18_region0',
#    'tm_activation_var_layer18_region0',
#    'tm_activation_quant0_layer18_region0',
#    'tm_activation_quant1_layer18_region0',
#    'tm_activation_quant2_layer18_region0',
#    'tm_activation_mean_layer19_region0',
#    'tm_activation_var_layer19_region0',
#    'tm_activation_quant0_layer19_region0',
#    'tm_activation_quant1_layer19_region0',
#    'tm_activation_quant2_layer19_region0',
#    'tm_activation_mean_layer20_region0',
#    'tm_activation_var_layer20_region0',
#    'tm_activation_quant0_layer20_region0',
#    'tm_activation_quant1_layer20_region0',
#    'tm_activation_quant2_layer20_region0',
#    'tm_activation_mean_layer21_region0',
#    'tm_activation_var_layer21_region0',
#    'tm_activation_quant0_layer21_region0',
#    'tm_activation_quant1_layer21_region0',
#    'tm_activation_quant2_layer21_region0',
#    'tm_activation_mean_layer22_region0',
#    'tm_activation_var_layer22_region0',
#    'tm_activation_quant0_layer22_region0',
#    'tm_activation_quant1_layer22_region0',
#    'tm_activation_quant2_layer22_region0',
#    'tm_activation_mean_layer23_region0',
#    'tm_activation_var_layer23_region0',
#    'tm_activation_quant0_layer23_region0',
#    'tm_activation_quant1_layer23_region0',
#    'tm_activation_quant2_layer23_region0',
#    'tm_activation_mean_layer24_region0',
#    'tm_activation_var_layer24_region0',
#    'tm_activation_quant0_layer24_region0',
#    'tm_activation_quant1_layer24_region0',
#    'tm_activation_quant2_layer24_region0',
#    'tm_activation_mean_layer25_region0',
#    'tm_activation_var_layer25_region0',
#    'tm_activation_quant0_layer25_region0',
#    'tm_activation_quant1_layer25_region0',
#    'tm_activation_quant2_layer25_region0',
#    'tm_activation_mean_layer26_region0',
#    'tm_activation_var_layer26_region0',
#    'tm_activation_quant0_layer26_region0',
#    'tm_activation_quant1_layer26_region0',
#    'tm_activation_quant2_layer26_region0',
#    'tm_activation_mean_layer27_region0',
#    'tm_activation_var_layer27_region0',
#    'tm_activation_quant0_layer27_region0',
#    'tm_activation_quant1_layer27_region0',
#    'tm_activation_quant2_layer27_region0',
#    'tm_activation_mean_layer28_region0',
#    'tm_activation_var_layer28_region0',
#    'tm_activation_quant0_layer28_region0',
#    'tm_activation_quant1_layer28_region0',
#    'tm_activation_quant2_layer28_region0',
#    'tm_activation_mean_layer29_region0',
#    'tm_activation_var_layer29_region0',
#    'tm_activation_quant0_layer29_region0',
#    'tm_activation_quant1_layer29_region0',
#    'tm_activation_quant2_layer29_region0',
#    'tm_activation_mean_layer30_region0',
#    'tm_activation_var_layer30_region0',
#    'tm_activation_quant0_layer30_region0',
#    'tm_activation_quant1_layer30_region0',
#    'tm_activation_quant2_layer30_region0',
#    'tm_activation_mean_layer31_region0',
#    'tm_activation_var_layer31_region0',
#    'tm_activation_quant0_layer31_region0',
#    'tm_activation_quant1_layer31_region0',
#    'tm_activation_quant2_layer31_region0',
#    'tm_activation_mean_layer32_region0',
#    'tm_activation_var_layer32_region0',
#    'tm_activation_quant0_layer32_region0',
#    'tm_activation_quant1_layer32_region0',
#    'tm_activation_quant2_layer32_region0',
#    'tm_activation_mean_layer33_region0',
#    'tm_activation_var_layer33_region0',
#    'tm_activation_quant0_layer33_region0',
#    'tm_activation_quant1_layer33_region0',
#    'tm_activation_quant2_layer33_region0',
#    'tm_activation_mean_layer34_region0',
#    'tm_activation_var_layer34_region0',
#    'tm_activation_quant0_layer34_region0',
#    'tm_activation_quant1_layer34_region0',
#    'tm_activation_quant2_layer34_region0',
#    'tm_activation_mean_layer35_region0',
#    'tm_activation_var_layer35_region0',
#    'tm_activation_quant0_layer35_region0',
#    'tm_activation_quant1_layer35_region0',
#    'tm_activation_quant2_layer35_region0',
#    'tm_activation_mean_layer36_region0',
#    'tm_activation_var_layer36_region0',
#    'tm_activation_quant0_layer36_region0',
#    'tm_activation_quant1_layer36_region0',
#    'tm_activation_quant2_layer36_region0',
#    'tm_activation_mean_layer37_region0',
#    'tm_activation_var_layer37_region0',
#    'tm_activation_quant0_layer37_region0',
#    'tm_activation_quant1_layer37_region0',
#    'tm_activation_quant2_layer37_region0',
#    'tm_activation_mean_layer38_region0',
#    'tm_activation_var_layer38_region0',
#    'tm_activation_quant0_layer38_region0',
#    'tm_activation_quant1_layer38_region0',
#    'tm_activation_quant2_layer38_region0',
#    'tm_activation_mean_layer39_region0',
#    'tm_activation_var_layer39_region0',
#    'tm_activation_quant0_layer39_region0',
#    'tm_activation_quant1_layer39_region0',
#    'tm_activation_quant2_layer39_region0',
#    'tm_activation_mean_layer40_region0',
#    'tm_activation_var_layer40_region0',
#    'tm_activation_quant0_layer40_region0',
#    'tm_activation_quant1_layer40_region0',
#    'tm_activation_quant2_layer40_region0',
#    'tm_activation_mean_layer41_region0',
#    'tm_activation_var_layer41_region0',
#    'tm_activation_quant0_layer41_region0',
#    'tm_activation_quant1_layer41_region0',
#    'tm_activation_quant2_layer41_region0',
#    'tm_activation_mean_layer42_region0',
#    'tm_activation_var_layer42_region0',
#    'tm_activation_quant0_layer42_region0',
#    'tm_activation_quant1_layer42_region0',
#    'tm_activation_quant2_layer42_region0',
#    'tm_activation_mean_layer43_region0',
#    'tm_activation_var_layer43_region0',
#    'tm_activation_quant0_layer43_region0',
#    'tm_activation_quant1_layer43_region0',
#    'tm_activation_quant2_layer43_region0',
#    'tm_activation_mean_layer44_region0',
#    'tm_activation_var_layer44_region0',
#    'tm_activation_quant0_layer44_region0',
#    'tm_activation_quant1_layer44_region0',
#    'tm_activation_quant2_layer44_region0',
#    'tm_activation_mean_layer45_region0',
#    'tm_activation_var_layer45_region0',
#    'tm_activation_quant0_layer45_region0',
#    'tm_activation_quant1_layer45_region0',
#    'tm_activation_quant2_layer45_region0',
#    'tm_activation_mean_layer46_region0',
#    'tm_activation_var_layer46_region0',
#    'tm_activation_quant0_layer46_region0',
#    'tm_activation_quant1_layer46_region0',
#    'tm_activation_quant2_layer46_region0',
#    'tm_activation_mean_layer47_region0',
#    'tm_activation_var_layer47_region0',
#    'tm_activation_quant0_layer47_region0',
#    'tm_activation_quant1_layer47_region0',
#    'tm_activation_quant2_layer47_region0',
#    'tm_activation_mean_layer48_region0',
#    'tm_activation_var_layer48_region0',
#    'tm_activation_quant0_layer48_region0',
#    'tm_activation_quant1_layer48_region0',
#    'tm_activation_quant2_layer48_region0',
#    'tm_activation_mean_layer49_region0',
#    'tm_activation_var_layer49_region0',
#    'tm_activation_quant0_layer49_region0',
#    'tm_activation_quant1_layer49_region0',
#    'tm_activation_quant2_layer49_region0',
#    'tm_activation_mean_layer50_region0',
#    'tm_activation_var_layer50_region0',
#    'tm_activation_quant0_layer50_region0',
#    'tm_activation_quant1_layer50_region0',
#    'tm_activation_quant2_layer50_region0',
#    'tm_activation_mean_layer51_region0',
#    'tm_activation_var_layer51_region0',
#    'tm_activation_quant0_layer51_region0',
#    'tm_activation_quant1_layer51_region0',
#    'tm_activation_quant2_layer51_region0',
#    'tm_activation_mean_layer52_region0',
#    'tm_activation_var_layer52_region0',
#    'tm_activation_quant0_layer52_region0',
#    'tm_activation_quant1_layer52_region0',
#    'tm_activation_quant2_layer52_region0',
#    'tm_activation_mean_layer53_region0',
#    'tm_activation_var_layer53_region0',
#    'tm_activation_quant0_layer53_region0',
#    'tm_activation_quant1_layer53_region0',
#    'tm_activation_quant2_layer53_region0',
#    'tm_activation_mean_layer54_region0',
#    'tm_activation_var_layer54_region0',
#    'tm_activation_quant0_layer54_region0',
#    'tm_activation_quant1_layer54_region0',
#    'tm_activation_quant2_layer54_region0',
#    'tm_activation_mean_layer55_region0',
#    'tm_activation_var_layer55_region0',
#    'tm_activation_quant0_layer55_region0',
#    'tm_activation_quant1_layer55_region0',
#    'tm_activation_quant2_layer55_region0',
#    'tm_activation_mean_layer56_region0',
#    'tm_activation_var_layer56_region0',
#    'tm_activation_quant0_layer56_region0',
#    'tm_activation_quant1_layer56_region0',
#    'tm_activation_quant2_layer56_region0',
#    'tm_activation_mean_layer57_region0',
#    'tm_activation_var_layer57_region0',
#    'tm_activation_quant0_layer57_region0',
#    'tm_activation_quant1_layer57_region0',
#    'tm_activation_quant2_layer57_region0',
#    'tm_activation_mean_layer58_region0',
#    'tm_activation_var_layer58_region0',
#    'tm_activation_quant0_layer58_region0',
#    'tm_activation_quant1_layer58_region0',
#    'tm_activation_quant2_layer58_region0',
#    'tm_activation_mean_layer59_region0',
#    'tm_activation_var_layer59_region0',
#    'tm_activation_quant0_layer59_region0',
#    'tm_activation_quant1_layer59_region0',
#    'tm_activation_quant2_layer59_region0',
#    'tm_activation_mean_layer60_region0',
#    'tm_activation_var_layer60_region0',
#    'tm_activation_quant0_layer60_region0',
#    'tm_activation_quant1_layer60_region0',
#    'tm_activation_quant2_layer60_region0',
#    'tm_activation_mean_layer61_region0',
#    'tm_activation_var_layer61_region0',
#    'tm_activation_quant0_layer61_region0',
#    'tm_activation_quant1_layer61_region0',
#    'tm_activation_quant2_layer61_region0',
#    'tm_activation_mean_layer62_region0',
#    'tm_activation_var_layer62_region0',
#    'tm_activation_quant0_layer62_region0',
#    'tm_activation_quant1_layer62_region0',
#    'tm_activation_quant2_layer62_region0',
#    'tm_activation_mean_layer63_region0',
#    'tm_activation_var_layer63_region0',
#    'tm_activation_quant0_layer63_region0',
#    'tm_activation_quant1_layer63_region0',
#    'tm_activation_quant2_layer63_region0',
#    'tm_activation_mean_layer64_region0',
#    'tm_activation_var_layer64_region0',
#    'tm_activation_quant0_layer64_region0',
#    'tm_activation_quant1_layer64_region0',
#    'tm_activation_quant2_layer64_region0',
#    'tm_activation_mean_layer65_region0',
#    'tm_activation_var_layer65_region0',
#    'tm_activation_quant0_layer65_region0',
#    'tm_activation_quant1_layer65_region0',
#    'tm_activation_quant2_layer65_region0',
#    'tm_activation_mean_layer66_region0',
#    'tm_activation_var_layer66_region0',
#    'tm_activation_quant0_layer66_region0',
#    'tm_activation_quant1_layer66_region0',
#    'tm_activation_quant2_layer66_region0',
#    'tm_activation_mean_layer67_region0',
#    'tm_activation_var_layer67_region0',
#    'tm_activation_quant0_layer67_region0',
#    'tm_activation_quant1_layer67_region0',
#    'tm_activation_quant2_layer67_region0',
#    'tm_activation_mean_layer68_region0',
#    'tm_activation_var_layer68_region0',
#    'tm_activation_quant0_layer68_region0',
#    'tm_activation_quant1_layer68_region0',
#    'tm_activation_quant2_layer68_region0',
#    'tm_activation_mean_layer69_region0',
#    'tm_activation_var_layer69_region0',
#    'tm_activation_quant0_layer69_region0',
#    'tm_activation_quant1_layer69_region0',
#    'tm_activation_quant2_layer69_region0',
#    'tm_activation_mean_layer70_region0',
#    'tm_activation_var_layer70_region0',
#    'tm_activation_quant0_layer70_region0',
#    'tm_activation_quant1_layer70_region0',
#    'tm_activation_quant2_layer70_region0',
#    'tm_activation_mean_layer71_region0',
#    'tm_activation_var_layer71_region0',
#    'tm_activation_quant0_layer71_region0',
#    'tm_activation_quant1_layer71_region0',
#    'tm_activation_quant2_layer71_region0',
#    'tm_activation_mean_layer72_region0',
#    'tm_activation_var_layer72_region0',
#    'tm_activation_quant0_layer72_region0',
#    'tm_activation_quant1_layer72_region0',
#    'tm_activation_quant2_layer72_region0',
#    'tm_activation_mean_layer73_region0',
#    'tm_activation_var_layer73_region0',
#    'tm_activation_quant0_layer73_region0',
#    'tm_activation_quant1_layer73_region0',
#    'tm_activation_quant2_layer73_region0',
#    'tm_activation_mean_layer74_region0',
#    'tm_activation_var_layer74_region0',
#    'tm_activation_quant0_layer74_region0',
#    'tm_activation_quant1_layer74_region0',
#    'tm_activation_quant2_layer74_region0',
#    'tm_activation_mean_layer75_region0',
#    'tm_activation_var_layer75_region0',
#    'tm_activation_quant0_layer75_region0',
#    'tm_activation_quant1_layer75_region0',
#    'tm_activation_quant2_layer75_region0',
#    'tm_activation_mean_layer76_region0',
#    'tm_activation_var_layer76_region0',
#    'tm_activation_quant0_layer76_region0',
#    'tm_activation_quant1_layer76_region0',
#    'tm_activation_quant2_layer76_region0',
#    'tm_activation_mean_layer77_region0',
#    'tm_activation_var_layer77_region0',
#    'tm_activation_quant0_layer77_region0',
#    'tm_activation_quant1_layer77_region0',
#    'tm_activation_quant2_layer77_region0',
#    'tm_activation_mean_layer78_region0',
#    'tm_activation_var_layer78_region0',
#    'tm_activation_quant0_layer78_region0',
#    'tm_activation_quant1_layer78_region0',
#    'tm_activation_quant2_layer78_region0',
#    'tm_activation_mean_layer79_region0',
#    'tm_activation_var_layer79_region0',
#    'tm_activation_quant0_layer79_region0',
#    'tm_activation_quant1_layer79_region0',
#    'tm_activation_quant2_layer79_region0',
#    'tm_activation_mean_layer80_region0',
#    'tm_activation_var_layer80',
#    'tm_activation_mean_layer0_region1',
#    'tm_activation_var_layer0_region1',
#    'tm_activation_quant0_layer0_region1',
#    'tm_activation_quant1_layer0_region1',
#    'tm_activation_quant2_layer0_region1',
#    'tm_activation_mean_layer1_region1',
#    'tm_activation_var_layer1_region1',
#    'tm_activation_quant0_layer1_region1',
#    'tm_activation_quant1_layer1_region1',
#    'tm_activation_quant2_layer1_region1',
#    'tm_activation_mean_layer2_region1',
#    'tm_activation_var_layer2_region1',
#    'tm_activation_quant0_layer2_region1',
#    'tm_activation_quant1_layer2_region1',
#    'tm_activation_quant2_layer2_region1',
#    'tm_activation_mean_layer3_region1',
#    'tm_activation_var_layer3_region1',
#    'tm_activation_quant0_layer3_region1',
#    'tm_activation_quant1_layer3_region1',
#    'tm_activation_quant2_layer3_region1',
#    'tm_activation_mean_layer4_region1',
#    'tm_activation_var_layer4_region1',
#    'tm_activation_quant0_layer4_region1',
#    'tm_activation_quant1_layer4_region1',
#    'tm_activation_quant2_layer4_region1',
#    'tm_activation_mean_layer5_region1',
#    'tm_activation_var_layer5_region1',
#    'tm_activation_quant0_layer5_region1',
#    'tm_activation_quant1_layer5_region1',
#    'tm_activation_quant2_layer5_region1',
#    'tm_activation_mean_layer6_region1',
#    'tm_activation_var_layer6_region1',
#    'tm_activation_quant0_layer6_region1',
#    'tm_activation_quant1_layer6_region1',
#    'tm_activation_quant2_layer6_region1',
#    'tm_activation_mean_layer7_region1',
#    'tm_activation_var_layer7_region1',
#    'tm_activation_quant0_layer7_region1',
#    'tm_activation_quant1_layer7_region1',
#    'tm_activation_quant2_layer7_region1',
#    'tm_activation_mean_layer8_region1',
#    'tm_activation_var_layer8_region1',
#    'tm_activation_quant0_layer8_region1',
#    'tm_activation_quant1_layer8_region1',
#    'tm_activation_quant2_layer8_region1',
#    'tm_activation_mean_layer9_region1',
#    'tm_activation_var_layer9_region1',
#    'tm_activation_quant0_layer9_region1',
#    'tm_activation_quant1_layer9_region1',
#    'tm_activation_quant2_layer9_region1',
#    'tm_activation_mean_layer10_region1',
#    'tm_activation_var_layer10_region1',
#    'tm_activation_quant0_layer10_region1',
#    'tm_activation_quant1_layer10_region1',
#    'tm_activation_quant2_layer10_region1',
#    'tm_activation_mean_layer11_region1',
#    'tm_activation_var_layer11_region1',
#    'tm_activation_quant0_layer11_region1',
#    'tm_activation_quant1_layer11_region1',
#    'tm_activation_quant2_layer11_region1',
#    'tm_activation_mean_layer12_region1',
#    'tm_activation_var_layer12_region1',
#    'tm_activation_quant0_layer12_region1',
#    'tm_activation_quant1_layer12_region1',
#    'tm_activation_quant2_layer12_region1',
#    'tm_activation_mean_layer13_region1',
#    'tm_activation_var_layer13_region1',
#    'tm_activation_quant0_layer13_region1',
#    'tm_activation_quant1_layer13_region1',
#    'tm_activation_quant2_layer13_region1',
#    'tm_activation_mean_layer14_region1',
#    'tm_activation_var_layer14_region1',
#    'tm_activation_quant0_layer14_region1',
#    'tm_activation_quant1_layer14_region1',
#    'tm_activation_quant2_layer14_region1',
#    'tm_activation_mean_layer15_region1',
#    'tm_activation_var_layer15_region1',
#    'tm_activation_quant0_layer15_region1',
#    'tm_activation_quant1_layer15_region1',
#    'tm_activation_quant2_layer15_region1',
#    'tm_activation_mean_layer16_region1',
#    'tm_activation_var_layer16_region1',
#    'tm_activation_quant0_layer16_region1',
#    'tm_activation_quant1_layer16_region1',
#    'tm_activation_quant2_layer16_region1',
#    'tm_activation_mean_layer17_region1',
#    'tm_activation_var_layer17_region1',
#    'tm_activation_quant0_layer17_region1',
#    'tm_activation_quant1_layer17_region1',
#    'tm_activation_quant2_layer17_region1',
#    'tm_activation_mean_layer18_region1',
#    'tm_activation_var_layer18_region1',
#    'tm_activation_quant0_layer18_region1',
#    'tm_activation_quant1_layer18_region1',
#    'tm_activation_quant2_layer18_region1',
#    'tm_activation_mean_layer19_region1',
#    'tm_activation_var_layer19_region1',
#    'tm_activation_quant0_layer19_region1',
#    'tm_activation_quant1_layer19_region1',
#    'tm_activation_quant2_layer19_region1',
#    'tm_activation_mean_layer20_region1',
#    'tm_activation_var_layer20_region1',
#    'tm_activation_quant0_layer20_region1',
#    'tm_activation_quant1_layer20_region1',
#    'tm_activation_quant2_layer20_region1',
#    'tm_activation_mean_layer21_region1',
#    'tm_activation_var_layer21_region1',
#    'tm_activation_quant0_layer21_region1',
#    'tm_activation_quant1_layer21_region1',
#    'tm_activation_quant2_layer21_region1',
#    'tm_activation_mean_layer22_region1',
#    'tm_activation_var_layer22_region1',
#    'tm_activation_quant0_layer22_region1',
#    'tm_activation_quant1_layer22_region1',
#    'tm_activation_quant2_layer22_region1',
#    'tm_activation_mean_layer23_region1',
#    'tm_activation_var_layer23_region1',
#    'tm_activation_quant0_layer23_region1',
#    'tm_activation_quant1_layer23_region1',
#    'tm_activation_quant2_layer23_region1',
#    'tm_activation_mean_layer24_region1',
#    'tm_activation_var_layer24_region1',
#    'tm_activation_quant0_layer24_region1',
#    'tm_activation_quant1_layer24_region1',
#    'tm_activation_quant2_layer24_region1',
#    'tm_activation_mean_layer25_region1',
#    'tm_activation_var_layer25_region1',
#    'tm_activation_quant0_layer25_region1',
#    'tm_activation_quant1_layer25_region1',
#    'tm_activation_quant2_layer25_region1',
#    'tm_activation_mean_layer26_region1',
#    'tm_activation_var_layer26_region1',
#    'tm_activation_quant0_layer26_region1',
#    'tm_activation_quant1_layer26_region1',
#    'tm_activation_quant2_layer26_region1',
#    'tm_activation_mean_layer27_region1',
#    'tm_activation_var_layer27_region1',
#    'tm_activation_quant0_layer27_region1',
#    'tm_activation_quant1_layer27_region1',
#    'tm_activation_quant2_layer27_region1',
#    'tm_activation_mean_layer28_region1',
#    'tm_activation_var_layer28_region1',
#    'tm_activation_quant0_layer28_region1',
#    'tm_activation_quant1_layer28_region1',
#    'tm_activation_quant2_layer28_region1',
#    'tm_activation_mean_layer29_region1',
#    'tm_activation_var_layer29_region1',
#    'tm_activation_quant0_layer29_region1',
#    'tm_activation_quant1_layer29_region1',
#    'tm_activation_quant2_layer29_region1',
#    'tm_activation_mean_layer30_region1',
#    'tm_activation_var_layer30_region1',
#    'tm_activation_quant0_layer30_region1',
#    'tm_activation_quant1_layer30_region1',
#    'tm_activation_quant2_layer30_region1',
#    'tm_activation_mean_layer31_region1',
#    'tm_activation_var_layer31_region1',
#    'tm_activation_quant0_layer31_region1',
#    'tm_activation_quant1_layer31_region1',
#    'tm_activation_quant2_layer31_region1',
#    'tm_activation_mean_layer32_region1',
#    'tm_activation_var_layer32_region1',
#    'tm_activation_quant0_layer32_region1',
#    'tm_activation_quant1_layer32_region1',
#    'tm_activation_quant2_layer32_region1',
#    'tm_activation_mean_layer33_region1',
#    'tm_activation_var_layer33_region1',
#    'tm_activation_quant0_layer33_region1',
#    'tm_activation_quant1_layer33_region1',
#    'tm_activation_quant2_layer33_region1',
#    'tm_activation_mean_layer34_region1',
#    'tm_activation_var_layer34_region1',
#    'tm_activation_quant0_layer34_region1',
#    'tm_activation_quant1_layer34_region1',
#    'tm_activation_quant2_layer34_region1',
#    'tm_activation_mean_layer35_region1',
#    'tm_activation_var_layer35_region1',
#    'tm_activation_quant0_layer35_region1',
#    'tm_activation_quant1_layer35_region1',
#    'tm_activation_quant2_layer35_region1',
#    'tm_activation_mean_layer36_region1',
#    'tm_activation_var_layer36_region1',
#    'tm_activation_quant0_layer36_region1',
#    'tm_activation_quant1_layer36_region1',
#    'tm_activation_quant2_layer36_region1',
#    'tm_activation_mean_layer37_region1',
#    'tm_activation_var_layer37_region1',
#    'tm_activation_quant0_layer37_region1',
#    'tm_activation_quant1_layer37_region1',
#    'tm_activation_quant2_layer37_region1',
#    'tm_activation_mean_layer38_region1',
#    'tm_activation_var_layer38_region1',
#    'tm_activation_quant0_layer38_region1',
#    'tm_activation_quant1_layer38_region1',
#    'tm_activation_quant2_layer38_region1',
#    'tm_activation_mean_layer39_region1',
#    'tm_activation_var_layer39_region1',
#    'tm_activation_quant0_layer39_region1',
#    'tm_activation_quant1_layer39_region1',
#    'tm_activation_quant2_layer39_region1',
#    'tm_activation_mean_layer40_region1',
#    'tm_activation_var_layer40_region1',
#    'tm_activation_quant0_layer40_region1',
#    'tm_activation_quant1_layer40_region1',
#    'tm_activation_quant2_layer40_region1',
#    'tm_activation_mean_layer41_region1',
#    'tm_activation_var_layer41_region1',
#    'tm_activation_quant0_layer41_region1',
#    'tm_activation_quant1_layer41_region1',
#    'tm_activation_quant2_layer41_region1',
#    'tm_activation_mean_layer42_region1',
#    'tm_activation_var_layer42_region1',
#    'tm_activation_quant0_layer42_region1',
#    'tm_activation_quant1_layer42_region1',
#    'tm_activation_quant2_layer42_region1',
#    'tm_activation_mean_layer43_region1',
#    'tm_activation_var_layer43_region1',
#    'tm_activation_quant0_layer43_region1',
#    'tm_activation_quant1_layer43_region1',
#    'tm_activation_quant2_layer43_region1',
#    'tm_activation_mean_layer44_region1',
#    'tm_activation_var_layer44_region1',
#    'tm_activation_quant0_layer44_region1',
#    'tm_activation_quant1_layer44_region1',
#    'tm_activation_quant2_layer44_region1',
#    'tm_activation_mean_layer45_region1',
#    'tm_activation_var_layer45_region1',
#    'tm_activation_quant0_layer45_region1',
#    'tm_activation_quant1_layer45_region1',
#    'tm_activation_quant2_layer45_region1',
#    'tm_activation_mean_layer46_region1',
#    'tm_activation_var_layer46_region1',
#    'tm_activation_quant0_layer46_region1',
#    'tm_activation_quant1_layer46_region1',
#    'tm_activation_quant2_layer46_region1',
#    'tm_activation_mean_layer47_region1',
#    'tm_activation_var_layer47_region1',
#    'tm_activation_quant0_layer47_region1',
#    'tm_activation_quant1_layer47_region1',
#    'tm_activation_quant2_layer47_region1',
#    'tm_activation_mean_layer48_region1',
#    'tm_activation_var_layer48_region1',
#    'tm_activation_quant0_layer48_region1',
#    'tm_activation_quant1_layer48_region1',
#    'tm_activation_quant2_layer48_region1',
#    'tm_activation_mean_layer49_region1',
#    'tm_activation_var_layer49_region1',
#    'tm_activation_quant0_layer49_region1',
#    'tm_activation_quant1_layer49_region1',
#    'tm_activation_quant2_layer49_region1',
#    'tm_activation_mean_layer50_region1',
#    'tm_activation_var_layer50_region1',
#    'tm_activation_quant0_layer50_region1',
#    'tm_activation_quant1_layer50_region1',
#    'tm_activation_quant2_layer50_region1',
#    'tm_activation_mean_layer51_region1',
#    'tm_activation_var_layer51_region1',
#    'tm_activation_quant0_layer51_region1',
#    'tm_activation_quant1_layer51_region1',
#    'tm_activation_quant2_layer51_region1',
#    'tm_activation_mean_layer52_region1',
#    'tm_activation_var_layer52_region1',
#    'tm_activation_quant0_layer52_region1',
#    'tm_activation_quant1_layer52_region1',
#    'tm_activation_quant2_layer52_region1',
#    'tm_activation_mean_layer53_region1',
#    'tm_activation_var_layer53_region1',
#    'tm_activation_quant0_layer53_region1',
#    'tm_activation_quant1_layer53_region1',
#    'tm_activation_quant2_layer53_region1',
#    'tm_activation_mean_layer54_region1',
#    'tm_activation_var_layer54_region1',
#    'tm_activation_quant0_layer54_region1',
#    'tm_activation_quant1_layer54_region1',
#    'tm_activation_quant2_layer54_region1',
#    'tm_activation_mean_layer55_region1',
#    'tm_activation_var_layer55_region1',
#    'tm_activation_quant0_layer55_region1',
#    'tm_activation_quant1_layer55_region1',
#    'tm_activation_quant2_layer55_region1',
#    'tm_activation_mean_layer56_region1',
#    'tm_activation_var_layer56_region1',
#    'tm_activation_quant0_layer56_region1',
#    'tm_activation_quant1_layer56_region1',
#    'tm_activation_quant2_layer56_region1',
#    'tm_activation_mean_layer57_region1',
#    'tm_activation_var_layer57_region1',
#    'tm_activation_quant0_layer57_region1',
#    'tm_activation_quant1_layer57_region1',
#    'tm_activation_quant2_layer57_region1',
#    'tm_activation_mean_layer58_region1',
#    'tm_activation_var_layer58_region1',
#    'tm_activation_quant0_layer58_region1',
#    'tm_activation_quant1_layer58_region1',
#    'tm_activation_quant2_layer58_region1',
#    'tm_activation_mean_layer59_region1',
#    'tm_activation_var_layer59_region1',
#    'tm_activation_quant0_layer59_region1',
#    'tm_activation_quant1_layer59_region1',
#    'tm_activation_quant2_layer59_region1',
#    'tm_activation_mean_layer60_region1',
#    'tm_activation_var_layer60_region1',
#    'tm_activation_quant0_layer60_region1',
#    'tm_activation_quant1_layer60_region1',
#    'tm_activation_quant2_layer60_region1',
#    'tm_activation_mean_layer61_region1',
#    'tm_activation_var_layer61_region1',
#    'tm_activation_quant0_layer61_region1',
#    'tm_activation_quant1_layer61_region1',
#    'tm_activation_quant2_layer61_region1',
#    'tm_activation_mean_layer62_region1',
#    'tm_activation_var_layer62_region1',
#    'tm_activation_quant0_layer62_region1',
#    'tm_activation_quant1_layer62_region1',
#    'tm_activation_quant2_layer62_region1',
#    'tm_activation_mean_layer63_region1',
#    'tm_activation_var_layer63_region1',
#    'tm_activation_quant0_layer63_region1',
#    'tm_activation_quant1_layer63_region1',
#    'tm_activation_quant2_layer63_region1',
#    'tm_activation_mean_layer64_region1',
#    'tm_activation_var_layer64_region1',
#    'tm_activation_quant0_layer64_region1',
#    'tm_activation_quant1_layer64_region1',
#    'tm_activation_quant2_layer64_region1',
#    'tm_activation_mean_layer65_region1',
#    'tm_activation_var_layer65_region1',
#    'tm_activation_quant0_layer65_region1',
#    'tm_activation_quant1_layer65_region1',
#    'tm_activation_quant2_layer65_region1',
#    'tm_activation_mean_layer66_region1',
#    'tm_activation_var_layer66_region1',
#    'tm_activation_quant0_layer66_region1',
#    'tm_activation_quant1_layer66_region1',
#    'tm_activation_quant2_layer66_region1',
#    'tm_activation_mean_layer67_region1',
#    'tm_activation_var_layer67_region1',
#    'tm_activation_quant0_layer67_region1',
#    'tm_activation_quant1_layer67_region1',
#    'tm_activation_quant2_layer67_region1',
#    'tm_activation_mean_layer68_region1',
#    'tm_activation_var_layer68_region1',
#    'tm_activation_quant0_layer68_region1',
#    'tm_activation_quant1_layer68_region1',
#    'tm_activation_quant2_layer68_region1',
#    'tm_activation_mean_layer69_region1',
#    'tm_activation_var_layer69_region1',
#    'tm_activation_quant0_layer69_region1',
#    'tm_activation_quant1_layer69_region1',
#    'tm_activation_quant2_layer69_region1',
#    'tm_activation_mean_layer70_region1',
#    'tm_activation_var_layer70_region1',
#    'tm_activation_quant0_layer70_region1',
#    'tm_activation_quant1_layer70_region1',
#    'tm_activation_quant2_layer70_region1',
#    'tm_activation_mean_layer71_region1',
#    'tm_activation_var_layer71_region1',
#    'tm_activation_quant0_layer71_region1',
#    'tm_activation_quant1_layer71_region1',
#    'tm_activation_quant2_layer71_region1',
#    'tm_activation_mean_layer72_region1',
#    'tm_activation_var_layer72_region1',
#    'tm_activation_quant0_layer72_region1',
#    'tm_activation_quant1_layer72_region1',
#    'tm_activation_quant2_layer72_region1',
#    'tm_activation_mean_layer73_region1',
#    'tm_activation_var_layer73_region1',
#    'tm_activation_quant0_layer73_region1',
#    'tm_activation_quant1_layer73_region1',
#    'tm_activation_quant2_layer73_region1',
#    'tm_activation_mean_layer74_region1',
#    'tm_activation_var_layer74_region1',
#    'tm_activation_quant0_layer74_region1',
#    'tm_activation_quant1_layer74_region1',
#    'tm_activation_quant2_layer74_region1',
#    'tm_activation_mean_layer75_region1',
#    'tm_activation_var_layer75_region1',
#    'tm_activation_quant0_layer75_region1',
#    'tm_activation_quant1_layer75_region1',
#    'tm_activation_quant2_layer75_region1',
#    'tm_activation_mean_layer76_region1',
#    'tm_activation_var_layer76_region1',
#    'tm_activation_quant0_layer76_region1',
#    'tm_activation_quant1_layer76_region1',
#    'tm_activation_quant2_layer76_region1',
#    'tm_activation_mean_layer77_region1',
#    'tm_activation_var_layer77_region1',
#    'tm_activation_quant0_layer77_region1',
#    'tm_activation_quant1_layer77_region1',
#    'tm_activation_quant2_layer77_region1',
#    'tm_activation_mean_layer78_region1',
#    'tm_activation_var_layer78_region1',
#    'tm_activation_quant0_layer78_region1',
#    'tm_activation_quant1_layer78_region1',
#    'tm_activation_quant2_layer78_region1',
#    'tm_activation_mean_layer79_region1',
#    'tm_activation_var_layer79_region1',
#    'tm_activation_quant0_layer79_region1',
#    'tm_activation_quant1_layer79_region1',
#    'tm_activation_quant2_layer79_region1',
#    'tm_activation_mean_layer80_region1',
#    'tm_activation_var_layer80',
#    'tm_activation_mean_layer0_region2',
#    'tm_activation_var_layer0_region2',
#    'tm_activation_quant0_layer0_region2',
#    'tm_activation_quant1_layer0_region2',
#    'tm_activation_quant2_layer0_region2',
#    'tm_activation_mean_layer1_region2',
#    'tm_activation_var_layer1_region2',
#    'tm_activation_quant0_layer1_region2',
#    'tm_activation_quant1_layer1_region2',
#    'tm_activation_quant2_layer1_region2',
#    'tm_activation_mean_layer2_region2',
#    'tm_activation_var_layer2_region2',
#    'tm_activation_quant0_layer2_region2',
#    'tm_activation_quant1_layer2_region2',
#    'tm_activation_quant2_layer2_region2',
#    'tm_activation_mean_layer3_region2',
#    'tm_activation_var_layer3_region2',
#    'tm_activation_quant0_layer3_region2',
#    'tm_activation_quant1_layer3_region2',
#    'tm_activation_quant2_layer3_region2',
#    'tm_activation_mean_layer4_region2',
#    'tm_activation_var_layer4_region2',
#    'tm_activation_quant0_layer4_region2',
#    'tm_activation_quant1_layer4_region2',
#    'tm_activation_quant2_layer4_region2',
#    'tm_activation_mean_layer5_region2',
#    'tm_activation_var_layer5_region2',
#    'tm_activation_quant0_layer5_region2',
#    'tm_activation_quant1_layer5_region2',
#    'tm_activation_quant2_layer5_region2',
#    'tm_activation_mean_layer6_region2',
#    'tm_activation_var_layer6_region2',
#    'tm_activation_quant0_layer6_region2',
#    'tm_activation_quant1_layer6_region2',
#    'tm_activation_quant2_layer6_region2',
#    'tm_activation_mean_layer7_region2',
#    'tm_activation_var_layer7_region2',
#    'tm_activation_quant0_layer7_region2',
#    'tm_activation_quant1_layer7_region2',
#    'tm_activation_quant2_layer7_region2',
#    'tm_activation_mean_layer8_region2',
#    'tm_activation_var_layer8_region2',
#    'tm_activation_quant0_layer8_region2',
#    'tm_activation_quant1_layer8_region2',
#    'tm_activation_quant2_layer8_region2',
#    'tm_activation_mean_layer9_region2',
#    'tm_activation_var_layer9_region2',
#    'tm_activation_quant0_layer9_region2',
#    'tm_activation_quant1_layer9_region2',
#    'tm_activation_quant2_layer9_region2',
#    'tm_activation_mean_layer10_region2',
#    'tm_activation_var_layer10_region2',
#    'tm_activation_quant0_layer10_region2',
#    'tm_activation_quant1_layer10_region2',
#    'tm_activation_quant2_layer10_region2',
#    'tm_activation_mean_layer11_region2',
#    'tm_activation_var_layer11_region2',
#    'tm_activation_quant0_layer11_region2',
#    'tm_activation_quant1_layer11_region2',
#    'tm_activation_quant2_layer11_region2',
#    'tm_activation_mean_layer12_region2',
#    'tm_activation_var_layer12_region2',
#    'tm_activation_quant0_layer12_region2',
#    'tm_activation_quant1_layer12_region2',
#    'tm_activation_quant2_layer12_region2',
#    'tm_activation_mean_layer13_region2',
#    'tm_activation_var_layer13_region2',
#    'tm_activation_quant0_layer13_region2',
#    'tm_activation_quant1_layer13_region2',
#    'tm_activation_quant2_layer13_region2',
#    'tm_activation_mean_layer14_region2',
#    'tm_activation_var_layer14_region2',
#    'tm_activation_quant0_layer14_region2',
#    'tm_activation_quant1_layer14_region2',
#    'tm_activation_quant2_layer14_region2',
#    'tm_activation_mean_layer15_region2',
#    'tm_activation_var_layer15_region2',
#    'tm_activation_quant0_layer15_region2',
#    'tm_activation_quant1_layer15_region2',
#    'tm_activation_quant2_layer15_region2',
#    'tm_activation_mean_layer16_region2',
#    'tm_activation_var_layer16_region2',
#    'tm_activation_quant0_layer16_region2',
#    'tm_activation_quant1_layer16_region2',
#    'tm_activation_quant2_layer16_region2',
#    'tm_activation_mean_layer17_region2',
#    'tm_activation_var_layer17_region2',
#    'tm_activation_quant0_layer17_region2',
#    'tm_activation_quant1_layer17_region2',
#    'tm_activation_quant2_layer17_region2',
#    'tm_activation_mean_layer18_region2',
#    'tm_activation_var_layer18_region2',
#    'tm_activation_quant0_layer18_region2',
#    'tm_activation_quant1_layer18_region2',
#    'tm_activation_quant2_layer18_region2',
#    'tm_activation_mean_layer19_region2',
#    'tm_activation_var_layer19_region2',
#    'tm_activation_quant0_layer19_region2',
#    'tm_activation_quant1_layer19_region2',
#    'tm_activation_quant2_layer19_region2',
#    'tm_activation_mean_layer20_region2',
#    'tm_activation_var_layer20_region2',
#    'tm_activation_quant0_layer20_region2',
#    'tm_activation_quant1_layer20_region2',
#    'tm_activation_quant2_layer20_region2',
#    'tm_activation_mean_layer21_region2',
#    'tm_activation_var_layer21_region2',
#    'tm_activation_quant0_layer21_region2',
#    'tm_activation_quant1_layer21_region2',
#    'tm_activation_quant2_layer21_region2',
#    'tm_activation_mean_layer22_region2',
#    'tm_activation_var_layer22_region2',
#    'tm_activation_quant0_layer22_region2',
#    'tm_activation_quant1_layer22_region2',
#    'tm_activation_quant2_layer22_region2',
#    'tm_activation_mean_layer23_region2',
#    'tm_activation_var_layer23_region2',
#    'tm_activation_quant0_layer23_region2',
#    'tm_activation_quant1_layer23_region2',
#    'tm_activation_quant2_layer23_region2',
#    'tm_activation_mean_layer24_region2',
#    'tm_activation_var_layer24_region2',
#    'tm_activation_quant0_layer24_region2',
#    'tm_activation_quant1_layer24_region2',
#    'tm_activation_quant2_layer24_region2',
#    'tm_activation_mean_layer25_region2',
#    'tm_activation_var_layer25_region2',
#    'tm_activation_quant0_layer25_region2',
#    'tm_activation_quant1_layer25_region2',
#    'tm_activation_quant2_layer25_region2',
#    'tm_activation_mean_layer26_region2',
#    'tm_activation_var_layer26_region2',
#    'tm_activation_quant0_layer26_region2',
#    'tm_activation_quant1_layer26_region2',
#    'tm_activation_quant2_layer26_region2',
#    'tm_activation_mean_layer27_region2',
#    'tm_activation_var_layer27_region2',
#    'tm_activation_quant0_layer27_region2',
#    'tm_activation_quant1_layer27_region2',
#    'tm_activation_quant2_layer27_region2',
#    'tm_activation_mean_layer28_region2',
#    'tm_activation_var_layer28_region2',
#    'tm_activation_quant0_layer28_region2',
#    'tm_activation_quant1_layer28_region2',
#    'tm_activation_quant2_layer28_region2',
#    'tm_activation_mean_layer29_region2',
#    'tm_activation_var_layer29_region2',
#    'tm_activation_quant0_layer29_region2',
#    'tm_activation_quant1_layer29_region2',
#    'tm_activation_quant2_layer29_region2',
#    'tm_activation_mean_layer30_region2',
#    'tm_activation_var_layer30_region2',
#    'tm_activation_quant0_layer30_region2',
#    'tm_activation_quant1_layer30_region2',
#    'tm_activation_quant2_layer30_region2',
#    'tm_activation_mean_layer31_region2',
#    'tm_activation_var_layer31_region2',
#    'tm_activation_quant0_layer31_region2',
#    'tm_activation_quant1_layer31_region2',
#    'tm_activation_quant2_layer31_region2',
#    'tm_activation_mean_layer32_region2',
#    'tm_activation_var_layer32_region2',
#    'tm_activation_quant0_layer32_region2',
#    'tm_activation_quant1_layer32_region2',
#    'tm_activation_quant2_layer32_region2',
#    'tm_activation_mean_layer33_region2',
#    'tm_activation_var_layer33_region2',
#    'tm_activation_quant0_layer33_region2',
#    'tm_activation_quant1_layer33_region2',
#    'tm_activation_quant2_layer33_region2',
#    'tm_activation_mean_layer34_region2',
#    'tm_activation_var_layer34_region2',
#    'tm_activation_quant0_layer34_region2',
#    'tm_activation_quant1_layer34_region2',
#    'tm_activation_quant2_layer34_region2',
#    'tm_activation_mean_layer35_region2',
#    'tm_activation_var_layer35_region2',
#    'tm_activation_quant0_layer35_region2',
#    'tm_activation_quant1_layer35_region2',
#    'tm_activation_quant2_layer35_region2',
#    'tm_activation_mean_layer36_region2',
#    'tm_activation_var_layer36_region2',
#    'tm_activation_quant0_layer36_region2',
#    'tm_activation_quant1_layer36_region2',
#    'tm_activation_quant2_layer36_region2',
#    'tm_activation_mean_layer37_region2',
#    'tm_activation_var_layer37_region2',
#    'tm_activation_quant0_layer37_region2',
#    'tm_activation_quant1_layer37_region2',
#    'tm_activation_quant2_layer37_region2',
#    'tm_activation_mean_layer38_region2',
#    'tm_activation_var_layer38_region2',
#    'tm_activation_quant0_layer38_region2',
#    'tm_activation_quant1_layer38_region2',
#    'tm_activation_quant2_layer38_region2',
#    'tm_activation_mean_layer39_region2',
#    ...],
#   array([[ 1.22949725e-03,  1.46804946e-02, -4.96474830e-02, ...,
#            4.84517053e-01,  1.70417786e-01,  1.72825279e+01]])),
#  'tm_gradient': (['tm_gradient_mean_layer0_region0',
#    'tm_gradient_var_layer0_region0',
#    'tm_gradient_mean_layer1_region0',
#    'tm_gradient_var_layer1_region0',
#    'tm_gradient_quant0_layer1_region0',
#    'tm_gradient_quant1_layer1_region0',
#    'tm_gradient_quant2_layer1_region0',
#    'tm_gradient_mean_layer2_region0',
#    'tm_gradient_var_layer2_region0',
#    'tm_gradient_quant0_layer2_region0',
#    'tm_gradient_quant1_layer2_region0',
#    'tm_gradient_quant2_layer2_region0',
#    'tm_gradient_mean_layer3_region0',
#    'tm_gradient_var_layer3_region0',
#    'tm_gradient_quant0_layer3_region0',
#    'tm_gradient_quant1_layer3_region0',
#    'tm_gradient_quant2_layer3_region0',
#    'tm_gradient_mean_layer4_region0',
#    'tm_gradient_var_layer4_region0',
#    'tm_gradient_quant0_layer4_region0',
#    'tm_gradient_quant1_layer4_region0',
#    'tm_gradient_quant2_layer4_region0',
#    'tm_gradient_mean_layer5_region0',
#    'tm_gradient_var_layer5_region0',
#    'tm_gradient_quant0_layer5_region0',
#    'tm_gradient_quant1_layer5_region0',
#    'tm_gradient_quant2_layer5_region0',
#    'tm_gradient_mean_layer6_region0',
#    'tm_gradient_var_layer6_region0',
#    'tm_gradient_quant0_layer6_region0',
#    'tm_gradient_quant1_layer6_region0',
#    'tm_gradient_quant2_layer6_region0',
#    'tm_gradient_mean_layer7_region0',
#    'tm_gradient_var_layer7_region0',
#    'tm_gradient_quant0_layer7_region0',
#    'tm_gradient_quant1_layer7_region0',
#    'tm_gradient_quant2_layer7_region0',
#    'tm_gradient_mean_layer8_region0',
#    'tm_gradient_var_layer8_region0',
#    'tm_gradient_quant0_layer8_region0',
#    'tm_gradient_quant1_layer8_region0',
#    'tm_gradient_quant2_layer8_region0',
#    'tm_gradient_mean_layer9_region0',
#    'tm_gradient_var_layer9_region0',
#    'tm_gradient_quant0_layer9_region0',
#    'tm_gradient_quant1_layer9_region0',
#    'tm_gradient_quant2_layer9_region0',
#    'tm_gradient_mean_layer10_region0',
#    'tm_gradient_var_layer10_region0',
#    'tm_gradient_quant0_layer10_region0',
#    'tm_gradient_quant1_layer10_region0',
#    'tm_gradient_quant2_layer10_region0',
#    'tm_gradient_mean_layer11_region0',
#    'tm_gradient_var_layer11_region0',
#    'tm_gradient_quant0_layer11_region0',
#    'tm_gradient_quant1_layer11_region0',
#    'tm_gradient_quant2_layer11_region0',
#    'tm_gradient_mean_layer12_region0',
#    'tm_gradient_var_layer12_region0',
#    'tm_gradient_quant0_layer12_region0',
#    'tm_gradient_quant1_layer12_region0',
#    'tm_gradient_quant2_layer12_region0',
#    'tm_gradient_mean_layer13_region0',
#    'tm_gradient_var_layer13_region0',
#    'tm_gradient_quant0_layer13_region0',
#    'tm_gradient_quant1_layer13_region0',
#    'tm_gradient_quant2_layer13_region0',
#    'tm_gradient_mean_layer14_region0',
#    'tm_gradient_var_layer14_region0',
#    'tm_gradient_quant0_layer14_region0',
#    'tm_gradient_quant1_layer14_region0',
#    'tm_gradient_quant2_layer14_region0',
#    'tm_gradient_mean_layer15_region0',
#    'tm_gradient_var_layer15_region0',
#    'tm_gradient_quant0_layer15_region0',
#    'tm_gradient_quant1_layer15_region0',
#    'tm_gradient_quant2_layer15_region0',
#    'tm_gradient_mean_layer16_region0',
#    'tm_gradient_var_layer16_region0',
#    'tm_gradient_quant0_layer16_region0',
#    'tm_gradient_quant1_layer16_region0',
#    'tm_gradient_quant2_layer16_region0',
#    'tm_gradient_mean_layer17_region0',
#    'tm_gradient_var_layer17_region0',
#    'tm_gradient_quant0_layer17_region0',
#    'tm_gradient_quant1_layer17_region0',
#    'tm_gradient_quant2_layer17_region0',
#    'tm_gradient_mean_layer18_region0',
#    'tm_gradient_var_layer18_region0',
#    'tm_gradient_quant0_layer18_region0',
#    'tm_gradient_quant1_layer18_region0',
#    'tm_gradient_quant2_layer18_region0',
#    'tm_gradient_mean_layer19_region0',
#    'tm_gradient_var_layer19_region0',
#    'tm_gradient_quant0_layer19_region0',
#    'tm_gradient_quant1_layer19_region0',
#    'tm_gradient_quant2_layer19_region0',
#    'tm_gradient_mean_layer20_region0',
#    'tm_gradient_var_layer20_region0',
#    'tm_gradient_quant0_layer20_region0',
#    'tm_gradient_quant1_layer20_region0',
#    'tm_gradient_quant2_layer20_region0',
#    'tm_gradient_mean_layer21_region0',
#    'tm_gradient_var_layer21_region0',
#    'tm_gradient_quant0_layer21_region0',
#    'tm_gradient_quant1_layer21_region0',
#    'tm_gradient_quant2_layer21_region0',
#    'tm_gradient_mean_layer22_region0',
#    'tm_gradient_var_layer22_region0',
#    'tm_gradient_quant0_layer22_region0',
#    'tm_gradient_quant1_layer22_region0',
#    'tm_gradient_quant2_layer22_region0',
#    'tm_gradient_mean_layer23_region0',
#    'tm_gradient_var_layer23_region0',
#    'tm_gradient_quant0_layer23_region0',
#    'tm_gradient_quant1_layer23_region0',
#    'tm_gradient_quant2_layer23_region0',
#    'tm_gradient_mean_layer24_region0',
#    'tm_gradient_var_layer24_region0',
#    'tm_gradient_quant0_layer24_region0',
#    'tm_gradient_quant1_layer24_region0',
#    'tm_gradient_quant2_layer24_region0',
#    'tm_gradient_mean_layer25_region0',
#    'tm_gradient_var_layer25_region0',
#    'tm_gradient_quant0_layer25_region0',
#    'tm_gradient_quant1_layer25_region0',
#    'tm_gradient_quant2_layer25_region0',
#    'tm_gradient_mean_layer26_region0',
#    'tm_gradient_var_layer26_region0',
#    'tm_gradient_quant0_layer26_region0',
#    'tm_gradient_quant1_layer26_region0',
#    'tm_gradient_quant2_layer26_region0',
#    'tm_gradient_mean_layer27_region0',
#    'tm_gradient_var_layer27_region0',
#    'tm_gradient_quant0_layer27_region0',
#    'tm_gradient_quant1_layer27_region0',
#    'tm_gradient_quant2_layer27_region0',
#    'tm_gradient_mean_layer28_region0',
# ...
#    'tm_gradient_quant1_layer19_region1',
#    'tm_gradient_quant2_layer19_region1',
#    'tm_gradient_mean_layer20_region1',
#    'tm_gradient_var_layer20_region1',
#    'tm_gradient_quant0_layer20_region1',
#    'tm_gradient_quant1_layer20_region1',
#    'tm_gradient_quant2_layer20_region1',
#    'tm_gradient_mean_layer21_region1',
#    'tm_gradient_var_layer21_region1',
#    'tm_gradient_quant0_layer21_region1',
#    'tm_gradient_quant1_layer21_region1',
#    'tm_gradient_quant2_layer21_region1',
#    'tm_gradient_mean_layer22_region1',
#    'tm_gradient_var_layer22_region1',
#    'tm_gradient_quant0_layer22_region1',
#    'tm_gradient_quant1_layer22_region1',
#    'tm_gradient_quant2_layer22_region1',
#    'tm_gradient_mean_layer23_region1',
#    'tm_gradient_var_layer23_region1',
#    'tm_gradient_quant0_layer23_region1',
#    'tm_gradient_quant1_layer23_region1',
#    'tm_gradient_quant2_layer23_region1',
#    'tm_gradient_mean_layer24_region1',
#    'tm_gradient_var_layer24_region1',
#    'tm_gradient_quant0_layer24_region1',
#    'tm_gradient_quant1_layer24_region1',
#    'tm_gradient_quant2_layer24_region1',
#    'tm_gradient_mean_layer25_region1',
#    'tm_gradient_var_layer25_region1',
#    'tm_gradient_quant0_layer25_region1',
#    'tm_gradient_quant1_layer25_region1',
#    'tm_gradient_quant2_layer25_region1',
#    'tm_gradient_mean_layer26_region1',
#    'tm_gradient_var_layer26_region1',
#    'tm_gradient_quant0_layer26_region1',
#    'tm_gradient_quant1_layer26_region1',
#    'tm_gradient_quant2_layer26_region1',
#    'tm_gradient_mean_layer27_region1',
#    'tm_gradient_var_layer27_region1',
#    'tm_gradient_quant0_layer27_region1',
#    'tm_gradient_quant1_layer27_region1',
#    'tm_gradient_quant2_layer27_region1',
#    'tm_gradient_mean_layer28_region1',
#    'tm_gradient_var_layer28_region1',
#    'tm_gradient_quant0_layer28_region1',
#    'tm_gradient_quant1_layer28_region1',
#    'tm_gradient_quant2_layer28_region1',
#    'tm_gradient_mean_layer29_region1',
#    'tm_gradient_var_layer29_region1',
#    'tm_gradient_quant0_layer29_region1',
#    'tm_gradient_quant1_layer29_region1',
#    'tm_gradient_quant2_layer29_region1',
#    'tm_gradient_mean_layer30_region1',
#    'tm_gradient_var_layer30_region1',
#    'tm_gradient_quant0_layer30_region1',
#    'tm_gradient_quant1_layer30_region1',
#    'tm_gradient_quant2_layer30_region1',
#    'tm_gradient_mean_layer31_region1',
#    'tm_gradient_var_layer31_region1',
#    'tm_gradient_quant0_layer31_region1',
#    'tm_gradient_quant1_layer31_region1',
#    'tm_gradient_quant2_layer31_region1',
#    'tm_gradient_mean_layer32_region1',
#    'tm_gradient_var_layer32_region1',
#    'tm_gradient_quant0_layer32_region1',
#    'tm_gradient_quant1_layer32_region1',
#    'tm_gradient_quant2_layer32_region1',
#    'tm_gradient_mean_layer33_region1',
#    'tm_gradient_var_layer33_region1',
#    'tm_gradient_quant0_layer33_region1',
#    'tm_gradient_quant1_layer33_region1',
#    'tm_gradient_quant2_layer33_region1',
#    'tm_gradient_mean_layer34_region1',
#    'tm_gradient_var_layer34_region1',
#    'tm_gradient_quant0_layer34_region1',
#    'tm_gradient_quant1_layer34_region1',
#    'tm_gradient_quant2_layer34_region1',
#    'tm_gradient_mean_layer35_region1',
#    'tm_gradient_var_layer35_region1',
#    'tm_gradient_quant0_layer35_region1',
#    'tm_gradient_quant1_layer35_region1',
#    'tm_gradient_quant2_layer35_region1',
#    'tm_gradient_mean_layer36_region1',
#    'tm_gradient_var_layer36_region1',
#    'tm_gradient_quant0_layer36_region1',
#    'tm_gradient_quant1_layer36_region1',
#    'tm_gradient_quant2_layer36_region1',
#    'tm_gradient_mean_layer37_region1',
#    'tm_gradient_var_layer37_region1',
#    'tm_gradient_quant0_layer37_region1',
#    'tm_gradient_quant1_layer37_region1',
#    'tm_gradient_quant2_layer37_region1',
#    'tm_gradient_mean_layer38_region1',
#    'tm_gradient_var_layer38_region1',
#    'tm_gradient_quant0_layer38_region1',
#    'tm_gradient_quant1_layer38_region1',
#    'tm_gradient_quant2_layer38_region1',
#    'tm_gradient_mean_layer39_region1',
#    'tm_gradient_var_layer39_region1',
#    'tm_gradient_quant0_layer39_region1',
#    'tm_gradient_quant1_layer39_region1',
#    'tm_gradient_quant2_layer39_region1',
#    'tm_gradient_mean_layer40_region1',
#    'tm_gradient_var_layer40_region1',
#    'tm_gradient_quant0_layer40_region1',
#    'tm_gradient_quant1_layer40_region1',
#    'tm_gradient_quant2_layer40_region1',
#    'tm_gradient_mean_layer41_region1',
#    'tm_gradient_var_layer41_region1',
#    'tm_gradient_quant0_layer41_region1',
#    'tm_gradient_quant1_layer41_region1',
#    'tm_gradient_quant2_layer41_region1',
#    'tm_gradient_mean_layer42_region1',
#    'tm_gradient_var_layer42_region1',
#    'tm_gradient_quant0_layer42_region1',
#    'tm_gradient_quant1_layer42_region1',
#    'tm_gradient_quant2_layer42_region1',
#    'tm_gradient_mean_layer43_region1',
#    'tm_gradient_var_layer43_region1',
#    'tm_gradient_quant0_layer43_region1',
#    'tm_gradient_quant1_layer43_region1',
#    'tm_gradient_quant2_layer43_region1',
#    'tm_gradient_mean_layer44_region1',
#    'tm_gradient_var_layer44_region1',
#    'tm_gradient_quant0_layer44_region1',
#    'tm_gradient_quant1_layer44_region1',
#    'tm_gradient_quant2_layer44_region1',
#    'tm_gradient_mean_layer45_region1',
#    'tm_gradient_var_layer45_region1',
#    'tm_gradient_quant0_layer45_region1',
#    'tm_gradient_quant1_layer45_region1',
#    'tm_gradient_quant2_layer45_region1',
#    'tm_gradient_mean_layer46_region1',
#    'tm_gradient_var_layer46_region1',
#    'tm_gradient_quant0_layer46_region1',
#    'tm_gradient_quant1_layer46_region1',
#    'tm_gradient_quant2_layer46_region1',
#    'tm_gradient_mean_layer47_region1',
#    'tm_gradient_var_layer47_region1',
#    'tm_gradient_quant0_layer47_region1',
#    'tm_gradient_quant1_layer47_region1',
#    'tm_gradient_quant2_layer47_region1',
#    'tm_gradient_mean_layer48_region1',
#    'tm_gradient_var_layer48_region1',
#    'tm_gradient_quant0_layer48_region1',
#    'tm_gradient_quant1_layer48_region1',
#    'tm_gradient_quant2_layer48_region1',
#    'tm_gradient_mean_layer49_region1',
#    'tm_gradient_var_layer49_region1',
#    'tm_gradient_quant0_layer49_region1',
#    'tm_gradient_quant1_layer49_region1',
#    'tm_gradient_quant2_layer49_region1',
#    'tm_gradient_mean_layer50_region1',
#    'tm_gradient_var_layer50_region1',
#    'tm_gradient_quant0_layer50_region1',
#    'tm_gradient_quant1_layer50_region1',
#    'tm_gradient_quant2_layer50_region1',
#    'tm_gradient_mean_layer51_region1',
#    'tm_gradient_var_layer51_region1',
#    'tm_gradient_quant0_layer51_region1',
#    'tm_gradient_quant1_layer51_region1',
#    'tm_gradient_quant2_layer51_region1',
#    'tm_gradient_mean_layer52_region1',
#    'tm_gradient_var_layer52_region1',
#    'tm_gradient_quant0_layer52_region1',
#    'tm_gradient_quant1_layer52_region1',
#    'tm_gradient_quant2_layer52_region1',
#    'tm_gradient_mean_layer53_region1',
#    'tm_gradient_var_layer53_region1',
#    'tm_gradient_quant0_layer53_region1',
#    'tm_gradient_quant1_layer53_region1',
#    'tm_gradient_quant2_layer53_region1',
#    'tm_gradient_mean_layer54_region1',
#    'tm_gradient_var_layer54_region1',
#    'tm_gradient_quant0_layer54_region1',
#    'tm_gradient_quant1_layer54_region1',
#    'tm_gradient_quant2_layer54_region1',
#    'tm_gradient_mean_layer55_region1',
#    'tm_gradient_var_layer55_region1',
#    'tm_gradient_quant0_layer55_region1',
#    'tm_gradient_quant1_layer55_region1',
#    'tm_gradient_quant2_layer55_region1',
#    'tm_gradient_mean_layer56_region1',
#    'tm_gradient_var_layer56_region1',
#    'tm_gradient_quant0_layer56_region1',
#    'tm_gradient_quant1_layer56_region1',
#    'tm_gradient_quant2_layer56_region1',
#    'tm_gradient_mean_layer57_region1',
#    'tm_gradient_var_layer57_region1',
#    'tm_gradient_quant0_layer57_region1',
#    'tm_gradient_quant1_layer57_region1',
#    'tm_gradient_quant2_layer57_region1',
#    'tm_gradient_mean_layer58_region1',
#    'tm_gradient_var_layer58_region1',
#    'tm_gradient_quant0_layer58_region1',
#    'tm_gradient_quant1_layer58_region1',
#    'tm_gradient_quant2_layer58_region1',
#    'tm_gradient_mean_layer59_region1',
#    'tm_gradient_var_layer59_region1',
#    'tm_gradient_quant0_layer59_region1',
#    'tm_gradient_quant1_layer59_region1',
#    'tm_gradient_quant2_layer59_region1',
#    'tm_gradient_mean_layer60_region1',
#    'tm_gradient_var_layer60_region1',
#    'tm_gradient_quant0_layer60_region1',
#    'tm_gradient_quant1_layer60_region1',
#    'tm_gradient_quant2_layer60_region1',
#    'tm_gradient_mean_layer61_region1',
#    'tm_gradient_var_layer61_region1',
#    'tm_gradient_quant0_layer61_region1',
#    'tm_gradient_quant1_layer61_region1',
#    'tm_gradient_quant2_layer61_region1',
#    'tm_gradient_mean_layer62_region1',
#    'tm_gradient_var_layer62_region1',
#    'tm_gradient_quant0_layer62_region1',
#    'tm_gradient_quant1_layer62_region1',
#    'tm_gradient_quant2_layer62_region1',
#    'tm_gradient_mean_layer63_region1',
#    'tm_gradient_var_layer63_region1',
#    'tm_gradient_quant0_layer63_region1',
#    'tm_gradient_quant1_layer63_region1',
#    'tm_gradient_quant2_layer63_region1',
#    'tm_gradient_mean_layer64_region1',
#    'tm_gradient_var_layer64_region1',
#    'tm_gradient_quant0_layer64_region1',
#    'tm_gradient_quant1_layer64_region1',
#    'tm_gradient_quant2_layer64_region1',
#    'tm_gradient_mean_layer65_region1',
#    'tm_gradient_var_layer65_region1',
#    'tm_gradient_quant0_layer65_region1',
#    'tm_gradient_quant1_layer65_region1',
#    'tm_gradient_quant2_layer65_region1',
#    'tm_gradient_mean_layer66_region1',
#    'tm_gradient_var_layer66_region1',
#    'tm_gradient_quant0_layer66_region1',
#    'tm_gradient_quant1_layer66_region1',
#    'tm_gradient_quant2_layer66_region1',
#    'tm_gradient_mean_layer67_region1',
#    'tm_gradient_var_layer67_region1',
#    'tm_gradient_quant0_layer67_region1',
#    'tm_gradient_quant1_layer67_region1',
#    'tm_gradient_quant2_layer67_region1',
#    'tm_gradient_mean_layer68_region1',
#    'tm_gradient_var_layer68_region1',
#    'tm_gradient_quant0_layer68_region1',
#    'tm_gradient_quant1_layer68_region1',
#    'tm_gradient_quant2_layer68_region1',
#    'tm_gradient_mean_layer69_region1',
#    'tm_gradient_var_layer69_region1',
#    'tm_gradient_quant0_layer69_region1',
#    'tm_gradient_quant1_layer69_region1',
#    'tm_gradient_quant2_layer69_region1',
#    'tm_gradient_mean_layer70_region1',
#    'tm_gradient_var_layer70_region1',
#    'tm_gradient_quant0_layer70_region1',
#    'tm_gradient_quant1_layer70_region1',
#    'tm_gradient_quant2_layer70_region1',
#    'tm_gradient_mean_layer71_region1',
#    'tm_gradient_var_layer71_region1',
#    'tm_gradient_quant0_layer71_region1',
#    'tm_gradient_quant1_layer71_region1',
#    'tm_gradient_quant2_layer71_region1',
#    'tm_gradient_mean_layer72_region1',
#    'tm_gradient_var_layer72_region1',
#    'tm_gradient_quant0_layer72_region1',
#    'tm_gradient_quant1_layer72_region1',
#    'tm_gradient_quant2_layer72_region1',
#    'tm_gradient_mean_layer73_region1',
#    'tm_gradient_var_layer73_region1',
#    'tm_gradient_quant0_layer73_region1',
#    'tm_gradient_quant1_layer73_region1',
#    'tm_gradient_quant2_layer73_region1',
#    'tm_gradient_mean_layer74_region1',
#    'tm_gradient_var_layer74_region1',
#    'tm_gradient_quant0_layer74_region1',
#    'tm_gradient_quant1_layer74_region1',
#    'tm_gradient_quant2_layer74_region1',
#    'tm_gradient_mean_layer75_region1',
#    'tm_gradient_var_layer75_region1',
#    'tm_gradient_quant0_layer75_region1',
#    'tm_gradient_quant1_layer75_region1',
#    'tm_gradient_quant2_layer75_region1',
#    'tm_gradient_mean_layer76_region1',
#    'tm_gradient_var_layer76_region1',
#    'tm_gradient_quant0_layer76_region1',
#    'tm_gradient_quant1_layer76_region1',
#    'tm_gradient_quant2_layer76_region1',
#    'tm_gradient_mean_layer77_region1',
#    'tm_gradient_var_layer77_region1',
#    'tm_gradient_quant0_layer77_region1',
#    'tm_gradient_quant1_layer77_region1',
#    'tm_gradient_quant2_layer77_region1',
#    'tm_gradient_mean_layer78_region1',
#    'tm_gradient_var_layer78_region1',
#    'tm_gradient_quant0_layer78_region1',
#    'tm_gradient_quant1_layer78_region1',
#    'tm_gradient_quant2_layer78_region1',
#    'tm_gradient_mean_layer79_region1',
#    'tm_gradient_var_layer79_region1',
#    'tm_gradient_quant0_layer79_region1',
#    'tm_gradient_quant1_layer79_region1',
#    'tm_gradient_quant2_layer79_region1',
#    'tm_gradient_mean_layer80_region1',
#    'tm_gradient_var_layer80_region1',
#    'tm_gradient_quant0_layer80_region1',
#    'tm_gradient_quant1_layer80_region1',
#    'tm_gradient_quant2_layer80_region1',
#    'tm_gradient_mean_layer81_region1',
#    'tm_gradient_var_layer81_region1',
#    'tm_gradient_quant0_layer81_region1',
#    'tm_gradient_quant1_layer81_region1',
#    'tm_gradient_quant2_layer81_region1',
#    'tm_gradient_mean_layer82_region1',
#    'tm_gradient_var_layer82_region1',
#    'tm_gradient_quant0_layer82_region1',
#    'tm_gradient_quant1_layer82_region1',
#    'tm_gradient_quant2_layer82_region1',
#    'tm_gradient_mean_layer83_region1',
#    'tm_gradient_var_layer83_region1',
#    'tm_gradient_quant0_layer83_region1',
#    'tm_gradient_quant1_layer83_region1',
#    'tm_gradient_quant2_layer83_region1',
#    'tm_gradient_mean_layer84_region1',
#    'tm_gradient_var_layer84_region1',
#    'tm_gradient_quant0_layer84_region1',
#    'tm_gradient_quant1_layer84_region1',
#    'tm_gradient_quant2_layer84_region1',
#    'tm_gradient_mean_layer85_region1',
#    'tm_gradient_var_layer85_region1',
#    'tm_gradient_quant0_layer85_region1',
#    'tm_gradient_quant1_layer85_region1',
#    'tm_gradient_quant2_layer85_region1',
#    'tm_gradient_mean_layer86_region1',
#    'tm_gradient_var_layer86_region1',
#    'tm_gradient_quant0_layer86_region1',
#    'tm_gradient_quant1_layer86_region1',
#    'tm_gradient_quant2_layer86_region1',
#    'tm_gradient_mean_layer87_region1',
#    'tm_gradient_var_layer87_region1',
#    'tm_gradient_quant0_layer87_region1',
#    'tm_gradient_quant1_layer87_region1',
#    'tm_gradient_quant2_layer87_region1',
#    'tm_gradient_mean_layer88_region1',
#    'tm_gradient_var_layer88_region1',
#    'tm_gradient_quant0_layer88_region1',
#    'tm_gradient_quant1_layer88_region1',
#    'tm_gradient_quant2_layer88_region1',
#    'tm_gradient_mean_layer89_region1',
#    'tm_gradient_var_layer89_region1',
#    'tm_gradient_quant0_layer89_region1',
#    'tm_gradient_quant1_layer89_region1',
#    'tm_gradient_quant2_layer89_region1',
#    'tm_gradient_mean_layer90_region1',
#    'tm_gradient_var_layer90_region1',
#    'tm_gradient_quant0_layer90_region1',
#    'tm_gradient_quant1_layer90_region1',
#    'tm_gradient_quant2_layer90_region1',
#    'tm_gradient_mean_layer91_region1',
#    'tm_gradient_var_layer91_region1',
#    'tm_gradient_quant0_layer91_region1',
#    'tm_gradient_quant1_layer91_region1',
#    'tm_gradient_quant2_layer91_region1',
#    'tm_gradient_mean_layer92_region1',
#    'tm_gradient_var_layer92_region1',
#    'tm_gradient_quant0_layer92_region1',
#    'tm_gradient_quant1_layer92_region1',
#    'tm_gradient_quant2_layer92_region1',
#    'tm_gradient_mean_layer93_region1',
#    'tm_gradient_var_layer93_region1',
#    'tm_gradient_quant0_layer93_region1',
#    'tm_gradient_quant1_layer93_region1',
#    'tm_gradient_quant2_layer93_region1',
#    'tm_gradient_mean_layer94_region1',
#    'tm_gradient_var_layer94_region1',
#    'tm_gradient_quant0_layer94_region1',
#    'tm_gradient_quant1_layer94_region1',
#    'tm_gradient_quant2_layer94_region1',
#    'tm_gradient_mean_layer95_region1',
#    'tm_gradient_var_layer95_region1',
#    'tm_gradient_quant0_layer95_region1',
#    'tm_gradient_quant1_layer95_region1',
#    'tm_gradient_quant2_layer95_region1',
#    'tm_gradient_mean_layer96_region1',
#    'tm_gradient_var_layer96_region1',
#    'tm_gradient_quant0_layer96_region1',
#    'tm_gradient_quant1_layer96_region1',
#    ...],
#   array([[-2.40069087e-13,  7.31272212e-06, -1.60052197e-11, ...,
#            1.19377342e-04, -1.22236088e-08,  1.19955217e-07]])),
#  'tm_posterior': (['tm_output_0', 'tm_output_1'],
#   array([[9.99755109e-01, 2.44891062e-04]])),
#  'tm_saliency': (['tm_simple_gradient_saliency_mean',
#    'tm_simple_gradient_saliency_var',
#    'tm_simple_gradient_saliency_quant0',
#    'tm_simple_gradient_saliency_quant1',
#    'tm_simple_gradient_saliency_quant2'],
#   array([[0.01176471, 0.00015268, 0.00293971, 0.00709179, 0.01529993]]))}

# %%
for extractor_name in res.keys():
    _, values = res[extractor_name][0], res[extractor_name][1]
    holder[idx]["deliverable"][extractor_name] = values
holder[idx]["num_successful_loop"] += 1

del target_model

# %%
loop_num = 4  # 4 extactor pipes

print("=" * 40)
print("--- all done")

keys_to_rm = []
for h in holder.keys():
    if holder[h]["num_successful_loop"] == loop_num:
        pass
    else:
        keys_to_rm.append(h)
_failed_extraction_count = 0
for _failed_extraction_count, k in enumerate(keys_to_rm):
    del holder[k]
print("total failed extraction: ", _failed_extraction_count, "out of", len(holder))
# Out:
# ========================================
# --- all done
# total failed extraction:  1 out of 1

# %%
def show_sample_instance(holder, index):
    """
    un-mutating printing util
    """
    out = {
        "num_successful_loop": holder[index]["num_successful_loop"],
        "primary_key": holder[index]["primary_key"],
        "unique_id": holder[index]["unique_id"],
        "deliverable": {},
    }

    for feat_name in holder[index]["deliverable"].keys():
        feat_shape = "arr/list of shape: " + str(
            np.array(holder[index]["deliverable"][feat_name]).shape
        )
        out["deliverable"][feat_name] = feat_shape
    display(out)

# %%
print("a sample holder value for sanity check")
sample_holder_item_key = list(holder.keys())[0]
show_sample_instance(holder, sample_holder_item_key)
# Out:
# a sample holder value for sanity check
# {'num_successful_loop': 4,
#  'primary_key': ['clean',
#   'none',
#   12,
#   'sentiment',
#   'distilcamembert',
#   'allocine',
#   12],
#  'unique_id': '227889344748385074993418811187107806614',
#  'deliverable': {'tp_avg_word_length': 'arr/list of shape: (1, 20)',
#   'tp_bert': 'arr/list of shape: (1, 768)',
#   'tp_is_first_word_lowercase': 'arr/list of shape: (1, 1)',
#   'tp_num_alpha_chars': 'arr/list of shape: (1, 1)',
#   'tp_num_cased_letters': 'arr/list of shape: (1, 4)',
#   'tp_num_cased_word_switches': 'arr/list of shape: (1, 1)',
#   'tp_num_chars': 'arr/list of shape: (1, 1)',
#   'tp_num_digits': 'arr/list of shape: (1, 1)',
#   'tp_num_lowercase_after_punctuation': 'arr/list of shape: (1, 1)',
#   'tp_num_mixed_case_words': 'arr/list of shape: (1, 1)',
#   'tp_num_multi_spaces': 'arr/list of shape: (1, 1)',
#   'tp_num_non_ascii': 'arr/list of shape: (1, 1)',
#   'tp_num_punctuation': 'arr/list of shape: (1, 1)',
#   'tp_num_single_lowercase_letters': 'arr/list of shape: (1, 1)',
#   'tp_num_words': 'arr/list of shape: (1, 1)',
#   'lm_perplexity': 'arr/list of shape: (1, 4)',
#   'lm_proba_and_rank': 'arr/list of shape: (1, 40)',
#   'tm_activation': 'arr/list of shape: (1, 1608)',
#   'tm_gradient': 'arr/list of shape: (1, 2076)',
#   'tm_posterior': 'arr/list of shape: (1, 2)',
#   'tm_saliency': 'arr/list of shape: (1, 5)'}}
