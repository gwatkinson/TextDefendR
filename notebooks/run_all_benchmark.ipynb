# %% [markdown]
# # Run all TCAB benchmark

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import time
from functools import reduce
from itertools import product

from tqdm.auto import tqdm

from scripts import (
    distribute_experiments,
    generate_catted_dataset,
    make_experiment,
    make_official_dataset_splits,
    run_experiment,
)

# from scripts import encode_main

t = time.time()

# %%
def process_args(args_grid):
    liste1 = [dict(zip(args_grid.keys(), v)) for v in product(*args_grid.values())]
    liste2 = [list(reduce(lambda x, y: x + y, dico.items())) for dico in liste1]
    liste3 = [list(filter(None, liste)) for liste in liste2]

    print(f"Number of parameters combinations: {len(liste3)}")
    for elem in liste3:
        print(elem)

    return liste3

# %%
def call_main_args(main, processed_args_grid):
    for args in tqdm(processed_args_grid):
        print(f"\n### Running main with {args}\n")
        main(args)

# %% [markdown]
# ## 1. scripts/generate_catted_dataset.py

# %%
generate_catted_dataset.main()
# Out:
# --- loading all data
# reading attacks/allocine/distilcamembert/none/clean/0/results.csv
# reading attacks/allocine/distilcamembert/textattack/bae/2000/results.csv
# reading attacks/allocine/distilcamembert/textattack/deepwordbug/2000/results.csv
# reading attacks/allocine/distilcamembert/textattack/input_reduction/2000/results.csv
# reading attacks/allocine/distilcamembert/textattack/pwws/2000/results.csv
# reading attacks/allocine/distilcamembert/textattack/textbugger/2000/results.csv
# reading attacks/allocine/distilcamembert/textattack/textfooler/2000/results.csv
# done, all data statistics:
# total_instances: 32000,
# attack_name: {'clean': 20000, 'bae': 2000, 'deepwordbug': 2000, 'input_reduction': 2000, 'pwws': 2000, 'textbugger': 2000, 'textfooler': 2000},
# target_model_dataset: {'allocine': 32000},
# target_model: {'distilcamembert': 32000},
# status: {'clean': 20000, 'failed': 3087, 'success': 8913},
# attack_toolchain: {'none': 20000, 'textattack': 12000},
# scenario: {'sentiment': 32000},
#
# --- doing global filtering over all data
# dropping unsuccessful attacks...
# dropping invalid attacks...
# done, all data statistics:
# total_instances: 28913,
# attack_name: {'clean': 20000, 'bae': 1217, 'deepwordbug': 1636, 'input_reduction': 2000, 'pwws': 741, 'textbugger': 1663, 'textfooler': 1656},
# target_model_dataset: {'allocine': 28913},
# target_model: {'distilcamembert': 28913},
# status: {'clean': 20000, 'success': 8913},
# attack_toolchain: {'none': 20000, 'textattack': 8913},
# scenario: {'sentiment': 28913},
#
# -- saving to disk

# %% [markdown]
# ## 2. scripts/encode_main.py

# %%
# encode_main.main()

# %% [markdown]
# ## 3. scripts/make_official_dataset_splits.py

# %%
make_official_dataset_splits.main()
# Out:
# --- reading data
# --- dropping unsupported datasets
# --- dropping duplicates
# --- making splits across all datasets ---
# allocine
# --- filtering for dataset  (28913, 20)
#   0%|          | 0/20000 [00:00<?, ?it/s]
#   0%|          | 0/8010 [00:00<?, ?it/s]
# --- Train DF stats ---
# total_instances: 17348,
# attack_name: {'input_reduction': 1187, 'clean': 11990, 'deepwordbug': 976, 'bae': 751, 'textfooler': 987, 'textbugger': 1004, 'pwws': 453},
# target_model_dataset: {'allocine': 17348},
# target_model: {'distilcamembert': 17348},
# status: {'success': 5358, 'clean': 11990},
# attack_toolchain: {'textattack': 5358, 'none': 11990},
# scenario: {'sentiment': 17348},
#
# --- Test DF stats ---
# total_instances: 5783,
# attack_name: {'input_reduction': 402, 'clean': 4006, 'deepwordbug': 326, 'textfooler': 333, 'pwws': 147, 'bae': 238, 'textbugger': 331},
# target_model_dataset: {'allocine': 5783},
# target_model: {'distilcamembert': 5783},
# status: {'success': 1777, 'clean': 4006},
# attack_toolchain: {'textattack': 1777, 'none': 4006},
# scenario: {'sentiment': 5783},
#
# --- Val DF stats ---
# total_instances: 5782,
# attack_name: {'clean': 4004, 'deepwordbug': 334, 'textfooler': 336, 'bae': 228, 'input_reduction': 411, 'textbugger': 328, 'pwws': 141},
# target_model_dataset: {'allocine': 5782},
# target_model: {'distilcamembert': 5782},
# status: {'clean': 4004, 'success': 1778},
# attack_toolchain: {'none': 4004, 'textattack': 1778},
# scenario: {'sentiment': 5782},
#
# --- filtering for target model
# --- Train DF stats ---
# total_instances: 17348,
# attack_name: {'input_reduction': 1187, 'clean': 11990, 'deepwordbug': 976, 'bae': 751, 'textfooler': 987, 'textbugger': 1004, 'pwws': 453},
# target_model_dataset: {'allocine': 17348},
# target_model: {'distilcamembert': 17348},
# status: {'success': 5358, 'clean': 11990},
# attack_toolchain: {'textattack': 5358, 'none': 11990},
# scenario: {'sentiment': 17348},
#
# --- Test DF stats ---
# total_instances: 5783,
# attack_name: {'input_reduction': 402, 'clean': 4006, 'deepwordbug': 326, 'textfooler': 333, 'pwws': 147, 'bae': 238, 'textbugger': 331},
# target_model_dataset: {'allocine': 5783},
# target_model: {'distilcamembert': 5783},
# status: {'success': 1777, 'clean': 4006},
# attack_toolchain: {'textattack': 1777, 'none': 4006},
# scenario: {'sentiment': 5783},
#
# --- Val DF stats ---
# total_instances: 5782,
# attack_name: {'clean': 4004, 'deepwordbug': 334, 'textfooler': 336, 'bae': 228, 'input_reduction': 411, 'textbugger': 328, 'pwws': 141},
# target_model_dataset: {'allocine': 5782},
# target_model: {'distilcamembert': 5782},
# status: {'clean': 4004, 'success': 1778},
# attack_toolchain: {'none': 4004, 'textattack': 1778},
# scenario: {'sentiment': 5782},
#
# --- allocine distilcamembert --- DONE.
# --- allocine --- DONE.
# --- combining splits across all datasets ---
# --- DONE.

# %% [markdown]
# ## 4. scripts/distribute_experiments.py

# %%
args_grid = {
    "--experiment_setting": ["clean_vs_all", "multiclass_with_clean"],
}
args_grid = process_args(args_grid)
# Out:
# Number of parameters combinations: 2
# ['--experiment_setting', 'clean_vs_all']
# ['--experiment_setting', 'multiclass_with_clean']

# %%
call_main_args(distribute_experiments.main, args_grid)
# Out:
#   0%|          | 0/2 [00:00<?, ?it/s]
# ### Running main with ['--experiment_setting', 'clean_vs_all']
#
# Reading train.csv from  data_tcab\official_TCAB_splits\splits_by_dataset_and_tm\allocine\distilcamembert\train.csv
# Reading val.csv from  data_tcab\official_TCAB_splits\splits_by_dataset_and_tm\allocine\distilcamembert\val.csv
# Reading test.csv from  data_tcab\official_TCAB_splits\splits_by_dataset_and_tm\allocine\distilcamembert\test.csv
# Dropping attacks by count, if less than < 10
#   0%|          | 0/4006 [00:00<?, ?it/s]
#  *** clean_vs_all saving to data_tcab\detection-experiments\allocine\distilcamembert\clean_vs_all
#
# ### Running main with ['--experiment_setting', 'multiclass_with_clean']
#
# Reading train.csv from  data_tcab\official_TCAB_splits\splits_by_dataset_and_tm\allocine\distilcamembert\train.csv
# Reading val.csv from  data_tcab\official_TCAB_splits\splits_by_dataset_and_tm\allocine\distilcamembert\val.csv
# Reading test.csv from  data_tcab\official_TCAB_splits\splits_by_dataset_and_tm\allocine\distilcamembert\test.csv
# Dropping attacks by count, if less than < 10
#   0%|          | 0/4006 [00:00<?, ?it/s]
#  *** multiclass_with_clean saving to data_tcab\detection-experiments\allocine\distilcamembert\multiclass_with_clean

# %% [markdown]
# ## 5. scripts/make_experiments.py

# %%
experiment_list = ["clean_vs_all", "multiclass_with_clean"]
experiment_dir_list = [
    "data_tcab/detection-experiments/allocine/distilcamembert/" + exp
    for exp in experiment_list
]
args_grid = {"--experiment_dir": experiment_dir_list}
args_grid = process_args(args_grid)
# Out:
# Number of parameters combinations: 2
# ['--experiment_dir', 'data_tcab/detection-experiments/allocine/distilcamembert/clean_vs_all']
# ['--experiment_dir', 'data_tcab/detection-experiments/allocine/distilcamembert/multiclass_with_clean']

# %%
call_main_args(make_experiment.main, args_grid)
# Out:
#   0%|          | 0/2 [00:00<?, ?it/s]
# ### Running main with ['--experiment_dir', 'data_tcab/detection-experiments/allocine/distilcamembert/clean_vs_all']
#
# making exp into...  data_tcab/detection-experiments/allocine/distilcamembert/clean_vs_all
#
# --- loading known instances from  data_tcab/reprs/samplewise
# --- target_model: distilcamembert, target_model_dataset: allocine
# --- No. joblib files of varied size to read: 1
# [0] data_tcab\reprs\samplewise\distilcamembert_allocine_ALL_ALL.joblib
#
# done, no. unique instances with extracted features: 28,913
#
# --- creating train.joblib
#     cannot find repr. for 0 / 10,716 instances
#
# --- creating val.joblib
#     cannot find repr. for 0 / 3,556 instances
#
# --- creating test_release.joblib
#     cannot find repr. for 0 / 2,891 instances
#
# ### Running main with ['--experiment_dir', 'data_tcab/detection-experiments/allocine/distilcamembert/multiclass_with_clean']
#
# making exp into...  data_tcab/detection-experiments/allocine/distilcamembert/multiclass_with_clean
#
# --- loading known instances from  data_tcab/reprs/samplewise
# --- target_model: distilcamembert, target_model_dataset: allocine
# --- No. joblib files of varied size to read: 1
# [0] data_tcab\reprs\samplewise\distilcamembert_allocine_ALL_ALL.joblib
#
# done, no. unique instances with extracted features: 28,913
#
# --- creating train.joblib
#     cannot find repr. for 0 / 6,545 instances
#
# --- creating val.joblib
#     cannot find repr. for 0 / 2,189 instances
#
# --- creating test_release.joblib
#     cannot find repr. for 0 / 2,891 instances

# %% [markdown]
# ## 6. scripts/run_experiment.py

# %%
args_grid = {
    "--experiment_dir": experiment_dir_list,
    "--feature_setting": ["bert", "bert+tp", "bert+tp+lm", "all"],
    "--model": ["LR", "RF", "LGB"],
    "--model_n_jobs": ["10"],
    "--disable_tune": [""],
}
args_grid = process_args(args_grid)
# Out:
# Number of parameters combinations: 24
# ['--experiment_dir', 'data_tcab/detection-experiments/allocine/distilcamembert/clean_vs_all', '--feature_setting', 'bert', '--model', 'LR', '--model_n_jobs', '10', '--disable_tune']
# ['--experiment_dir', 'data_tcab/detection-experiments/allocine/distilcamembert/clean_vs_all', '--feature_setting', 'bert', '--model', 'RF', '--model_n_jobs', '10', '--disable_tune']
# ['--experiment_dir', 'data_tcab/detection-experiments/allocine/distilcamembert/clean_vs_all', '--feature_setting', 'bert', '--model', 'LGB', '--model_n_jobs', '10', '--disable_tune']
# ['--experiment_dir', 'data_tcab/detection-experiments/allocine/distilcamembert/clean_vs_all', '--feature_setting', 'bert+tp', '--model', 'LR', '--model_n_jobs', '10', '--disable_tune']
# ['--experiment_dir', 'data_tcab/detection-experiments/allocine/distilcamembert/clean_vs_all', '--feature_setting', 'bert+tp', '--model', 'RF', '--model_n_jobs', '10', '--disable_tune']
# ['--experiment_dir', 'data_tcab/detection-experiments/allocine/distilcamembert/clean_vs_all', '--feature_setting', 'bert+tp', '--model', 'LGB', '--model_n_jobs', '10', '--disable_tune']
# ['--experiment_dir', 'data_tcab/detection-experiments/allocine/distilcamembert/clean_vs_all', '--feature_setting', 'bert+tp+lm', '--model', 'LR', '--model_n_jobs', '10', '--disable_tune']
# ['--experiment_dir', 'data_tcab/detection-experiments/allocine/distilcamembert/clean_vs_all', '--feature_setting', 'bert+tp+lm', '--model', 'RF', '--model_n_jobs', '10', '--disable_tune']
# ['--experiment_dir', 'data_tcab/detection-experiments/allocine/distilcamembert/clean_vs_all', '--feature_setting', 'bert+tp+lm', '--model', 'LGB', '--model_n_jobs', '10', '--disable_tune']
# ['--experiment_dir', 'data_tcab/detection-experiments/allocine/distilcamembert/clean_vs_all', '--feature_setting', 'all', '--model', 'LR', '--model_n_jobs', '10', '--disable_tune']
# ['--experiment_dir', 'data_tcab/detection-experiments/allocine/distilcamembert/clean_vs_all', '--feature_setting', 'all', '--model', 'RF', '--model_n_jobs', '10', '--disable_tune']
# ['--experiment_dir', 'data_tcab/detection-experiments/allocine/distilcamembert/clean_vs_all', '--feature_setting', 'all', '--model', 'LGB', '--model_n_jobs', '10', '--disable_tune']
# ['--experiment_dir', 'data_tcab/detection-experiments/allocine/distilcamembert/multiclass_with_clean', '--feature_setting', 'bert', '--model', 'LR', '--model_n_jobs', '10', '--disable_tune']
# ['--experiment_dir', 'data_tcab/detection-experiments/allocine/distilcamembert/multiclass_with_clean', '--feature_setting', 'bert', '--model', 'RF', '--model_n_jobs', '10', '--disable_tune']
# ['--experiment_dir', 'data_tcab/detection-experiments/allocine/distilcamembert/multiclass_with_clean', '--feature_setting', 'bert', '--model', 'LGB', '--model_n_jobs', '10', '--disable_tune']
# ['--experiment_dir', 'data_tcab/detection-experiments/allocine/distilcamembert/multiclass_with_clean', '--feature_setting', 'bert+tp', '--model', 'LR', '--model_n_jobs', '10', '--disable_tune']
# ['--experiment_dir', 'data_tcab/detection-experiments/allocine/distilcamembert/multiclass_with_clean', '--feature_setting', 'bert+tp', '--model', 'RF', '--model_n_jobs', '10', '--disable_tune']
# ['--experiment_dir', 'data_tcab/detection-experiments/allocine/distilcamembert/multiclass_with_clean', '--feature_setting', 'bert+tp', '--model', 'LGB', '--model_n_jobs', '10', '--disable_tune']
# ['--experiment_dir', 'data_tcab/detection-experiments/allocine/distilcamembert/multiclass_with_clean', '--feature_setting', 'bert+tp+lm', '--model', 'LR', '--model_n_jobs', '10', '--disable_tune']
# ['--experiment_dir', 'data_tcab/detection-experiments/allocine/distilcamembert/multiclass_with_clean', '--feature_setting', 'bert+tp+lm', '--model', 'RF', '--model_n_jobs', '10', '--disable_tune']
# ['--experiment_dir', 'data_tcab/detection-experiments/allocine/distilcamembert/multiclass_with_clean', '--feature_setting', 'bert+tp+lm', '--model', 'LGB', '--model_n_jobs', '10', '--disable_tune']
# ['--experiment_dir', 'data_tcab/detection-experiments/allocine/distilcamembert/multiclass_with_clean', '--feature_setting', 'all', '--model', 'LR', '--model_n_jobs', '10', '--disable_tune']
# ['--experiment_dir', 'data_tcab/detection-experiments/allocine/distilcamembert/multiclass_with_clean', '--feature_setting', 'all', '--model', 'RF', '--model_n_jobs', '10', '--disable_tune']
# ['--experiment_dir', 'data_tcab/detection-experiments/allocine/distilcamembert/multiclass_with_clean', '--feature_setting', 'all', '--model', 'LGB', '--model_n_jobs', '10', '--disable_tune']

# %%
call_main_args(run_experiment.main, args_grid)
# Out:
#   0%|          | 0/24 [00:00<?, ?it/s]
# ### Running main with ['--experiment_dir', 'data_tcab/detection-experiments/allocine/distilcamembert/clean_vs_all', '--feature_setting', 'bert', '--model', 'LR', '--model_n_jobs', '10', '--disable_tune']
#
# starting experiment: data_tcab\detection-experiments\allocine\distilcamembert\clean_vs_all
# CPU available : 16
# --- searching exp data in data_tcab\detection-experiments\allocine\distilcamembert\clean_vs_all
# --- using these features:
# ['tp_bert']
# --- output to data_tcab\detection-experiments\allocine\distilcamembert\clean_vs_all\LR\bert
# --- loading from data_tcab\detection-experiments\allocine\distilcamembert\clean_vs_all\train.joblib
# num of instances in the file:  10716
# loaded, labels:  Counter({'perturbed': 5358, 'clean': 5358})
# --- loading from data_tcab\detection-experiments\allocine\distilcamembert\clean_vs_all\val.joblib
# num of instances in the file:  3556
# loaded, labels:  Counter({'perturbed': 1778, 'clean': 1778})
# --- loading from data_tcab\detection-experiments\allocine\distilcamembert\clean_vs_all\test_release.joblib
# num of instances in the file:  2891
# loaded, labels:  Counter({'clean': 2009, 'perturbed': 882})
# --- training main starting
# skip if done: False
#
# no. train: 10,716
# no. val: 3,556
# no. test: 2,891
# no. features: 768
#
# --- starting training
# --- finished training
# --- training time: 00:00:01
# {'train_accuracy': 0.7685703620754013, 'train_balanced_accuracy': 0.7689085096908266, 'train_confusion_matrix': [[4213, 1145], [1335, 4023]], 'train_roc_auc': 0.7685703620754012}
# {'validation_accuracy': 0.6892575928008999, 'validation_balanced_accuracy': 0.6925070215703542, 'validation_confusion_matrix': [[1341, 437], [668, 1110]], 'validation_roc_auc': 0.6892575928008999}
# {'test_accuracy': 0.7260463507436873, 'test_balanced_accuracy': 0.6861414947541287, 'test_confusion_matrix': [[1533, 476], [316, 566]], 'test_roc_auc': 0.7023947790498313}
# --- saving metrics to data_tcab\detection-experiments\allocine\distilcamembert\clean_vs_all\LR\bert
#
# ### Running main with ['--experiment_dir', 'data_tcab/detection-experiments/allocine/distilcamembert/clean_vs_all', '--feature_setting', 'bert', '--model', 'RF', '--model_n_jobs', '10', '--disable_tune']
#
# starting experiment: data_tcab\detection-experiments\allocine\distilcamembert\clean_vs_all
# CPU available : 16
# --- searching exp data in data_tcab\detection-experiments\allocine\distilcamembert\clean_vs_all
# --- using these features:
# ['tp_bert']
# --- output to data_tcab\detection-experiments\allocine\distilcamembert\clean_vs_all\RF\bert
# --- loading from data_tcab\detection-experiments\allocine\distilcamembert\clean_vs_all\train.joblib
# num of instances in the file:  10716
# loaded, labels:  Counter({'perturbed': 5358, 'clean': 5358})
# --- loading from data_tcab\detection-experiments\allocine\distilcamembert\clean_vs_all\val.joblib
# num of instances in the file:  3556
# loaded, labels:  Counter({'perturbed': 1778, 'clean': 1778})
# --- loading from data_tcab\detection-experiments\allocine\distilcamembert\clean_vs_all\test_release.joblib
# num of instances in the file:  2891
# loaded, labels:  Counter({'clean': 2009, 'perturbed': 882})
# --- training main starting
# skip if done: False
#
# no. train: 10,716
# no. val: 3,556
# no. test: 2,891
# no. features: 768
#
# --- starting training
# --- finished training
# --- training time: 00:00:01
# {'train_accuracy': 0.7075401269130273, 'train_balanced_accuracy': 0.7107970505021686, 'train_confusion_matrix': [[4124, 1234], [1900, 3458]], 'train_roc_auc': 0.7075401269130273}
# {'validation_accuracy': 0.6259842519685039, 'validation_balanced_accuracy': 0.6297269126537419, 'validation_confusion_matrix': [[1264, 514], [816, 962]], 'validation_roc_auc': 0.6259842519685039}
# {'test_accuracy': 0.6720857834659287, 'test_balanced_accuracy': 0.628551587178517, 'test_confusion_matrix': [[1450, 559], [389, 493]], 'test_roc_auc': 0.6403545157900559}
# --- saving metrics to data_tcab\detection-experiments\allocine\distilcamembert\clean_vs_all\RF\bert
#
# ### Running main with ['--experiment_dir', 'data_tcab/detection-experiments/allocine/distilcamembert/clean_vs_all', '--feature_setting', 'bert', '--model', 'LGB', '--model_n_jobs', '10', '--disable_tune']
#
# starting experiment: data_tcab\detection-experiments\allocine\distilcamembert\clean_vs_all
# CPU available : 16
# --- searching exp data in data_tcab\detection-experiments\allocine\distilcamembert\clean_vs_all
# --- using these features:
# ['tp_bert']
# --- output to data_tcab\detection-experiments\allocine\distilcamembert\clean_vs_all\LGB\bert
# --- loading from data_tcab\detection-experiments\allocine\distilcamembert\clean_vs_all\train.joblib
# num of instances in the file:  10716
# loaded, labels:  Counter({'perturbed': 5358, 'clean': 5358})
# --- loading from data_tcab\detection-experiments\allocine\distilcamembert\clean_vs_all\val.joblib
# num of instances in the file:  3556
# loaded, labels:  Counter({'perturbed': 1778, 'clean': 1778})
# --- loading from data_tcab\detection-experiments\allocine\distilcamembert\clean_vs_all\test_release.joblib
# num of instances in the file:  2891
# loaded, labels:  Counter({'clean': 2009, 'perturbed': 882})
# --- training main starting
# skip if done: False
#
# no. train: 10,716
# no. val: 3,556
# no. test: 2,891
# no. features: 768
#
# --- starting training
# --- finished training
# --- training time: 00:00:01
# {'train_accuracy': 0.9174132138857782, 'train_balanced_accuracy': 0.9180739177738947, 'train_confusion_matrix': [[4809, 549], [336, 5022]], 'train_roc_auc': 0.9174132138857782}
# {'validation_accuracy': 0.655511811023622, 'validation_balanced_accuracy': 0.6670351437808233, 'validation_confusion_matrix': [[1399, 379], [846, 932]], 'validation_roc_auc': 0.6555118110236221}
# {'test_accuracy': 0.7059840885506745, 'test_balanced_accuracy': 0.6536670219895382, 'test_confusion_matrix': [[1581, 428], [422, 460]], 'test_roc_auc': 0.6542503180133842}
# --- saving metrics to data_tcab\detection-experiments\allocine\distilcamembert\clean_vs_all\LGB\bert
#
# ### Running main with ['--experiment_dir', 'data_tcab/detection-experiments/allocine/distilcamembert/clean_vs_all', '--feature_setting', 'bert+tp', '--model', 'LR', '--model_n_jobs', '10', '--disable_tune']
#
# starting experiment: data_tcab\detection-experiments\allocine\distilcamembert\clean_vs_all
# CPU available : 16
# --- searching exp data in data_tcab\detection-experiments\allocine\distilcamembert\clean_vs_all
# --- using these features:
# ['tp_avg_word_length', 'tp_bert', 'tp_is_first_word_lowercase', 'tp_num_alpha_chars', 'tp_num_cased_letters', 'tp_num_cased_word_switches', 'tp_num_chars', 'tp_num_digits', 'tp_num_lowercase_after_punctuation', 'tp_num_mixed_case_words', 'tp_num_multi_spaces', 'tp_num_non_ascii', 'tp_num_punctuation', 'tp_num_single_lowercase_letters', 'tp_num_words']
# --- output to data_tcab\detection-experiments\allocine\distilcamembert\clean_vs_all\LR\bert+tp
# --- loading from data_tcab\detection-experiments\allocine\distilcamembert\clean_vs_all\train.joblib
# num of instances in the file:  10716
# loaded, labels:  Counter({'perturbed': 5358, 'clean': 5358})
# --- loading from data_tcab\detection-experiments\allocine\distilcamembert\clean_vs_all\val.joblib
# num of instances in the file:  3556
# loaded, labels:  Counter({'perturbed': 1778, 'clean': 1778})
# --- loading from data_tcab\detection-experiments\allocine\distilcamembert\clean_vs_all\test_release.joblib
# num of instances in the file:  2891
# loaded, labels:  Counter({'clean': 2009, 'perturbed': 882})
# --- training main starting
# skip if done: False
#
# no. train: 10,716
# no. val: 3,556
# no. test: 2,891
# no. features: 804
#
# --- starting training
# --- finished training
# --- training time: 00:00:01
# {'train_accuracy': 0.7888204553938036, 'train_balanced_accuracy': 0.7893771211393009, 'train_confusion_matrix': [[4344, 1014], [1249, 4109]], 'train_roc_auc': 0.7888204553938036}
# {'validation_accuracy': 0.717941507311586, 'validation_balanced_accuracy': 0.7218838915788948, 'validation_confusion_matrix': [[1395, 383], [620, 1158]], 'validation_roc_auc': 0.717941507311586}
# {'test_accuracy': 0.7457627118644068, 'test_balanced_accuracy': 0.7062036582706357, 'test_confusion_matrix': [[1573, 436], [299, 583]], 'test_roc_auc': 0.7219871688512803}
# --- saving metrics to data_tcab\detection-experiments\allocine\distilcamembert\clean_vs_all\LR\bert+tp
#
# ### Running main with ['--experiment_dir', 'data_tcab/detection-experiments/allocine/distilcamembert/clean_vs_all', '--feature_setting', 'bert+tp', '--model', 'RF', '--model_n_jobs', '10', '--disable_tune']
#
# starting experiment: data_tcab\detection-experiments\allocine\distilcamembert\clean_vs_all
# CPU available : 16
# --- searching exp data in data_tcab\detection-experiments\allocine\distilcamembert\clean_vs_all
# --- using these features:
# ['tp_avg_word_length', 'tp_bert', 'tp_is_first_word_lowercase', 'tp_num_alpha_chars', 'tp_num_cased_letters', 'tp_num_cased_word_switches', 'tp_num_chars', 'tp_num_digits', 'tp_num_lowercase_after_punctuation', 'tp_num_mixed_case_words', 'tp_num_multi_spaces', 'tp_num_non_ascii', 'tp_num_punctuation', 'tp_num_single_lowercase_letters', 'tp_num_words']
# --- output to data_tcab\detection-experiments\allocine\distilcamembert\clean_vs_all\RF\bert+tp
# --- loading from data_tcab\detection-experiments\allocine\distilcamembert\clean_vs_all\train.joblib
# num of instances in the file:  10716
# loaded, labels:  Counter({'perturbed': 5358, 'clean': 5358})
# --- loading from data_tcab\detection-experiments\allocine\distilcamembert\clean_vs_all\val.joblib
# num of instances in the file:  3556
# loaded, labels:  Counter({'perturbed': 1778, 'clean': 1778})
# --- loading from data_tcab\detection-experiments\allocine\distilcamembert\clean_vs_all\test_release.joblib
# num of instances in the file:  2891
# loaded, labels:  Counter({'clean': 2009, 'perturbed': 882})
# --- training main starting
# skip if done: False
#
# no. train: 10,716
# no. val: 3,556
# no. test: 2,891
# no. features: 804
#
# --- starting training
# --- finished training
# --- training time: 00:00:01
# {'train_accuracy': 0.7391750653228817, 'train_balanced_accuracy': 0.7454847167617146, 'train_confusion_matrix': [[4390, 968], [1827, 3531]], 'train_roc_auc': 0.7391750653228817}
# {'validation_accuracy': 0.6743532058492688, 'validation_balanced_accuracy': 0.683550458226769, 'validation_confusion_matrix': [[1398, 380], [778, 1000]], 'validation_roc_auc': 0.6743532058492688}
# {'test_accuracy': 0.7156693185748876, 'test_balanced_accuracy': 0.6708548096230831, 'test_confusion_matrix': [[1547, 462], [360, 522]], 'test_roc_auc': 0.6809357889497262}
# --- saving metrics to data_tcab\detection-experiments\allocine\distilcamembert\clean_vs_all\RF\bert+tp
#
# ### Running main with ['--experiment_dir', 'data_tcab/detection-experiments/allocine/distilcamembert/clean_vs_all', '--feature_setting', 'bert+tp', '--model', 'LGB', '--model_n_jobs', '10', '--disable_tune']
#
# starting experiment: data_tcab\detection-experiments\allocine\distilcamembert\clean_vs_all
# CPU available : 16
# --- searching exp data in data_tcab\detection-experiments\allocine\distilcamembert\clean_vs_all
# --- using these features:
# ['tp_avg_word_length', 'tp_bert', 'tp_is_first_word_lowercase', 'tp_num_alpha_chars', 'tp_num_cased_letters', 'tp_num_cased_word_switches', 'tp_num_chars', 'tp_num_digits', 'tp_num_lowercase_after_punctuation', 'tp_num_mixed_case_words', 'tp_num_multi_spaces', 'tp_num_non_ascii', 'tp_num_punctuation', 'tp_num_single_lowercase_letters', 'tp_num_words']
# --- output to data_tcab\detection-experiments\allocine\distilcamembert\clean_vs_all\LGB\bert+tp
# --- loading from data_tcab\detection-experiments\allocine\distilcamembert\clean_vs_all\train.joblib
# num of instances in the file:  10716
# loaded, labels:  Counter({'perturbed': 5358, 'clean': 5358})
# --- loading from data_tcab\detection-experiments\allocine\distilcamembert\clean_vs_all\val.joblib
# num of instances in the file:  3556
# loaded, labels:  Counter({'perturbed': 1778, 'clean': 1778})
# --- loading from data_tcab\detection-experiments\allocine\distilcamembert\clean_vs_all\test_release.joblib
# num of instances in the file:  2891
# loaded, labels:  Counter({'clean': 2009, 'perturbed': 882})
# --- training main starting
# skip if done: False
#
# no. train: 10,716
# no. val: 3,556
# no. test: 2,891
# no. features: 804
#
# --- starting training
# --- finished training
# --- training time: 00:00:01
# {'train_accuracy': 0.9106942889137738, 'train_balanced_accuracy': 0.9112278593131751, 'train_confusion_matrix': [[4976, 382], [575, 4783]], 'train_roc_auc': 0.9106942889137738}
# {'validation_accuracy': 0.7263779527559056, 'validation_balanced_accuracy': 0.7434627921004081, 'validation_confusion_matrix': [[1527, 251], [722, 1056]], 'validation_roc_auc': 0.7263779527559054}
# {'test_accuracy': 0.7592528536838464, 'test_balanced_accuracy': 0.716026352625927, 'test_confusion_matrix': [[1663, 346], [350, 532]], 'test_roc_auc': 0.7154748078093026}
# --- saving metrics to data_tcab\detection-experiments\allocine\distilcamembert\clean_vs_all\LGB\bert+tp
#
# ### Running main with ['--experiment_dir', 'data_tcab/detection-experiments/allocine/distilcamembert/clean_vs_all', '--feature_setting', 'bert+tp+lm', '--model', 'LR', '--model_n_jobs', '10', '--disable_tune']
#
# starting experiment: data_tcab\detection-experiments\allocine\distilcamembert\clean_vs_all
# CPU available : 16
# --- searching exp data in data_tcab\detection-experiments\allocine\distilcamembert\clean_vs_all
# --- using these features:
# ['lm_perplexity', 'lm_proba_and_rank', 'tp_avg_word_length', 'tp_bert', 'tp_is_first_word_lowercase', 'tp_num_alpha_chars', 'tp_num_cased_letters', 'tp_num_cased_word_switches', 'tp_num_chars', 'tp_num_digits', 'tp_num_lowercase_after_punctuation', 'tp_num_mixed_case_words', 'tp_num_multi_spaces', 'tp_num_non_ascii', 'tp_num_punctuation', 'tp_num_single_lowercase_letters', 'tp_num_words']
# --- output to data_tcab\detection-experiments\allocine\distilcamembert\clean_vs_all\LR\bert+tp+lm
# --- loading from data_tcab\detection-experiments\allocine\distilcamembert\clean_vs_all\train.joblib
# num of instances in the file:  10716
# loaded, labels:  Counter({'perturbed': 5358, 'clean': 5358})
# --- loading from data_tcab\detection-experiments\allocine\distilcamembert\clean_vs_all\val.joblib
# num of instances in the file:  3556
# loaded, labels:  Counter({'perturbed': 1778, 'clean': 1778})
# --- loading from data_tcab\detection-experiments\allocine\distilcamembert\clean_vs_all\test_release.joblib
# num of instances in the file:  2891
# loaded, labels:  Counter({'clean': 2009, 'perturbed': 882})
# --- training main starting
# skip if done: False
#
# no. train: 10,716
# no. val: 3,556
# no. test: 2,891
# no. features: 848
#
# --- starting training
# --- finished training
# --- training time: 00:00:01
# {'train_accuracy': 0.8287607316162747, 'train_balanced_accuracy': 0.8293518935492601, 'train_confusion_matrix': [[4554, 804], [1031, 4327]], 'train_roc_auc': 0.8287607316162747}
# {'validation_accuracy': 0.7589988751406074, 'validation_balanced_accuracy': 0.764525633756403, 'validation_confusion_matrix': [[1478, 300], [557, 1221]], 'validation_roc_auc': 0.7589988751406074}
# {'test_accuracy': 0.7737806987201661, 'test_balanced_accuracy': 0.7352299591143332, 'test_confusion_matrix': [[1636, 373], [281, 601]], 'test_roc_auc': 0.7478706929926443}
# --- saving metrics to data_tcab\detection-experiments\allocine\distilcamembert\clean_vs_all\LR\bert+tp+lm
#
# ### Running main with ['--experiment_dir', 'data_tcab/detection-experiments/allocine/distilcamembert/clean_vs_all', '--feature_setting', 'bert+tp+lm', '--model', 'RF', '--model_n_jobs', '10', '--disable_tune']
#
# starting experiment: data_tcab\detection-experiments\allocine\distilcamembert\clean_vs_all
# CPU available : 16
# --- searching exp data in data_tcab\detection-experiments\allocine\distilcamembert\clean_vs_all
# --- using these features:
# ['lm_perplexity', 'lm_proba_and_rank', 'tp_avg_word_length', 'tp_bert', 'tp_is_first_word_lowercase', 'tp_num_alpha_chars', 'tp_num_cased_letters', 'tp_num_cased_word_switches', 'tp_num_chars', 'tp_num_digits', 'tp_num_lowercase_after_punctuation', 'tp_num_mixed_case_words', 'tp_num_multi_spaces', 'tp_num_non_ascii', 'tp_num_punctuation', 'tp_num_single_lowercase_letters', 'tp_num_words']
# --- output to data_tcab\detection-experiments\allocine\distilcamembert\clean_vs_all\RF\bert+tp+lm
# --- loading from data_tcab\detection-experiments\allocine\distilcamembert\clean_vs_all\train.joblib
# num of instances in the file:  10716
# loaded, labels:  Counter({'perturbed': 5358, 'clean': 5358})
# --- loading from data_tcab\detection-experiments\allocine\distilcamembert\clean_vs_all\val.joblib
# num of instances in the file:  3556
# loaded, labels:  Counter({'perturbed': 1778, 'clean': 1778})
# --- loading from data_tcab\detection-experiments\allocine\distilcamembert\clean_vs_all\test_release.joblib
# num of instances in the file:  2891
# loaded, labels:  Counter({'clean': 2009, 'perturbed': 882})
# --- training main starting
# skip if done: False
#
# no. train: 10,716
# no. val: 3,556
# no. test: 2,891
# no. features: 848
#
# --- starting training
# --- finished training
# --- training time: 00:00:01
# {'train_accuracy': 0.7855543113101904, 'train_balanced_accuracy': 0.7883759759644826, 'train_confusion_matrix': [[4474, 884], [1414, 3944]], 'train_roc_auc': 0.7855543113101904}
# {'validation_accuracy': 0.7679977502812149, 'validation_balanced_accuracy': 0.7709954051335198, 'validation_confusion_matrix': [[1459, 319], [506, 1272]], 'validation_roc_auc': 0.7679977502812148}
# {'test_accuracy': 0.7941888619854721, 'test_balanced_accuracy': 0.7581740077185755, 'test_confusion_matrix': [[1663, 346], [249, 633]], 'test_roc_auc': 0.772731043636967}
# --- saving metrics to data_tcab\detection-experiments\allocine\distilcamembert\clean_vs_all\RF\bert+tp+lm
#
# ### Running main with ['--experiment_dir', 'data_tcab/detection-experiments/allocine/distilcamembert/clean_vs_all', '--feature_setting', 'bert+tp+lm', '--model', 'LGB', '--model_n_jobs', '10', '--disable_tune']
#
# starting experiment: data_tcab\detection-experiments\allocine\distilcamembert\clean_vs_all
# CPU available : 16
# --- searching exp data in data_tcab\detection-experiments\allocine\distilcamembert\clean_vs_all
# --- using these features:
# ['lm_perplexity', 'lm_proba_and_rank', 'tp_avg_word_length', 'tp_bert', 'tp_is_first_word_lowercase', 'tp_num_alpha_chars', 'tp_num_cased_letters', 'tp_num_cased_word_switches', 'tp_num_chars', 'tp_num_digits', 'tp_num_lowercase_after_punctuation', 'tp_num_mixed_case_words', 'tp_num_multi_spaces', 'tp_num_non_ascii', 'tp_num_punctuation', 'tp_num_single_lowercase_letters', 'tp_num_words']
# --- output to data_tcab\detection-experiments\allocine\distilcamembert\clean_vs_all\LGB\bert+tp+lm
# --- loading from data_tcab\detection-experiments\allocine\distilcamembert\clean_vs_all\train.joblib
# num of instances in the file:  10716
# loaded, labels:  Counter({'perturbed': 5358, 'clean': 5358})
# --- loading from data_tcab\detection-experiments\allocine\distilcamembert\clean_vs_all\val.joblib
# num of instances in the file:  3556
# loaded, labels:  Counter({'perturbed': 1778, 'clean': 1778})
# --- loading from data_tcab\detection-experiments\allocine\distilcamembert\clean_vs_all\test_release.joblib
# num of instances in the file:  2891
# loaded, labels:  Counter({'clean': 2009, 'perturbed': 882})
# --- training main starting
# skip if done: False
#
# no. train: 10,716
# no. val: 3,556
# no. test: 2,891
# no. features: 848
#
# --- starting training
# --- finished training
# --- training time: 00:00:01
# {'train_accuracy': 0.9365434863755132, 'train_balanced_accuracy': 0.9373354019970561, 'train_confusion_matrix': [[5132, 226], [454, 4904]], 'train_roc_auc': 0.9365434863755133}
# {'validation_accuracy': 0.7896512935883014, 'validation_balanced_accuracy': 0.7987324741353211, 'validation_confusion_matrix': [[1559, 219], [529, 1249]], 'validation_roc_auc': 0.7896512935883016}
# {'test_accuracy': 0.8201314424074715, 'test_balanced_accuracy': 0.7875582355616595, 'test_confusion_matrix': [[1741, 268], [252, 630]], 'test_roc_auc': 0.7904430064708811}
# --- saving metrics to data_tcab\detection-experiments\allocine\distilcamembert\clean_vs_all\LGB\bert+tp+lm
#
# ### Running main with ['--experiment_dir', 'data_tcab/detection-experiments/allocine/distilcamembert/clean_vs_all', '--feature_setting', 'all', '--model', 'LR', '--model_n_jobs', '10', '--disable_tune']
#
# starting experiment: data_tcab\detection-experiments\allocine\distilcamembert\clean_vs_all
# CPU available : 16
# --- searching exp data in data_tcab\detection-experiments\allocine\distilcamembert\clean_vs_all
# --- using these features:
# ['lm_perplexity', 'lm_proba_and_rank', 'tm_activation', 'tm_gradient', 'tm_posterior', 'tm_saliency', 'tp_avg_word_length', 'tp_bert', 'tp_is_first_word_lowercase', 'tp_num_alpha_chars', 'tp_num_cased_letters', 'tp_num_cased_word_switches', 'tp_num_chars', 'tp_num_digits', 'tp_num_lowercase_after_punctuation', 'tp_num_mixed_case_words', 'tp_num_multi_spaces', 'tp_num_non_ascii', 'tp_num_punctuation', 'tp_num_single_lowercase_letters', 'tp_num_words']
# --- output to data_tcab\detection-experiments\allocine\distilcamembert\clean_vs_all\LR\all
# c:\Users\Baptiste\AppData\Local\pypoetry\Cache\virtualenvs\nlp-adversarial-attacks-ghBt6cj_-py3.10\lib\site-packages\torch\nn\modules\module.py:1117: UserWarning: Using a non-full backward hook when the forward contains multiple autograd Nodes is deprecated and will be removed in future versions. This hook will be missing some grad_input. Please use register_full_backward_hook to get the documented behavior.
#   warnings.warn("Using a non-full backward hook when the forward contains multiple autograd Nodes "
# --- loading from data_tcab\detection-experiments\allocine\distilcamembert\clean_vs_all\train.joblib
# num of instances in the file:  10716
# loaded, labels:  Counter({'perturbed': 5358, 'clean': 5358})
# --- loading from data_tcab\detection-experiments\allocine\distilcamembert\clean_vs_all\val.joblib
# num of instances in the file:  3556
# loaded, labels:  Counter({'perturbed': 1778, 'clean': 1778})
# --- loading from data_tcab\detection-experiments\allocine\distilcamembert\clean_vs_all\test_release.joblib
# num of instances in the file:  2891
# loaded, labels:  Counter({'clean': 2009, 'perturbed': 882})
# --- training main starting
# skip if done: False
#
# no. train: 10,716
# no. val: 3,556
# no. test: 2,891
# no. features: 4,539
#
# --- starting training
# --- finished training
# --- training time: 00:00:04
# {'train_accuracy': 0.9997200447928332, 'train_balanced_accuracy': 0.9997200621997304, 'train_confusion_matrix': [[5356, 2], [1, 5357]], 'train_roc_auc': 0.999720044792833}
# {'validation_accuracy': 0.9468503937007874, 'validation_balanced_accuracy': 0.9472478015497985, 'validation_confusion_matrix': [[1710, 68], [121, 1657]], 'validation_roc_auc': 0.9468503937007874}
# {'test_accuracy': 0.9550328606018679, 'test_balanced_accuracy': 0.9435077081283298, 'test_confusion_matrix': [[1929, 80], [50, 832]], 'test_roc_auc': 0.9517449256125214}
# --- saving metrics to data_tcab\detection-experiments\allocine\distilcamembert\clean_vs_all\LR\all
#
# ### Running main with ['--experiment_dir', 'data_tcab/detection-experiments/allocine/distilcamembert/clean_vs_all', '--feature_setting', 'all', '--model', 'RF', '--model_n_jobs', '10', '--disable_tune']
#
# starting experiment: data_tcab\detection-experiments\allocine\distilcamembert\clean_vs_all
# CPU available : 16
# --- searching exp data in data_tcab\detection-experiments\allocine\distilcamembert\clean_vs_all
# --- using these features:
# ['lm_perplexity', 'lm_proba_and_rank', 'tm_activation', 'tm_gradient', 'tm_posterior', 'tm_saliency', 'tp_avg_word_length', 'tp_bert', 'tp_is_first_word_lowercase', 'tp_num_alpha_chars', 'tp_num_cased_letters', 'tp_num_cased_word_switches', 'tp_num_chars', 'tp_num_digits', 'tp_num_lowercase_after_punctuation', 'tp_num_mixed_case_words', 'tp_num_multi_spaces', 'tp_num_non_ascii', 'tp_num_punctuation', 'tp_num_single_lowercase_letters', 'tp_num_words']
# --- output to data_tcab\detection-experiments\allocine\distilcamembert\clean_vs_all\RF\all
# c:\Users\Baptiste\AppData\Local\pypoetry\Cache\virtualenvs\nlp-adversarial-attacks-ghBt6cj_-py3.10\lib\site-packages\torch\nn\modules\module.py:1117: UserWarning: Using a non-full backward hook when the forward contains multiple autograd Nodes is deprecated and will be removed in future versions. This hook will be missing some grad_input. Please use register_full_backward_hook to get the documented behavior.
#   warnings.warn("Using a non-full backward hook when the forward contains multiple autograd Nodes "
# --- loading from data_tcab\detection-experiments\allocine\distilcamembert\clean_vs_all\train.joblib
# num of instances in the file:  10716
# loaded, labels:  Counter({'perturbed': 5358, 'clean': 5358})
# --- loading from data_tcab\detection-experiments\allocine\distilcamembert\clean_vs_all\val.joblib
# num of instances in the file:  3556
# loaded, labels:  Counter({'perturbed': 1778, 'clean': 1778})
# --- loading from data_tcab\detection-experiments\allocine\distilcamembert\clean_vs_all\test_release.joblib
# num of instances in the file:  2891
# loaded, labels:  Counter({'clean': 2009, 'perturbed': 882})
# --- training main starting
# skip if done: False
#
# no. train: 10,716
# no. val: 3,556
# no. test: 2,891
# no. features: 4,539
#
# --- starting training
# --- finished training
# --- training time: 00:00:04
# {'train_accuracy': 0.9592198581560284, 'train_balanced_accuracy': 0.9596348688629408, 'train_confusion_matrix': [[5059, 299], [138, 5220]], 'train_roc_auc': 0.9592198581560284}
# {'validation_accuracy': 0.9547244094488189, 'validation_balanced_accuracy': 0.9553329538662407, 'validation_confusion_matrix': [[1665, 113], [48, 1730]], 'validation_roc_auc': 0.9547244094488189}
# {'test_accuracy': 0.9456935316499481, 'test_balanced_accuracy': 0.9272927075275342, 'test_confusion_matrix': [[1882, 127], [30, 852]], 'test_roc_auc': 0.9513854322216692}
# --- saving metrics to data_tcab\detection-experiments\allocine\distilcamembert\clean_vs_all\RF\all
#
# ### Running main with ['--experiment_dir', 'data_tcab/detection-experiments/allocine/distilcamembert/clean_vs_all', '--feature_setting', 'all', '--model', 'LGB', '--model_n_jobs', '10', '--disable_tune']
#
# starting experiment: data_tcab\detection-experiments\allocine\distilcamembert\clean_vs_all
# CPU available : 16
# --- searching exp data in data_tcab\detection-experiments\allocine\distilcamembert\clean_vs_all
# --- using these features:
# ['lm_perplexity', 'lm_proba_and_rank', 'tm_activation', 'tm_gradient', 'tm_posterior', 'tm_saliency', 'tp_avg_word_length', 'tp_bert', 'tp_is_first_word_lowercase', 'tp_num_alpha_chars', 'tp_num_cased_letters', 'tp_num_cased_word_switches', 'tp_num_chars', 'tp_num_digits', 'tp_num_lowercase_after_punctuation', 'tp_num_mixed_case_words', 'tp_num_multi_spaces', 'tp_num_non_ascii', 'tp_num_punctuation', 'tp_num_single_lowercase_letters', 'tp_num_words']
# --- output to data_tcab\detection-experiments\allocine\distilcamembert\clean_vs_all\LGB\all
# c:\Users\Baptiste\AppData\Local\pypoetry\Cache\virtualenvs\nlp-adversarial-attacks-ghBt6cj_-py3.10\lib\site-packages\torch\nn\modules\module.py:1117: UserWarning: Using a non-full backward hook when the forward contains multiple autograd Nodes is deprecated and will be removed in future versions. This hook will be missing some grad_input. Please use register_full_backward_hook to get the documented behavior.
#   warnings.warn("Using a non-full backward hook when the forward contains multiple autograd Nodes "
# --- loading from data_tcab\detection-experiments\allocine\distilcamembert\clean_vs_all\train.joblib
# num of instances in the file:  10716
# loaded, labels:  Counter({'perturbed': 5358, 'clean': 5358})
# --- loading from data_tcab\detection-experiments\allocine\distilcamembert\clean_vs_all\val.joblib
# num of instances in the file:  3556
# loaded, labels:  Counter({'perturbed': 1778, 'clean': 1778})
# --- loading from data_tcab\detection-experiments\allocine\distilcamembert\clean_vs_all\test_release.joblib
# num of instances in the file:  2891
# loaded, labels:  Counter({'clean': 2009, 'perturbed': 882})
# --- training main starting
# skip if done: False
#
# no. train: 10,716
# no. val: 3,556
# no. test: 2,891
# no. features: 4,539
#
# --- starting training
# --- finished training
# --- training time: 00:00:10
# {'train_accuracy': 0.9997200447928332, 'train_balanced_accuracy': 0.9997202014549524, 'train_confusion_matrix': [[5355, 3], [0, 5358]], 'train_roc_auc': 0.9997200447928332}
# {'validation_accuracy': 0.9637232845894264, 'validation_balanced_accuracy': 0.9638008956720784, 'validation_confusion_matrix': [[1702, 76], [53, 1725]], 'validation_roc_auc': 0.9637232845894264}
# {'test_accuracy': 0.9602213766862677, 'test_balanced_accuracy': 0.9462296829203305, 'test_confusion_matrix': [[1920, 89], [26, 856]], 'test_roc_auc': 0.9631104474310049}
# --- saving metrics to data_tcab\detection-experiments\allocine\distilcamembert\clean_vs_all\LGB\all
#
# ### Running main with ['--experiment_dir', 'data_tcab/detection-experiments/allocine/distilcamembert/multiclass_with_clean', '--feature_setting', 'bert', '--model', 'LR', '--model_n_jobs', '10', '--disable_tune']
#
# starting experiment: data_tcab\detection-experiments\allocine\distilcamembert\multiclass_with_clean
# CPU available : 16
# --- searching exp data in data_tcab\detection-experiments\allocine\distilcamembert\multiclass_with_clean
# --- using these features:
# ['tp_bert']
# --- output to data_tcab\detection-experiments\allocine\distilcamembert\multiclass_with_clean\LR\bert
# --- loading from data_tcab\detection-experiments\allocine\distilcamembert\multiclass_with_clean\train.joblib
# num of instances in the file:  6545
# loaded, labels:  Counter({'clean': 1187, 'input_reduction': 1187, 'textbugger': 1004, 'textfooler': 987, 'deepwordbug': 976, 'bae': 751, 'pwws': 453})
# --- loading from data_tcab\detection-experiments\allocine\distilcamembert\multiclass_with_clean\val.joblib
# num of instances in the file:  2189
# loaded, labels:  Counter({'clean': 411, 'input_reduction': 411, 'textfooler': 336, 'deepwordbug': 334, 'textbugger': 328, 'bae': 228, 'pwws': 141})
# --- loading from data_tcab\detection-experiments\allocine\distilcamembert\multiclass_with_clean\test_release.joblib
# num of instances in the file:  2891
# loaded, labels:  Counter({'clean': 2009, 'input_reduction': 204, 'textbugger': 165, 'deepwordbug': 163, 'textfooler': 162, 'bae': 116, 'pwws': 72})
# --- training main starting
# skip if done: False
#
# no. train: 6,545
# no. val: 2,189
# no. test: 2,891
# no. features: 768
#
# --- starting training
# --- finished training
# --- training time: 00:00:01
# {'train_accuracy': 0.7045072574484339, 'train_balanced_accuracy': 0.6948475590504165, 'train_confusion_matrix': [[476, 128, 35, 3, 39, 30, 40], [256, 596, 84, 17, 71, 45, 118], [73, 80, 697, 7, 29, 56, 34], [9, 9, 3, 1152, 4, 5, 5], [19, 16, 7, 1, 389, 5, 16], [71, 65, 81, 4, 35, 683, 65], [104, 109, 52, 5, 57, 42, 618]]}
# {'validation_accuracy': 0.5216994061215167, 'validation_balanced_accuracy': 0.4901331150451465, 'validation_confusion_matrix': [[72, 53, 22, 14, 18, 22, 27], [62, 141, 49, 35, 33, 29, 62], [24, 32, 186, 13, 17, 26, 36], [8, 12, 15, 353, 7, 8, 8], [19, 19, 5, 7, 59, 12, 20], [30, 43, 30, 5, 17, 166, 37], [27, 51, 32, 13, 27, 21, 165]]}
# {'test_accuracy': 0.4060878588723625, 'test_balanced_accuracy': 0.3326402853584608, 'test_confusion_matrix': [[32, 22, 13, 7, 16, 9, 17], [358, 697, 259, 117, 167, 137, 274], [11, 14, 84, 9, 13, 16, 16], [10, 5, 7, 169, 6, 2, 5], [3, 5, 6, 2, 36, 6, 14], [10, 18, 26, 3, 10, 80, 18], [12, 19, 17, 9, 18, 11, 76]]}
# --- saving metrics to data_tcab\detection-experiments\allocine\distilcamembert\multiclass_with_clean\
# --- loading from data_tcab\detection-experiments\allocine\distilcamembert\multiclass_with_clean\val.joblib
# num of instances in the file:  2189
# loaded, labels:  Counter({'clean': 411, 'input_reduction': 411, 'textfooler': 336, 'deepwordbug': 334, 'textbugger': 328, 'bae': 228, 'pwws': 141})
# --- loading from data_tcab\detection-experiments\allocine\distilcamembert\multiclass_with_clean\test_release.joblib
# num of instances in the file:  2891
# loaded, labels:  Counter({'clean': 2009, 'input_reduction': 204, 'textbugger': 165, 'deepwordbug': 163, 'textfooler': 162, 'bae': 116, 'pwws': 72})
# --- training main starting
# skip if done: False
#
# no. train: 6,545
# no. val: 2,189
# no. test: 2,891
# no. features: 848
#
# --- starting training
# --- finished training
# --- training time: 00:00:01
# {'train_accuracy': 0.5457601222307105, 'train_balanced_accuracy': 0.5385449697901356, 'train_confusion_matrix': [[247, 298, 18, 92, 28, 42, 26], [74, 869, 12, 101, 37, 53, 41], [38, 128, 536, 106, 67, 65, 36], [12, 5, 12, 1136, 16, 1, 5], [16, 62, 9, 31, 312, 13, 10], [60, 251, 75, 137, 128, 295, 58], [55, 274, 72, 150, 163, 96, 177]]}
# {'validation_accuracy': 0.511192325262677, 'validation_balanced_accuracy': 0.4886142642866628, 'validation_confusion_matrix': [[45, 109, 3, 43, 14, 12, 2], [20, 304, 4, 49, 9, 20, 5], [10, 47, 186, 55, 20, 11, 5], [2, 0, 5, 400, 1, 2, 1], [9, 24, 2, 20, 73, 8, 5], [20, 101, 21, 49, 36, 75, 26], [12, 107, 27, 55, 69, 30, 36]]}
# {'test_accuracy': 0.6271186440677966, 'test_balanced_accuracy': 0.3674937882210108, 'test_confusion_matrix': [[27, 44, 5, 19, 8, 7, 6], [124, 1425, 28, 237, 57, 97, 41], [7, 25, 75, 21, 11, 16, 8], [3, 1, 5, 191, 2, 1, 1], [3, 12, 8, 7, 36, 4, 2], [11, 37, 13, 32, 25, 39, 8], [8, 43, 12, 28, 38, 13, 20]]}
# --- saving metrics to data_tcab\detection-experiments\allocine\distilcamembert\multiclass_with_clean\RF\bert+tp+lm
#
# ### Running main with ['--experiment_dir', 'data_tcab/detection-experiments/allocine/distilcamembert/multiclass_with_clean', '--feature_setting', 'bert+tp+lm', '--model', 'LGB', '--model_n_jobs', '10', '--disable_tune']
#
# starting experiment: data_tcab\detection-experiments\allocine\distilcamembert\multiclass_with_clean
# CPU available : 16
# --- searching exp data in data_tcab\detection-experiments\allocine\distilcamembert\multiclass_with_clean
# --- using these features:
# ['lm_perplexity', 'lm_proba_and_rank', 'tp_avg_word_length', 'tp_bert', 'tp_is_first_word_lowercase', 'tp_num_alpha_chars', 'tp_num_cased_letters', 'tp_num_cased_word_switches', 'tp_num_chars', 'tp_num_digits', 'tp_num_lowercase_after_punctuation', 'tp_num_mixed_case_words', 'tp_num_multi_spaces', 'tp_num_non_ascii', 'tp_num_punctuation', 'tp_num_single_lowercase_letters', 'tp_num_words']
# --- output to data_tcab\detection-experiments\allocine\distilcamembert\multiclass_with_clean\LGB\bert+tp+lm
# --- loading from data_tcab\detection-experiments\allocine\distilcamembert\multiclass_with_clean\train.joblib
# num of instances in the file:  6545
# loaded, labels:  Counter({'clean': 1187, 'input_reduction': 1187, 'textbugger': 1004, 'textfooler': 987, 'deepwordbug': 976, 'bae': 751, 'pwws': 453})
# --- loading from data_tcab\detection-experiments\allocine\distilcamembert\multiclass_with_clean\val.joblib
# num of instances in the file:  2189
# loaded, labels:  Counter({'clean': 411, 'input_reduction': 411, 'textfooler': 336, 'deepwordbug': 334, 'textbugger': 328, 'bae': 228, 'pwws': 141})
# --- loading from data_tcab\detection-experiments\allocine\distilcamembert\multiclass_with_clean\test_release.joblib
# num of instances in the file:  2891
# loaded, labels:  Counter({'clean': 2009, 'input_reduction': 204, 'textbugger': 165, 'deepwordbug': 163, 'textfooler': 162, 'bae': 116, 'pwws': 72})
# --- training main starting
# skip if done: False
#
# no. train: 6,545
# no. val: 2,189
# no. test: 2,891
# no. features: 848
#
# --- starting training
# --- finished training
# --- training time: 00:00:06
# {'train_accuracy': 0.9844155844155844, 'train_balanced_accuracy': 0.9828647501349225, 'train_confusion_matrix': [[746, 4, 0, 0, 1, 0, 0], [6, 1174, 0, 2, 4, 0, 1], [2, 6, 951, 0, 5, 10, 2], [0, 1, 0, 1186, 0, 0, 0], [0, 0, 0, 0, 453, 0, 0], [2, 8, 1, 0, 2, 975, 16], [9, 12, 0, 0, 3, 5, 958]]}
# {'validation_accuracy': 0.6176336226587483, 'validation_balanced_accuracy': 0.6054962515737211, 'validation_confusion_matrix': [[84, 76, 7, 23, 3, 18, 17], [48, 275, 11, 17, 4, 21, 35], [14, 30, 224, 17, 3, 25, 21], [4, 2, 5, 389, 1, 6, 4], [13, 20, 7, 7, 67, 11, 16], [24, 59, 19, 8, 10, 165, 43], [19, 78, 23, 12, 16, 40, 148]]}
# {'test_accuracy': 0.6323071601521965, 'test_balanced_accuracy': 0.44624215566670716, 'test_confusion_matrix': [[40, 44, 9, 8, 1, 5, 9], [243, 1301, 78, 81, 34, 112, 160], [9, 20, 104, 5, 0, 12, 13], [3, 2, 1, 196, 0, 2, 0], [7, 8, 7, 4, 30, 5, 11], [14, 22, 13, 10, 3, 81, 22], [13, 30, 15, 5, 10, 13, 76]]}
# --- saving metrics to data_tcab\detection-experiments\allocine\distilcamembert\multiclass_with_clean\LGB\bert+tp+lm
#
# ### Running main with ['--experiment_dir', 'data_tcab/detection-experiments/allocine/distilcamembert/multiclass_with_clean', '--feature_setting', 'all', '--model', 'LR', '--model_n_jobs', '10', '--disable_tune']
#
# starting experiment: data_tcab\detection-experiments\allocine\distilcamembert\multiclass_with_clean
# CPU available : 16
# --- searching exp data in data_tcab\detection-experiments\allocine\distilcamembert\multiclass_with_clean
# --- using these features:
# ['lm_perplexity', 'lm_proba_and_rank', 'tm_activation', 'tm_gradient', 'tm_posterior', 'tm_saliency', 'tp_avg_word_length', 'tp_bert', 'tp_is_first_word_lowercase', 'tp_num_alpha_chars', 'tp_num_cased_letters', 'tp_num_cased_word_switches', 'tp_num_chars', 'tp_num_digits', 'tp_num_lowercase_after_punctuation', 'tp_num_mixed_case_words', 'tp_num_multi_spaces', 'tp_num_non_ascii', 'tp_num_punctuation', 'tp_num_single_lowercase_letters', 'tp_num_words']
# --- output to data_tcab\detection-experiments\allocine\distilcamembert\multiclass_with_clean\LR\all
# c:\Users\Baptiste\AppData\Local\pypoetry\Cache\virtualenvs\nlp-adversarial-attacks-ghBt6cj_-py3.10\lib\site-packages\torch\nn\modules\module.py:1117: UserWarning: Using a non-full backward hook when the forward contains multiple autograd Nodes is deprecated and will be removed in future versions. This hook will be missing some grad_input. Please use register_full_backward_hook to get the documented behavior.
#   warnings.warn("Using a non-full backward hook when the forward contains multiple autograd Nodes "
# --- loading from data_tcab\detection-experiments\allocine\distilcamembert\multiclass_with_clean\train.joblib
# num of instances in the file:  6545
# loaded, labels:  Counter({'clean': 1187, 'input_reduction': 1187, 'textbugger': 1004, 'textfooler': 987, 'deepwordbug': 976, 'bae': 751, 'pwws': 453})
# --- loading from data_tcab\detection-experiments\allocine\distilcamembert\multiclass_with_clean\val.joblib
# num of instances in the file:  2189
# loaded, labels:  Counter({'clean': 411, 'input_reduction': 411, 'textfooler': 336, 'deepwordbug': 334, 'textbugger': 328, 'bae': 228, 'pwws': 141})
# --- loading from data_tcab\detection-experiments\allocine\distilcamembert\multiclass_with_clean\test_release.joblib
# num of instances in the file:  2891
# loaded, labels:  Counter({'clean': 2009, 'input_reduction': 204, 'textbugger': 165, 'deepwordbug': 163, 'textfooler': 162, 'bae': 116, 'pwws': 72})
# --- training main starting
# skip if done: False
#
# no. train: 6,545
# no. val: 2,189
# no. test: 2,891
# no. features: 4,539
#
# --- starting training
# --- finished training
# --- training time: 00:00:08
# {'train_accuracy': 0.9938884644766998, 'train_balanced_accuracy': 0.9939556131811501, 'train_confusion_matrix': [[750, 0, 0, 0, 0, 0, 1], [0, 1186, 0, 1, 0, 0, 0], [0, 0, 973, 0, 0, 3, 0], [0, 2, 0, 1185, 0, 0, 0], [0, 0, 0, 0, 453, 0, 0], [1, 0, 3, 0, 0, 984, 16], [3, 0, 0, 0, 1, 9, 974]]}
# {'validation_accuracy': 0.7336683417085427, 'validation_balanced_accuracy': 0.6964462459464899, 'validation_confusion_matrix': [[121, 6, 16, 13, 11, 25, 36], [9, 368, 10, 4, 6, 5, 9], [12, 4, 242, 4, 9, 44, 19], [4, 4, 0, 401, 0, 1, 1], [11, 2, 12, 0, 80, 12, 24], [25, 3, 35, 4, 10, 205, 46], [38, 5, 30, 5, 28, 41, 189]]}
# {'test_accuracy': 0.8235904531304047, 'test_balanced_accuracy': 0.5942311306007058, 'test_confusion_matrix': [[57, 3, 8, 4, 5, 14, 25], [83, 1776, 33, 24, 28, 29, 36], [14, 3, 111, 2, 8, 13, 12], [4, 0, 0, 199, 1, 0, 0], [5, 1, 5, 1, 40, 6, 14], [16, 1, 11, 2, 14, 104, 17], [23, 3, 9, 3, 16, 14, 94]]}
# --- saving metrics to data_tcab\detection-experiments\allocine\distilcamembert\multiclass_with_clean\LR\all
#
# ### Running main with ['--experiment_dir', 'data_tcab/detection-experiments/allocine/distilcamembert/multiclass_with_clean', '--feature_setting', 'all', '--model', 'RF', '--model_n_jobs', '10', '--disable_tune']
#
# starting experiment: data_tcab\detection-experiments\allocine\distilcamembert\multiclass_with_clean
# CPU available : 16
# --- searching exp data in data_tcab\detection-experiments\allocine\distilcamembert\multiclass_with_clean
# --- using these features:
# ['lm_perplexity', 'lm_proba_and_rank', 'tm_activation', 'tm_gradient', 'tm_posterior', 'tm_saliency', 'tp_avg_word_length', 'tp_bert', 'tp_is_first_word_lowercase', 'tp_num_alpha_chars', 'tp_num_cased_letters', 'tp_num_cased_word_switches', 'tp_num_chars', 'tp_num_digits', 'tp_num_lowercase_after_punctuation', 'tp_num_mixed_case_words', 'tp_num_multi_spaces', 'tp_num_non_ascii', 'tp_num_punctuation', 'tp_num_single_lowercase_letters', 'tp_num_words']
# --- output to data_tcab\detection-experiments\allocine\distilcamembert\multiclass_with_clean\RF\all
# c:\Users\Baptiste\AppData\Local\pypoetry\Cache\virtualenvs\nlp-adversarial-attacks-ghBt6cj_-py3.10\lib\site-packages\torch\nn\modules\module.py:1117: UserWarning: Using a non-full backward hook when the forward contains multiple autograd Nodes is deprecated and will be removed in future versions. This hook will be missing some grad_input. Please use register_full_backward_hook to get the documented behavior.
#   warnings.warn("Using a non-full backward hook when the forward contains multiple autograd Nodes "
# --- loading from data_tcab\detection-experiments\allocine\distilcamembert\multiclass_with_clean\train.joblib
# num of instances in the file:  6545
# loaded, labels:  Counter({'clean': 1187, 'input_reduction': 1187, 'textbugger': 1004, 'textfooler': 987, 'deepwordbug': 976, 'bae': 751, 'pwws': 453})
# --- loading from data_tcab\detection-experiments\allocine\distilcamembert\multiclass_with_clean\val.joblib
# num of instances in the file:  2189
# loaded, labels:  Counter({'clean': 411, 'input_reduction': 411, 'textfooler': 336, 'deepwordbug': 334, 'textbugger': 328, 'bae': 228, 'pwws': 141})
# --- loading from data_tcab\detection-experiments\allocine\distilcamembert\multiclass_with_clean\test_release.joblib
# num of instances in the file:  2891
# loaded, labels:  Counter({'clean': 2009, 'input_reduction': 204, 'textbugger': 165, 'deepwordbug': 163, 'textfooler': 162, 'bae': 116, 'pwws': 72})
# --- training main starting
# skip if done: False
#
# no. train: 6,545
# no. val: 2,189
# no. test: 2,891
# no. features: 4,539
#
# --- starting training
# --- finished training
# --- training time: 00:00:02
# {'train_accuracy': 0.6360580595874713, 'train_balanced_accuracy': 0.6416511334251377, 'train_confusion_matrix': [[575, 15, 14, 45, 52, 35, 15], [50, 1098, 6, 27, 3, 2, 1], [187, 37, 515, 29, 121, 73, 14], [11, 5, 5, 1164, 0, 1, 1], [97, 7, 20, 8, 312, 4, 5], [295, 25, 170, 25, 147, 314, 28], [331, 22, 105, 33, 231, 80, 185]]}
# {'validation_accuracy': 0.6094106898126999, 'validation_balanced_accuracy': 0.5945863629366673, 'validation_confusion_matrix': [[155, 13, 1, 23, 16, 15, 5], [12, 381, 3, 14, 1, 0, 0], [53, 13, 173, 22, 43, 27, 3], [1, 4, 2, 399, 1, 0, 4], [38, 4, 6, 1, 85, 4, 3], [92, 8, 55, 11, 58, 95, 9], [104, 5, 45, 14, 92, 30, 46]]}
# {'test_accuracy': 0.7959183673469388, 'test_balanced_accuracy': 0.5396508544245852, 'test_confusion_matrix': [[68, 5, 9, 7, 11, 11, 5], [74, 1852, 8, 64, 8, 3, 0], [32, 9, 75, 12, 17, 14, 4], [1, 3, 1, 199, 0, 0, 0], [15, 2, 8, 1, 42, 2, 2], [45, 6, 33, 5, 31, 42, 3], [52, 3, 24, 6, 43, 11, 23]]}
# --- saving metrics to data_tcab\detection-experiments\allocine\distilcamembert\multiclass_with_clean\RF\all
#
# ### Running main with ['--experiment_dir', 'data_tcab/detection-experiments/allocine/distilcamembert/multiclass_with_clean', '--feature_setting', 'all', '--model', 'LGB', '--model_n_jobs', '10', '--disable_tune']
#
# starting experiment: data_tcab\detection-experiments\allocine\distilcamembert\multiclass_with_clean
# CPU available : 16
# --- searching exp data in data_tcab\detection-experiments\allocine\distilcamembert\multiclass_with_clean
# --- using these features:
# ['lm_perplexity', 'lm_proba_and_rank', 'tm_activation', 'tm_gradient', 'tm_posterior', 'tm_saliency', 'tp_avg_word_length', 'tp_bert', 'tp_is_first_word_lowercase', 'tp_num_alpha_chars', 'tp_num_cased_letters', 'tp_num_cased_word_switches', 'tp_num_chars', 'tp_num_digits', 'tp_num_lowercase_after_punctuation', 'tp_num_mixed_case_words', 'tp_num_multi_spaces', 'tp_num_non_ascii', 'tp_num_punctuation', 'tp_num_single_lowercase_letters', 'tp_num_words']
# --- output to data_tcab\detection-experiments\allocine\distilcamembert\multiclass_with_clean\LGB\all
# c:\Users\Baptiste\AppData\Local\pypoetry\Cache\virtualenvs\nlp-adversarial-attacks-ghBt6cj_-py3.10\lib\site-packages\torch\nn\modules\module.py:1117: UserWarning: Using a non-full backward hook when the forward contains multiple autograd Nodes is deprecated and will be removed in future versions. This hook will be missing some grad_input. Please use register_full_backward_hook to get the documented behavior.
#   warnings.warn("Using a non-full backward hook when the forward contains multiple autograd Nodes "
# --- loading from data_tcab\detection-experiments\allocine\distilcamembert\multiclass_with_clean\train.joblib
# num of instances in the file:  6545
# loaded, labels:  Counter({'clean': 1187, 'input_reduction': 1187, 'textbugger': 1004, 'textfooler': 987, 'deepwordbug': 976, 'bae': 751, 'pwws': 453})
# --- loading from data_tcab\detection-experiments\allocine\distilcamembert\multiclass_with_clean\val.joblib
# num of instances in the file:  2189
# loaded, labels:  Counter({'clean': 411, 'input_reduction': 411, 'textfooler': 336, 'deepwordbug': 334, 'textbugger': 328, 'bae': 228, 'pwws': 141})
# --- loading from data_tcab\detection-experiments\allocine\distilcamembert\multiclass_with_clean\test_release.joblib
# num of instances in the file:  2891
# loaded, labels:  Counter({'clean': 2009, 'input_reduction': 204, 'textbugger': 165, 'deepwordbug': 163, 'textfooler': 162, 'bae': 116, 'pwws': 72})
# --- training main starting
# skip if done: False
#
# no. train: 6,545
# no. val: 2,189
# no. test: 2,891
# no. features: 4,539
#
# --- starting training
# --- finished training
# --- training time: 00:00:42
# {'train_accuracy': 0.9951107715813599, 'train_balanced_accuracy': 0.995275676471011, 'train_confusion_matrix': [[751, 0, 0, 0, 0, 0, 0], [0, 1185, 0, 2, 0, 0, 0], [0, 0, 975, 0, 0, 1, 0], [0, 1, 0, 1186, 0, 0, 0], [0, 0, 0, 0, 453, 0, 0], [1, 0, 3, 0, 0, 988, 12], [3, 0, 0, 0, 0, 9, 975]]}
# {'validation_accuracy': 0.7501142074006396, 'validation_balanced_accuracy': 0.723345165353155, 'validation_confusion_matrix': [[144, 8, 7, 10, 3, 26, 30], [12, 385, 2, 4, 0, 4, 4], [18, 4, 246, 4, 2, 35, 25], [2, 1, 2, 404, 0, 1, 1], [14, 2, 10, 0, 68, 17, 30], [38, 6, 21, 4, 9, 200, 50], [49, 4, 18, 5, 19, 46, 195]]}
# {'test_accuracy': 0.8595641646489104, 'test_balanced_accuracy': 0.6715860200343207, 'test_confusion_matrix': [[69, 6, 5, 4, 1, 15, 16], [79, 1857, 17, 19, 6, 16, 15], [9, 4, 117, 2, 0, 19, 12], [2, 1, 0, 201, 0, 0, 0], [8, 2, 8, 1, 31, 8, 14], [17, 1, 12, 2, 3, 96, 34], [19, 2, 6, 2, 6, 13, 114]]}
# --- saving metrics to data_tcab\detection-experiments\allocine\distilcamembert\multiclass_with_clean\LGB\all

# %%
print(f"Total time: {time.strftime('%H:%M:%S', time.gmtime(time.time()-t))}")
# Out:
# Total time: 00:08:14
