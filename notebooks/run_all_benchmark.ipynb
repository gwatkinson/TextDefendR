# %% [markdown]
# # Run all TCAB benchmark

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import time
from functools import reduce
from itertools import product

from tqdm.auto import tqdm

from scripts import (
    distribute_experiments,
    make_experiment,
    make_official_dataset_splits,
    run_experiment,
)

# from scripts import encode_main

t = time.time()

# %%
def process_args(args_grid):
    liste1 = [dict(zip(args_grid.keys(), v)) for v in product(*args_grid.values())]
    liste2 = [list(reduce(lambda x, y: x + y, dico.items())) for dico in liste1]
    liste3 = [list(filter(None, liste)) for liste in liste2]

    print(f"Number of parameters combinations: {len(liste3)}")
    for elem in liste3:
        print(elem)

    return liste3

# %%
def call_main_args(main, processed_args_grid):
    for args in tqdm(processed_args_grid):
        print(f"\n### Running main with {args}\n")
        main(args)

# %% [markdown]
# ## 1. scripts/encode_main.py

# %%
# encode_main.main()

# %% [markdown]
# ## 2. scripts/make_official_dataset_splits.py

# %%
make_official_dataset_splits.main()
# Out:
# --- reading data
# --- dropping unsupported datasets
# --- dropping duplicates
# --- making splits across all datasets ---
# allocine
# --- filtering for dataset  (28913, 17)
#   0%|          | 0/20000 [00:00<?, ?it/s]
#   0%|          | 0/8010 [00:00<?, ?it/s]
# --- Train DF stats ---
# total_instances: 17348,
# attack_name: {'input_reduction': 1187, 'clean': 11990, 'deepwordbug': 976, 'bae': 751, 'textfooler': 987, 'textbugger': 1004, 'pwws': 453},
# target_dataset: {'allocine': 17348},
# target_model: {'distilcamembert': 17348},
# status: {'success': 5358, 'clean': 11990},
# attack_toolchain: {'textattack': 5358, 'none': 11990},
# scenario: {'sentiment': 17348},
#
# --- Test DF stats ---
# total_instances: 5783,
# attack_name: {'input_reduction': 402, 'clean': 4006, 'deepwordbug': 326, 'textfooler': 333, 'pwws': 147, 'bae': 238, 'textbugger': 331},
# target_dataset: {'allocine': 5783},
# target_model: {'distilcamembert': 5783},
# status: {'success': 1777, 'clean': 4006},
# attack_toolchain: {'textattack': 1777, 'none': 4006},
# scenario: {'sentiment': 5783},
#
# --- Val DF stats ---
# total_instances: 5782,
# attack_name: {'clean': 4004, 'deepwordbug': 334, 'textfooler': 336, 'bae': 228, 'input_reduction': 411, 'textbugger': 328, 'pwws': 141},
# target_dataset: {'allocine': 5782},
# target_model: {'distilcamembert': 5782},
# status: {'clean': 4004, 'success': 1778},
# attack_toolchain: {'none': 4004, 'textattack': 1778},
# scenario: {'sentiment': 5782},
#
# --- filtering for target model
# --- Train DF stats ---
# total_instances: 17348,
# attack_name: {'input_reduction': 1187, 'clean': 11990, 'deepwordbug': 976, 'bae': 751, 'textfooler': 987, 'textbugger': 1004, 'pwws': 453},
# target_dataset: {'allocine': 17348},
# target_model: {'distilcamembert': 17348},
# status: {'success': 5358, 'clean': 11990},
# attack_toolchain: {'textattack': 5358, 'none': 11990},
# scenario: {'sentiment': 17348},
#
# --- Test DF stats ---
# total_instances: 5783,
# attack_name: {'input_reduction': 402, 'clean': 4006, 'deepwordbug': 326, 'textfooler': 333, 'pwws': 147, 'bae': 238, 'textbugger': 331},
# target_dataset: {'allocine': 5783},
# target_model: {'distilcamembert': 5783},
# status: {'success': 1777, 'clean': 4006},
# attack_toolchain: {'textattack': 1777, 'none': 4006},
# scenario: {'sentiment': 5783},
#
# --- Val DF stats ---
# total_instances: 5782,
# attack_name: {'clean': 4004, 'deepwordbug': 334, 'textfooler': 336, 'bae': 228, 'input_reduction': 411, 'textbugger': 328, 'pwws': 141},
# target_dataset: {'allocine': 5782},
# target_model: {'distilcamembert': 5782},
# status: {'clean': 4004, 'success': 1778},
# attack_toolchain: {'none': 4004, 'textattack': 1778},
# scenario: {'sentiment': 5782},
#
# --- allocine distilcamembert --- DONE.
# --- allocine --- DONE.
# --- combining splits across all datasets ---
# --- DONE.

# %% [markdown]
# ## 3. scripts/distribute_experiments.py

# %%
args_grid = {
    "--embeddings_name": ["default", "fr+small"],
    "--experiment_setting": ["clean_vs_all", "multiclass_with_clean"],
}
args_grid = process_args(args_grid)
# Out:
# Number of parameters combinations: 4
# ['--embeddings_name', 'default', '--experiment_setting', 'clean_vs_all']
# ['--embeddings_name', 'default', '--experiment_setting', 'multiclass_with_clean']
# ['--embeddings_name', 'fr+small', '--experiment_setting', 'clean_vs_all']
# ['--embeddings_name', 'fr+small', '--experiment_setting', 'multiclass_with_clean']

# %%
call_main_args(distribute_experiments.main, args_grid)
# Out:
#   0%|          | 0/4 [00:00<?, ?it/s]
# ### Running main with ['--embeddings_name', 'default', '--experiment_setting', 'clean_vs_all']
#
# Reading train.csv from  data_tcab\official_TCAB_splits\splits_by_dataset_and_tm\allocine\distilcamembert\train.csv
# Reading val.csv from  data_tcab\official_TCAB_splits\splits_by_dataset_and_tm\allocine\distilcamembert\val.csv
# Reading test.csv from  data_tcab\official_TCAB_splits\splits_by_dataset_and_tm\allocine\distilcamembert\test.csv
# Dropping attacks by count, if less than < 10
#   0%|          | 0/4006 [00:00<?, ?it/s]
#  *** clean_vs_all saving to data_tcab\detection-experiments\allocine\distilcamembert\default\clean_vs_all
#
# ### Running main with ['--embeddings_name', 'default', '--experiment_setting', 'multiclass_with_clean']
#
# Reading train.csv from  data_tcab\official_TCAB_splits\splits_by_dataset_and_tm\allocine\distilcamembert\train.csv
# Reading val.csv from  data_tcab\official_TCAB_splits\splits_by_dataset_and_tm\allocine\distilcamembert\val.csv
# Reading test.csv from  data_tcab\official_TCAB_splits\splits_by_dataset_and_tm\allocine\distilcamembert\test.csv
# Dropping attacks by count, if less than < 10
#   0%|          | 0/4006 [00:00<?, ?it/s]
#  *** multiclass_with_clean saving to data_tcab\detection-experiments\allocine\distilcamembert\default\multiclass_with_clean
#
# ### Running main with ['--embeddings_name', 'fr+small', '--experiment_setting', 'clean_vs_all']
#
# Reading train.csv from  data_tcab\official_TCAB_splits\splits_by_dataset_and_tm\allocine\distilcamembert\train.csv
# Reading val.csv from  data_tcab\official_TCAB_splits\splits_by_dataset_and_tm\allocine\distilcamembert\val.csv
# Reading test.csv from  data_tcab\official_TCAB_splits\splits_by_dataset_and_tm\allocine\distilcamembert\test.csv
# Dropping attacks by count, if less than < 10
#   0%|          | 0/4006 [00:00<?, ?it/s]
#  *** clean_vs_all saving to data_tcab\detection-experiments\allocine\distilcamembert\fr+small\clean_vs_all
#
# ### Running main with ['--embeddings_name', 'fr+small', '--experiment_setting', 'multiclass_with_clean']
#
# Reading train.csv from  data_tcab\official_TCAB_splits\splits_by_dataset_and_tm\allocine\distilcamembert\train.csv
# Reading val.csv from  data_tcab\official_TCAB_splits\splits_by_dataset_and_tm\allocine\distilcamembert\val.csv
# Reading test.csv from  data_tcab\official_TCAB_splits\splits_by_dataset_and_tm\allocine\distilcamembert\test.csv
# Dropping attacks by count, if less than < 10
#   0%|          | 0/4006 [00:00<?, ?it/s]
#  *** multiclass_with_clean saving to data_tcab\detection-experiments\allocine\distilcamembert\fr+small\multiclass_with_clean

# %% [markdown]
# ## 4. scripts/make_experiments.py

# %%
embeddings_list = ["default", "fr+small"]
experiment_list = ["clean_vs_all", "multiclass_with_clean"]
experiment_dir_list = [
    f"data_tcab/detection-experiments/allocine/distilcamembert/{emb}/{exp}"
    for emb, exp in product(embeddings_list, experiment_list)
]
args_grid = {"--experiment_dir": experiment_dir_list}
args_grid = process_args(args_grid)
# Out:
# Number of parameters combinations: 4
# ['--experiment_dir', 'data_tcab/detection-experiments/allocine/distilcamembert/default/clean_vs_all']
# ['--experiment_dir', 'data_tcab/detection-experiments/allocine/distilcamembert/default/multiclass_with_clean']
# ['--experiment_dir', 'data_tcab/detection-experiments/allocine/distilcamembert/fr+small/clean_vs_all']
# ['--experiment_dir', 'data_tcab/detection-experiments/allocine/distilcamembert/fr+small/multiclass_with_clean']

# %%
call_main_args(make_experiment.main, args_grid)
# Out:
#   0%|          | 0/4 [00:00<?, ?it/s]
# ### Running main with ['--experiment_dir', 'data_tcab/detection-experiments/allocine/distilcamembert/default/clean_vs_all']
#
# making exp into...  data_tcab/detection-experiments/allocine/distilcamembert/default/clean_vs_all
#
# --- loading known instances from  data_tcab/embeddings/
# --- target_model: distilcamembert, target_dataset: allocine
# --- No. joblib files of varied size to read: 1
# [0] data_tcab\embeddings\default_distilcamembert_allocine_ALL_ALL.joblib
#
# done, no. unique instances with extracted features: 28,913
#
# --- creating train.joblib
#     cannot find embeddings for 0 / 10,716 instances
#
# --- creating val.joblib
#     cannot find embeddings for 0 / 3,556 instances
#
# --- creating test_release.joblib
#     cannot find embeddings for 0 / 2,891 instances
#
# ### Running main with ['--experiment_dir', 'data_tcab/detection-experiments/allocine/distilcamembert/default/multiclass_with_clean']
#
# making exp into...  data_tcab/detection-experiments/allocine/distilcamembert/default/multiclass_with_clean
#
# --- loading known instances from  data_tcab/embeddings/
# --- target_model: distilcamembert, target_dataset: allocine
# --- No. joblib files of varied size to read: 1
# [0] data_tcab\embeddings\default_distilcamembert_allocine_ALL_ALL.joblib
#
# done, no. unique instances with extracted features: 28,913
#
# --- creating train.joblib
#     cannot find embeddings for 0 / 6,545 instances
#
# --- creating val.joblib
#     cannot find embeddings for 0 / 2,189 instances
#
# --- creating test_release.joblib
#     cannot find embeddings for 0 / 2,891 instances
#
# ### Running main with ['--experiment_dir', 'data_tcab/detection-experiments/allocine/distilcamembert/fr+small/clean_vs_all']
#
# making exp into...  data_tcab/detection-experiments/allocine/distilcamembert/fr+small/clean_vs_all
#
# --- loading known instances from  data_tcab/embeddings/
# --- target_model: distilcamembert, target_dataset: allocine
# --- No. joblib files of varied size to read: 1
# [0] data_tcab\embeddings\fr+small_distilcamembert_allocine_ALL_ALL.joblib
#
# done, no. unique instances with extracted features: 28,913
#
# --- creating train.joblib
#     cannot find embeddings for 0 / 10,716 instances
#
# --- creating val.joblib
#     cannot find embeddings for 0 / 3,556 instances
#
# --- creating test_release.joblib
#     cannot find embeddings for 0 / 2,891 instances
#
# ### Running main with ['--experiment_dir', 'data_tcab/detection-experiments/allocine/distilcamembert/fr+small/multiclass_with_clean']
#
# making exp into...  data_tcab/detection-experiments/allocine/distilcamembert/fr+small/multiclass_with_clean
#
# --- loading known instances from  data_tcab/embeddings/
# --- target_model: distilcamembert, target_dataset: allocine
# --- No. joblib files of varied size to read: 1
# [0] data_tcab\embeddings\fr+small_distilcamembert_allocine_ALL_ALL.joblib
#
# done, no. unique instances with extracted features: 28,913
#
# --- creating train.joblib
#     cannot find embeddings for 0 / 6,545 instances
#
# --- creating val.joblib
#     cannot find embeddings for 0 / 2,189 instances
#
# --- creating test_release.joblib
#     cannot find embeddings for 0 / 2,891 instances

# %% [markdown]
# ## 5. scripts/run_experiment.py

# %%
args_grid = {
    "--experiment_dir": experiment_dir_list,
    "--feature_setting": ["bert", "bert+tp", "bert+tp+lm", "all"],
    "--model": ["LR", "RF", "LGB"],
    "--model_n_jobs": ["10"],
}
args_grid = process_args(args_grid)
# Out:
# Number of parameters combinations: 48
# ['--experiment_dir', 'data_tcab/detection-experiments/allocine/distilcamembert/default/clean_vs_all', '--feature_setting', 'bert', '--model', 'LR', '--model_n_jobs', '10']
# ['--experiment_dir', 'data_tcab/detection-experiments/allocine/distilcamembert/default/clean_vs_all', '--feature_setting', 'bert', '--model', 'RF', '--model_n_jobs', '10']
# ['--experiment_dir', 'data_tcab/detection-experiments/allocine/distilcamembert/default/clean_vs_all', '--feature_setting', 'bert', '--model', 'LGB', '--model_n_jobs', '10']
# ['--experiment_dir', 'data_tcab/detection-experiments/allocine/distilcamembert/default/clean_vs_all', '--feature_setting', 'bert+tp', '--model', 'LR', '--model_n_jobs', '10']
# ['--experiment_dir', 'data_tcab/detection-experiments/allocine/distilcamembert/default/clean_vs_all', '--feature_setting', 'bert+tp', '--model', 'RF', '--model_n_jobs', '10']
# ['--experiment_dir', 'data_tcab/detection-experiments/allocine/distilcamembert/default/clean_vs_all', '--feature_setting', 'bert+tp', '--model', 'LGB', '--model_n_jobs', '10']
# ['--experiment_dir', 'data_tcab/detection-experiments/allocine/distilcamembert/default/clean_vs_all', '--feature_setting', 'bert+tp+lm', '--model', 'LR', '--model_n_jobs', '10']
# ['--experiment_dir', 'data_tcab/detection-experiments/allocine/distilcamembert/default/clean_vs_all', '--feature_setting', 'bert+tp+lm', '--model', 'RF', '--model_n_jobs', '10']
# ['--experiment_dir', 'data_tcab/detection-experiments/allocine/distilcamembert/default/clean_vs_all', '--feature_setting', 'bert+tp+lm', '--model', 'LGB', '--model_n_jobs', '10']
# ['--experiment_dir', 'data_tcab/detection-experiments/allocine/distilcamembert/default/clean_vs_all', '--feature_setting', 'all', '--model', 'LR', '--model_n_jobs', '10']
# ['--experiment_dir', 'data_tcab/detection-experiments/allocine/distilcamembert/default/clean_vs_all', '--feature_setting', 'all', '--model', 'RF', '--model_n_jobs', '10']
# ['--experiment_dir', 'data_tcab/detection-experiments/allocine/distilcamembert/default/clean_vs_all', '--feature_setting', 'all', '--model', 'LGB', '--model_n_jobs', '10']
# ['--experiment_dir', 'data_tcab/detection-experiments/allocine/distilcamembert/default/multiclass_with_clean', '--feature_setting', 'bert', '--model', 'LR', '--model_n_jobs', '10']
# ['--experiment_dir', 'data_tcab/detection-experiments/allocine/distilcamembert/default/multiclass_with_clean', '--feature_setting', 'bert', '--model', 'RF', '--model_n_jobs', '10']
# ['--experiment_dir', 'data_tcab/detection-experiments/allocine/distilcamembert/default/multiclass_with_clean', '--feature_setting', 'bert', '--model', 'LGB', '--model_n_jobs', '10']
# ['--experiment_dir', 'data_tcab/detection-experiments/allocine/distilcamembert/default/multiclass_with_clean', '--feature_setting', 'bert+tp', '--model', 'LR', '--model_n_jobs', '10']
# ['--experiment_dir', 'data_tcab/detection-experiments/allocine/distilcamembert/default/multiclass_with_clean', '--feature_setting', 'bert+tp', '--model', 'RF', '--model_n_jobs', '10']
# ['--experiment_dir', 'data_tcab/detection-experiments/allocine/distilcamembert/default/multiclass_with_clean', '--feature_setting', 'bert+tp', '--model', 'LGB', '--model_n_jobs', '10']
# ['--experiment_dir', 'data_tcab/detection-experiments/allocine/distilcamembert/default/multiclass_with_clean', '--feature_setting', 'bert+tp+lm', '--model', 'LR', '--model_n_jobs', '10']
# ['--experiment_dir', 'data_tcab/detection-experiments/allocine/distilcamembert/default/multiclass_with_clean', '--feature_setting', 'bert+tp+lm', '--model', 'RF', '--model_n_jobs', '10']
# ['--experiment_dir', 'data_tcab/detection-experiments/allocine/distilcamembert/default/multiclass_with_clean', '--feature_setting', 'bert+tp+lm', '--model', 'LGB', '--model_n_jobs', '10']
# ['--experiment_dir', 'data_tcab/detection-experiments/allocine/distilcamembert/default/multiclass_with_clean', '--feature_setting', 'all', '--model', 'LR', '--model_n_jobs', '10']
# ['--experiment_dir', 'data_tcab/detection-experiments/allocine/distilcamembert/default/multiclass_with_clean', '--feature_setting', 'all', '--model', 'RF', '--model_n_jobs', '10']
# ['--experiment_dir', 'data_tcab/detection-experiments/allocine/distilcamembert/default/multiclass_with_clean', '--feature_setting', 'all', '--model', 'LGB', '--model_n_jobs', '10']
# ['--experiment_dir', 'data_tcab/detection-experiments/allocine/distilcamembert/fr+small/clean_vs_all', '--feature_setting', 'bert', '--model', 'LR', '--model_n_jobs', '10']
# ['--experiment_dir', 'data_tcab/detection-experiments/allocine/distilcamembert/fr+small/clean_vs_all', '--feature_setting', 'bert', '--model', 'RF', '--model_n_jobs', '10']
# ['--experiment_dir', 'data_tcab/detection-experiments/allocine/distilcamembert/fr+small/clean_vs_all', '--feature_setting', 'bert', '--model', 'LGB', '--model_n_jobs', '10']
# ['--experiment_dir', 'data_tcab/detection-experiments/allocine/distilcamembert/fr+small/clean_vs_all', '--feature_setting', 'bert+tp', '--model', 'LR', '--model_n_jobs', '10']
# ['--experiment_dir', 'data_tcab/detection-experiments/allocine/distilcamembert/fr+small/clean_vs_all', '--feature_setting', 'bert+tp', '--model', 'RF', '--model_n_jobs', '10']
# ['--experiment_dir', 'data_tcab/detection-experiments/allocine/distilcamembert/fr+small/clean_vs_all', '--feature_setting', 'bert+tp', '--model', 'LGB', '--model_n_jobs', '10']
# ['--experiment_dir', 'data_tcab/detection-experiments/allocine/distilcamembert/fr+small/clean_vs_all', '--feature_setting', 'bert+tp+lm', '--model', 'LR', '--model_n_jobs', '10']
# ['--experiment_dir', 'data_tcab/detection-experiments/allocine/distilcamembert/fr+small/clean_vs_all', '--feature_setting', 'bert+tp+lm', '--model', 'RF', '--model_n_jobs', '10']
# ['--experiment_dir', 'data_tcab/detection-experiments/allocine/distilcamembert/fr+small/clean_vs_all', '--feature_setting', 'bert+tp+lm', '--model', 'LGB', '--model_n_jobs', '10']
# ['--experiment_dir', 'data_tcab/detection-experiments/allocine/distilcamembert/fr+small/clean_vs_all', '--feature_setting', 'all', '--model', 'LR', '--model_n_jobs', '10']
# ['--experiment_dir', 'data_tcab/detection-experiments/allocine/distilcamembert/fr+small/clean_vs_all', '--feature_setting', 'all', '--model', 'RF', '--model_n_jobs', '10']
# ['--experiment_dir', 'data_tcab/detection-experiments/allocine/distilcamembert/fr+small/clean_vs_all', '--feature_setting', 'all', '--model', 'LGB', '--model_n_jobs', '10']
# ['--experiment_dir', 'data_tcab/detection-experiments/allocine/distilcamembert/fr+small/multiclass_with_clean', '--feature_setting', 'bert', '--model', 'LR', '--model_n_jobs', '10']
# ['--experiment_dir', 'data_tcab/detection-experiments/allocine/distilcamembert/fr+small/multiclass_with_clean', '--feature_setting', 'bert', '--model', 'RF', '--model_n_jobs', '10']
# ['--experiment_dir', 'data_tcab/detection-experiments/allocine/distilcamembert/fr+small/multiclass_with_clean', '--feature_setting', 'bert', '--model', 'LGB', '--model_n_jobs', '10']
# ['--experiment_dir', 'data_tcab/detection-experiments/allocine/distilcamembert/fr+small/multiclass_with_clean', '--feature_setting', 'bert+tp', '--model', 'LR', '--model_n_jobs', '10']
# ['--experiment_dir', 'data_tcab/detection-experiments/allocine/distilcamembert/fr+small/multiclass_with_clean', '--feature_setting', 'bert+tp', '--model', 'RF', '--model_n_jobs', '10']
# ['--experiment_dir', 'data_tcab/detection-experiments/allocine/distilcamembert/fr+small/multiclass_with_clean', '--feature_setting', 'bert+tp', '--model', 'LGB', '--model_n_jobs', '10']
# ['--experiment_dir', 'data_tcab/detection-experiments/allocine/distilcamembert/fr+small/multiclass_with_clean', '--feature_setting', 'bert+tp+lm', '--model', 'LR', '--model_n_jobs', '10']
# ['--experiment_dir', 'data_tcab/detection-experiments/allocine/distilcamembert/fr+small/multiclass_with_clean', '--feature_setting', 'bert+tp+lm', '--model', 'RF', '--model_n_jobs', '10']
# ['--experiment_dir', 'data_tcab/detection-experiments/allocine/distilcamembert/fr+small/multiclass_with_clean', '--feature_setting', 'bert+tp+lm', '--model', 'LGB', '--model_n_jobs', '10']
# ['--experiment_dir', 'data_tcab/detection-experiments/allocine/distilcamembert/fr+small/multiclass_with_clean', '--feature_setting', 'all', '--model', 'LR', '--model_n_jobs', '10']
# ['--experiment_dir', 'data_tcab/detection-experiments/allocine/distilcamembert/fr+small/multiclass_with_clean', '--feature_setting', 'all', '--model', 'RF', '--model_n_jobs', '10']
# ['--experiment_dir', 'data_tcab/detection-experiments/allocine/distilcamembert/fr+small/multiclass_with_clean', '--feature_setting', 'all', '--model', 'LGB', '--model_n_jobs', '10']

# %%
call_main_args(run_experiment.main, args_grid)
# Out:
#   0%|          | 0/48 [00:00<?, ?it/s]
# ### Running main with ['--experiment_dir', 'data_tcab/detection-experiments/allocine/distilcamembert/default/clean_vs_all', '--feature_setting', 'bert', '--model', 'LR', '--model_n_jobs', '10']
#
# starting experiment: data_tcab\detection-experiments\allocine\distilcamembert\default\clean_vs_all
# CPU available : 16
# --- searching exp data in data_tcab\detection-experiments\allocine\distilcamembert\default\clean_vs_all
# --- using these features:
# ['tp_bert']
# --- output to data_tcab\detection-experiments\allocine\distilcamembert\default\clean_vs_all\LR\bert
# --- loading from data_tcab\detection-experiments\allocine\distilcamembert\default\clean_vs_all\train.joblib
# num of instances in the file:  10716
# loaded, labels:  Counter({'perturbed': 5358, 'clean': 5358})
# --- loading from data_tcab\detection-experiments\allocine\distilcamembert\default\clean_vs_all\val.joblib
# num of instances in the file:  3556
# loaded, labels:  Counter({'perturbed': 1778, 'clean': 1778})
# --- loading from data_tcab\detection-experiments\allocine\distilcamembert\default\clean_vs_all\test_release.joblib
# num of instances in the file:  2891
# loaded, labels:  Counter({'clean': 2009, 'perturbed': 882})
# --- training main starting
# skip if done: False
#
# no. train: 10,716
# no. val: 3,556
# no. test: 2,891
# no. features: 768
#
# --- starting training
# Fitting 3 folds for each of 2 candidates, totalling 6 fits
# [CV 1/3] END .........logisticregression__C=0.1;, score=0.716 total time=   2.4s
# [CV 2/3] END .........logisticregression__C=0.1;, score=0.723 total time=   1.8s
# [CV 3/3] END .........logisticregression__C=0.1;, score=0.714 total time=   1.6s
# [CV 1/3] END .........logisticregression__C=1.0;, score=0.713 total time=   1.6s
# [CV 2/3] END .........logisticregression__C=1.0;, score=0.721 total time=   1.7s
# [CV 3/3] END .........logisticregression__C=1.0;, score=0.717 total time=   1.7s
# --- finished training
# --- training time: 00:00:13
# {'train_accuracy': 0.7692235908921239, 'train_balanced_accuracy': 0.7692235908921239, 'train_confusion_matrix': [[4245, 1113], [1360, 3998]], 'train_recall': 0.746173945502053, 'train_precision': 0.7822343963999218, 'train_f1_score': 0.7637787754322285, 'train_roc_auc': 0.7692235908921239}
# {'validation_accuracy': 0.6991001124859393, 'validation_balanced_accuracy': 0.6991001124859393, 'validation_confusion_matrix': [[1368, 410], [660, 1118]], 'validation_recall': 0.6287964004499438, 'validation_precision': 0.731675392670157, 'validation_f1_score': 0.6763460375075621, 'validation_roc_auc': 0.6991001124859393}
# {'test_accuracy': 0.7343479764787271, 'test_balanced_accuracy': 0.7090039267739616, 'test_confusion_matrix': [[1555, 454], [314, 568]], 'test_recall': 0.6439909297052154, 'test_precision': 0.5557729941291585, 'test_f1_score': 0.5966386554621849, 'test_roc_auc': 0.7090039267739616}
# --- saving metrics to data_tcab\detection-experiments\allocine\distilcamembert\default\clean_vs_all\LR\bert
#
# ### Running main with ['--experiment_dir', 'data_tcab/detection-experiments/allocine/distilcamembert/default/clean_vs_all', '--feature_setting', 'bert', '--model', 'RF', '--model_n_jobs', '10']
#
# starting experiment: data_tcab\detection-experiments\allocine\distilcamembert\default\clean_vs_all
# CPU available : 16
# --- searching exp data in data_tcab\detection-experiments\allocine\distilcamembert\default\clean_vs_all
# --- using these features:
# ['tp_bert']
# --- output to data_tcab\detection-experiments\allocine\distilcamembert\default\clean_vs_all\RF\bert
# --- loading from data_tcab\detection-experiments\allocine\distilcamembert\default\clean_vs_all\train.joblib
# num of instances in the file:  10716
# loaded, labels:  Counter({'perturbed': 5358, 'clean': 5358})
# --- loading from data_tcab\detection-experiments\allocine\distilcamembert\default\clean_vs_all\val.joblib
# num of instances in the file:  3556
# loaded, labels:  Counter({'perturbed': 1778, 'clean': 1778})
# --- loading from data_tcab\detection-experiments\allocine\distilcamembert\default\clean_vs_all\test_release.joblib
# num of instances in the file:  2891
# loaded, labels:  Counter({'clean': 2009, 'perturbed': 882})
# --- training main starting
# skip if done: False
#
# no. train: 10,716
# no. val: 3,556
# no. test: 2,891
# no. features: 768
#
# --- starting training
# Fitting 3 folds for each of 8 candidates, totalling 24 fits
# [CV 1/3] END randomforestclassifier__max_depth=3, randomforestclassifier__min_samples_leaf=2, randomforestclassifier__n_estimators=50;, score=0.610 total time=   1.1s
# [CV 2/3] END randomforestclassifier__max_depth=3, randomforestclassifier__min_samples_leaf=2, randomforestclassifier__n_estimators=50;, score=0.592 total time=   0.9s
# [CV 3/3] END randomforestclassifier__max_depth=3, randomforestclassifier__min_samples_leaf=2, randomforestclassifier__n_estimators=50;, score=0.595 total time=   0.7s
# [CV 1/3] END randomforestclassifier__max_depth=3, randomforestclassifier__min_samples_leaf=2, randomforestclassifier__n_estimators=100;, score=0.615 total time=   1.2s
# [CV 2/3] END randomforestclassifier__max_depth=3, randomforestclassifier__min_samples_leaf=2, randomforestclassifier__n_estimators=100;, score=0.596 total time=   1.2s
# [CV 3/3] END randomforestclassifier__max_depth=3, randomforestclassifier__min_samples_leaf=2, randomforestclassifier__n_estimators=100;, score=0.604 total time=   1.2s
# [CV 1/3] END randomforestclassifier__max_depth=3, randomforestclassifier__min_samples_leaf=4, randomforestclassifier__n_estimators=50;, score=0.610 total time=   0.8s
# [CV 2/3] END randomforestclassifier__max_depth=3, randomforestclassifier__min_samples_leaf=4, randomforestclassifier__n_estimators=50;, score=0.592 total time=   0.7s
# [CV 3/3] END randomforestclassifier__max_depth=3, randomforestclassifier__min_samples_leaf=4, randomforestclassifier__n_estimators=50;, score=0.595 total time=   0.8s
# [CV 1/3] END randomforestclassifier__max_depth=3, randomforestclassifier__min_samples_leaf=4, randomforestclassifier__n_estimators=100;, score=0.615 total time=   1.2s
# [CV 2/3] END randomforestclassifier__max_depth=3, randomforestclassifier__min_samples_leaf=4, randomforestclassifier__n_estimators=100;, score=0.595 total time=   1.1s
# [CV 3/3] END randomforestclassifier__max_depth=3, randomforestclassifier__min_samples_leaf=4, randomforestclassifier__n_estimators=100;, score=0.604 total time=   1.1s
# [CV 1/3] END randomforestclassifier__max_depth=5, randomforestclassifier__min_samples_leaf=2, randomforestclassifier__n_estimators=50;, score=0.624 total time=   1.0s
# [CV 2/3] END randomforestclassifier__max_depth=5, randomforestclassifier__min_samples_leaf=2, randomforestclassifier__n_estimators=50;, score=0.613 total time=   0.9s
# [CV 3/3] END randomforestclassifier__max_depth=5, randomforestclassifier__min_samples_leaf=2, randomforestclassifier__n_estimators=50;, score=0.624 total time=   0.9s
# [CV 1/3] END randomforestclassifier__max_depth=5, randomforestclassifier__min_samples_leaf=2, randomforestclassifier__n_estimators=100;, score=0.631 total time=   1.6s
# [CV 2/3] END randomforestclassifier__max_depth=5, randomforestclassifier__min_samples_leaf=2, randomforestclassifier__n_estimators=100;, score=0.619 total time=   1.5s
# [CV 3/3] END randomforestclassifier__max_depth=5, randomforestclassifier__min_samples_leaf=2, randomforestclassifier__n_estimators=100;, score=0.629 total time=   1.5s
# [CV 1/3] END randomforestclassifier__max_depth=5, randomforestclassifier__min_samples_leaf=4, randomforestclassifier__n_estimators=50;, score=0.624 total time=   1.2s
# [CV 2/3] END randomforestclassifier__max_depth=5, randomforestclassifier__min_samples_leaf=4, randomforestclassifier__n_estimators=50;, score=0.619 total time=   1.0s
# [CV 3/3] END randomforestclassifier__max_depth=5, randomforestclassifier__min_samples_leaf=4, randomforestclassifier__n_estimators=50;, score=0.624 total time=   1.1s
# [CV 1/3] END randomforestclassifier__max_depth=5, randomforestclassifier__min_samples_leaf=4, randomforestclassifier__n_estimators=100;, score=0.631 total time=   1.7s
# [CV 2/3] END randomforestclassifier__max_depth=5, randomforestclassifier__min_samples_leaf=4, randomforestclassifier__n_estimators=100;, score=0.620 total time=   1.5s
# [CV 3/3] END randomforestclassifier__max_depth=5, randomforestclassifier__min_samples_leaf=4, randomforestclassifier__n_estimators=100;, score=0.630 total time=   1.5s
# --- finished training
# --- training time: 00:00:32
# {'train_accuracy': 0.7051138484509145, 'train_balanced_accuracy': 0.7051138484509145, 'train_confusion_matrix': [[4129, 1229], [1931, 3427]], 'train_recall': 0.6396043299738708, 'train_precision': 0.7360395189003437, 'train_f1_score': 0.6844417815058917, 'train_roc_auc': 0.7051138484509145}
# {'validation_accuracy': 0.6220472440944882, 'validation_balanced_accuracy': 0.6220472440944882, 'validation_confusion_matrix': [[1248, 530], [814, 964]], 'validation_recall': 0.5421822272215973, 'validation_precision': 0.6452476572958501, 'validation_f1_score': 0.589242053789731, 'validation_roc_auc': 0.6220472440944882}
# {'test_accuracy': 0.6703562781044621, 'test_balanced_accuracy': 0.6387921022067363, 'test_confusion_matrix': [[1446, 563], [390, 492]], 'test_recall': 0.5578231292517006, 'test_precision': 0.4663507109004739, 'test_f1_score': 0.5080020650490449, 'test_roc_auc': 0.6387921022067363}
# --- saving metrics to data_tcab\detection-experiments\allocine\distilcamembert\default\clean_vs_all\RF\bert
#
# ### Running main with ['--experiment_dir', 'data_tcab/detection-experiments/allocine/distilcamembert/default/clean_vs_all', '--feature_setting', 'bert', '--model', 'LGB', '--model_n_jobs', '10']
#
# starting experiment: data_tcab\detection-experiments\allocine\distilcamembert\default\clean_vs_all
# CPU available : 16
# --- searching exp data in data_tcab\detection-experiments\allocine\distilcamembert\default\clean_vs_all
# --- using these features:
# ['tp_bert']
# --- output to data_tcab\detection-experiments\allocine\distilcamembert\default\clean_vs_all\LGB\bert
# --- loading from data_tcab\detection-experiments\allocine\distilcamembert\default\clean_vs_all\train.joblib
# num of instances in the file:  10716
# loaded, labels:  Counter({'perturbed': 5358, 'clean': 5358})
# --- loading from data_tcab\detection-experiments\allocine\distilcamembert\default\clean_vs_all\val.joblib
# num of instances in the file:  3556
# loaded, labels:  Counter({'perturbed': 1778, 'clean': 1778})
# --- loading from data_tcab\detection-experiments\allocine\distilcamembert\default\clean_vs_all\test_release.joblib
# num of instances in the file:  2891
# loaded, labels:  Counter({'clean': 2009, 'perturbed': 882})
# --- training main starting
# skip if done: False
#
# no. train: 10,716
# no. val: 3,556
# no. test: 2,891
# no. features: 768
#
# --- starting training
# Fitting 3 folds for each of 8 candidates, totalling 24 fits
# [CV 1/3] END lgbmclassifier__boosting_type=gbdt, lgbmclassifier__max_depth=3, lgbmclassifier__n_estimators=50, lgbmclassifier__num_leaves=2;, score=0.617 total time=   0.4s
# [CV 2/3] END lgbmclassifier__boosting_type=gbdt, lgbmclassifier__max_depth=3, lgbmclassifier__n_estimators=50, lgbmclassifier__num_leaves=2;, score=0.627 total time=   0.5s
# [CV 3/3] END lgbmclassifier__boosting_type=gbdt, lgbmclassifier__max_depth=3, lgbmclassifier__n_estimators=50, lgbmclassifier__num_leaves=2;, score=0.620 total time=   0.4s
# [CV 1/3] END lgbmclassifier__boosting_type=gbdt, lgbmclassifier__max_depth=3, lgbmclassifier__n_estimators=50, lgbmclassifier__num_leaves=15;, score=0.653 total time=   0.6s
# [CV 2/3] END lgbmclassifier__boosting_type=gbdt, lgbmclassifier__max_depth=3, lgbmclassifier__n_estimators=50, lgbmclassifier__num_leaves=15;, score=0.660 total time=   0.6s
# [CV 3/3] END lgbmclassifier__boosting_type=gbdt, lgbmclassifier__max_depth=3, lgbmclassifier__n_estimators=50, lgbmclassifier__num_leaves=15;, score=0.653 total time=   0.6s
# [CV 1/3] END lgbmclassifier__boosting_type=gbdt, lgbmclassifier__max_depth=3, lgbmclassifier__n_estimators=100, lgbmclassifier__num_leaves=2;, score=0.624 total time=   0.4s
# [CV 2/3] END lgbmclassifier__boosting_type=gbdt, lgbmclassifier__max_depth=3, lgbmclassifier__n_estimators=100, lgbmclassifier__num_leaves=2;, score=0.637 total time=   0.5s
# [CV 3/3] END lgbmclassifier__boosting_type=gbdt, lgbmclassifier__max_depth=3, lgbmclassifier__n_estimators=100, lgbmclassifier__num_leaves=2;, score=0.636 total time=   0.4s
# [CV 1/3] END lgbmclassifier__boosting_type=gbdt, lgbmclassifier__max_depth=3, lgbmclassifier__n_estimators=100, lgbmclassifier__num_leaves=15;, score=0.664 total time=   0.7s
# [CV 2/3] END lgbmclassifier__boosting_type=gbdt, lgbmclassifier__max_depth=3, lgbmclassifier__n_estimators=100, lgbmclassifier__num_leaves=15;, score=0.667 total time=   0.7s
# [CV 3/3] END lgbmclassifier__boosting_type=gbdt, lgbmclassifier__max_depth=3, lgbmclassifier__n_estimators=100, lgbmclassifier__num_leaves=15;, score=0.669 total time=   0.6s
# [CV 1/3] END lgbmclassifier__boosting_type=gbdt, lgbmclassifier__max_depth=5, lgbmclassifier__n_estimators=50, lgbmclassifier__num_leaves=2;, score=0.617 total time=   0.4s
# [CV 2/3] END lgbmclassifier__boosting_type=gbdt, lgbmclassifier__max_depth=5, lgbmclassifier__n_estimators=50, lgbmclassifier__num_leaves=2;, score=0.627 total time=   0.4s
# [CV 3/3] END lgbmclassifier__boosting_type=gbdt, lgbmclassifier__max_depth=5, lgbmclassifier__n_estimators=50, lgbmclassifier__num_leaves=2;, score=0.620 total time=   0.5s
# [CV 1/3] END lgbmclassifier__boosting_type=gbdt, lgbmclassifier__max_depth=5, lgbmclassifier__n_estimators=50, lgbmclassifier__num_leaves=15;, score=0.660 total time=   0.8s
# [CV 2/3] END lgbmclassifier__boosting_type=gbdt, lgbmclassifier__max_depth=5, lgbmclassifier__n_estimators=50, lgbmclassifier__num_leaves=15;, score=0.669 total time=   0.7s
# [CV 3/3] END lgbmclassifier__boosting_type=gbdt, lgbmclassifier__max_depth=5, lgbmclassifier__n_estimators=50, lgbmclassifier__num_leaves=15;, score=0.672 total time=   0.8s
# [CV 1/3] END lgbmclassifier__boosting_type=gbdt, lgbmclassifier__max_depth=5, lgbmclassifier__n_estimators=100, lgbmclassifier__num_leaves=2;, score=0.624 total time=   0.6s
# [CV 2/3] END lgbmclassifier__boosting_type=gbdt, lgbmclassifier__max_depth=5, lgbmclassifier__n_estimators=100, lgbmclassifier__num_leaves=2;, score=0.637 total time=   0.6s
# [CV 3/3] END lgbmclassifier__boosting_type=gbdt, lgbmclassifier__max_depth=5, lgbmclassifier__n_estimators=100, lgbmclassifier__num_leaves=2;, score=0.636 total time=   0.6s
# [CV 1/3] END lgbmclassifier__boosting_type=gbdt, lgbmclassifier__max_depth=5, lgbmclassifier__n_estimators=100, lgbmclassifier__num_leaves=15;, score=0.671 total time=   1.5s
# [CV 2/3] END lgbmclassifier__boosting_type=gbdt, lgbmclassifier__max_depth=5, lgbmclassifier__n_estimators=100, lgbmclassifier__num_leaves=15;, score=0.688 total time=   1.5s
# [CV 3/3] END lgbmclassifier__boosting_type=gbdt, lgbmclassifier__max_depth=5, lgbmclassifier__n_estimators=100, lgbmclassifier__num_leaves=15;, score=0.694 total time=   1.5s
# --- finished training
# --- training time: 00:00:20
# {'train_accuracy': 0.8608622620380739, 'train_balanced_accuracy': 0.8608622620380739, 'train_confusion_matrix': [[4569, 789], [702, 4656]], 'train_recall': 0.8689809630459127, 'train_precision': 0.8550964187327824, 'train_f1_score': 0.8619827825603998, 'train_roc_auc': 0.8608622620380739}
# {'validation_accuracy': 0.6605736782902137, 'validation_balanced_accuracy': 0.6605736782902136, 'validation_confusion_matrix': [[1372, 406], [801, 977]], 'validation_recall': 0.5494938132733408, 'validation_precision': 0.7064352856109906, 'validation_f1_score': 0.6181588105030053, 'validation_roc_auc': 0.6605736782902136}
# {'test_accuracy': 0.6952611553095814, 'test_balanced_accuracy': 0.6541673580001106, 'test_confusion_matrix': [[1526, 483], [398, 484]], 'test_recall': 0.5487528344671202, 'test_precision': 0.500517063081696, 'test_f1_score': 0.523526230394808, 'test_roc_auc': 0.6541673580001106}
# --- saving metrics to data_tcab\detection-experiments\allocine\distilcamembert\default\clean_vs_all\LGB\bert
#
# ### Running main with ['--experiment_dir', 'data_tcab/detection-experiments/allocine/distilcamembert/default/clean_vs_all', '--feature_setting', 'bert+tp', '--model', 'LR', '--model_n_jobs', '10']
#
# starting experiment: data_tcab\detection-experiments\allocine\distilcamembert\default\clean_vs_all
# CPU available : 16
# --- searching exp data in data_tcab\detection-experiments\allocine\distilcamembert\default\clean_vs_all
# --- using these features:
# ['tp_avg_word_length', 'tp_bert', 'tp_is_first_word_lowercase', 'tp_num_alpha_chars', 'tp_num_cased_letters', 'tp_num_cased_word_switches', 'tp_num_chars', 'tp_num_digits', 'tp_num_lowercase_after_punctuation', 'tp_num_mixed_case_words', 'tp_num_multi_spaces', 'tp_num_non_ascii', 'tp_num_punctuation', 'tp_num_single_lowercase_letters', 'tp_num_words']
# --- output to data_tcab\detection-experiments\allocine\distilcamembert\default\clean_vs_all\LR\bert+tp
# --- loading from data_tcab\detection-experiments\allocine\distilcamembert\default\clean_vs_all\train.joblib
# num of instances in the file:  10716
# loaded, labels:  Counter({'perturbed': 5358, 'clean': 5358})
# --- loading from data_tcab\detection-experiments\allocine\distilcamembert\default\clean_vs_all\val.joblib
# num of instances in the file:  3556
# loaded, labels:  Counter({'perturbed': 1778, 'clean': 1778})
# --- loading from data_tcab\detection-experiments\allocine\distilcamembert\default\clean_vs_all\test_release.joblib
# num of instances in the file:  2891
# loaded, labels:  Counter({'clean': 2009, 'perturbed': 882})
# --- training main starting
# skip if done: False
#
# no. train: 10,716
# no. val: 3,556
# no. test: 2,891
# no. features: 804
#
# --- starting training
# Fitting 3 folds for each of 2 candidates, totalling 6 fits
# [CV 1/3] END .........logisticregression__C=0.1;, score=0.740 total time=   2.2s
# [CV 2/3] END .........logisticregression__C=0.1;, score=0.721 total time=   2.3s
# [CV 3/3] END .........logisticregression__C=0.1;, score=0.744 total time=   2.2s
# [CV 1/3] END .........logisticregression__C=1.0;, score=0.734 total time=   2.2s
# [CV 2/3] END .........logisticregression__C=1.0;, score=0.716 total time=   2.3s
# [CV 3/3] END .........logisticregression__C=1.0;, score=0.739 total time=   2.2s
# --- finished training
# --- training time: 00:00:16
# {'train_accuracy': 0.7892870474057484, 'train_balanced_accuracy': 0.7892870474057484, 'train_confusion_matrix': [[4387, 971], [1287, 4071]], 'train_recall': 0.7597984322508399, 'train_precision': 0.8074176913923047, 'train_f1_score': 0.7828846153846154, 'train_roc_auc': 0.7892870474057484}
# {'validation_accuracy': 0.7275028121484814, 'validation_balanced_accuracy': 0.7275028121484814, 'validation_confusion_matrix': [[1421, 357], [612, 1166]], 'validation_recall': 0.655793025871766, 'validation_precision': 0.7655942219304005, 'validation_f1_score': 0.7064525901242048, 'validation_roc_auc': 0.7275028121484816}
# {'test_accuracy': 0.7512971290211, 'test_balanced_accuracy': 0.729149383330568, 'test_confusion_matrix': [[1579, 430], [289, 593]], 'test_recall': 0.6723356009070295, 'test_precision': 0.5796676441837733, 'test_f1_score': 0.6225721784776903, 'test_roc_auc': 0.7291493833305679}
# --- saving metrics to data_tcab\detection-experiments\allocine\distilcamembert\default\clean_vs_all\LR\bert+tp
#
# ### Running main with ['--experiment_dir', 'data_tcab/detection-experiments/allocine/distilcamembert/default/clean_vs_all', '--feature_setting', 'bert+tp', '--model', 'RF', '--model_n_jobs', '10']
#
# starting experiment: data_tcab\detection-experiments\allocine\distilcamembert\default\clean_vs_all
# CPU available : 16
# --- searching exp data in data_tcab\detection-experiments\allocine\distilcamembert\default\clean_vs_all
# --- using these features:
# ['tp_avg_word_length', 'tp_bert', 'tp_is_first_word_lowercase', 'tp_num_alpha_chars', 'tp_num_cased_letters', 'tp_num_cased_word_switches', 'tp_num_chars', 'tp_num_digits', 'tp_num_lowercase_after_punctuation', 'tp_num_mixed_case_words', 'tp_num_multi_spaces', 'tp_num_non_ascii', 'tp_num_punctuation', 'tp_num_single_lowercase_letters', 'tp_num_words']
# --- output to data_tcab\detection-experiments\allocine\distilcamembert\default\clean_vs_all\RF\bert+tp
# --- loading from data_tcab\detection-experiments\allocine\distilcamembert\default\clean_vs_all\train.joblib
# num of instances in the file:  10716
# loaded, labels:  Counter({'perturbed': 5358, 'clean': 5358})
# --- loading from data_tcab\detection-experiments\allocine\distilcamembert\default\clean_vs_all\val.joblib
# num of instances in the file:  3556
# loaded, labels:  Counter({'perturbed': 1778, 'clean': 1778})
# --- loading from data_tcab\detection-experiments\allocine\distilcamembert\default\clean_vs_all\test_release.joblib
# num of instances in the file:  2891
# loaded, labels:  Counter({'clean': 2009, 'perturbed': 882})
# --- training main starting
# skip if done: False
#
# no. train: 10,716
# no. val: 3,556
# no. test: 2,891
# no. features: 804
#
# --- starting training
# Fitting 3 folds for each of 8 candidates, totalling 24 fits
# [CV 1/3] END randomforestclassifier__max_depth=3, randomforestclassifier__min_samples_leaf=2, randomforestclassifier__n_estimators=50;, score=0.649 total time=   1.0s
# [CV 2/3] END randomforestclassifier__max_depth=3, randomforestclassifier__min_samples_leaf=2, randomforestclassifier__n_estimators=50;, score=0.636 total time=   0.9s
# [CV 3/3] END randomforestclassifier__max_depth=3, randomforestclassifier__min_samples_leaf=2, randomforestclassifier__n_estimators=50;, score=0.617 total time=   0.8s
# [CV 1/3] END randomforestclassifier__max_depth=3, randomforestclassifier__min_samples_leaf=2, randomforestclassifier__n_estimators=100;, score=0.648 total time=   1.2s
# [CV 2/3] END randomforestclassifier__max_depth=3, randomforestclassifier__min_samples_leaf=2, randomforestclassifier__n_estimators=100;, score=0.635 total time=   1.3s
# [CV 3/3] END randomforestclassifier__max_depth=3, randomforestclassifier__min_samples_leaf=2, randomforestclassifier__n_estimators=100;, score=0.624 total time=   1.2s
# [CV 1/3] END randomforestclassifier__max_depth=3, randomforestclassifier__min_samples_leaf=4, randomforestclassifier__n_estimators=50;, score=0.648 total time=   0.8s
# [CV 2/3] END randomforestclassifier__max_depth=3, randomforestclassifier__min_samples_leaf=4, randomforestclassifier__n_estimators=50;, score=0.634 total time=   0.9s
# [CV 3/3] END randomforestclassifier__max_depth=3, randomforestclassifier__min_samples_leaf=4, randomforestclassifier__n_estimators=50;, score=0.617 total time=   0.8s
# [CV 1/3] END randomforestclassifier__max_depth=3, randomforestclassifier__min_samples_leaf=4, randomforestclassifier__n_estimators=100;, score=0.645 total time=   1.3s
# [CV 2/3] END randomforestclassifier__max_depth=3, randomforestclassifier__min_samples_leaf=4, randomforestclassifier__n_estimators=100;, score=0.634 total time=   1.2s
# [CV 3/3] END randomforestclassifier__max_depth=3, randomforestclassifier__min_samples_leaf=4, randomforestclassifier__n_estimators=100;, score=0.623 total time=   1.1s
# [CV 1/3] END randomforestclassifier__max_depth=5, randomforestclassifier__min_samples_leaf=2, randomforestclassifier__n_estimators=50;, score=0.669 total time=   1.1s
# [CV 2/3] END randomforestclassifier__max_depth=5, randomforestclassifier__min_samples_leaf=2, randomforestclassifier__n_estimators=50;, score=0.652 total time=   1.1s
# [CV 3/3] END randomforestclassifier__max_depth=5, randomforestclassifier__min_samples_leaf=2, randomforestclassifier__n_estimators=50;, score=0.667 total time=   1.0s
# [CV 1/3] END randomforestclassifier__max_depth=5, randomforestclassifier__min_samples_leaf=2, randomforestclassifier__n_estimators=100;, score=0.667 total time=   1.6s
# [CV 2/3] END randomforestclassifier__max_depth=5, randomforestclassifier__min_samples_leaf=2, randomforestclassifier__n_estimators=100;, score=0.657 total time=   1.6s
# [CV 3/3] END randomforestclassifier__max_depth=5, randomforestclassifier__min_samples_leaf=2, randomforestclassifier__n_estimators=100;, score=0.665 total time=   1.6s
# [CV 1/3] END randomforestclassifier__max_depth=5, randomforestclassifier__min_samples_leaf=4, randomforestclassifier__n_estimators=50;, score=0.669 total time=   1.1s
# [CV 2/3] END randomforestclassifier__max_depth=5, randomforestclassifier__min_samples_leaf=4, randomforestclassifier__n_estimators=50;, score=0.659 total time=   1.0s
# [CV 3/3] END randomforestclassifier__max_depth=5, randomforestclassifier__min_samples_leaf=4, randomforestclassifier__n_estimators=50;, score=0.658 total time=   1.1s
# [CV 1/3] END randomforestclassifier__max_depth=5, randomforestclassifier__min_samples_leaf=4, randomforestclassifier__n_estimators=100;, score=0.665 total time=   1.7s
# [CV 2/3] END randomforestclassifier__max_depth=5, randomforestclassifier__min_samples_leaf=4, randomforestclassifier__n_estimators=100;, score=0.661 total time=   1.7s
# [CV 3/3] END randomforestclassifier__max_depth=5, randomforestclassifier__min_samples_leaf=4, randomforestclassifier__n_estimators=100;, score=0.663 total time=   1.5s
# --- finished training
# --- training time: 00:00:32
# {'train_accuracy': 0.7317095931317655, 'train_balanced_accuracy': 0.7317095931317656, 'train_confusion_matrix': [[4358, 1000], [1875, 3483]], 'train_recall': 0.6500559910414334, 'train_precision': 0.7769350881106402, 'train_f1_score': 0.7078548927954478, 'train_roc_auc': 0.7317095931317656}
# {'validation_accuracy': 0.6690101237345332, 'validation_balanced_accuracy': 0.6690101237345332, 'validation_confusion_matrix': [[1378, 400], [777, 1001]], 'validation_recall': 0.562992125984252, 'validation_precision': 0.7144896502498216, 'validation_f1_score': 0.6297577854671281, 'validation_roc_auc': 0.6690101237345332}
# {'test_accuracy': 0.7097890003459011, 'test_balanced_accuracy': 0.6751147613516951, 'test_confusion_matrix': [[1535, 474], [365, 517]], 'test_recall': 0.5861678004535147, 'test_precision': 0.5216952573158425, 'test_f1_score': 0.5520555258942872, 'test_roc_auc': 0.6751147613516951}
# --- saving metrics to data_tcab\detection-experiments\allocine\distilcamembert\default\clean_vs_all\RF\bert+tp
#
# ### Running main with ['--experiment_dir', 'data_tcab/detection-experiments/allocine/distilcamembert/default/clean_vs_all', '--feature_setting', 'bert+tp', '--model', 'LGB', '--model_n_jobs', '10']
#
# starting experiment: data_tcab\detection-experiments\allocine\distilcamembert\default\clean_vs_all
# CPU available : 16
# --- searching exp data in data_tcab\detection-experiments\allocine\distilcamembert\default\clean_vs_all
# --- using these features:
# ['tp_avg_word_length', 'tp_bert', 'tp_is_first_word_lowercase', 'tp_num_alpha_chars', 'tp_num_cased_letters', 'tp_num_cased_word_switches', 'tp_num_chars', 'tp_num_digits', 'tp_num_lowercase_after_punctuation', 'tp_num_mixed_case_words', 'tp_num_multi_spaces', 'tp_num_non_ascii', 'tp_num_punctuation', 'tp_num_single_lowercase_letters', 'tp_num_words']
# --- output to data_tcab\detection-experiments\allocine\distilcamembert\default\clean_vs_all\LGB\bert+tp
# --- loading from data_tcab\detection-experiments\allocine\distilcamembert\default\clean_vs_all\train.joblib
# num of instances in the file:  10716
# loaded, labels:  Counter({'perturbed': 5358, 'clean': 5358})
# --- loading from data_tcab\detection-experiments\allocine\distilcamembert\default\clean_vs_all\val.joblib
# num of instances in the file:  3556
# loaded, labels:  Counter({'perturbed': 1778, 'clean': 1778})
# --- loading from data_tcab\detection-experiments\allocine\distilcamembert\default\clean_vs_all\test_release.joblib
# num of instances in the file:  2891
# loaded, labels:  Counter({'clean': 2009, 'perturbed': 882})
# --- training main starting
# skip if done: False
#
# no. train: 10,716
# no. val: 3,556
# no. test: 2,891
# no. features: 804
#
# --- starting training
# Fitting 3 folds for each of 8 candidates, totalling 24 fits
# [CV 1/3] END lgbmclassifier__boosting_type=gbdt, lgbmclassifier__max_depth=3, lgbmclassifier__n_estimators=50, lgbmclassifier__num_leaves=2;, score=0.667 total time=   0.5s
# [CV 2/3] END lgbmclassifier__boosting_type=gbdt, lgbmclassifier__max_depth=3, lgbmclassifier__n_estimators=50, lgbmclassifier__num_leaves=2;, score=0.668 total time=   0.4s
# [CV 3/3] END lgbmclassifier__boosting_type=gbdt, lgbmclassifier__max_depth=3, lgbmclassifier__n_estimators=50, lgbmclassifier__num_leaves=2;, score=0.664 total time=   0.4s
# [CV 1/3] END lgbmclassifier__boosting_type=gbdt, lgbmclassifier__max_depth=3, lgbmclassifier__n_estimators=50, lgbmclassifier__num_leaves=15;, score=0.701 total time=   0.6s
# [CV 2/3] END lgbmclassifier__boosting_type=gbdt, lgbmclassifier__max_depth=3, lgbmclassifier__n_estimators=50, lgbmclassifier__num_leaves=15;, score=0.695 total time=   0.5s
# [CV 3/3] END lgbmclassifier__boosting_type=gbdt, lgbmclassifier__max_depth=3, lgbmclassifier__n_estimators=50, lgbmclassifier__num_leaves=15;, score=0.695 total time=   0.6s
# [CV 1/3] END lgbmclassifier__boosting_type=gbdt, lgbmclassifier__max_depth=3, lgbmclassifier__n_estimators=100, lgbmclassifier__num_leaves=2;, score=0.684 total time=   0.5s
# [CV 2/3] END lgbmclassifier__boosting_type=gbdt, lgbmclassifier__max_depth=3, lgbmclassifier__n_estimators=100, lgbmclassifier__num_leaves=2;, score=0.682 total time=   0.6s
# [CV 3/3] END lgbmclassifier__boosting_type=gbdt, lgbmclassifier__max_depth=3, lgbmclassifier__n_estimators=100, lgbmclassifier__num_leaves=2;, score=0.671 total time=   0.6s
# [CV 1/3] END lgbmclassifier__boosting_type=gbdt, lgbmclassifier__max_depth=3, lgbmclassifier__n_estimators=100, lgbmclassifier__num_leaves=15;, score=0.719 total time=   0.7s
# [CV 2/3] END lgbmclassifier__boosting_type=gbdt, lgbmclassifier__max_depth=3, lgbmclassifier__n_estimators=100, lgbmclassifier__num_leaves=15;, score=0.712 total time=   0.7s
# [CV 3/3] END lgbmclassifier__boosting_type=gbdt, lgbmclassifier__max_depth=3, lgbmclassifier__n_estimators=100, lgbmclassifier__num_leaves=15;, score=0.710 total time=   0.8s
# [CV 1/3] END lgbmclassifier__boosting_type=gbdt, lgbmclassifier__max_depth=5, lgbmclassifier__n_estimators=50, lgbmclassifier__num_leaves=2;, score=0.667 total time=   0.4s
# [CV 2/3] END lgbmclassifier__boosting_type=gbdt, lgbmclassifier__max_depth=5, lgbmclassifier__n_estimators=50, lgbmclassifier__num_leaves=2;, score=0.668 total time=   0.5s
# [CV 3/3] END lgbmclassifier__boosting_type=gbdt, lgbmclassifier__max_depth=5, lgbmclassifier__n_estimators=50, lgbmclassifier__num_leaves=2;, score=0.664 total time=   0.5s
# [CV 1/3] END lgbmclassifier__boosting_type=gbdt, lgbmclassifier__max_depth=5, lgbmclassifier__n_estimators=50, lgbmclassifier__num_leaves=15;, score=0.709 total time=   0.8s
# [CV 2/3] END lgbmclassifier__boosting_type=gbdt, lgbmclassifier__max_depth=5, lgbmclassifier__n_estimators=50, lgbmclassifier__num_leaves=15;, score=0.710 total time=   0.8s
# [CV 3/3] END lgbmclassifier__boosting_type=gbdt, lgbmclassifier__max_depth=5, lgbmclassifier__n_estimators=50, lgbmclassifier__num_leaves=15;, score=0.712 total time=   0.8s
# [CV 1/3] END lgbmclassifier__boosting_type=gbdt, lgbmclassifier__max_depth=5, lgbmclassifier__n_estimators=100, lgbmclassifier__num_leaves=2;, score=0.684 total time=   0.5s
# [CV 2/3] END lgbmclassifier__boosting_type=gbdt, lgbmclassifier__max_depth=5, lgbmclassifier__n_estimators=100, lgbmclassifier__num_leaves=2;, score=0.682 total time=   0.6s
# [CV 3/3] END lgbmclassifier__boosting_type=gbdt, lgbmclassifier__max_depth=5, lgbmclassifier__n_estimators=100, lgbmclassifier__num_leaves=2;, score=0.671 total time=   0.5s
# [CV 1/3] END lgbmclassifier__boosting_type=gbdt, lgbmclassifier__max_depth=5, lgbmclassifier__n_estimators=100, lgbmclassifier__num_leaves=15;, score=0.730 total time=   1.1s
# [CV 2/3] END lgbmclassifier__boosting_type=gbdt, lgbmclassifier__max_depth=5, lgbmclassifier__n_estimators=100, lgbmclassifier__num_leaves=15;, score=0.734 total time=   1.2s
# [CV 3/3] END lgbmclassifier__boosting_type=gbdt, lgbmclassifier__max_depth=5, lgbmclassifier__n_estimators=100, lgbmclassifier__num_leaves=15;, score=0.726 total time=   1.2s
# --- finished training
# --- training time: 00:00:19
# {'train_accuracy': 0.860675625233296, 'train_balanced_accuracy': 0.860675625233296, 'train_confusion_matrix': [[4722, 636], [857, 4501]], 'train_recall': 0.8400522583053378, 'train_precision': 0.8761923301537863, 'train_f1_score': 0.8577417818008576, 'train_roc_auc': 0.860675625233296}
# {'validation_accuracy': 0.7255343082114736, 'validation_balanced_accuracy': 0.7255343082114736, 'validation_confusion_matrix': [[1484, 294], [682, 1096]], 'validation_recall': 0.6164229471316085, 'validation_precision': 0.7884892086330936, 'validation_f1_score': 0.691919191919192, 'validation_roc_auc': 0.7255343082114736}
# {'test_accuracy': 0.7540643375994466, 'test_balanced_accuracy': 0.7177838615120845, 'test_confusion_matrix': [[1629, 380], [331, 551]], 'test_recall': 0.6247165532879818, 'test_precision': 0.5918367346938775, 'test_f1_score': 0.6078323221180363, 'test_roc_auc': 0.7177838615120844}
# --- saving metrics to data_tcab\detection-experiments\allocine\distilcamembert\default\clean_vs_all\LGB\bert+tp
#
# ### Running main with ['--experiment_dir', 'data_tcab/detection-experiments/allocine/distilcamembert/default/clean_vs_all', '--feature_setting', 'bert+tp+lm', '--model', 'LR', '--model_n_jobs', '10']
#
# starting experiment: data_tcab\detection-experiments\allocine\distilcamembert\default\clean_vs_all
# CPU available : 16
# --- searching exp data in data_tcab\detection-experiments\allocine\distilcamembert\default\clean_vs_all
# --- using these features:
# ['lm_perplexity', 'lm_proba_and_rank', 'tp_avg_word_length', 'tp_bert', 'tp_is_first_word_lowercase', 'tp_num_alpha_chars', 'tp_num_cased_letters', 'tp_num_cased_word_switches', 'tp_num_chars', 'tp_num_digits', 'tp_num_lowercase_after_punctuation', 'tp_num_mixed_case_words', 'tp_num_multi_spaces', 'tp_num_non_ascii', 'tp_num_punctuation', 'tp_num_single_lowercase_letters', 'tp_num_words']
# --- output to data_tcab\detection-experiments\allocine\distilcamembert\default\clean_vs_all\LR\bert+tp+lm
# --- loading from data_tcab\detection-experiments\allocine\distilcamembert\default\clean_vs_all\train.joblib
# num of instances in the file:  10716
# loaded, labels:  Counter({'perturbed': 5358, 'clean': 5358})
# --- loading from data_tcab\detection-experiments\allocine\distilcamembert\default\clean_vs_all\val.joblib
# num of instances in the file:  3556
# loaded, labels:  Counter({'perturbed': 1778, 'clean': 1778})
# --- loading from data_tcab\detection-experiments\allocine\distilcamembert\default\clean_vs_all\test_release.joblib
# num of instances in the file:  2891
# loaded, labels:  Counter({'clean': 2009, 'perturbed': 882})
# --- training main starting
# skip if done: False
#
# no. train: 10,716
# no. val: 3,556
# no. test: 2,891
# no. features: 848
#
# --- starting training
# Fitting 3 folds for each of 2 candidates, totalling 6 fits
# [CV 1/3] END .........logisticregression__C=0.1;, score=0.781 total time=   2.4s
# [CV 2/3] END .........logisticregression__C=0.1;, score=0.780 total time=   2.0s
# [CV 3/3] END .........logisticregression__C=0.1;, score=0.774 total time=   2.3s
# [CV 1/3] END .........logisticregression__C=1.0;, score=0.769 total time=   2.4s
# [CV 2/3] END .........logisticregression__C=1.0;, score=0.778 total time=   2.2s
# [CV 3/3] END .........logisticregression__C=1.0;, score=0.772 total time=   2.1s
# --- finished training
# --- training time: 00:00:17
# {'train_accuracy': 0.8260544979469951, 'train_balanced_accuracy': 0.8260544979469951, 'train_confusion_matrix': [[4586, 772], [1092, 4266]], 'train_recall': 0.7961926091825308, 'train_precision': 0.8467645891226677, 'train_f1_score': 0.8207002693343594, 'train_roc_auc': 0.8260544979469951}
# {'validation_accuracy': 0.7674353205849269, 'validation_balanced_accuracy': 0.7674353205849269, 'validation_confusion_matrix': [[1486, 292], [535, 1243]], 'validation_recall': 0.6991001124859393, 'validation_precision': 0.8097719869706841, 'validation_f1_score': 0.7503773015393903, 'validation_roc_auc': 0.7674353205849269}
# {'test_accuracy': 0.7848495330335524, 'test_balanced_accuracy': 0.7574249211879873, 'test_confusion_matrix': [[1663, 346], [276, 606]], 'test_recall': 0.6870748299319728, 'test_precision': 0.6365546218487395, 'test_f1_score': 0.6608505997818974, 'test_roc_auc': 0.7574249211879874}
# --- saving metrics to data_tcab\detection-experiments\allocine\distilcamembert\default\clean_vs_all\LR\bert+tp+lm
#
# ### Running main with ['--experiment_dir', 'data_tcab/detection-experiments/allocine/distilcamembert/default/clean_vs_all', '--feature_setting', 'bert+tp+lm', '--model', 'RF', '--model_n_jobs', '10']
#
# starting experiment: data_tcab\detection-experiments\allocine\distilcamembert\default\clean_vs_all
# CPU available : 16
# --- searching exp data in data_tcab\detection-experiments\allocine\distilcamembert\default\clean_vs_all
# --- using these features:
# ['lm_perplexity', 'lm_proba_and_rank', 'tp_avg_word_length', 'tp_bert', 'tp_is_first_word_lowercase', 'tp_num_alpha_chars', 'tp_num_cased_letters', 'tp_num_cased_word_switches', 'tp_num_chars', 'tp_num_digits', 'tp_num_lowercase_after_punctuation', 'tp_num_mixed_case_words', 'tp_num_multi_spaces', 'tp_num_non_ascii', 'tp_num_punctuation', 'tp_num_single_lowercase_letters', 'tp_num_words']
# --- output to data_tcab\detection-experiments\allocine\distilcamembert\default\clean_vs_all\RF\bert+tp+lm
# --- loading from data_tcab\detection-experiments\allocine\distilcamembert\default\clean_vs_all\train.joblib
# num of instances in the file:  10716
# loaded, labels:  Counter({'perturbed': 5358, 'clean': 5358})
# --- loading from data_tcab\detection-experiments\allocine\distilcamembert\default\clean_vs_all\val.joblib
# num of instances in the file:  3556
# loaded, labels:  Counter({'perturbed': 1778, 'clean': 1778})
# --- loading from data_tcab\detection-experiments\allocine\distilcamembert\default\clean_vs_all\test_release.joblib
# num of instances in the file:  2891
# loaded, labels:  Counter({'clean': 2009, 'perturbed': 882})
# --- training main starting
# skip if done: False
#
# no. train: 10,716
# no. val: 3,556
# no. test: 2,891
# no. features: 848
#
# --- starting training
# Fitting 3 folds for each of 8 candidates, totalling 24 fits
# [CV 1/3] END randomforestclassifier__max_depth=3, randomforestclassifier__min_samples_leaf=2, randomforestclassifier__n_estimators=50;, score=0.751 total time=   0.8s
# [CV 2/3] END randomforestclassifier__max_depth=3, randomforestclassifier__min_samples_leaf=2, randomforestclassifier__n_estimators=50;, score=0.745 total time=   1.0s
# [CV 3/3] END randomforestclassifier__max_depth=3, randomforestclassifier__min_samples_leaf=2, randomforestclassifier__n_estimators=50;, score=0.756 total time=   0.7s
# [CV 1/3] END randomforestclassifier__max_depth=3, randomforestclassifier__min_samples_leaf=2, randomforestclassifier__n_estimators=100;, score=0.753 total time=   1.3s
# [CV 2/3] END randomforestclassifier__max_depth=3, randomforestclassifier__min_samples_leaf=2, randomforestclassifier__n_estimators=100;, score=0.747 total time=   1.1s
# [CV 3/3] END randomforestclassifier__max_depth=3, randomforestclassifier__min_samples_leaf=2, randomforestclassifier__n_estimators=100;, score=0.756 total time=   1.3s
# [CV 1/3] END randomforestclassifier__max_depth=3, randomforestclassifier__min_samples_leaf=4, randomforestclassifier__n_estimators=50;, score=0.750 total time=   0.8s
# [CV 2/3] END randomforestclassifier__max_depth=3, randomforestclassifier__min_samples_leaf=4, randomforestclassifier__n_estimators=50;, score=0.745 total time=   0.8s
# [CV 3/3] END randomforestclassifier__max_depth=3, randomforestclassifier__min_samples_leaf=4, randomforestclassifier__n_estimators=50;, score=0.756 total time=   0.7s
# [CV 1/3] END randomforestclassifier__max_depth=3, randomforestclassifier__min_samples_leaf=4, randomforestclassifier__n_estimators=100;, score=0.753 total time=   1.2s
# [CV 2/3] END randomforestclassifier__max_depth=3, randomforestclassifier__min_samples_leaf=4, randomforestclassifier__n_estimators=100;, score=0.747 total time=   1.1s
# [CV 3/3] END randomforestclassifier__max_depth=3, randomforestclassifier__min_samples_leaf=4, randomforestclassifier__n_estimators=100;, score=0.758 total time=   1.2s
# [CV 1/3] END randomforestclassifier__max_depth=5, randomforestclassifier__min_samples_leaf=2, randomforestclassifier__n_estimators=50;, score=0.757 total time=   1.1s
# [CV 2/3] END randomforestclassifier__max_depth=5, randomforestclassifier__min_samples_leaf=2, randomforestclassifier__n_estimators=50;, score=0.756 total time=   1.1s
# [CV 3/3] END randomforestclassifier__max_depth=5, randomforestclassifier__min_samples_leaf=2, randomforestclassifier__n_estimators=50;, score=0.768 total time=   1.0s
# [CV 1/3] END randomforestclassifier__max_depth=5, randomforestclassifier__min_samples_leaf=2, randomforestclassifier__n_estimators=100;, score=0.757 total time=   1.6s
# [CV 2/3] END randomforestclassifier__max_depth=5, randomforestclassifier__min_samples_leaf=2, randomforestclassifier__n_estimators=100;, score=0.758 total time=   1.6s
# [CV 3/3] END randomforestclassifier__max_depth=5, randomforestclassifier__min_samples_leaf=2, randomforestclassifier__n_estimators=100;, score=0.772 total time=   1.7s
# [CV 1/3] END randomforestclassifier__max_depth=5, randomforestclassifier__min_samples_leaf=4, randomforestclassifier__n_estimators=50;, score=0.758 total time=   1.1s
# [CV 2/3] END randomforestclassifier__max_depth=5, randomforestclassifier__min_samples_leaf=4, randomforestclassifier__n_estimators=50;, score=0.754 total time=   0.9s
# [CV 3/3] END randomforestclassifier__max_depth=5, randomforestclassifier__min_samples_leaf=4, randomforestclassifier__n_estimators=50;, score=0.764 total time=   1.0s
# [CV 1/3] END randomforestclassifier__max_depth=5, randomforestclassifier__min_samples_leaf=4, randomforestclassifier__n_estimators=100;, score=0.759 total time=   1.7s
# [CV 2/3] END randomforestclassifier__max_depth=5, randomforestclassifier__min_samples_leaf=4, randomforestclassifier__n_estimators=100;, score=0.756 total time=   1.5s
# [CV 3/3] END randomforestclassifier__max_depth=5, randomforestclassifier__min_samples_leaf=4, randomforestclassifier__n_estimators=100;, score=0.771 total time=   1.6s
# --- finished training
# --- training time: 00:00:32
# {'train_accuracy': 0.7837812616648003, 'train_balanced_accuracy': 0.7837812616648003, 'train_confusion_matrix': [[4464, 894], [1423, 3935]], 'train_recall': 0.7344158268010451, 'train_precision': 0.8148685027956099, 'train_f1_score': 0.7725532541474428, 'train_roc_auc': 0.7837812616648003}
# {'validation_accuracy': 0.7696850393700787, 'validation_balanced_accuracy': 0.7696850393700787, 'validation_confusion_matrix': [[1473, 305], [514, 1264]], 'validation_recall': 0.7109111361079865, 'validation_precision': 0.8056086679413639, 'validation_f1_score': 0.7553032566477442, 'validation_roc_auc': 0.7696850393700788}
# {'test_accuracy': 0.788654444828779, 'test_balanced_accuracy': 0.7668408826945412, 'test_confusion_matrix': [[1653, 356], [255, 627]], 'test_recall': 0.7108843537414966, 'test_precision': 0.6378433367243134, 'test_f1_score': 0.6723860589812333, 'test_roc_auc': 0.7668408826945412}
# --- saving metrics to data_tcab\detection-experiments\allocine\distilcamembert\default\clean_vs_all\RF\bert+tp+lm
#
# ### Running main with ['--experiment_dir', 'data_tcab/detection-experiments/allocine/distilcamembert/default/clean_vs_all', '--feature_setting', 'bert+tp+lm', '--model', 'LGB', '--model_n_jobs', '10']
#
# starting experiment: data_tcab\detection-experiments\allocine\distilcamembert\default\clean_vs_all
# CPU available : 16
# --- searching exp data in data_tcab\detection-experiments\allocine\distilcamembert\default\clean_vs_all
# --- using these features:
# ['lm_perplexity', 'lm_proba_and_rank', 'tp_avg_word_length', 'tp_bert', 'tp_is_first_word_lowercase', 'tp_num_alpha_chars', 'tp_num_cased_letters', 'tp_num_cased_word_switches', 'tp_num_chars', 'tp_num_digits', 'tp_num_lowercase_after_punctuation', 'tp_num_mixed_case_words', 'tp_num_multi_spaces', 'tp_num_non_ascii', 'tp_num_punctuation', 'tp_num_single_lowercase_letters', 'tp_num_words']
# --- output to data_tcab\detection-experiments\allocine\distilcamembert\default\clean_vs_all\LGB\bert+tp+lm
# --- loading from data_tcab\detection-experiments\allocine\distilcamembert\default\clean_vs_all\train.joblib
# num of instances in the file:  10716
# loaded, labels:  Counter({'perturbed': 5358, 'clean': 5358})
# --- loading from data_tcab\detection-experiments\allocine\distilcamembert\default\clean_vs_all\val.joblib
# num of instances in the file:  3556
# loaded, labels:  Counter({'perturbed': 1778, 'clean': 1778})
# --- loading from data_tcab\detection-experiments\allocine\distilcamembert\default\clean_vs_all\test_release.joblib
# num of instances in the file:  2891
# loaded, labels:  Counter({'clean': 2009, 'perturbed': 882})
# --- training main starting
# skip if done: False
#
# no. train: 10,716
# no. val: 3,556
# no. test: 2,891
# no. features: 848
#
# --- starting training
# Fitting 3 folds for each of 8 candidates, totalling 24 fits
# [CV 1/3] END lgbmclassifier__boosting_type=gbdt, lgbmclassifier__max_depth=3, lgbmclassifier__n_estimators=50, lgbmclassifier__num_leaves=2;, score=0.759 total time=   0.5s
# [CV 2/3] END lgbmclassifier__boosting_type=gbdt, lgbmclassifier__max_depth=3, lgbmclassifier__n_estimators=50, lgbmclassifier__num_leaves=2;, score=0.745 total time=  12.5s
# [CV 3/3] END lgbmclassifier__boosting_type=gbdt, lgbmclassifier__max_depth=3, lgbmclassifier__n_estimators=50, lgbmclassifier__num_leaves=2;, score=0.765 total time=   1.4s
# [CV 1/3] END lgbmclassifier__boosting_type=gbdt, lgbmclassifier__max_depth=3, lgbmclassifier__n_estimators=50, lgbmclassifier__num_leaves=15;, score=0.779 total time=   0.8s
# [CV 2/3] END lgbmclassifier__boosting_type=gbdt, lgbmclassifier__max_depth=3, lgbmclassifier__n_estimators=50, lgbmclassifier__num_leaves=15;, score=0.765 total time=   0.8s
# [CV 3/3] END lgbmclassifier__boosting_type=gbdt, lgbmclassifier__max_depth=3, lgbmclassifier__n_estimators=50, lgbmclassifier__num_leaves=15;, score=0.789 total time=   0.7s
# [CV 1/3] END lgbmclassifier__boosting_type=gbdt, lgbmclassifier__max_depth=3, lgbmclassifier__n_estimators=100, lgbmclassifier__num_leaves=2;, score=0.768 total time=   0.6s
# [CV 2/3] END lgbmclassifier__boosting_type=gbdt, lgbmclassifier__max_depth=3, lgbmclassifier__n_estimators=100, lgbmclassifier__num_leaves=2;, score=0.754 total time=   0.6s
# [CV 3/3] END lgbmclassifier__boosting_type=gbdt, lgbmclassifier__max_depth=3, lgbmclassifier__n_estimators=100, lgbmclassifier__num_leaves=2;, score=0.774 total time=   0.6s
# [CV 1/3] END lgbmclassifier__boosting_type=gbdt, lgbmclassifier__max_depth=3, lgbmclassifier__n_estimators=100, lgbmclassifier__num_leaves=15;, score=0.784 total time=   0.8s
# [CV 2/3] END lgbmclassifier__boosting_type=gbdt, lgbmclassifier__max_depth=3, lgbmclassifier__n_estimators=100, lgbmclassifier__num_leaves=15;, score=0.775 total time=   0.8s
# [CV 3/3] END lgbmclassifier__boosting_type=gbdt, lgbmclassifier__max_depth=3, lgbmclassifier__n_estimators=100, lgbmclassifier__num_leaves=15;, score=0.796 total time=   1.4s
# [CV 1/3] END lgbmclassifier__boosting_type=gbdt, lgbmclassifier__max_depth=5, lgbmclassifier__n_estimators=50, lgbmclassifier__num_leaves=2;, score=0.759 total time=   0.7s
# [CV 2/3] END lgbmclassifier__boosting_type=gbdt, lgbmclassifier__max_depth=5, lgbmclassifier__n_estimators=50, lgbmclassifier__num_leaves=2;, score=0.745 total time=   0.6s
# [CV 3/3] END lgbmclassifier__boosting_type=gbdt, lgbmclassifier__max_depth=5, lgbmclassifier__n_estimators=50, lgbmclassifier__num_leaves=2;, score=0.765 total time=   0.5s
# [CV 1/3] END lgbmclassifier__boosting_type=gbdt, lgbmclassifier__max_depth=5, lgbmclassifier__n_estimators=50, lgbmclassifier__num_leaves=15;, score=0.787 total time=   0.9s
# [CV 2/3] END lgbmclassifier__boosting_type=gbdt, lgbmclassifier__max_depth=5, lgbmclassifier__n_estimators=50, lgbmclassifier__num_leaves=15;, score=0.779 total time=   0.9s
# ...
# --- saving metrics to data_tcab\detection-experiments\allocine\distilcamembert\fr+small\multiclass_with_clean\LR\all
#
# ### Running main with ['--experiment_dir', 'data_tcab/detection-experiments/allocine/distilcamembert/fr+small/multiclass_with_clean', '--feature_setting', 'all', '--model', 'RF', '--model_n_jobs', '10']
#
# starting experiment: data_tcab\detection-experiments\allocine\distilcamembert\fr+small\multiclass_with_clean
# CPU available : 16
# --- searching exp data in data_tcab\detection-experiments\allocine\distilcamembert\fr+small\multiclass_with_clean
# --- using these features:
# ['lm_perplexity', 'lm_proba_and_rank', 'tm_activation', 'tm_gradient', 'tm_posterior', 'tm_saliency', 'tp_avg_word_length', 'tp_bert', 'tp_is_first_word_lowercase', 'tp_num_alpha_chars', 'tp_num_cased_letters', 'tp_num_cased_word_switches', 'tp_num_chars', 'tp_num_digits', 'tp_num_lowercase_after_punctuation', 'tp_num_mixed_case_words', 'tp_num_multi_spaces', 'tp_num_non_ascii', 'tp_num_punctuation', 'tp_num_single_lowercase_letters', 'tp_num_words']
# --- output to data_tcab\detection-experiments\allocine\distilcamembert\fr+small\multiclass_with_clean\RF\all
# c:\Users\Baptiste\AppData\Local\pypoetry\Cache\virtualenvs\nlp-adversarial-attacks-ghBt6cj_-py3.10\lib\site-packages\torch\nn\modules\module.py:1117: UserWarning: Using a non-full backward hook when the forward contains multiple autograd Nodes is deprecated and will be removed in future versions. This hook will be missing some grad_input. Please use register_full_backward_hook to get the documented behavior.
#   warnings.warn("Using a non-full backward hook when the forward contains multiple autograd Nodes "
# --- loading from data_tcab\detection-experiments\allocine\distilcamembert\fr+small\multiclass_with_clean\train.joblib
# num of instances in the file:  6545
# loaded, labels:  Counter({'clean': 1187, 'input_reduction': 1187, 'textbugger': 1004, 'textfooler': 987, 'deepwordbug': 976, 'bae': 751, 'pwws': 453})
# --- loading from data_tcab\detection-experiments\allocine\distilcamembert\fr+small\multiclass_with_clean\val.joblib
# num of instances in the file:  2189
# loaded, labels:  Counter({'clean': 411, 'input_reduction': 411, 'textfooler': 336, 'deepwordbug': 334, 'textbugger': 328, 'bae': 228, 'pwws': 141})
# --- loading from data_tcab\detection-experiments\allocine\distilcamembert\fr+small\multiclass_with_clean\test_release.joblib
# num of instances in the file:  2891
# loaded, labels:  Counter({'clean': 2009, 'input_reduction': 204, 'textbugger': 165, 'deepwordbug': 163, 'textfooler': 162, 'bae': 116, 'pwws': 72})
# --- training main starting
# skip if done: False
#
# no. train: 6,545
# no. val: 2,189
# no. test: 2,891
# no. features: 4,539
#
# --- starting training
# Fitting 3 folds for each of 8 candidates, totalling 24 fits
# [CV 1/3] END randomforestclassifier__max_depth=3, randomforestclassifier__min_samples_leaf=2, randomforestclassifier__n_estimators=50;, score=0.576 total time=   1.5s
# [CV 2/3] END randomforestclassifier__max_depth=3, randomforestclassifier__min_samples_leaf=2, randomforestclassifier__n_estimators=50;, score=0.504 total time=   1.8s
# [CV 3/3] END randomforestclassifier__max_depth=3, randomforestclassifier__min_samples_leaf=2, randomforestclassifier__n_estimators=50;, score=0.539 total time=   1.5s
# [CV 1/3] END randomforestclassifier__max_depth=3, randomforestclassifier__min_samples_leaf=2, randomforestclassifier__n_estimators=100;, score=0.559 total time=   2.3s
# [CV 2/3] END randomforestclassifier__max_depth=3, randomforestclassifier__min_samples_leaf=2, randomforestclassifier__n_estimators=100;, score=0.495 total time=   2.2s
# [CV 3/3] END randomforestclassifier__max_depth=3, randomforestclassifier__min_samples_leaf=2, randomforestclassifier__n_estimators=100;, score=0.504 total time=   2.2s
# [CV 1/3] END randomforestclassifier__max_depth=3, randomforestclassifier__min_samples_leaf=4, randomforestclassifier__n_estimators=50;, score=0.576 total time=   1.6s
# [CV 2/3] END randomforestclassifier__max_depth=3, randomforestclassifier__min_samples_leaf=4, randomforestclassifier__n_estimators=50;, score=0.505 total time=   1.8s
# [CV 3/3] END randomforestclassifier__max_depth=3, randomforestclassifier__min_samples_leaf=4, randomforestclassifier__n_estimators=50;, score=0.539 total time=   1.5s
# [CV 1/3] END randomforestclassifier__max_depth=3, randomforestclassifier__min_samples_leaf=4, randomforestclassifier__n_estimators=100;, score=0.558 total time=   2.1s
# [CV 2/3] END randomforestclassifier__max_depth=3, randomforestclassifier__min_samples_leaf=4, randomforestclassifier__n_estimators=100;, score=0.495 total time=   2.4s
# [CV 3/3] END randomforestclassifier__max_depth=3, randomforestclassifier__min_samples_leaf=4, randomforestclassifier__n_estimators=100;, score=0.505 total time=   2.3s
# [CV 1/3] END randomforestclassifier__max_depth=5, randomforestclassifier__min_samples_leaf=2, randomforestclassifier__n_estimators=50;, score=0.583 total time=   1.8s
# [CV 2/3] END randomforestclassifier__max_depth=5, randomforestclassifier__min_samples_leaf=2, randomforestclassifier__n_estimators=50;, score=0.546 total time=   2.2s
# [CV 3/3] END randomforestclassifier__max_depth=5, randomforestclassifier__min_samples_leaf=2, randomforestclassifier__n_estimators=50;, score=0.574 total time=   1.9s
# [CV 1/3] END randomforestclassifier__max_depth=5, randomforestclassifier__min_samples_leaf=2, randomforestclassifier__n_estimators=100;, score=0.575 total time=   2.8s
# [CV 2/3] END randomforestclassifier__max_depth=5, randomforestclassifier__min_samples_leaf=2, randomforestclassifier__n_estimators=100;, score=0.543 total time=   2.8s
# [CV 3/3] END randomforestclassifier__max_depth=5, randomforestclassifier__min_samples_leaf=2, randomforestclassifier__n_estimators=100;, score=0.563 total time=   2.8s
# [CV 1/3] END randomforestclassifier__max_depth=5, randomforestclassifier__min_samples_leaf=4, randomforestclassifier__n_estimators=50;, score=0.582 total time=   1.7s
# [CV 2/3] END randomforestclassifier__max_depth=5, randomforestclassifier__min_samples_leaf=4, randomforestclassifier__n_estimators=50;, score=0.549 total time=   1.8s
# [CV 3/3] END randomforestclassifier__max_depth=5, randomforestclassifier__min_samples_leaf=4, randomforestclassifier__n_estimators=50;, score=0.578 total time=   1.8s
# [CV 1/3] END randomforestclassifier__max_depth=5, randomforestclassifier__min_samples_leaf=4, randomforestclassifier__n_estimators=100;, score=0.569 total time=   2.8s
# [CV 2/3] END randomforestclassifier__max_depth=5, randomforestclassifier__min_samples_leaf=4, randomforestclassifier__n_estimators=100;, score=0.547 total time=   3.0s
# [CV 3/3] END randomforestclassifier__max_depth=5, randomforestclassifier__min_samples_leaf=4, randomforestclassifier__n_estimators=100;, score=0.557 total time=   2.9s
# --- finished training
# --- training time: 00:00:56
# {'train_accuracy': 0.6119174942704354, 'train_balanced_accuracy': 0.5979708839550514, 'train_confusion_matrix': [[511, 10, 13, 53, 104, 40, 20], [130, 979, 8, 15, 38, 7, 10], [187, 15, 488, 37, 132, 92, 25], [4, 0, 4, 1175, 0, 2, 2], [98, 3, 32, 10, 279, 18, 13], [275, 13, 130, 27, 174, 334, 51], [281, 19, 89, 39, 179, 141, 239]]}
# {'validation_accuracy': 0.5975331201461854, 'validation_balanced_accuracy': 0.5747936127381875, 'validation_confusion_matrix': [[136, 4, 1, 23, 44, 14, 6], [32, 348, 0, 11, 15, 5, 0], [48, 4, 185, 18, 47, 26, 6], [0, 1, 4, 405, 1, 0, 0], [35, 2, 5, 2, 82, 10, 5], [84, 9, 42, 8, 65, 98, 22], [91, 11, 38, 14, 71, 57, 54]]}
# {'test_accuracy': 0.7295053614666206, 'test_balanced_accuracy': 0.5402535254577695, 'test_confusion_matrix': [[60, 5, 4, 8, 21, 13, 5], [180, 1666, 9, 52, 66, 17, 19], [19, 5, 79, 7, 32, 18, 3], [0, 2, 1, 199, 0, 1, 1], [12, 2, 8, 2, 43, 2, 3], [35, 1, 28, 6, 42, 43, 10], [44, 2, 20, 8, 38, 31, 19]]}
# --- saving metrics to data_tcab\detection-experiments\allocine\distilcamembert\fr+small\multiclass_with_clean\RF\all
#
# ### Running main with ['--experiment_dir', 'data_tcab/detection-experiments/allocine/distilcamembert/fr+small/multiclass_with_clean', '--feature_setting', 'all', '--model', 'LGB', '--model_n_jobs', '10']
#
# starting experiment: data_tcab\detection-experiments\allocine\distilcamembert\fr+small\multiclass_with_clean
# CPU available : 16
# --- searching exp data in data_tcab\detection-experiments\allocine\distilcamembert\fr+small\multiclass_with_clean
# --- using these features:
# ['lm_perplexity', 'lm_proba_and_rank', 'tm_activation', 'tm_gradient', 'tm_posterior', 'tm_saliency', 'tp_avg_word_length', 'tp_bert', 'tp_is_first_word_lowercase', 'tp_num_alpha_chars', 'tp_num_cased_letters', 'tp_num_cased_word_switches', 'tp_num_chars', 'tp_num_digits', 'tp_num_lowercase_after_punctuation', 'tp_num_mixed_case_words', 'tp_num_multi_spaces', 'tp_num_non_ascii', 'tp_num_punctuation', 'tp_num_single_lowercase_letters', 'tp_num_words']
# --- output to data_tcab\detection-experiments\allocine\distilcamembert\fr+small\multiclass_with_clean\LGB\all
# c:\Users\Baptiste\AppData\Local\pypoetry\Cache\virtualenvs\nlp-adversarial-attacks-ghBt6cj_-py3.10\lib\site-packages\torch\nn\modules\module.py:1117: UserWarning: Using a non-full backward hook when the forward contains multiple autograd Nodes is deprecated and will be removed in future versions. This hook will be missing some grad_input. Please use register_full_backward_hook to get the documented behavior.
#   warnings.warn("Using a non-full backward hook when the forward contains multiple autograd Nodes "
# --- loading from data_tcab\detection-experiments\allocine\distilcamembert\fr+small\multiclass_with_clean\train.joblib
# num of instances in the file:  6545
# loaded, labels:  Counter({'clean': 1187, 'input_reduction': 1187, 'textbugger': 1004, 'textfooler': 987, 'deepwordbug': 976, 'bae': 751, 'pwws': 453})
# --- loading from data_tcab\detection-experiments\allocine\distilcamembert\fr+small\multiclass_with_clean\val.joblib
# num of instances in the file:  2189
# loaded, labels:  Counter({'clean': 411, 'input_reduction': 411, 'textfooler': 336, 'deepwordbug': 334, 'textbugger': 328, 'bae': 228, 'pwws': 141})
# --- loading from data_tcab\detection-experiments\allocine\distilcamembert\fr+small\multiclass_with_clean\test_release.joblib
# num of instances in the file:  2891
# loaded, labels:  Counter({'clean': 2009, 'input_reduction': 204, 'textbugger': 165, 'deepwordbug': 163, 'textfooler': 162, 'bae': 116, 'pwws': 72})
# --- training main starting
# skip if done: False
#
# no. train: 6,545
# no. val: 2,189
# no. test: 2,891
# no. features: 4,539
#
# --- starting training
# Fitting 3 folds for each of 8 candidates, totalling 24 fits
# [CV 1/3] END lgbmclassifier__boosting_type=gbdt, lgbmclassifier__max_depth=3, lgbmclassifier__n_estimators=50, lgbmclassifier__num_leaves=2;, score=0.651 total time=   4.5s
# [CV 2/3] END lgbmclassifier__boosting_type=gbdt, lgbmclassifier__max_depth=3, lgbmclassifier__n_estimators=50, lgbmclassifier__num_leaves=2;, score=0.663 total time=   4.7s
# [CV 3/3] END lgbmclassifier__boosting_type=gbdt, lgbmclassifier__max_depth=3, lgbmclassifier__n_estimators=50, lgbmclassifier__num_leaves=2;, score=0.633 total time=   4.5s
# [CV 1/3] END lgbmclassifier__boosting_type=gbdt, lgbmclassifier__max_depth=3, lgbmclassifier__n_estimators=50, lgbmclassifier__num_leaves=15;, score=0.689 total time=  10.2s
# [CV 2/3] END lgbmclassifier__boosting_type=gbdt, lgbmclassifier__max_depth=3, lgbmclassifier__n_estimators=50, lgbmclassifier__num_leaves=15;, score=0.675 total time=   9.9s
# [CV 3/3] END lgbmclassifier__boosting_type=gbdt, lgbmclassifier__max_depth=3, lgbmclassifier__n_estimators=50, lgbmclassifier__num_leaves=15;, score=0.666 total time=  10.2s
# [CV 1/3] END lgbmclassifier__boosting_type=gbdt, lgbmclassifier__max_depth=3, lgbmclassifier__n_estimators=100, lgbmclassifier__num_leaves=2;, score=0.681 total time=   6.3s
# [CV 2/3] END lgbmclassifier__boosting_type=gbdt, lgbmclassifier__max_depth=3, lgbmclassifier__n_estimators=100, lgbmclassifier__num_leaves=2;, score=0.675 total time=   6.7s
# [CV 3/3] END lgbmclassifier__boosting_type=gbdt, lgbmclassifier__max_depth=3, lgbmclassifier__n_estimators=100, lgbmclassifier__num_leaves=2;, score=0.653 total time=   7.1s
# [CV 1/3] END lgbmclassifier__boosting_type=gbdt, lgbmclassifier__max_depth=3, lgbmclassifier__n_estimators=100, lgbmclassifier__num_leaves=15;, score=0.697 total time=  16.0s
# [CV 2/3] END lgbmclassifier__boosting_type=gbdt, lgbmclassifier__max_depth=3, lgbmclassifier__n_estimators=100, lgbmclassifier__num_leaves=15;, score=0.673 total time=  18.5s
# [CV 3/3] END lgbmclassifier__boosting_type=gbdt, lgbmclassifier__max_depth=3, lgbmclassifier__n_estimators=100, lgbmclassifier__num_leaves=15;, score=0.669 total time=  18.1s
# [CV 1/3] END lgbmclassifier__boosting_type=gbdt, lgbmclassifier__max_depth=5, lgbmclassifier__n_estimators=50, lgbmclassifier__num_leaves=2;, score=0.651 total time=   4.3s
# [CV 2/3] END lgbmclassifier__boosting_type=gbdt, lgbmclassifier__max_depth=5, lgbmclassifier__n_estimators=50, lgbmclassifier__num_leaves=2;, score=0.663 total time=   4.5s
# [CV 3/3] END lgbmclassifier__boosting_type=gbdt, lgbmclassifier__max_depth=5, lgbmclassifier__n_estimators=50, lgbmclassifier__num_leaves=2;, score=0.633 total time=   4.8s
# [CV 1/3] END lgbmclassifier__boosting_type=gbdt, lgbmclassifier__max_depth=5, lgbmclassifier__n_estimators=50, lgbmclassifier__num_leaves=15;, score=0.683 total time=  22.1s
# [CV 2/3] END lgbmclassifier__boosting_type=gbdt, lgbmclassifier__max_depth=5, lgbmclassifier__n_estimators=50, lgbmclassifier__num_leaves=15;, score=0.670 total time=  21.6s
# [CV 3/3] END lgbmclassifier__boosting_type=gbdt, lgbmclassifier__max_depth=5, lgbmclassifier__n_estimators=50, lgbmclassifier__num_leaves=15;, score=0.653 total time=  21.5s
# [CV 1/3] END lgbmclassifier__boosting_type=gbdt, lgbmclassifier__max_depth=5, lgbmclassifier__n_estimators=100, lgbmclassifier__num_leaves=2;, score=0.681 total time=   6.1s
# [CV 2/3] END lgbmclassifier__boosting_type=gbdt, lgbmclassifier__max_depth=5, lgbmclassifier__n_estimators=100, lgbmclassifier__num_leaves=2;, score=0.675 total time=   6.0s
# [CV 3/3] END lgbmclassifier__boosting_type=gbdt, lgbmclassifier__max_depth=5, lgbmclassifier__n_estimators=100, lgbmclassifier__num_leaves=2;, score=0.653 total time=   6.7s
# [CV 1/3] END lgbmclassifier__boosting_type=gbdt, lgbmclassifier__max_depth=5, lgbmclassifier__n_estimators=100, lgbmclassifier__num_leaves=15;, score=0.680 total time=  38.9s
# [CV 2/3] END lgbmclassifier__boosting_type=gbdt, lgbmclassifier__max_depth=5, lgbmclassifier__n_estimators=100, lgbmclassifier__num_leaves=15;, score=0.666 total time=  38.5s
# [CV 3/3] END lgbmclassifier__boosting_type=gbdt, lgbmclassifier__max_depth=5, lgbmclassifier__n_estimators=100, lgbmclassifier__num_leaves=15;, score=0.657 total time=  35.5s
# --- finished training
# --- training time: 00:05:49
# {'train_accuracy': 0.9483575248281131, 'train_balanced_accuracy': 0.9504076637367082, 'train_confusion_matrix': [[739, 0, 2, 0, 0, 4, 6], [5, 1170, 3, 2, 2, 2, 3], [32, 2, 891, 0, 5, 36, 10], [0, 1, 0, 1186, 0, 0, 0], [2, 0, 0, 0, 449, 2, 0], [42, 6, 22, 0, 7, 899, 28], [56, 8, 7, 0, 19, 24, 873]]}
# {'validation_accuracy': 0.7309273640931933, 'validation_balanced_accuracy': 0.6950234680982748, 'validation_confusion_matrix': [[146, 6, 9, 9, 14, 17, 27], [19, 375, 3, 3, 3, 4, 4], [15, 4, 249, 3, 9, 28, 26], [2, 2, 1, 400, 2, 1, 3], [26, 2, 11, 0, 73, 11, 18], [41, 6, 33, 3, 20, 185, 40], [57, 12, 25, 4, 26, 40, 172]]}
# {'test_accuracy': 0.8253199584918713, 'test_balanced_accuracy': 0.6764344920936615, 'test_confusion_matrix': [[70, 6, 6, 3, 6, 9, 16], [103, 1793, 24, 12, 17, 25, 35], [13, 3, 119, 2, 5, 13, 8], [1, 1, 0, 199, 0, 2, 1], [12, 0, 7, 1, 36, 4, 12], [19, 0, 21, 2, 8, 86, 29], [31, 4, 15, 2, 14, 13, 83]]}
# --- saving metrics to data_tcab\detection-experiments\allocine\distilcamembert\fr+small\multiclass_with_clean\LGB\all

# %%
print(f"Total time: {time.strftime('%H:%M:%S', time.gmtime(time.time()-t))}")
# Out:
# Total time: 00:58:40
