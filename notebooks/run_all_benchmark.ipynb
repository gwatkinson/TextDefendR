# %% [markdown]
# # Run all TCAB benchmark

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import time
from functools import reduce
from itertools import product

from tqdm.auto import tqdm

from scripts import (
    distribute_experiments,
    make_experiment,
    make_official_dataset_splits,
    run_experiment,
)

# from scripts import encode_main

t = time.time()

# %%
def process_args(args_grid):
    liste1 = [dict(zip(args_grid.keys(), v)) for v in product(*args_grid.values())]
    liste2 = [list(reduce(lambda x, y: x + y, dico.items())) for dico in liste1]
    liste3 = [list(filter(None, liste)) for liste in liste2]

    print(f"Number of parameters combinations: {len(liste3)}")
    for elem in liste3:
        print(elem)

    return liste3

# %%
def call_main_args(main, processed_args_grid):
    for args in tqdm(processed_args_grid):
        print(f"\n### Running main with {args}\n")
        main(args)

# %% [markdown]
# ## 1. scripts/encode_main.py

# %%
# encode_main.main()

# %% [markdown]
# ## 2. scripts/make_official_dataset_splits.py

# %%
make_official_dataset_splits.main()
# Out:
# --- reading data
# --- dropping unsupported datasets
# --- dropping duplicates
# --- making splits across all datasets ---
# allocine
# --- filtering for dataset  (28913, 17)
#   0%|          | 0/20000 [00:00<?, ?it/s]
#   0%|          | 0/8010 [00:00<?, ?it/s]
# --- Train DF stats ---
# total_instances: 17348,
# attack_name: {'input_reduction': 1187, 'clean': 11990, 'deepwordbug': 976, 'bae': 751, 'textfooler': 987, 'textbugger': 1004, 'pwws': 453},
# target_dataset: {'allocine': 17348},
# target_model: {'distilcamembert': 17348},
# status: {'success': 5358, 'clean': 11990},
# attack_toolchain: {'textattack': 5358, 'none': 11990},
# scenario: {'sentiment': 17348},
#
# --- Test DF stats ---
# total_instances: 5783,
# attack_name: {'input_reduction': 402, 'clean': 4006, 'deepwordbug': 326, 'textfooler': 333, 'pwws': 147, 'bae': 238, 'textbugger': 331},
# target_dataset: {'allocine': 5783},
# target_model: {'distilcamembert': 5783},
# status: {'success': 1777, 'clean': 4006},
# attack_toolchain: {'textattack': 1777, 'none': 4006},
# scenario: {'sentiment': 5783},
#
# --- Val DF stats ---
# total_instances: 5782,
# attack_name: {'clean': 4004, 'deepwordbug': 334, 'textfooler': 336, 'bae': 228, 'input_reduction': 411, 'textbugger': 328, 'pwws': 141},
# target_dataset: {'allocine': 5782},
# target_model: {'distilcamembert': 5782},
# status: {'clean': 4004, 'success': 1778},
# attack_toolchain: {'none': 4004, 'textattack': 1778},
# scenario: {'sentiment': 5782},
#
# --- filtering for target model
# --- Train DF stats ---
# total_instances: 17348,
# attack_name: {'input_reduction': 1187, 'clean': 11990, 'deepwordbug': 976, 'bae': 751, 'textfooler': 987, 'textbugger': 1004, 'pwws': 453},
# target_dataset: {'allocine': 17348},
# target_model: {'distilcamembert': 17348},
# status: {'success': 5358, 'clean': 11990},
# attack_toolchain: {'textattack': 5358, 'none': 11990},
# scenario: {'sentiment': 17348},
#
# --- Test DF stats ---
# total_instances: 5783,
# attack_name: {'input_reduction': 402, 'clean': 4006, 'deepwordbug': 326, 'textfooler': 333, 'pwws': 147, 'bae': 238, 'textbugger': 331},
# target_dataset: {'allocine': 5783},
# target_model: {'distilcamembert': 5783},
# status: {'success': 1777, 'clean': 4006},
# attack_toolchain: {'textattack': 1777, 'none': 4006},
# scenario: {'sentiment': 5783},
#
# --- Val DF stats ---
# total_instances: 5782,
# attack_name: {'clean': 4004, 'deepwordbug': 334, 'textfooler': 336, 'bae': 228, 'input_reduction': 411, 'textbugger': 328, 'pwws': 141},
# target_dataset: {'allocine': 5782},
# target_model: {'distilcamembert': 5782},
# status: {'clean': 4004, 'success': 1778},
# attack_toolchain: {'none': 4004, 'textattack': 1778},
# scenario: {'sentiment': 5782},
#
# --- allocine distilcamembert --- DONE.
# --- allocine --- DONE.
# --- combining splits across all datasets ---
# --- DONE.

# %% [markdown]
# ## 3. scripts/distribute_experiments.py

# %%
args_grid = {
    "--embeddings_name": ["default", "fr+small"],
    "--experiment_setting": ["clean_vs_all", "multiclass_with_clean"],
}
args_grid = process_args(args_grid)
# Out:
# Number of parameters combinations: 4
# ['--embeddings_name', 'default', '--experiment_setting', 'clean_vs_all']
# ['--embeddings_name', 'default', '--experiment_setting', 'multiclass_with_clean']
# ['--embeddings_name', 'fr+small', '--experiment_setting', 'clean_vs_all']
# ['--embeddings_name', 'fr+small', '--experiment_setting', 'multiclass_with_clean']

# %%
call_main_args(distribute_experiments.main, args_grid)
# Out:
#   0%|          | 0/4 [00:00<?, ?it/s]
# ### Running main with ['--embeddings_name', 'default', '--experiment_setting', 'clean_vs_all']
#
# Reading train.csv from  data_tcab\official_TCAB_splits\splits_by_dataset_and_tm\allocine\distilcamembert\train.csv
# Reading val.csv from  data_tcab\official_TCAB_splits\splits_by_dataset_and_tm\allocine\distilcamembert\val.csv
# Reading test.csv from  data_tcab\official_TCAB_splits\splits_by_dataset_and_tm\allocine\distilcamembert\test.csv
# Dropping attacks by count, if less than < 10
#   0%|          | 0/4006 [00:00<?, ?it/s]
#  *** clean_vs_all saving to data_tcab\detection-experiments\allocine\distilcamembert\default\clean_vs_all
#
# ### Running main with ['--embeddings_name', 'default', '--experiment_setting', 'multiclass_with_clean']
#
# Reading train.csv from  data_tcab\official_TCAB_splits\splits_by_dataset_and_tm\allocine\distilcamembert\train.csv
# Reading val.csv from  data_tcab\official_TCAB_splits\splits_by_dataset_and_tm\allocine\distilcamembert\val.csv
# Reading test.csv from  data_tcab\official_TCAB_splits\splits_by_dataset_and_tm\allocine\distilcamembert\test.csv
# Dropping attacks by count, if less than < 10
#   0%|          | 0/4006 [00:00<?, ?it/s]
#  *** multiclass_with_clean saving to data_tcab\detection-experiments\allocine\distilcamembert\default\multiclass_with_clean
#
# ### Running main with ['--embeddings_name', 'fr+small', '--experiment_setting', 'clean_vs_all']
#
# Reading train.csv from  data_tcab\official_TCAB_splits\splits_by_dataset_and_tm\allocine\distilcamembert\train.csv
# Reading val.csv from  data_tcab\official_TCAB_splits\splits_by_dataset_and_tm\allocine\distilcamembert\val.csv
# Reading test.csv from  data_tcab\official_TCAB_splits\splits_by_dataset_and_tm\allocine\distilcamembert\test.csv
# Dropping attacks by count, if less than < 10
#   0%|          | 0/4006 [00:00<?, ?it/s]
#  *** clean_vs_all saving to data_tcab\detection-experiments\allocine\distilcamembert\fr+small\clean_vs_all
#
# ### Running main with ['--embeddings_name', 'fr+small', '--experiment_setting', 'multiclass_with_clean']
#
# Reading train.csv from  data_tcab\official_TCAB_splits\splits_by_dataset_and_tm\allocine\distilcamembert\train.csv
# Reading val.csv from  data_tcab\official_TCAB_splits\splits_by_dataset_and_tm\allocine\distilcamembert\val.csv
# Reading test.csv from  data_tcab\official_TCAB_splits\splits_by_dataset_and_tm\allocine\distilcamembert\test.csv
# Dropping attacks by count, if less than < 10
#   0%|          | 0/4006 [00:00<?, ?it/s]
#  *** multiclass_with_clean saving to data_tcab\detection-experiments\allocine\distilcamembert\fr+small\multiclass_with_clean

# %% [markdown]
# ## 4. scripts/make_experiments.py

# %%
embeddings_list = ["default", "fr+small"]
experiment_list = ["clean_vs_all", "multiclass_with_clean"]
experiment_dir_list = [
    f"data_tcab/detection-experiments/allocine/distilcamembert/{emb}/{exp}"
    for emb, exp in product(embeddings_list, experiment_list)
]
args_grid = {"--experiment_dir": experiment_dir_list}
args_grid = process_args(args_grid)
# Out:
# Number of parameters combinations: 4
# ['--experiment_dir', 'data_tcab/detection-experiments/allocine/distilcamembert/default/clean_vs_all']
# ['--experiment_dir', 'data_tcab/detection-experiments/allocine/distilcamembert/default/multiclass_with_clean']
# ['--experiment_dir', 'data_tcab/detection-experiments/allocine/distilcamembert/fr+small/clean_vs_all']
# ['--experiment_dir', 'data_tcab/detection-experiments/allocine/distilcamembert/fr+small/multiclass_with_clean']

# %%
call_main_args(make_experiment.main, args_grid)
# Out:
#   0%|          | 0/4 [00:00<?, ?it/s]
# ### Running main with ['--experiment_dir', 'data_tcab/detection-experiments/allocine/distilcamembert/default/clean_vs_all']
#
# making exp into...  data_tcab/detection-experiments/allocine/distilcamembert/default/clean_vs_all
#
# --- loading known instances from  data_tcab/embeddings/
# --- target_model: distilcamembert, target_dataset: allocine
# --- No. joblib files of varied size to read: 1
# [0] data_tcab\embeddings\default_distilcamembert_allocine_ALL_ALL.joblib
#
# done, no. unique instances with extracted features: 28,913
#
# --- creating train.joblib
#     cannot find embeddings for 0 / 10,716 instances
#
# --- creating val.joblib
#     cannot find embeddings for 0 / 3,556 instances
#
# --- creating test_release.joblib
#     cannot find embeddings for 0 / 2,891 instances
#
# ### Running main with ['--experiment_dir', 'data_tcab/detection-experiments/allocine/distilcamembert/default/multiclass_with_clean']
#
# making exp into...  data_tcab/detection-experiments/allocine/distilcamembert/default/multiclass_with_clean
#
# --- loading known instances from  data_tcab/embeddings/
# --- target_model: distilcamembert, target_dataset: allocine
# --- No. joblib files of varied size to read: 1
# [0] data_tcab\embeddings\default_distilcamembert_allocine_ALL_ALL.joblib
#
# done, no. unique instances with extracted features: 28,913
#
# --- creating train.joblib
#     cannot find embeddings for 0 / 6,545 instances
#
# --- creating val.joblib
#     cannot find embeddings for 0 / 2,189 instances
#
# --- creating test_release.joblib
#     cannot find embeddings for 0 / 2,891 instances
#
# ### Running main with ['--experiment_dir', 'data_tcab/detection-experiments/allocine/distilcamembert/fr+small/clean_vs_all']
#
# making exp into...  data_tcab/detection-experiments/allocine/distilcamembert/fr+small/clean_vs_all
#
# --- loading known instances from  data_tcab/embeddings/
# --- target_model: distilcamembert, target_dataset: allocine
# --- No. joblib files of varied size to read: 1
# [0] data_tcab\embeddings\fr+small_distilcamembert_allocine_ALL_ALL.joblib
#
# done, no. unique instances with extracted features: 28,913
#
# --- creating train.joblib
#     cannot find embeddings for 0 / 10,716 instances
#
# --- creating val.joblib
#     cannot find embeddings for 0 / 3,556 instances
#
# --- creating test_release.joblib
#     cannot find embeddings for 0 / 2,891 instances
#
# ### Running main with ['--experiment_dir', 'data_tcab/detection-experiments/allocine/distilcamembert/fr+small/multiclass_with_clean']
#
# making exp into...  data_tcab/detection-experiments/allocine/distilcamembert/fr+small/multiclass_with_clean
#
# --- loading known instances from  data_tcab/embeddings/
# --- target_model: distilcamembert, target_dataset: allocine
# --- No. joblib files of varied size to read: 1
# [0] data_tcab\embeddings\fr+small_distilcamembert_allocine_ALL_ALL.joblib
#
# done, no. unique instances with extracted features: 28,913
#
# --- creating train.joblib
#     cannot find embeddings for 0 / 6,545 instances
#
# --- creating val.joblib
#     cannot find embeddings for 0 / 2,189 instances
#
# --- creating test_release.joblib
#     cannot find embeddings for 0 / 2,891 instances

# %% [markdown]
# ## 5. scripts/run_experiment.py

# %%
args_grid = {
    "--experiment_dir": experiment_dir_list,
    "--feature_setting": ["bert", "bert+tp", "bert+tp+lm", "all"],
    "--model": ["LR", "RF", "LGB"],
    "--model_n_jobs": ["10"],
    "--disable_tune": [""],
}
args_grid = process_args(args_grid)
# Out:
# Number of parameters combinations: 48
# ['--experiment_dir', 'data_tcab/detection-experiments/allocine/distilcamembert/default/clean_vs_all', '--feature_setting', 'bert', '--model', 'LR', '--model_n_jobs', '10', '--disable_tune']
# ['--experiment_dir', 'data_tcab/detection-experiments/allocine/distilcamembert/default/clean_vs_all', '--feature_setting', 'bert', '--model', 'RF', '--model_n_jobs', '10', '--disable_tune']
# ['--experiment_dir', 'data_tcab/detection-experiments/allocine/distilcamembert/default/clean_vs_all', '--feature_setting', 'bert', '--model', 'LGB', '--model_n_jobs', '10', '--disable_tune']
# ['--experiment_dir', 'data_tcab/detection-experiments/allocine/distilcamembert/default/clean_vs_all', '--feature_setting', 'bert+tp', '--model', 'LR', '--model_n_jobs', '10', '--disable_tune']
# ['--experiment_dir', 'data_tcab/detection-experiments/allocine/distilcamembert/default/clean_vs_all', '--feature_setting', 'bert+tp', '--model', 'RF', '--model_n_jobs', '10', '--disable_tune']
# ['--experiment_dir', 'data_tcab/detection-experiments/allocine/distilcamembert/default/clean_vs_all', '--feature_setting', 'bert+tp', '--model', 'LGB', '--model_n_jobs', '10', '--disable_tune']
# ['--experiment_dir', 'data_tcab/detection-experiments/allocine/distilcamembert/default/clean_vs_all', '--feature_setting', 'bert+tp+lm', '--model', 'LR', '--model_n_jobs', '10', '--disable_tune']
# ['--experiment_dir', 'data_tcab/detection-experiments/allocine/distilcamembert/default/clean_vs_all', '--feature_setting', 'bert+tp+lm', '--model', 'RF', '--model_n_jobs', '10', '--disable_tune']
# ['--experiment_dir', 'data_tcab/detection-experiments/allocine/distilcamembert/default/clean_vs_all', '--feature_setting', 'bert+tp+lm', '--model', 'LGB', '--model_n_jobs', '10', '--disable_tune']
# ['--experiment_dir', 'data_tcab/detection-experiments/allocine/distilcamembert/default/clean_vs_all', '--feature_setting', 'all', '--model', 'LR', '--model_n_jobs', '10', '--disable_tune']
# ['--experiment_dir', 'data_tcab/detection-experiments/allocine/distilcamembert/default/clean_vs_all', '--feature_setting', 'all', '--model', 'RF', '--model_n_jobs', '10', '--disable_tune']
# ['--experiment_dir', 'data_tcab/detection-experiments/allocine/distilcamembert/default/clean_vs_all', '--feature_setting', 'all', '--model', 'LGB', '--model_n_jobs', '10', '--disable_tune']
# ['--experiment_dir', 'data_tcab/detection-experiments/allocine/distilcamembert/default/multiclass_with_clean', '--feature_setting', 'bert', '--model', 'LR', '--model_n_jobs', '10', '--disable_tune']
# ['--experiment_dir', 'data_tcab/detection-experiments/allocine/distilcamembert/default/multiclass_with_clean', '--feature_setting', 'bert', '--model', 'RF', '--model_n_jobs', '10', '--disable_tune']
# ['--experiment_dir', 'data_tcab/detection-experiments/allocine/distilcamembert/default/multiclass_with_clean', '--feature_setting', 'bert', '--model', 'LGB', '--model_n_jobs', '10', '--disable_tune']
# ['--experiment_dir', 'data_tcab/detection-experiments/allocine/distilcamembert/default/multiclass_with_clean', '--feature_setting', 'bert+tp', '--model', 'LR', '--model_n_jobs', '10', '--disable_tune']
# ['--experiment_dir', 'data_tcab/detection-experiments/allocine/distilcamembert/default/multiclass_with_clean', '--feature_setting', 'bert+tp', '--model', 'RF', '--model_n_jobs', '10', '--disable_tune']
# ['--experiment_dir', 'data_tcab/detection-experiments/allocine/distilcamembert/default/multiclass_with_clean', '--feature_setting', 'bert+tp', '--model', 'LGB', '--model_n_jobs', '10', '--disable_tune']
# ['--experiment_dir', 'data_tcab/detection-experiments/allocine/distilcamembert/default/multiclass_with_clean', '--feature_setting', 'bert+tp+lm', '--model', 'LR', '--model_n_jobs', '10', '--disable_tune']
# ['--experiment_dir', 'data_tcab/detection-experiments/allocine/distilcamembert/default/multiclass_with_clean', '--feature_setting', 'bert+tp+lm', '--model', 'RF', '--model_n_jobs', '10', '--disable_tune']
# ['--experiment_dir', 'data_tcab/detection-experiments/allocine/distilcamembert/default/multiclass_with_clean', '--feature_setting', 'bert+tp+lm', '--model', 'LGB', '--model_n_jobs', '10', '--disable_tune']
# ['--experiment_dir', 'data_tcab/detection-experiments/allocine/distilcamembert/default/multiclass_with_clean', '--feature_setting', 'all', '--model', 'LR', '--model_n_jobs', '10', '--disable_tune']
# ['--experiment_dir', 'data_tcab/detection-experiments/allocine/distilcamembert/default/multiclass_with_clean', '--feature_setting', 'all', '--model', 'RF', '--model_n_jobs', '10', '--disable_tune']
# ['--experiment_dir', 'data_tcab/detection-experiments/allocine/distilcamembert/default/multiclass_with_clean', '--feature_setting', 'all', '--model', 'LGB', '--model_n_jobs', '10', '--disable_tune']
# ['--experiment_dir', 'data_tcab/detection-experiments/allocine/distilcamembert/fr+small/clean_vs_all', '--feature_setting', 'bert', '--model', 'LR', '--model_n_jobs', '10', '--disable_tune']
# ['--experiment_dir', 'data_tcab/detection-experiments/allocine/distilcamembert/fr+small/clean_vs_all', '--feature_setting', 'bert', '--model', 'RF', '--model_n_jobs', '10', '--disable_tune']
# ['--experiment_dir', 'data_tcab/detection-experiments/allocine/distilcamembert/fr+small/clean_vs_all', '--feature_setting', 'bert', '--model', 'LGB', '--model_n_jobs', '10', '--disable_tune']
# ['--experiment_dir', 'data_tcab/detection-experiments/allocine/distilcamembert/fr+small/clean_vs_all', '--feature_setting', 'bert+tp', '--model', 'LR', '--model_n_jobs', '10', '--disable_tune']
# ['--experiment_dir', 'data_tcab/detection-experiments/allocine/distilcamembert/fr+small/clean_vs_all', '--feature_setting', 'bert+tp', '--model', 'RF', '--model_n_jobs', '10', '--disable_tune']
# ['--experiment_dir', 'data_tcab/detection-experiments/allocine/distilcamembert/fr+small/clean_vs_all', '--feature_setting', 'bert+tp', '--model', 'LGB', '--model_n_jobs', '10', '--disable_tune']
# ['--experiment_dir', 'data_tcab/detection-experiments/allocine/distilcamembert/fr+small/clean_vs_all', '--feature_setting', 'bert+tp+lm', '--model', 'LR', '--model_n_jobs', '10', '--disable_tune']
# ['--experiment_dir', 'data_tcab/detection-experiments/allocine/distilcamembert/fr+small/clean_vs_all', '--feature_setting', 'bert+tp+lm', '--model', 'RF', '--model_n_jobs', '10', '--disable_tune']
# ['--experiment_dir', 'data_tcab/detection-experiments/allocine/distilcamembert/fr+small/clean_vs_all', '--feature_setting', 'bert+tp+lm', '--model', 'LGB', '--model_n_jobs', '10', '--disable_tune']
# ['--experiment_dir', 'data_tcab/detection-experiments/allocine/distilcamembert/fr+small/clean_vs_all', '--feature_setting', 'all', '--model', 'LR', '--model_n_jobs', '10', '--disable_tune']
# ['--experiment_dir', 'data_tcab/detection-experiments/allocine/distilcamembert/fr+small/clean_vs_all', '--feature_setting', 'all', '--model', 'RF', '--model_n_jobs', '10', '--disable_tune']
# ['--experiment_dir', 'data_tcab/detection-experiments/allocine/distilcamembert/fr+small/clean_vs_all', '--feature_setting', 'all', '--model', 'LGB', '--model_n_jobs', '10', '--disable_tune']
# ['--experiment_dir', 'data_tcab/detection-experiments/allocine/distilcamembert/fr+small/multiclass_with_clean', '--feature_setting', 'bert', '--model', 'LR', '--model_n_jobs', '10', '--disable_tune']
# ['--experiment_dir', 'data_tcab/detection-experiments/allocine/distilcamembert/fr+small/multiclass_with_clean', '--feature_setting', 'bert', '--model', 'RF', '--model_n_jobs', '10', '--disable_tune']
# ['--experiment_dir', 'data_tcab/detection-experiments/allocine/distilcamembert/fr+small/multiclass_with_clean', '--feature_setting', 'bert', '--model', 'LGB', '--model_n_jobs', '10', '--disable_tune']
# ['--experiment_dir', 'data_tcab/detection-experiments/allocine/distilcamembert/fr+small/multiclass_with_clean', '--feature_setting', 'bert+tp', '--model', 'LR', '--model_n_jobs', '10', '--disable_tune']
# ['--experiment_dir', 'data_tcab/detection-experiments/allocine/distilcamembert/fr+small/multiclass_with_clean', '--feature_setting', 'bert+tp', '--model', 'RF', '--model_n_jobs', '10', '--disable_tune']
# ['--experiment_dir', 'data_tcab/detection-experiments/allocine/distilcamembert/fr+small/multiclass_with_clean', '--feature_setting', 'bert+tp', '--model', 'LGB', '--model_n_jobs', '10', '--disable_tune']
# ['--experiment_dir', 'data_tcab/detection-experiments/allocine/distilcamembert/fr+small/multiclass_with_clean', '--feature_setting', 'bert+tp+lm', '--model', 'LR', '--model_n_jobs', '10', '--disable_tune']
# ['--experiment_dir', 'data_tcab/detection-experiments/allocine/distilcamembert/fr+small/multiclass_with_clean', '--feature_setting', 'bert+tp+lm', '--model', 'RF', '--model_n_jobs', '10', '--disable_tune']
# ['--experiment_dir', 'data_tcab/detection-experiments/allocine/distilcamembert/fr+small/multiclass_with_clean', '--feature_setting', 'bert+tp+lm', '--model', 'LGB', '--model_n_jobs', '10', '--disable_tune']
# ['--experiment_dir', 'data_tcab/detection-experiments/allocine/distilcamembert/fr+small/multiclass_with_clean', '--feature_setting', 'all', '--model', 'LR', '--model_n_jobs', '10', '--disable_tune']
# ['--experiment_dir', 'data_tcab/detection-experiments/allocine/distilcamembert/fr+small/multiclass_with_clean', '--feature_setting', 'all', '--model', 'RF', '--model_n_jobs', '10', '--disable_tune']
# ['--experiment_dir', 'data_tcab/detection-experiments/allocine/distilcamembert/fr+small/multiclass_with_clean', '--feature_setting', 'all', '--model', 'LGB', '--model_n_jobs', '10', '--disable_tune']

# %%
call_main_args(run_experiment.main, args_grid)
# Out:
#   0%|          | 0/48 [00:00<?, ?it/s]
# ### Running main with ['--experiment_dir', 'data_tcab/detection-experiments/allocine/distilcamembert/default/clean_vs_all', '--feature_setting', 'bert', '--model', 'LR', '--model_n_jobs', '10', '--disable_tune']
#
# starting experiment: data_tcab\detection-experiments\allocine\distilcamembert\default\clean_vs_all
# CPU available : 16
# --- searching exp data in data_tcab\detection-experiments\allocine\distilcamembert\default\clean_vs_all
# --- using these features:
# ['tp_bert']
# --- output to data_tcab\detection-experiments\allocine\distilcamembert\default\clean_vs_all\LR\bert
# --- loading from data_tcab\detection-experiments\allocine\distilcamembert\default\clean_vs_all\train.joblib
# num of instances in the file:  10716
# loaded, labels:  Counter({'perturbed': 5358, 'clean': 5358})
# --- loading from data_tcab\detection-experiments\allocine\distilcamembert\default\clean_vs_all\val.joblib
# num of instances in the file:  3556
# loaded, labels:  Counter({'perturbed': 1778, 'clean': 1778})
# --- loading from data_tcab\detection-experiments\allocine\distilcamembert\default\clean_vs_all\test_release.joblib
# num of instances in the file:  2891
# loaded, labels:  Counter({'clean': 2009, 'perturbed': 882})
# --- training main starting
# skip if done: False
#
# no. train: 10,716
# no. val: 3,556
# no. test: 2,891
# no. features: 768
#
# --- starting training
# --- finished training
# --- training time: 00:00:03
# {'train_accuracy': 0.7685703620754013, 'train_balanced_accuracy': 0.7685703620754012, 'train_confusion_matrix': [[4213, 1145], [1335, 4023]], 'train_recall': 0.7508398656215005, 'train_precision': 0.7784442724458205, 'train_f1_score': 0.7643929317879535, 'train_roc_auc': 0.7685703620754012}
# {'validation_accuracy': 0.6892575928008999, 'validation_balanced_accuracy': 0.6892575928008999, 'validation_confusion_matrix': [[1341, 437], [668, 1110]], 'validation_recall': 0.6242969628796401, 'validation_precision': 0.7175177763413058, 'validation_f1_score': 0.6676691729323309, 'validation_roc_auc': 0.6892575928008999}
# {'test_accuracy': 0.7260463507436873, 'test_balanced_accuracy': 0.7023947790498313, 'test_confusion_matrix': [[1533, 476], [316, 566]], 'test_recall': 0.6417233560090703, 'test_precision': 0.5431861804222649, 'test_f1_score': 0.5883575883575883, 'test_roc_auc': 0.7023947790498313}
# --- saving metrics to data_tcab\detection-experiments\allocine\distilcamembert\default\clean_vs_all\LR\bert
#
# ### Running main with ['--experiment_dir', 'data_tcab/detection-experiments/allocine/distilcamembert/default/clean_vs_all', '--feature_setting', 'bert', '--model', 'RF', '--model_n_jobs', '10', '--disable_tune']
#
# starting experiment: data_tcab\detection-experiments\allocine\distilcamembert\default\clean_vs_all
# CPU available : 16
# --- searching exp data in data_tcab\detection-experiments\allocine\distilcamembert\default\clean_vs_all
# --- using these features:
# ['tp_bert']
# --- output to data_tcab\detection-experiments\allocine\distilcamembert\default\clean_vs_all\RF\bert
# --- loading from data_tcab\detection-experiments\allocine\distilcamembert\default\clean_vs_all\train.joblib
# num of instances in the file:  10716
# loaded, labels:  Counter({'perturbed': 5358, 'clean': 5358})
# --- loading from data_tcab\detection-experiments\allocine\distilcamembert\default\clean_vs_all\val.joblib
# num of instances in the file:  3556
# loaded, labels:  Counter({'perturbed': 1778, 'clean': 1778})
# --- loading from data_tcab\detection-experiments\allocine\distilcamembert\default\clean_vs_all\test_release.joblib
# num of instances in the file:  2891
# loaded, labels:  Counter({'clean': 2009, 'perturbed': 882})
# --- training main starting
# skip if done: False
#
# no. train: 10,716
# no. val: 3,556
# no. test: 2,891
# no. features: 768
#
# --- starting training
# --- finished training
# --- training time: 00:00:01
# {'train_accuracy': 0.7044606196341918, 'train_balanced_accuracy': 0.7044606196341918, 'train_confusion_matrix': [[4113, 1245], [1922, 3436]], 'train_recall': 0.641284061216872, 'train_precision': 0.7340311899166845, 'train_f1_score': 0.6845303317063453, 'train_roc_auc': 0.7044606196341919}
# {'validation_accuracy': 0.6268278965129359, 'validation_balanced_accuracy': 0.6268278965129359, 'validation_confusion_matrix': [[1277, 501], [826, 952]], 'validation_recall': 0.5354330708661418, 'validation_precision': 0.6551961459050241, 'validation_f1_score': 0.5892912411018261, 'validation_roc_auc': 0.6268278965129359}
# {'test_accuracy': 0.6720857834659287, 'test_balanced_accuracy': 0.6406725291742713, 'test_confusion_matrix': [[1449, 560], [388, 494]], 'test_recall': 0.5600907029478458, 'test_precision': 0.4686907020872865, 'test_f1_score': 0.5103305785123967, 'test_roc_auc': 0.6406725291742714}
# --- saving metrics to data_tcab\detection-experiments\allocine\distilcamembert\default\clean_vs_all\RF\bert
#
# ### Running main with ['--experiment_dir', 'data_tcab/detection-experiments/allocine/distilcamembert/default/clean_vs_all', '--feature_setting', 'bert', '--model', 'LGB', '--model_n_jobs', '10', '--disable_tune']
#
# starting experiment: data_tcab\detection-experiments\allocine\distilcamembert\default\clean_vs_all
# CPU available : 16
# --- searching exp data in data_tcab\detection-experiments\allocine\distilcamembert\default\clean_vs_all
# --- using these features:
# ['tp_bert']
# --- output to data_tcab\detection-experiments\allocine\distilcamembert\default\clean_vs_all\LGB\bert
# --- loading from data_tcab\detection-experiments\allocine\distilcamembert\default\clean_vs_all\train.joblib
# num of instances in the file:  10716
# loaded, labels:  Counter({'perturbed': 5358, 'clean': 5358})
# --- loading from data_tcab\detection-experiments\allocine\distilcamembert\default\clean_vs_all\val.joblib
# num of instances in the file:  3556
# loaded, labels:  Counter({'perturbed': 1778, 'clean': 1778})
# --- loading from data_tcab\detection-experiments\allocine\distilcamembert\default\clean_vs_all\test_release.joblib
# num of instances in the file:  2891
# loaded, labels:  Counter({'clean': 2009, 'perturbed': 882})
# --- training main starting
# skip if done: False
#
# no. train: 10,716
# no. val: 3,556
# no. test: 2,891
# no. features: 768
#
# --- starting training
# --- finished training
# --- training time: 00:00:01
# {'train_accuracy': 0.9174132138857782, 'train_balanced_accuracy': 0.9174132138857782, 'train_confusion_matrix': [[4809, 549], [336, 5022]], 'train_recall': 0.9372900335946248, 'train_precision': 0.901453957996769, 'train_f1_score': 0.919022783420258, 'train_roc_auc': 0.9174132138857782}
# {'validation_accuracy': 0.655511811023622, 'validation_balanced_accuracy': 0.655511811023622, 'validation_confusion_matrix': [[1399, 379], [846, 932]], 'validation_recall': 0.5241844769403825, 'validation_precision': 0.7109077040427155, 'validation_f1_score': 0.6034315312398835, 'validation_roc_auc': 0.6555118110236221}
# {'test_accuracy': 0.7059840885506745, 'test_balanced_accuracy': 0.6542503180133843, 'test_confusion_matrix': [[1581, 428], [422, 460]], 'test_recall': 0.5215419501133787, 'test_precision': 0.5180180180180181, 'test_f1_score': 0.519774011299435, 'test_roc_auc': 0.6542503180133842}
# --- saving metrics to data_tcab\detection-experiments\allocine\distilcamembert\default\clean_vs_all\LGB\bert
#
# ### Running main with ['--experiment_dir', 'data_tcab/detection-experiments/allocine/distilcamembert/default/clean_vs_all', '--feature_setting', 'bert+tp', '--model', 'LR', '--model_n_jobs', '10', '--disable_tune']
#
# starting experiment: data_tcab\detection-experiments\allocine\distilcamembert\default\clean_vs_all
# CPU available : 16
# --- searching exp data in data_tcab\detection-experiments\allocine\distilcamembert\default\clean_vs_all
# --- using these features:
# ['tp_avg_word_length', 'tp_bert', 'tp_is_first_word_lowercase', 'tp_num_alpha_chars', 'tp_num_cased_letters', 'tp_num_cased_word_switches', 'tp_num_chars', 'tp_num_digits', 'tp_num_lowercase_after_punctuation', 'tp_num_mixed_case_words', 'tp_num_multi_spaces', 'tp_num_non_ascii', 'tp_num_punctuation', 'tp_num_single_lowercase_letters', 'tp_num_words']
# --- output to data_tcab\detection-experiments\allocine\distilcamembert\default\clean_vs_all\LR\bert+tp
# --- loading from data_tcab\detection-experiments\allocine\distilcamembert\default\clean_vs_all\train.joblib
# num of instances in the file:  10716
# loaded, labels:  Counter({'perturbed': 5358, 'clean': 5358})
# --- loading from data_tcab\detection-experiments\allocine\distilcamembert\default\clean_vs_all\val.joblib
# num of instances in the file:  3556
# loaded, labels:  Counter({'perturbed': 1778, 'clean': 1778})
# --- loading from data_tcab\detection-experiments\allocine\distilcamembert\default\clean_vs_all\test_release.joblib
# num of instances in the file:  2891
# loaded, labels:  Counter({'clean': 2009, 'perturbed': 882})
# --- training main starting
# skip if done: False
#
# no. train: 10,716
# no. val: 3,556
# no. test: 2,891
# no. features: 804
#
# --- starting training
# --- finished training
# --- training time: 00:00:02
# {'train_accuracy': 0.7888204553938036, 'train_balanced_accuracy': 0.7888204553938036, 'train_confusion_matrix': [[4344, 1014], [1249, 4109]], 'train_recall': 0.7668906308324002, 'train_precision': 0.8020691001366387, 'train_f1_score': 0.7840854880259517, 'train_roc_auc': 0.7888204553938036}
# {'validation_accuracy': 0.717941507311586, 'validation_balanced_accuracy': 0.717941507311586, 'validation_confusion_matrix': [[1395, 383], [620, 1158]], 'validation_recall': 0.6512935883014623, 'validation_precision': 0.7514600908500974, 'validation_f1_score': 0.6978005423320277, 'validation_roc_auc': 0.717941507311586}
# {'test_accuracy': 0.7457627118644068, 'test_balanced_accuracy': 0.7219871688512804, 'test_confusion_matrix': [[1573, 436], [299, 583]], 'test_recall': 0.6609977324263039, 'test_precision': 0.5721295387634936, 'test_f1_score': 0.613361388742767, 'test_roc_auc': 0.7219871688512803}
# --- saving metrics to data_tcab\detection-experiments\allocine\distilcamembert\default\clean_vs_all\LR\bert+tp
#
# ### Running main with ['--experiment_dir', 'data_tcab/detection-experiments/allocine/distilcamembert/default/clean_vs_all', '--feature_setting', 'bert+tp', '--model', 'RF', '--model_n_jobs', '10', '--disable_tune']
#
# starting experiment: data_tcab\detection-experiments\allocine\distilcamembert\default\clean_vs_all
# CPU available : 16
# --- searching exp data in data_tcab\detection-experiments\allocine\distilcamembert\default\clean_vs_all
# --- using these features:
# ['tp_avg_word_length', 'tp_bert', 'tp_is_first_word_lowercase', 'tp_num_alpha_chars', 'tp_num_cased_letters', 'tp_num_cased_word_switches', 'tp_num_chars', 'tp_num_digits', 'tp_num_lowercase_after_punctuation', 'tp_num_mixed_case_words', 'tp_num_multi_spaces', 'tp_num_non_ascii', 'tp_num_punctuation', 'tp_num_single_lowercase_letters', 'tp_num_words']
# --- output to data_tcab\detection-experiments\allocine\distilcamembert\default\clean_vs_all\RF\bert+tp
# --- loading from data_tcab\detection-experiments\allocine\distilcamembert\default\clean_vs_all\train.joblib
# num of instances in the file:  10716
# loaded, labels:  Counter({'perturbed': 5358, 'clean': 5358})
# --- loading from data_tcab\detection-experiments\allocine\distilcamembert\default\clean_vs_all\val.joblib
# num of instances in the file:  3556
# loaded, labels:  Counter({'perturbed': 1778, 'clean': 1778})
# --- loading from data_tcab\detection-experiments\allocine\distilcamembert\default\clean_vs_all\test_release.joblib
# num of instances in the file:  2891
# loaded, labels:  Counter({'clean': 2009, 'perturbed': 882})
# --- training main starting
# skip if done: False
#
# no. train: 10,716
# no. val: 3,556
# no. test: 2,891
# no. features: 804
#
# --- starting training
# --- finished training
# --- training time: 00:00:02
# {'train_accuracy': 0.7354423292273237, 'train_balanced_accuracy': 0.7354423292273237, 'train_confusion_matrix': [[4357, 1001], [1834, 3524]], 'train_recall': 0.6577081000373274, 'train_precision': 0.7787845303867403, 'train_f1_score': 0.7131437822523525, 'train_roc_auc': 0.7354423292273236}
# {'validation_accuracy': 0.6732283464566929, 'validation_balanced_accuracy': 0.6732283464566929, 'validation_confusion_matrix': [[1400, 378], [784, 994]], 'validation_recall': 0.5590551181102362, 'validation_precision': 0.7244897959183674, 'validation_f1_score': 0.6311111111111112, 'validation_roc_auc': 0.6732283464566928}
# {'test_accuracy': 0.712902109996541, 'test_balanced_accuracy': 0.6767186549416515, 'test_confusion_matrix': [[1546, 463], [367, 515]], 'test_recall': 0.5839002267573696, 'test_precision': 0.5265848670756647, 'test_f1_score': 0.553763440860215, 'test_roc_auc': 0.6767186549416514}
# --- saving metrics to data_tcab\detection-experiments\allocine\distilcamembert\default\clean_vs_all\RF\bert+tp
#
# ### Running main with ['--experiment_dir', 'data_tcab/detection-experiments/allocine/distilcamembert/default/clean_vs_all', '--feature_setting', 'bert+tp', '--model', 'LGB', '--model_n_jobs', '10', '--disable_tune']
#
# starting experiment: data_tcab\detection-experiments\allocine\distilcamembert\default\clean_vs_all
# CPU available : 16
# --- searching exp data in data_tcab\detection-experiments\allocine\distilcamembert\default\clean_vs_all
# --- using these features:
# ['tp_avg_word_length', 'tp_bert', 'tp_is_first_word_lowercase', 'tp_num_alpha_chars', 'tp_num_cased_letters', 'tp_num_cased_word_switches', 'tp_num_chars', 'tp_num_digits', 'tp_num_lowercase_after_punctuation', 'tp_num_mixed_case_words', 'tp_num_multi_spaces', 'tp_num_non_ascii', 'tp_num_punctuation', 'tp_num_single_lowercase_letters', 'tp_num_words']
# --- output to data_tcab\detection-experiments\allocine\distilcamembert\default\clean_vs_all\LGB\bert+tp
# --- loading from data_tcab\detection-experiments\allocine\distilcamembert\default\clean_vs_all\train.joblib
# num of instances in the file:  10716
# loaded, labels:  Counter({'perturbed': 5358, 'clean': 5358})
# --- loading from data_tcab\detection-experiments\allocine\distilcamembert\default\clean_vs_all\val.joblib
# num of instances in the file:  3556
# loaded, labels:  Counter({'perturbed': 1778, 'clean': 1778})
# --- loading from data_tcab\detection-experiments\allocine\distilcamembert\default\clean_vs_all\test_release.joblib
# num of instances in the file:  2891
# loaded, labels:  Counter({'clean': 2009, 'perturbed': 882})
# --- training main starting
# skip if done: False
#
# no. train: 10,716
# no. val: 3,556
# no. test: 2,891
# no. features: 804
#
# --- starting training
# --- finished training
# --- training time: 00:00:02
# {'train_accuracy': 0.9106942889137738, 'train_balanced_accuracy': 0.9106942889137738, 'train_confusion_matrix': [[4976, 382], [575, 4783]], 'train_recall': 0.8926838372527063, 'train_precision': 0.9260406582768635, 'train_f1_score': 0.9090563527511166, 'train_roc_auc': 0.9106942889137738}
# {'validation_accuracy': 0.7263779527559056, 'validation_balanced_accuracy': 0.7263779527559056, 'validation_confusion_matrix': [[1527, 251], [722, 1056]], 'validation_recall': 0.59392575928009, 'validation_precision': 0.8079571537872992, 'validation_f1_score': 0.6846029173419773, 'validation_roc_auc': 0.7263779527559054}
# {'test_accuracy': 0.7592528536838464, 'test_balanced_accuracy': 0.7154748078093025, 'test_confusion_matrix': [[1663, 346], [350, 532]], 'test_recall': 0.6031746031746031, 'test_precision': 0.6059225512528473, 'test_f1_score': 0.6045454545454545, 'test_roc_auc': 0.7154748078093026}
# --- saving metrics to data_tcab\detection-experiments\allocine\distilcamembert\default\clean_vs_all\LGB\bert+tp
#
# ### Running main with ['--experiment_dir', 'data_tcab/detection-experiments/allocine/distilcamembert/default/clean_vs_all', '--feature_setting', 'bert+tp+lm', '--model', 'LR', '--model_n_jobs', '10', '--disable_tune']
#
# starting experiment: data_tcab\detection-experiments\allocine\distilcamembert\default\clean_vs_all
# CPU available : 16
# --- searching exp data in data_tcab\detection-experiments\allocine\distilcamembert\default\clean_vs_all
# --- using these features:
# ['lm_perplexity', 'lm_proba_and_rank', 'tp_avg_word_length', 'tp_bert', 'tp_is_first_word_lowercase', 'tp_num_alpha_chars', 'tp_num_cased_letters', 'tp_num_cased_word_switches', 'tp_num_chars', 'tp_num_digits', 'tp_num_lowercase_after_punctuation', 'tp_num_mixed_case_words', 'tp_num_multi_spaces', 'tp_num_non_ascii', 'tp_num_punctuation', 'tp_num_single_lowercase_letters', 'tp_num_words']
# --- output to data_tcab\detection-experiments\allocine\distilcamembert\default\clean_vs_all\LR\bert+tp+lm
# --- loading from data_tcab\detection-experiments\allocine\distilcamembert\default\clean_vs_all\train.joblib
# num of instances in the file:  10716
# loaded, labels:  Counter({'perturbed': 5358, 'clean': 5358})
# --- loading from data_tcab\detection-experiments\allocine\distilcamembert\default\clean_vs_all\val.joblib
# num of instances in the file:  3556
# loaded, labels:  Counter({'perturbed': 1778, 'clean': 1778})
# --- loading from data_tcab\detection-experiments\allocine\distilcamembert\default\clean_vs_all\test_release.joblib
# num of instances in the file:  2891
# loaded, labels:  Counter({'clean': 2009, 'perturbed': 882})
# --- training main starting
# skip if done: False
#
# no. train: 10,716
# no. val: 3,556
# no. test: 2,891
# no. features: 848
#
# --- starting training
# --- finished training
# --- training time: 00:00:02
# {'train_accuracy': 0.8287607316162747, 'train_balanced_accuracy': 0.8287607316162747, 'train_confusion_matrix': [[4554, 804], [1031, 4327]], 'train_recall': 0.8075774542739829, 'train_precision': 0.843305398557786, 'train_f1_score': 0.8250548193345408, 'train_roc_auc': 0.8287607316162747}
# {'validation_accuracy': 0.7589988751406074, 'validation_balanced_accuracy': 0.7589988751406074, 'validation_confusion_matrix': [[1478, 300], [557, 1221]], 'validation_recall': 0.686726659167604, 'validation_precision': 0.8027613412228797, 'validation_f1_score': 0.7402243103970899, 'validation_roc_auc': 0.7589988751406074}
# {'test_accuracy': 0.7737806987201661, 'test_balanced_accuracy': 0.7478706929926442, 'test_confusion_matrix': [[1636, 373], [281, 601]], 'test_recall': 0.68140589569161, 'test_precision': 0.6170431211498973, 'test_f1_score': 0.6476293103448276, 'test_roc_auc': 0.7478706929926443}
# --- saving metrics to data_tcab\detection-experiments\allocine\distilcamembert\default\clean_vs_all\LR\bert+tp+lm
#
# ### Running main with ['--experiment_dir', 'data_tcab/detection-experiments/allocine/distilcamembert/default/clean_vs_all', '--feature_setting', 'bert+tp+lm', '--model', 'RF', '--model_n_jobs', '10', '--disable_tune']
#
# starting experiment: data_tcab\detection-experiments\allocine\distilcamembert\default\clean_vs_all
# CPU available : 16
# --- searching exp data in data_tcab\detection-experiments\allocine\distilcamembert\default\clean_vs_all
# --- using these features:
# ['lm_perplexity', 'lm_proba_and_rank', 'tp_avg_word_length', 'tp_bert', 'tp_is_first_word_lowercase', 'tp_num_alpha_chars', 'tp_num_cased_letters', 'tp_num_cased_word_switches', 'tp_num_chars', 'tp_num_digits', 'tp_num_lowercase_after_punctuation', 'tp_num_mixed_case_words', 'tp_num_multi_spaces', 'tp_num_non_ascii', 'tp_num_punctuation', 'tp_num_single_lowercase_letters', 'tp_num_words']
# --- output to data_tcab\detection-experiments\allocine\distilcamembert\default\clean_vs_all\RF\bert+tp+lm
# --- loading from data_tcab\detection-experiments\allocine\distilcamembert\default\clean_vs_all\train.joblib
# num of instances in the file:  10716
# loaded, labels:  Counter({'perturbed': 5358, 'clean': 5358})
# --- loading from data_tcab\detection-experiments\allocine\distilcamembert\default\clean_vs_all\val.joblib
# num of instances in the file:  3556
# loaded, labels:  Counter({'perturbed': 1778, 'clean': 1778})
# --- loading from data_tcab\detection-experiments\allocine\distilcamembert\default\clean_vs_all\test_release.joblib
# num of instances in the file:  2891
# loaded, labels:  Counter({'clean': 2009, 'perturbed': 882})
# --- training main starting
# skip if done: False
#
# no. train: 10,716
# no. val: 3,556
# no. test: 2,891
# no. features: 848
#
# --- starting training
# --- finished training
# --- training time: 00:00:02
# {'train_accuracy': 0.7850877192982456, 'train_balanced_accuracy': 0.7850877192982456, 'train_confusion_matrix': [[4438, 920], [1383, 3975]], 'train_recall': 0.7418812989921613, 'train_precision': 0.8120531154239019, 'train_f1_score': 0.7753828147859163, 'train_roc_auc': 0.7850877192982456}
# {'validation_accuracy': 0.7679977502812149, 'validation_balanced_accuracy': 0.7679977502812149, 'validation_confusion_matrix': [[1460, 318], [507, 1271]], 'validation_recall': 0.7148481439820022, 'validation_precision': 0.7998741346758967, 'validation_f1_score': 0.7549747549747551, 'validation_roc_auc': 0.7679977502812149}
# {'test_accuracy': 0.7938429609131789, 'test_balanced_accuracy': 0.7740722305182235, 'test_confusion_matrix': [[1657, 352], [244, 638]], 'test_recall': 0.7233560090702947, 'test_precision': 0.6444444444444445, 'test_f1_score': 0.6816239316239316, 'test_roc_auc': 0.7740722305182235}
# --- saving metrics to data_tcab\detection-experiments\allocine\distilcamembert\default\clean_vs_all\RF\bert+tp+lm
#
# ### Running main with ['--experiment_dir', 'data_tcab/detection-experiments/allocine/distilcamembert/default/clean_vs_all', '--feature_setting', 'bert+tp+lm', '--model', 'LGB', '--model_n_jobs', '10', '--disable_tune']
#
# starting experiment: data_tcab\detection-experiments\allocine\distilcamembert\default\clean_vs_all
# CPU available : 16
# --- searching exp data in data_tcab\detection-experiments\allocine\distilcamembert\default\clean_vs_all
# --- using these features:
# ['lm_perplexity', 'lm_proba_and_rank', 'tp_avg_word_length', 'tp_bert', 'tp_is_first_word_lowercase', 'tp_num_alpha_chars', 'tp_num_cased_letters', 'tp_num_cased_word_switches', 'tp_num_chars', 'tp_num_digits', 'tp_num_lowercase_after_punctuation', 'tp_num_mixed_case_words', 'tp_num_multi_spaces', 'tp_num_non_ascii', 'tp_num_punctuation', 'tp_num_single_lowercase_letters', 'tp_num_words']
# --- output to data_tcab\detection-experiments\allocine\distilcamembert\default\clean_vs_all\LGB\bert+tp+lm
# --- loading from data_tcab\detection-experiments\allocine\distilcamembert\default\clean_vs_all\train.joblib
# num of instances in the file:  10716
# loaded, labels:  Counter({'perturbed': 5358, 'clean': 5358})
# --- loading from data_tcab\detection-experiments\allocine\distilcamembert\default\clean_vs_all\val.joblib
# num of instances in the file:  3556
# loaded, labels:  Counter({'perturbed': 1778, 'clean': 1778})
# --- loading from data_tcab\detection-experiments\allocine\distilcamembert\default\clean_vs_all\test_release.joblib
# num of instances in the file:  2891
# loaded, labels:  Counter({'clean': 2009, 'perturbed': 882})
# --- training main starting
# skip if done: False
#
# no. train: 10,716
# no. val: 3,556
# no. test: 2,891
# no. features: 848
#
# --- starting training
# --- finished training
# --- training time: 00:00:02
# {'train_accuracy': 0.9365434863755132, 'train_balanced_accuracy': 0.9365434863755133, 'train_confusion_matrix': [[5132, 226], [454, 4904]], 'train_recall': 0.9152668906308324, 'train_precision': 0.9559454191033139, 'train_f1_score': 0.9351639969488941, 'train_roc_auc': 0.9365434863755133}
# {'validation_accuracy': 0.7896512935883014, 'validation_balanced_accuracy': 0.7896512935883016, 'validation_confusion_matrix': [[1559, 219], [529, 1249]], 'validation_recall': 0.7024746906636671, 'validation_precision': 0.8508174386920981, 'validation_f1_score': 0.7695625385089342, 'validation_roc_auc': 0.7896512935883016}
# {'test_accuracy': 0.8201314424074715, 'test_balanced_accuracy': 0.7904430064708811, 'test_confusion_matrix': [[1741, 268], [252, 630]], 'test_recall': 0.7142857142857143, 'test_precision': 0.7015590200445434, 'test_f1_score': 0.7078651685393258, 'test_roc_auc': 0.7904430064708811}
# --- saving metrics to data_tcab\detection-experiments\allocine\distilcamembert\default\clean_vs_all\LGB\bert+tp+lm
#
# ### Running main with ['--experiment_dir', 'data_tcab/detection-experiments/allocine/distilcamembert/default/clean_vs_all', '--feature_setting', 'all', '--model', 'LR', '--model_n_jobs', '10', '--disable_tune']
#
# starting experiment: data_tcab\detection-experiments\allocine\distilcamembert\default\clean_vs_all
# CPU available : 16
# --- searching exp data in data_tcab\detection-experiments\allocine\distilcamembert\default\clean_vs_all
# --- using these features:
# ['lm_perplexity', 'lm_proba_and_rank', 'tm_activation', 'tm_gradient', 'tm_posterior', 'tm_saliency', 'tp_avg_word_length', 'tp_bert', 'tp_is_first_word_lowercase', 'tp_num_alpha_chars', 'tp_num_cased_letters', 'tp_num_cased_word_switches', 'tp_num_chars', 'tp_num_digits', 'tp_num_lowercase_after_punctuation', 'tp_num_mixed_case_words', 'tp_num_multi_spaces', 'tp_num_non_ascii', 'tp_num_punctuation', 'tp_num_single_lowercase_letters', 'tp_num_words']
# --- output to data_tcab\detection-experiments\allocine\distilcamembert\default\clean_vs_all\LR\all
# c:\Users\Baptiste\AppData\Local\pypoetry\Cache\virtualenvs\nlp-adversarial-attacks-ghBt6cj_-py3.10\lib\site-packages\torch\nn\modules\module.py:1117: UserWarning: Using a non-full backward hook when the forward contains multiple autograd Nodes is deprecated and will be removed in future versions. This hook will be missing some grad_input. Please use register_full_backward_hook to get the documented behavior.
#   warnings.warn("Using a non-full backward hook when the forward contains multiple autograd Nodes "
# --- loading from data_tcab\detection-experiments\allocine\distilcamembert\default\clean_vs_all\train.joblib
# num of instances in the file:  10716
# loaded, labels:  Counter({'perturbed': 5358, 'clean': 5358})
# --- loading from data_tcab\detection-experiments\allocine\distilcamembert\default\clean_vs_all\val.joblib
# num of instances in the file:  3556
# loaded, labels:  Counter({'perturbed': 1778, 'clean': 1778})
# --- loading from data_tcab\detection-experiments\allocine\distilcamembert\default\clean_vs_all\test_release.joblib
# num of instances in the file:  2891
# loaded, labels:  Counter({'clean': 2009, 'perturbed': 882})
# --- training main starting
# skip if done: False
#
# no. train: 10,716
# no. val: 3,556
# no. test: 2,891
# no. features: 4,539
#
# --- starting training
# --- finished training
# --- training time: 00:00:10
# {'train_accuracy': 0.9997200447928332, 'train_balanced_accuracy': 0.9997200447928332, 'train_confusion_matrix': [[5356, 2], [1, 5357]], 'train_recall': 0.9998133631952221, 'train_precision': 0.999626796044038, 'train_f1_score': 0.9997200709153681, 'train_roc_auc': 0.999720044792833}
# {'validation_accuracy': 0.9465691788526435, 'validation_balanced_accuracy': 0.9465691788526435, 'validation_confusion_matrix': [[1709, 69], [121, 1657]], 'validation_recall': 0.9319460067491564, 'validation_precision': 0.9600231749710313, 'validation_f1_score': 0.9457762557077626, 'validation_roc_auc': 0.9465691788526432}
# {'test_accuracy': 0.9546869595295745, 'test_balanced_accuracy': 0.9511780321884852, 'test_confusion_matrix': [[1929, 80], [51, 831]], 'test_recall': 0.9421768707482994, 'test_precision': 0.9121844127332601, 'test_f1_score': 0.9269380925822643, 'test_roc_auc': 0.9511780321884852}
# --- saving metrics to data_tcab\detection-experiments\allocine\distilcamembert\default\clean_vs_all\LR\all
#
# ### Running main with ['--experiment_dir', 'data_tcab/detection-experiments/allocine/distilcamembert/default/clean_vs_all', '--feature_setting', 'all', '--model', 'RF', '--model_n_jobs', '10', '--disable_tune']
#
# starting experiment: data_tcab\detection-experiments\allocine\distilcamembert\default\clean_vs_all
# CPU available : 16
# --- searching exp data in data_tcab\detection-experiments\allocine\distilcamembert\default\clean_vs_all
# --- using these features:
# ['lm_perplexity', 'lm_proba_and_rank', 'tm_activation', 'tm_gradient', 'tm_posterior', 'tm_saliency', 'tp_avg_word_length', 'tp_bert', 'tp_is_first_word_lowercase', 'tp_num_alpha_chars', 'tp_num_cased_letters', 'tp_num_cased_word_switches', 'tp_num_chars', 'tp_num_digits', 'tp_num_lowercase_after_punctuation', 'tp_num_mixed_case_words', 'tp_num_multi_spaces', 'tp_num_non_ascii', 'tp_num_punctuation', 'tp_num_single_lowercase_letters', 'tp_num_words']
# --- output to data_tcab\detection-experiments\allocine\distilcamembert\default\clean_vs_all\RF\all
# c:\Users\Baptiste\AppData\Local\pypoetry\Cache\virtualenvs\nlp-adversarial-attacks-ghBt6cj_-py3.10\lib\site-packages\torch\nn\modules\module.py:1117: UserWarning: Using a non-full backward hook when the forward contains multiple autograd Nodes is deprecated and will be removed in future versions. This hook will be missing some grad_input. Please use register_full_backward_hook to get the documented behavior.
#   warnings.warn("Using a non-full backward hook when the forward contains multiple autograd Nodes "
# --- loading from data_tcab\detection-experiments\allocine\distilcamembert\default\clean_vs_all\train.joblib
# num of instances in the file:  10716
# loaded, labels:  Counter({'perturbed': 5358, 'clean': 5358})
# --- loading from data_tcab\detection-experiments\allocine\distilcamembert\default\clean_vs_all\val.joblib
# num of instances in the file:  3556
# loaded, labels:  Counter({'perturbed': 1778, 'clean': 1778})
# --- loading from data_tcab\detection-experiments\allocine\distilcamembert\default\clean_vs_all\test_release.joblib
# num of instances in the file:  2891
# loaded, labels:  Counter({'clean': 2009, 'perturbed': 882})
# --- training main starting
# skip if done: False
#
# no. train: 10,716
# no. val: 3,556
# no. test: 2,891
# no. features: 4,539
#
# --- starting training
# --- finished training
# --- training time: 00:00:05
# {'train_accuracy': 0.9594064949608063, 'train_balanced_accuracy': 0.9594064949608063, 'train_confusion_matrix': [[5058, 300], [135, 5223]], 'train_recall': 0.9748040313549832, 'train_precision': 0.9456816947311244, 'train_f1_score': 0.9600220567962504, 'train_roc_auc': 0.9594064949608063}
# {'validation_accuracy': 0.9550056242969629, 'validation_balanced_accuracy': 0.9550056242969629, 'validation_confusion_matrix': [[1666, 112], [48, 1730]], 'validation_recall': 0.9730033745781778, 'validation_precision': 0.9391965255157437, 'validation_f1_score': 0.9558011049723758, 'validation_roc_auc': 0.9550056242969629}
# {'test_accuracy': 0.9446558284330682, 'test_balanced_accuracy': 0.9493667385653448, 'test_confusion_matrix': [[1883, 126], [34, 848]], 'test_recall': 0.9614512471655329, 'test_precision': 0.8706365503080082, 'test_f1_score': 0.9137931034482759, 'test_roc_auc': 0.9493667385653448}
# --- saving metrics to data_tcab\detection-experiments\allocine\distilcamembert\default\clean_vs_all\RF\all
#
# ### Running main with ['--experiment_dir', 'data_tcab/detection-experiments/allocine/distilcamembert/default/clean_vs_all', '--feature_setting', 'all', '--model', 'LGB', '--model_n_jobs', '10', '--disable_tune']
#
# starting experiment: data_tcab\detection-experiments\allocine\distilcamembert\default\clean_vs_all
# CPU available : 16
# --- searching exp data in data_tcab\detection-experiments\allocine\distilcamembert\default\clean_vs_all
# --- using these features:
# ['lm_perplexity', 'lm_proba_and_rank', 'tm_activation', 'tm_gradient', 'tm_posterior', 'tm_saliency', 'tp_avg_word_length', 'tp_bert', 'tp_is_first_word_lowercase', 'tp_num_alpha_chars', 'tp_num_cased_letters', 'tp_num_cased_word_switches', 'tp_num_chars', 'tp_num_digits', 'tp_num_lowercase_after_punctuation', 'tp_num_mixed_case_words', 'tp_num_multi_spaces', 'tp_num_non_ascii', 'tp_num_punctuation', 'tp_num_single_lowercase_letters', 'tp_num_words']
# --- output to data_tcab\detection-experiments\allocine\distilcamembert\default\clean_vs_all\LGB\all
# c:\Users\Baptiste\AppData\Local\pypoetry\Cache\virtualenvs\nlp-adversarial-attacks-ghBt6cj_-py3.10\lib\site-packages\torch\nn\modules\module.py:1117: UserWarning: Using a non-full backward hook when the forward contains multiple autograd Nodes is deprecated and will be removed in future versions. This hook will be missing some grad_input. Please use register_full_backward_hook to get the documented behavior.
#   warnings.warn("Using a non-full backward hook when the forward contains multiple autograd Nodes "
# --- loading from data_tcab\detection-experiments\allocine\distilcamembert\default\clean_vs_all\train.joblib
# num of instances in the file:  10716
# loaded, labels:  Counter({'perturbed': 5358, 'clean': 5358})
# --- loading from data_tcab\detection-experiments\allocine\distilcamembert\default\clean_vs_all\val.joblib
# num of instances in the file:  3556
# loaded, labels:  Counter({'perturbed': 1778, 'clean': 1778})
# --- loading from data_tcab\detection-experiments\allocine\distilcamembert\default\clean_vs_all\test_release.joblib
# num of instances in the file:  2891
# loaded, labels:  Counter({'clean': 2009, 'perturbed': 882})
# --- training main starting
# skip if done: False
#
# no. train: 10,716
# no. val: 3,556
# no. test: 2,891
# no. features: 4,539
#
# --- starting training
# --- finished training
# --- training time: 00:00:15
# {'train_accuracy': 0.9997200447928332, 'train_balanced_accuracy': 0.9997200447928332, 'train_confusion_matrix': [[5356, 2], [1, 5357]], 'train_recall': 0.9998133631952221, 'train_precision': 0.999626796044038, 'train_f1_score': 0.9997200709153681, 'train_roc_auc': 0.999720044792833}
# {'validation_accuracy': 0.9617547806524185, 'validation_balanced_accuracy': 0.9617547806524185, 'validation_confusion_matrix': [[1695, 83], [53, 1725]], 'validation_recall': 0.9701912260967379, 'validation_precision': 0.9540929203539823, 'validation_f1_score': 0.9620747350808702, 'validation_roc_auc': 0.9617547806524185}
# {'test_accuracy': 0.9578000691802144, 'test_balanced_accuracy': 0.9613682871522593, 'test_confusion_matrix': [[1913, 96], [26, 856]], 'test_recall': 0.9705215419501134, 'test_precision': 0.8991596638655462, 'test_f1_score': 0.9334787350054528, 'test_roc_auc': 0.9613682871522593}
# --- saving metrics to data_tcab\detection-experiments\allocine\distilcamembert\default\clean_vs_all\LGB\all
#
# ### Running main with ['--experiment_dir', 'data_tcab/detection-experiments/allocine/distilcamembert/default/multiclass_with_clean', '--feature_setting', 'bert', '--model', 'LR', '--model_n_jobs', '10', '--disable_tune']
#
# starting experiment: data_tcab\detection-experiments\allocine\distilcamembert\default\multiclass_with_clean
# CPU available : 16
# --- searching exp data in data_tcab\detection-experiments\allocine\distilcamembert\default\multiclass_with_clean
# --- using these features:
# ['tp_bert']
# --- output to data_tcab\detection-experiments\allocine\distilcamembert\default\multiclass_with_clean\LR\bert
# --- loading from data_tcab\detection-experiments\allocine\distilcamembert\default\multiclass_with_clean\train.joblib
# num of instances in the file:  6545
# loaded, labels:  Counter({'clean': 1187, 'input_reduction': 1187, 'textbugger': 1004, 'textfooler': 987, 'deepwordbug': 976, 'bae': 751, 'pwws': 453})
# --- loading from data_tcab\detection-experiments\allocine\distilcamembert\default\multiclass_with_clean\val.joblib
# num of instances in the file:  2189
# loaded, labels:  Counter({'clean': 411, 'input_reduction': 411, 'textfooler': 336, 'deepwordbug': 334, 'textbugger': 328, 'bae': 228, 'pwws': 141})
# --- loading from data_tcab\detection-experiments\allocine\distilcamembert\default\multiclass_with_clean\test_release.joblib
# num of instances in the file:  2891
# loaded, labels:  Counter({'clean': 2009, 'input_reduction': 204, 'textbugger': 165, 'deepwordbug': 163, 'textfooler': 162, 'bae': 116, 'pwws': 72})
# --- training main starting
# skip if done: False
#
# no. train: 6,545
# no. val: 2,189
# no. test: 2,891
# no. features: 768
#
# --- starting training
# --- finished training
# --- training time: 00:00:02
# {'train_accuracy': 0.7045072574484339, 'train_balanced_accuracy': 0.712245616419813, 'train_confusion_matrix': [[476, 128, 35, 3, 39, 30, 40], [256, 596, 84, 17, 71, 45, 118], [73, 80, 697, 7, 29, 56, 34], [9, 9, 3, 1152, 4, 5, 5], [19, 16, 7, 1, 389, 5, 16], [71, 65, 81, 4, 35, 683, 65], [104, 109, 52, 5, 57, 42, 618]]}
# {'validation_accuracy': 0.5216994061215167, 'validation_balanced_accuracy': 0.4986044113010971, 'validation_confusion_matrix': [[72, 53, 22, 14, 18, 22, 27], [62, 141, 49, 35, 33, 29, 62], [24, 32, 186, 13, 17, 26, 36], [8, 12, 15, 353, 7, 8, 8], [19, 19, 5, 7, 59, 12, 20], [30, 43, 30, 5, 17, 166, 37], [27, 51, 32, 13, 27, 21, 165]]}
# {'test_accuracy': 0.4060878588723625, 'test_balanced_accuracy': 0.48865056109360644, 'test_confusion_matrix': [[32, 22, 13, 7, 16, 9, 17], [358, 697, 259, 117, 167, 137, 274], [11, 14, 84, 9, 13, 16, 16], [10, 5, 7, 169, 6, 2, 5], [3, 5, 6, 2, 36, 6, 14], [10, 18, 26, 3, 10, 80, 18], [12, 19, 17, 9, 18, 11, 76]]}
# --- saving metrics to data_tcab\detection-experiments\allocine\distilcamembert\default\multiclass_with_clean\LR\bert
#
# ### Running main with ['--experiment_dir', 'data_tcab/detection-experiments/allocine/distilcamembert/default/multiclass_with_clean', '--feature_setting', 'bert', '--model', 'RF', '--model_n_jobs', '10', '--disable_tune']
#
# starting experiment: data_tcab\detection-experiments\allocine\distilcamembert\default\multiclass_with_clean
# CPU available : 16
# --- searching exp data in data_tcab\detection-experiments\allocine\distilcamembert\default\multiclass_with_clean
# --- using these features:
# ['tp_bert']
# --- output to data_tcab\detection-experiments\allocine\distilcamembert\default\multiclass_with_clean\RF\bert
# --- loading from data_tcab\detection-experiments\allocine\distilcamembert\default\multiclass_with_clean\train.joblib
# num of instances in the file:  6545
# loaded, labels:  Counter({'clean': 1187, 'input_reduction': 1187, 'textbugger': 1004, 'textfooler': 987, 'deepwordbug': 976, 'bae': 751, 'pwws': 453})
# --- loading from data_tcab\detection-experiments\allocine\distilcamembert\default\multiclass_with_clean\val.joblib
# num of instances in the file:  2189
# loaded, labels:  Counter({'clean': 411, 'input_reduction': 411, 'textfooler': 336, 'deepwordbug': 334, 'textbugger': 328, 'bae': 228, 'pwws': 141})
# --- loading from data_tcab\detection-experiments\allocine\distilcamembert\default\multiclass_with_clean\test_release.joblib
# num of instances in the file:  2891
# loaded, labels:  Counter({'clean': 2009, 'input_reduction': 204, 'textbugger': 165, 'deepwordbug': 163, 'textfooler': 162, 'bae': 116, 'pwws': 72})
# --- training main starting
# skip if done: False
#
# no. train: 6,545
# no. val: 2,189
# no. test: 2,891
# no. features: 768
#
# --- starting training
# --- finished training
# --- training time: 00:00:01
# {'train_accuracy': 0.3912910618792972, 'train_balanced_accuracy': 0.41388547378533935, 'train_confusion_matrix': [[315, 35, 46, 108, 152, 51, 44], [295, 185, 84, 196, 220, 102, 105], [146, 65, 220, 189, 193, 87, 76], [17, 34, 24, 937, 79, 36, 60], [45, 14, 8, 32, 332, 15, 7], [136, 60, 73, 127, 219, 310, 79], [142, 64, 66, 137, 234, 82, 262]]}
# {'validation_accuracy': 0.3005938784833257, 'validation_balanced_accuracy': 0.3077439240693884, 'validation_confusion_matrix': [[56, 32, 2, 43, 59, 8, 28], [90, 46, 25, 84, 87, 34, 45], [45, 28, 38, 98, 72, 25, 28], [7, 11, 19, 310, 29, 14, 21], [17, 7, 3, 12, 74, 11, 17], [48, 31, 18, 50, 80, 69, 32], [43, 25, 17, 57, 97, 32, 65]]}
# {'test_accuracy': 0.1909373919059149, 'test_balanced_accuracy': 0.3255759178952708, 'test_confusion_matrix': [[28, 13, 3, 18, 40, 8, 6], [479, 238, 117, 422, 441, 143, 169], [22, 8, 17, 40, 48, 15, 13], [1, 6, 7, 154, 20, 5, 11], [6, 4, 4, 8, 46, 1, 3], [21, 7, 8, 26, 48, 43, 12], [24, 11, 8, 24, 58, 11, 26]]}
# --- saving metrics to data_tcab\detection-experiments\allocine\distilcamembert\default\multiclass_with_clean\RF\bert
#
# ### Running main with ['--experiment_dir', 'data_tcab/detection-experiments/allocine/distilcamembert/default/multiclass_with_clean', '--feature_setting', 'bert', '--model', 'LGB', '--model_n_jobs', '10', '--disable_tune']
#
# starting experiment: data_tcab\detection-experiments\allocine\distilcamembert\default\multiclass_with_clean
# CPU available : 16
# --- searching exp data in data_tcab\detection-experiments\allocine\distilcamembert\default\multiclass_with_clean
# --- using these features:
# ['tp_bert']
# --- output to data_tcab\detection-experiments\allocine\distilcamembert\default\multiclass_with_clean\LGB\bert
# --- loading from data_tcab\detection-experiments\allocine\distilcamembert\default\multiclass_with_clean\train.joblib
# num of instances in the file:  6545
# loaded, labels:  Counter({'clean': 1187, 'input_reduction': 1187, 'textbugger': 1004, 'textfooler': 987, 'deepwordbug': 976, 'bae': 751, 'pwws': 453})
# --- loading from data_tcab\detection-experiments\allocine\distilcamembert\default\multiclass_with_clean\val.joblib
# num of instances in the file:  2189
# loaded, labels:  Counter({'clean': 411, 'input_reduction': 411, 'textfooler': 336, 'deepwordbug': 334, 'textbugger': 328, 'bae': 228, 'pwws': 141})
# --- loading from data_tcab\detection-experiments\allocine\distilcamembert\default\multiclass_with_clean\test_release.joblib
# num of instances in the file:  2891
# loaded, labels:  Counter({'clean': 2009, 'input_reduction': 204, 'textbugger': 165, 'deepwordbug': 163, 'textfooler': 162, 'bae': 116, 'pwws': 72})
# --- training main starting
# skip if done: False
#
# no. train: 6,545
# no. val: 2,189
# no. test: 2,891
# no. features: 768
#
# --- starting training
# --- finished training
# --- training time: 00:00:07
# {'train_accuracy': 0.9483575248281131, 'train_balanced_accuracy': 0.9531566614880704, 'train_confusion_matrix': [[730, 2, 0, 0, 17, 1, 1], [33, 1067, 14, 3, 38, 18, 14], [16, 4, 920, 0, 23, 12, 1], [0, 0, 0, 1186, 0, 0, 1], [0, 0, 0, 0, 453, 0, 0], [24, 6, 4, 0, 24, 933, 13], [21, 10, 2, 0, 19, 17, 918]]}
# {'validation_accuracy': 0.42348104157149385, 'validation_balanced_accuracy': 0.3849826633516171, 'validation_confusion_matrix': [[37, 88, 15, 36, 7, 12, 33], [50, 163, 42, 55, 12, 23, 66], [20, 71, 132, 36, 10, 24, 41], [5, 19, 12, 335, 7, 11, 22], [6, 32, 14, 8, 35, 13, 33], [22, 80, 41, 21, 5, 108, 51], [19, 91, 30, 37, 9, 33, 117]]}
# {'test_accuracy': 0.41265997924593567, 'test_balanced_accuracy': 0.38889464755768943, 'test_confusion_matrix': [[17, 42, 6, 12, 4, 13, 22], [247, 822, 189, 255, 74, 138, 284], [8, 32, 46, 22, 5, 19, 31], [6, 10, 6, 153, 5, 8, 16], [5, 12, 3, 6, 24, 8, 14], [7, 24, 12, 14, 7, 68, 33], [12, 28, 12, 17, 8, 22, 63]]}
# --- saving metrics to data_tcab\detection-experiments\allocine\distilcamembert\default\multiclass_with_clean\LGB\bert
#
# ### Running main with ['--experiment_dir', 'data_tcab/detection-experiments/allocine/distilcamembert/default/multiclass_with_clean', '--feature_setting', 'bert+tp', '--model', 'LR', '--model_n_jobs', '10', '--disable_tune']
#
# starting experiment: data_tcab\detection-experiments\allocine\distilcamembert\default\multiclass_with_clean
# CPU available : 16
# --- searching exp data in data_tcab\detection-experiments\allocine\distilcamembert\default\multiclass_with_clean
# --- using these features:
# ['tp_avg_word_length', 'tp_bert', 'tp_is_first_word_lowercase', 'tp_num_alpha_chars', 'tp_num_cased_letters', 'tp_num_cased_word_switches', 'tp_num_chars', 'tp_num_digits', 'tp_num_lowercase_after_punctuation', 'tp_num_mixed_case_words', 'tp_num_multi_spaces', 'tp_num_non_ascii', 'tp_num_punctuation', 'tp_num_single_lowercase_letters', 'tp_num_words']
# --- output to data_tcab\detection-experiments\allocine\distilcamembert\default\multiclass_with_clean\LR\bert+tp
# --- loading from data_tcab\detection-experiments\allocine\distilcamembert\default\multiclass_with_clean\train.joblib
# num of instances in the file:  6545
# loaded, labels:  Counter({'clean': 1187, 'input_reduction': 1187, 'textbugger': 1004, 'textfooler': 987, 'deepwordbug': 976, 'bae': 751, 'pwws': 453})
# --- loading from data_tcab\detection-experiments\allocine\distilcamembert\default\multiclass_with_clean\val.joblib
# num of instances in the file:  2189
# loaded, labels:  Counter({'clean': 411, 'input_reduction': 411, 'textfooler': 336, 'deepwordbug': 334, 'textbugger': 328, 'bae': 228, 'pwws': 141})
# --- loading from data_tcab\detection-experiments\allocine\distilcamembert\default\multiclass_with_clean\test_release.joblib
# num of instances in the file:  2891
# loaded, labels:  Counter({'clean': 2009, 'input_reduction': 204, 'textbugger': 165, 'deepwordbug': 163, 'textfooler': 162, 'bae': 116, 'pwws': 72})
# --- training main starting
# skip if done: False
#
# no. train: 6,545
# no. val: 2,189
# no. test: 2,891
# no. features: 804
#
# --- starting training
# --- finished training
# --- training time: 00:00:02
# {'train_accuracy': 0.773414820473644, 'train_balanced_accuracy': 0.7840886942056523, 'train_confusion_matrix': [[553, 103, 19, 0, 18, 27, 31], [207, 697, 50, 5, 42, 65, 121], [42, 68, 791, 0, 13, 34, 28], [2, 5, 1, 1178, 0, 0, 1], [4, 10, 4, 0, 425, 2, 8], [54, 80, 46, 0, 26, 738, 60], [77, 130, 21, 1, 34, 44, 680]]}
# {'validation_accuracy': 0.5783462768387392, 'validation_balanced_accuracy': 0.5627996164661198, 'validation_confusion_matrix': [[83, 41, 12, 17, 23, 25, 27], [65, 163, 30, 17, 33, 45, 58], [19, 28, 224, 10, 11, 21, 21], [13, 6, 4, 373, 7, 3, 5], [15, 14, 6, 6, 80, 7, 13], [25, 47, 26, 5, 14, 173, 38], [33, 57, 21, 5, 17, 33, 170]]}
# {'test_accuracy': 0.4469041854029748, 'test_balanced_accuracy': 0.5477384451076189, 'test_confusion_matrix': [[38, 23, 11, 7, 10, 9, 18], [344, 760, 200, 79, 165, 179, 282], [11, 15, 99, 3, 10, 13, 12], [8, 1, 2, 188, 2, 1, 2], [4, 8, 5, 1, 43, 5, 6], [10, 20, 13, 4, 9, 91, 18], [15, 28, 12, 7, 13, 14, 73]]}
# --- saving metrics to data_tcab\detection-experiments\allocine\distilcamembert\default\multiclass_with_clean\LR\bert+tp
#
# ### Running main with ['--experiment_dir', 'data_tcab/detection-experiments/allocine/distilcamembert/default/multiclass_with_clean', '--feature_setting', 'bert+tp', '--model', 'RF', '--model_n_jobs', '10', '--disable_tune']
#
# starting experiment: data_tcab\detection-experiments\allocine\distilcamembert\default\multiclass_with_clean
# CPU available : 16
# --- searching exp data in data_tcab\detection-experiments\allocine\distilcamembert\default\multiclass_with_clean
# --- using these features:
# ['tp_avg_word_length', 'tp_bert', 'tp_is_first_word_lowercase', 'tp_num_alpha_chars', 'tp_num_cased_letters', 'tp_num_cased_word_switches', 'tp_num_chars', 'tp_num_digits', 'tp_num_lowercase_after_punctuation', 'tp_num_mixed_case_words', 'tp_num_multi_spaces', 'tp_num_non_ascii', 'tp_num_punctuation', 'tp_num_single_lowercase_letters', 'tp_num_words']
# --- output to data_tcab\detection-experiments\allocine\distilcamembert\default\multiclass_with_clean\RF\bert+tp
# --- loading from data_tcab\detection-experiments\allocine\distilcamembert\default\multiclass_with_clean\train.joblib
# num of instances in the file:  6545
# loaded, labels:  Counter({'clean': 1187, 'input_reduction': 1187, 'textbugger': 1004, 'textfooler': 987, 'deepwordbug': 976, 'bae': 751, 'pwws': 453})
# --- loading from data_tcab\detection-experiments\allocine\distilcamembert\default\multiclass_with_clean\val.joblib
# num of instances in the file:  2189
# loaded, labels:  Counter({'clean': 411, 'input_reduction': 411, 'textfooler': 336, 'deepwordbug': 334, 'textbugger': 328, 'bae': 228, 'pwws': 141})
# --- loading from data_tcab\detection-experiments\allocine\distilcamembert\default\multiclass_with_clean\test_release.joblib
# num of instances in the file:  2891
# loaded, labels:  Counter({'clean': 2009, 'input_reduction': 204, 'textbugger': 165, 'deepwordbug': 163, 'textfooler': 162, 'bae': 116, 'pwws': 72})
# --- training main starting
# skip if done: False
#
# no. train: 6,545
# no. val: 2,189
# no. test: 2,891
# no. features: 804
#
# --- starting training
# --- finished training
# --- training time: 00:00:01
# {'train_accuracy': 0.49931245225362875, 'train_balanced_accuracy': 0.5055202730125951, 'train_confusion_matrix': [[267, 96, 68, 119, 98, 46, 57], [131, 322, 106, 165, 173, 124, 166], [51, 69, 563, 122, 80, 49, 42], [17, 2, 8, 1120, 26, 4, 10], [18, 28, 14, 36, 325, 15, 17], [74, 100, 105, 113, 158, 340, 114], [73, 110, 85, 126, 174, 88, 331]]}
# ...
# --- loading from data_tcab\detection-experiments\allocine\distilcamembert\fr+small\multiclass_with_clean\test_release.joblib
# num of instances in the file:  2891
# loaded, labels:  Counter({'clean': 2009, 'input_reduction': 204, 'textbugger': 165, 'deepwordbug': 163, 'textfooler': 162, 'bae': 116, 'pwws': 72})
# --- training main starting
# skip if done: False
#
# no. train: 6,545
# no. val: 2,189
# no. test: 2,891
# no. features: 848
#
# --- starting training
# --- finished training
# --- training time: 00:00:01
# {'train_accuracy': 0.5859434682964094, 'train_balanced_accuracy': 0.5590313775440318, 'train_confusion_matrix': [[311, 198, 30, 91, 56, 43, 22], [63, 984, 29, 43, 28, 29, 11], [47, 153, 549, 69, 42, 96, 20], [1, 0, 3, 1178, 2, 3, 0], [40, 72, 13, 47, 250, 26, 5], [68, 247, 95, 78, 60, 413, 43], [84, 229, 68, 173, 89, 194, 150]]}
# {'validation_accuracy': 0.540886249428963, 'validation_balanced_accuracy': 0.4967261923810252, 'validation_confusion_matrix': [[69, 73, 7, 35, 21, 19, 4], [26, 329, 6, 23, 10, 12, 5], [10, 63, 179, 44, 16, 21, 1], [0, 0, 2, 404, 3, 2, 0], [14, 30, 3, 14, 59, 17, 4], [21, 96, 18, 27, 39, 111, 16], [30, 80, 20, 70, 34, 69, 33]]}
# {'test_accuracy': 0.6994119681771014, 'test_balanced_accuracy': 0.45900723720021647, 'test_confusion_matrix': [[27, 40, 14, 14, 8, 8, 5], [104, 1628, 52, 92, 45, 66, 22], [5, 29, 80, 19, 3, 22, 5], [0, 0, 2, 202, 0, 0, 0], [8, 12, 9, 10, 22, 10, 1], [13, 42, 20, 15, 16, 49, 10], [12, 43, 17, 36, 10, 30, 14]]}
# --- saving metrics to data_tcab\detection-experiments\allocine\distilcamembert\fr+small\multiclass_with_clean\RF\bert+tp+lm
#
# ### Running main with ['--experiment_dir', 'data_tcab/detection-experiments/allocine/distilcamembert/fr+small/multiclass_with_clean', '--feature_setting', 'bert+tp+lm', '--model', 'LGB', '--model_n_jobs', '10', '--disable_tune']
#
# starting experiment: data_tcab\detection-experiments\allocine\distilcamembert\fr+small\multiclass_with_clean
# CPU available : 16
# --- searching exp data in data_tcab\detection-experiments\allocine\distilcamembert\fr+small\multiclass_with_clean
# --- using these features:
# ['lm_perplexity', 'lm_proba_and_rank', 'tp_avg_word_length', 'tp_bert', 'tp_is_first_word_lowercase', 'tp_num_alpha_chars', 'tp_num_cased_letters', 'tp_num_cased_word_switches', 'tp_num_chars', 'tp_num_digits', 'tp_num_lowercase_after_punctuation', 'tp_num_mixed_case_words', 'tp_num_multi_spaces', 'tp_num_non_ascii', 'tp_num_punctuation', 'tp_num_single_lowercase_letters', 'tp_num_words']
# --- output to data_tcab\detection-experiments\allocine\distilcamembert\fr+small\multiclass_with_clean\LGB\bert+tp+lm
# --- loading from data_tcab\detection-experiments\allocine\distilcamembert\fr+small\multiclass_with_clean\train.joblib
# num of instances in the file:  6545
# loaded, labels:  Counter({'clean': 1187, 'input_reduction': 1187, 'textbugger': 1004, 'textfooler': 987, 'deepwordbug': 976, 'bae': 751, 'pwws': 453})
# --- loading from data_tcab\detection-experiments\allocine\distilcamembert\fr+small\multiclass_with_clean\val.joblib
# num of instances in the file:  2189
# loaded, labels:  Counter({'clean': 411, 'input_reduction': 411, 'textfooler': 336, 'deepwordbug': 334, 'textbugger': 328, 'bae': 228, 'pwws': 141})
# --- loading from data_tcab\detection-experiments\allocine\distilcamembert\fr+small\multiclass_with_clean\test_release.joblib
# num of instances in the file:  2891
# loaded, labels:  Counter({'clean': 2009, 'input_reduction': 204, 'textbugger': 165, 'deepwordbug': 163, 'textfooler': 162, 'bae': 116, 'pwws': 72})
# --- training main starting
# skip if done: False
#
# no. train: 6,545
# no. val: 2,189
# no. test: 2,891
# no. features: 848
#
# --- starting training
# --- finished training
# --- training time: 00:00:08
# {'train_accuracy': 0.9915966386554622, 'train_balanced_accuracy': 0.9921874750976711, 'train_confusion_matrix': [[751, 0, 0, 0, 0, 0, 0], [1, 1183, 0, 2, 1, 0, 0], [1, 0, 965, 0, 4, 5, 1], [0, 1, 0, 1186, 0, 0, 0], [0, 0, 0, 0, 453, 0, 0], [2, 1, 2, 0, 4, 986, 9], [4, 2, 0, 0, 2, 13, 966]]}
# {'validation_accuracy': 0.665600730927364, 'validation_balanced_accuracy': 0.6193628065377214, 'validation_confusion_matrix': [[107, 46, 10, 13, 8, 18, 26], [27, 326, 16, 1, 3, 20, 18], [14, 24, 232, 4, 7, 40, 13], [1, 2, 2, 401, 2, 1, 2], [19, 17, 7, 1, 55, 20, 22], [26, 52, 22, 3, 12, 175, 38], [34, 46, 22, 9, 13, 51, 161]]}
# {'test_accuracy': 0.7350397786233137, 'test_balanced_accuracy': 0.5942940544092928, 'test_confusion_matrix': [[45, 30, 10, 4, 4, 7, 16], [141, 1586, 89, 14, 30, 79, 70], [8, 17, 110, 3, 1, 15, 9], [1, 0, 1, 200, 0, 0, 2], [10, 7, 8, 1, 26, 10, 10], [14, 20, 19, 2, 6, 80, 24], [20, 24, 13, 4, 8, 15, 78]]}
# --- saving metrics to data_tcab\detection-experiments\allocine\distilcamembert\fr+small\multiclass_with_clean\LGB\bert+tp+lm
#
# ### Running main with ['--experiment_dir', 'data_tcab/detection-experiments/allocine/distilcamembert/fr+small/multiclass_with_clean', '--feature_setting', 'all', '--model', 'LR', '--model_n_jobs', '10', '--disable_tune']
#
# starting experiment: data_tcab\detection-experiments\allocine\distilcamembert\fr+small\multiclass_with_clean
# CPU available : 16
# --- searching exp data in data_tcab\detection-experiments\allocine\distilcamembert\fr+small\multiclass_with_clean
# --- using these features:
# ['lm_perplexity', 'lm_proba_and_rank', 'tm_activation', 'tm_gradient', 'tm_posterior', 'tm_saliency', 'tp_avg_word_length', 'tp_bert', 'tp_is_first_word_lowercase', 'tp_num_alpha_chars', 'tp_num_cased_letters', 'tp_num_cased_word_switches', 'tp_num_chars', 'tp_num_digits', 'tp_num_lowercase_after_punctuation', 'tp_num_mixed_case_words', 'tp_num_multi_spaces', 'tp_num_non_ascii', 'tp_num_punctuation', 'tp_num_single_lowercase_letters', 'tp_num_words']
# --- output to data_tcab\detection-experiments\allocine\distilcamembert\fr+small\multiclass_with_clean\LR\all
# c:\Users\Baptiste\AppData\Local\pypoetry\Cache\virtualenvs\nlp-adversarial-attacks-ghBt6cj_-py3.10\lib\site-packages\torch\nn\modules\module.py:1117: UserWarning: Using a non-full backward hook when the forward contains multiple autograd Nodes is deprecated and will be removed in future versions. This hook will be missing some grad_input. Please use register_full_backward_hook to get the documented behavior.
#   warnings.warn("Using a non-full backward hook when the forward contains multiple autograd Nodes "
# --- loading from data_tcab\detection-experiments\allocine\distilcamembert\fr+small\multiclass_with_clean\train.joblib
# num of instances in the file:  6545
# loaded, labels:  Counter({'clean': 1187, 'input_reduction': 1187, 'textbugger': 1004, 'textfooler': 987, 'deepwordbug': 976, 'bae': 751, 'pwws': 453})
# --- loading from data_tcab\detection-experiments\allocine\distilcamembert\fr+small\multiclass_with_clean\val.joblib
# num of instances in the file:  2189
# loaded, labels:  Counter({'clean': 411, 'input_reduction': 411, 'textfooler': 336, 'deepwordbug': 334, 'textbugger': 328, 'bae': 228, 'pwws': 141})
# --- loading from data_tcab\detection-experiments\allocine\distilcamembert\fr+small\multiclass_with_clean\test_release.joblib
# num of instances in the file:  2891
# loaded, labels:  Counter({'clean': 2009, 'input_reduction': 204, 'textbugger': 165, 'deepwordbug': 163, 'textfooler': 162, 'bae': 116, 'pwws': 72})
# --- training main starting
# skip if done: False
#
# no. train: 6,545
# no. val: 2,189
# no. test: 2,891
# no. features: 4,539
#
# --- starting training
# --- finished training
# --- training time: 00:00:12
# {'train_accuracy': 0.9912910618792972, 'train_balanced_accuracy': 0.9919127021385593, 'train_confusion_matrix': [[751, 0, 0, 0, 0, 0, 0], [1, 1184, 1, 1, 0, 0, 0], [1, 0, 965, 0, 1, 7, 2], [0, 2, 0, 1185, 0, 0, 0], [0, 0, 0, 0, 453, 0, 0], [3, 0, 6, 0, 0, 980, 15], [4, 0, 1, 0, 0, 12, 970]]}
# {'validation_accuracy': 0.7313841936957515, 'validation_balanced_accuracy': 0.695410142995069, 'validation_confusion_matrix': [[125, 5, 14, 11, 9, 24, 40], [19, 362, 3, 5, 5, 8, 9], [17, 5, 239, 3, 11, 40, 19], [3, 1, 0, 406, 1, 0, 0], [20, 2, 8, 1, 79, 14, 17], [37, 8, 30, 1, 18, 199, 35], [40, 11, 18, 6, 29, 41, 191]]}
# {'test_accuracy': 0.8087167070217918, 'test_balanced_accuracy': 0.666552618768675, 'test_confusion_matrix': [[58, 5, 6, 6, 4, 17, 20], [86, 1747, 45, 15, 36, 37, 43], [15, 0, 109, 2, 3, 10, 24], [0, 1, 0, 202, 0, 0, 1], [9, 1, 5, 1, 36, 8, 12], [17, 1, 13, 2, 8, 96, 28], [26, 4, 8, 5, 9, 20, 90]]}
# --- saving metrics to data_tcab\detection-experiments\allocine\distilcamembert\fr+small\multiclass_with_clean\LR\all
#
# ### Running main with ['--experiment_dir', 'data_tcab/detection-experiments/allocine/distilcamembert/fr+small/multiclass_with_clean', '--feature_setting', 'all', '--model', 'RF', '--model_n_jobs', '10', '--disable_tune']
#
# starting experiment: data_tcab\detection-experiments\allocine\distilcamembert\fr+small\multiclass_with_clean
# CPU available : 16
# --- searching exp data in data_tcab\detection-experiments\allocine\distilcamembert\fr+small\multiclass_with_clean
# --- using these features:
# ['lm_perplexity', 'lm_proba_and_rank', 'tm_activation', 'tm_gradient', 'tm_posterior', 'tm_saliency', 'tp_avg_word_length', 'tp_bert', 'tp_is_first_word_lowercase', 'tp_num_alpha_chars', 'tp_num_cased_letters', 'tp_num_cased_word_switches', 'tp_num_chars', 'tp_num_digits', 'tp_num_lowercase_after_punctuation', 'tp_num_mixed_case_words', 'tp_num_multi_spaces', 'tp_num_non_ascii', 'tp_num_punctuation', 'tp_num_single_lowercase_letters', 'tp_num_words']
# --- output to data_tcab\detection-experiments\allocine\distilcamembert\fr+small\multiclass_with_clean\RF\all
# c:\Users\Baptiste\AppData\Local\pypoetry\Cache\virtualenvs\nlp-adversarial-attacks-ghBt6cj_-py3.10\lib\site-packages\torch\nn\modules\module.py:1117: UserWarning: Using a non-full backward hook when the forward contains multiple autograd Nodes is deprecated and will be removed in future versions. This hook will be missing some grad_input. Please use register_full_backward_hook to get the documented behavior.
#   warnings.warn("Using a non-full backward hook when the forward contains multiple autograd Nodes "
# --- loading from data_tcab\detection-experiments\allocine\distilcamembert\fr+small\multiclass_with_clean\train.joblib
# num of instances in the file:  6545
# loaded, labels:  Counter({'clean': 1187, 'input_reduction': 1187, 'textbugger': 1004, 'textfooler': 987, 'deepwordbug': 976, 'bae': 751, 'pwws': 453})
# --- loading from data_tcab\detection-experiments\allocine\distilcamembert\fr+small\multiclass_with_clean\val.joblib
# num of instances in the file:  2189
# loaded, labels:  Counter({'clean': 411, 'input_reduction': 411, 'textfooler': 336, 'deepwordbug': 334, 'textbugger': 328, 'bae': 228, 'pwws': 141})
# --- loading from data_tcab\detection-experiments\allocine\distilcamembert\fr+small\multiclass_with_clean\test_release.joblib
# num of instances in the file:  2891
# loaded, labels:  Counter({'clean': 2009, 'input_reduction': 204, 'textbugger': 165, 'deepwordbug': 163, 'textfooler': 162, 'bae': 116, 'pwws': 72})
# --- training main starting
# skip if done: False
#
# no. train: 6,545
# no. val: 2,189
# no. test: 2,891
# no. features: 4,539
#
# --- starting training
# --- finished training
# --- training time: 00:00:03
# {'train_accuracy': 0.598472116119175, 'train_balanced_accuracy': 0.5892460157603029, 'train_confusion_matrix': [[519, 8, 11, 52, 124, 30, 7], [139, 974, 7, 19, 45, 3, 0], [206, 14, 520, 35, 148, 50, 3], [2, 1, 2, 1179, 0, 0, 3], [109, 3, 20, 8, 299, 9, 5], [302, 13, 162, 28, 219, 269, 11], [306, 18, 109, 43, 247, 107, 157]]}
# {'validation_accuracy': 0.5733211512105985, 'validation_balanced_accuracy': 0.5512907298402732, 'validation_confusion_matrix': [[132, 4, 5, 24, 51, 10, 2], [33, 349, 1, 11, 16, 1, 0], [58, 3, 180, 15, 58, 17, 3], [0, 3, 4, 403, 1, 0, 0], [39, 2, 8, 2, 82, 5, 3], [93, 8, 56, 11, 78, 76, 6], [94, 10, 50, 16, 89, 44, 33]]}
# {'test_accuracy': 0.7305430646835005, 'test_balanced_accuracy': 0.5439862844580319, 'test_confusion_matrix': [[66, 4, 5, 8, 17, 13, 3], [190, 1668, 9, 55, 76, 8, 3], [27, 3, 87, 6, 28, 11, 1], [0, 1, 0, 202, 0, 1, 0], [13, 2, 5, 2, 44, 2, 4], [41, 1, 27, 4, 47, 37, 8], [48, 2, 28, 7, 48, 21, 8]]}
# --- saving metrics to data_tcab\detection-experiments\allocine\distilcamembert\fr+small\multiclass_with_clean\RF\all
#
# ### Running main with ['--experiment_dir', 'data_tcab/detection-experiments/allocine/distilcamembert/fr+small/multiclass_with_clean', '--feature_setting', 'all', '--model', 'LGB', '--model_n_jobs', '10', '--disable_tune']
#
# starting experiment: data_tcab\detection-experiments\allocine\distilcamembert\fr+small\multiclass_with_clean
# CPU available : 16
# --- searching exp data in data_tcab\detection-experiments\allocine\distilcamembert\fr+small\multiclass_with_clean
# --- using these features:
# ['lm_perplexity', 'lm_proba_and_rank', 'tm_activation', 'tm_gradient', 'tm_posterior', 'tm_saliency', 'tp_avg_word_length', 'tp_bert', 'tp_is_first_word_lowercase', 'tp_num_alpha_chars', 'tp_num_cased_letters', 'tp_num_cased_word_switches', 'tp_num_chars', 'tp_num_digits', 'tp_num_lowercase_after_punctuation', 'tp_num_mixed_case_words', 'tp_num_multi_spaces', 'tp_num_non_ascii', 'tp_num_punctuation', 'tp_num_single_lowercase_letters', 'tp_num_words']
# --- output to data_tcab\detection-experiments\allocine\distilcamembert\fr+small\multiclass_with_clean\LGB\all
# c:\Users\Baptiste\AppData\Local\pypoetry\Cache\virtualenvs\nlp-adversarial-attacks-ghBt6cj_-py3.10\lib\site-packages\torch\nn\modules\module.py:1117: UserWarning: Using a non-full backward hook when the forward contains multiple autograd Nodes is deprecated and will be removed in future versions. This hook will be missing some grad_input. Please use register_full_backward_hook to get the documented behavior.
#   warnings.warn("Using a non-full backward hook when the forward contains multiple autograd Nodes "
# --- loading from data_tcab\detection-experiments\allocine\distilcamembert\fr+small\multiclass_with_clean\train.joblib
# num of instances in the file:  6545
# loaded, labels:  Counter({'clean': 1187, 'input_reduction': 1187, 'textbugger': 1004, 'textfooler': 987, 'deepwordbug': 976, 'bae': 751, 'pwws': 453})
# --- loading from data_tcab\detection-experiments\allocine\distilcamembert\fr+small\multiclass_with_clean\val.joblib
# num of instances in the file:  2189
# loaded, labels:  Counter({'clean': 411, 'input_reduction': 411, 'textfooler': 336, 'deepwordbug': 334, 'textbugger': 328, 'bae': 228, 'pwws': 141})
# --- loading from data_tcab\detection-experiments\allocine\distilcamembert\fr+small\multiclass_with_clean\test_release.joblib
# num of instances in the file:  2891
# loaded, labels:  Counter({'clean': 2009, 'input_reduction': 204, 'textbugger': 165, 'deepwordbug': 163, 'textfooler': 162, 'bae': 116, 'pwws': 72})
# --- training main starting
# skip if done: False
#
# no. train: 6,545
# no. val: 2,189
# no. test: 2,891
# no. features: 4,539
#
# --- starting training
# --- finished training
# --- training time: 00:00:55
# {'train_accuracy': 0.9951107715813599, 'train_balanced_accuracy': 0.9954758403313276, 'train_confusion_matrix': [[751, 0, 0, 0, 0, 0, 0], [0, 1185, 0, 2, 0, 0, 0], [0, 0, 973, 0, 0, 3, 0], [0, 1, 0, 1186, 0, 0, 0], [0, 0, 0, 0, 453, 0, 0], [1, 0, 1, 0, 0, 988, 14], [3, 0, 0, 0, 0, 7, 977]]}
# {'validation_accuracy': 0.737779808131567, 'validation_balanced_accuracy': 0.6949154042136808, 'validation_confusion_matrix': [[142, 4, 9, 10, 8, 22, 33], [12, 377, 5, 1, 4, 5, 7], [12, 3, 255, 2, 4, 33, 25], [1, 2, 1, 404, 1, 1, 1], [29, 2, 8, 0, 64, 16, 22], [43, 5, 28, 2, 9, 191, 50], [48, 11, 24, 4, 21, 46, 182]]}
# {'test_accuracy': 0.8222068488412314, 'test_balanced_accuracy': 0.6616753051589982, 'test_confusion_matrix': [[62, 5, 9, 2, 3, 13, 22], [93, 1788, 21, 10, 18, 33, 46], [14, 2, 113, 2, 3, 15, 14], [0, 1, 0, 201, 0, 1, 1], [12, 1, 8, 1, 29, 4, 17], [18, 1, 21, 2, 5, 88, 30], [27, 1, 13, 2, 10, 13, 96]]}
# --- saving metrics to data_tcab\detection-experiments\allocine\distilcamembert\fr+small\multiclass_with_clean\LGB\all

# %%
print(f"Total time: {time.strftime('%H:%M:%S', time.gmtime(time.time()-t))}")
# Out:
# Total time: 00:20:36
